# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl

CROP = 256
image_size = (CROP,CROP)

# %%
def anisodiff(img,niter=1,lambd=50,gamma=0.1,step=(1.,1.),sigma=0, option=1,ploton=False):

    img = img.astype('float32')
    imgout = img.copy()

    deltaS = np.zeros_like(imgout)
    deltaE = deltaS.copy()
    NS = deltaS.copy()
    EW = deltaS.copy()
    gS = np.ones_like(imgout)
    gE = gS.copy()

    if ploton:

        fig = pl.figure(figsize=(20,5.5),num="Anisotropic diffusion")
        ax1,ax2 = fig.add_subplot(1,2,1),fig.add_subplot(1,2,2)

        ax1.imshow(img,interpolation='nearest')
        ih = ax2.imshow(imgout,interpolation='nearest',animated=True)
        ax1.set_title("Original image")
        ax2.set_title("Iteration 0")

        fig.canvas.draw()

    for ii in np.arange(1,niter):

        deltaS[:-1,: ] = np.diff(imgout,axis=0)
        deltaE[: ,:-1] = np.diff(imgout,axis=1)

        if 0<sigma:
            deltaSf=flt.gaussian_filter(deltaS,sigma);
            deltaEf=flt.gaussian_filter(deltaE,sigma);
        else: 
            deltaSf=deltaS;
            deltaEf=deltaE;

        if option == 1:
            gS = np.exp(-(deltaSf/lambd)**2.)/step[0]
            gE = np.exp(-(deltaEf/lambd)**2.)/step[1]
        elif option == 2:
            gS = 1./(1.+(deltaSf/lambd)**2.)/step[0]
            gE = 1./(1.+(deltaEf/lambd)**2.)/step[1]
        elif option == 3:
            gS = lambd/step[0]
            gE = lambd/step[1]

        E = gE*deltaE
        S = gS*deltaS

        NS[:] = S
        EW[:] = E
        NS[1:,:] -= S[:-1,:]
        EW[:,1:] -= E[:,:-1]


        imgout += gamma*(NS+EW)

        if ploton:
            iterstring = "Iteration %i" %(ii+1)
            ih.set_data(imgout)
            ax2.set_title(iterstring)
            fig.canvas.draw()

            

    return imgout

# %% [markdown]
# # Examining data set

# %%
ncols = 4
nrows = 3

fig,axs = plt.subplots(nrows = nrows,ncols = ncols,figsize=(20,10))
test = glob('../../images/test/*.jpg')
train = glob('../../images/train/*.jpg')
val = glob('../../images/val/*.jpg')

imgs = [train,test,val]
titles = ['train','test','val']

for i in range(len(imgs)):
    for j in range(ncols):
        _ = np.random.choice(imgs[i])
        axs[i,j].imshow(cv2.imread(_,cv2.IMREAD_GRAYSCALE),cmap = 'gray')
        axs[i,j].set_xticks([])
        axs[i,j].set_xticklabels([])
        axs[i,j].set_yticks([])
        axs[i,j].set_yticklabels([])
        axs[i,j].set_title(titles[i])
        
        
plt.show()

# %% [markdown]
# # Blur

# %%
def augment(yx, crop=256, do_flips=True, do_rotate=True, do_scale=False):
    
    ch, cw = yx[0].shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((cw/2,ch/2),np.random.randint(-90,90),1)
    yx[0] = cv2.warpAffine(yx[0],rotation_matrix, (ch,cw),cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
    yx[1] = cv2.warpAffine(yx[1],rotation_matrix, (ch,cw),cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
    
    return yx

# %%
def open_frame(frame_num,var=1):
    input_path = frame_num
    
    img = np.asarray(cv2.cvtColor(cv2.imread(input_path), cv2.COLOR_BGR2GRAY), dtype=np.float32)
    img = cv2.resize(img,(CROP,CROP))
    input_channel = img/np.amax(img)
    gausBlur = cv2.blur(input_channel, (var,var)) 
    gausBlur = gausBlur/np.amax(gausBlur)
    
    return [input_channel, gausBlur]

# %%
ncols = 4
nrows = 3

fig,axs = plt.subplots(nrows = nrows,ncols = ncols,figsize=(20,10))
test = glob('../../images/test/*.jpg')
train = glob('../../images/train/*.jpg')
val = glob('../../images/val/*.jpg')

imgs = [train,test,val]
titles = ['train','test','val']
var = np.asarray(np.linspace(2,10,ncols),dtype='int')

for i in range(len(imgs)):
    for j in range(ncols):
        _ = np.random.choice(imgs[i])
        im = open_frame(_,var[j])
        axs[i,j].imshow(im[1],cmap = 'gray')
        axs[i,j].set_xticks([])
        axs[i,j].set_xticklabels([])
        axs[i,j].set_yticks([])
        axs[i,j].set_yticklabels([])
        axs[i,j].set_title(f'{titles[i]} kernel size: {var[j]}')
        
        
plt.show()

# %% [markdown]
# ## Data augmentation

# %%
N_REPEAT_FRAME = 1

def sample_images(frame_nums):
    while True:
        try:
            img = open_frame(np.random.choice(frame_nums),var)
        except Exception as e:
            print(f'Exception {e} on file')
            #continue
            break
        for n in range(N_REPEAT_FRAME):
            img = open_frame(np.random.choice(frame_nums),var)
            a =  augment(img, do_flips=True, do_rotate=True, do_scale=True)
            yield a

# %%
def get_data_generator(sampler,var):
    def get_data():
        while True:
            yx = next(sampler)
            x,y = yx[1],yx[0]
            yield np.expand_dims(x,axis=-1),np.expand_dims(y,axis=-1)
        
    return get_data

# %%
var = 5

# %%
BATCH_SIZE = 10

dg_train = tf.data.Dataset.from_generator(
    get_data_generator(sample_images(train),var),
    output_types=(tf.float32, tf.float32),
    output_shapes=((CROP, CROP, 1),(CROP, CROP, 1)) )

dg_val = tf.data.Dataset.from_generator(
    get_data_generator(sample_images(test),var),
    output_types=(tf.float32, tf.float32),
    output_shapes=((CROP, CROP, 1),(CROP, CROP, 1)) )

gen_batch_train = dg_train.batch(BATCH_SIZE)
gen_batch_val = dg_val.batch(BATCH_SIZE)

# %%
xs, ys = next(gen_batch_train.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs))
        axs[i,2*j].imshow(np.squeeze(xs[_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        
plt.show()

# %% [markdown]
# # Neural networks

# %%
def divergence_x(x):
    return(x[:,1:]-x[:,:-1])

def divergence_y(x):
    return(x[:,:,1:]-x[:,:,:-1])

def fourier(input_shape, typ,option=1, num_classes=2,kernel_size=4,pool_size=3):
    inputs = input_shape
    
    x = tf.keras.layers.Conv2D(32, kernel_size, strides=2, padding="same")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.Conv2D(64, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [16,32,64,128]:
        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.MaxPooling2D(pool_size, strides=2, padding="same")(x)

        # Project residual
        residual = tf.keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = tf.keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = tf.keras.layers.SeparableConv2D(1024, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
        
    activation = "linear"
    units = 1

    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(1, activation=activation,name=f'lambdas_{typ}')(x)
    outputs = tf.keras.layers.Lambda(lambda z: tf.math.pow(z,-2))(outputs)
    

    dx = tf.keras.layers.Lambda(divergence_x)(inputs)
    dy = tf.keras.layers.Lambda(divergence_y)(inputs)

    dx = tf.keras.layers.Lambda(lambda z:tf.image.resize(z,[CROP,CROP]))(dx)
    dy = tf.keras.layers.Lambda(lambda z:tf.image.resize(z,[CROP,CROP]))(dy)
    
    dx2 = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(dx)
    dy2 = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(dy)
    
    norm = tf.keras.layers.add([dx2,dy2])
    
    if option == 1:
        coeff = tf.keras.layers.multiply([outputs,norm])
        coeff = tf.keras.layers.Lambda(lambda z: tf.math.exp(-z),name=f'coeff_{typ}')(coeff)
    elif option == 2:
        coeff = tf.keras.layers.multiply([outputs,norm])
        coeff = tf.keras.layers.Lambda(lambda z: 1./(1. + z),name=f'coeff_{typ}')(coeff)
        
    outputs_x = tf.keras.layers.multiply([coeff,dx])
    outputs_y = tf.keras.layers.multiply([coeff,dy])

    outputs_x = tf.keras.layers.Lambda(divergence_x)(outputs_x)
    outputs_y = tf.keras.layers.Lambda(divergence_y)(outputs_y)

    outputs_x = tf.keras.layers.Lambda(lambda x:tf.image.resize(x,[CROP,CROP]))(outputs_x)
    outputs_y = tf.keras.layers.Lambda(lambda x:tf.image.resize(x,[CROP,CROP]))(outputs_y)

    outputs = tf.keras.layers.add([outputs_x,outputs_y])
    #outputs = tf.keras.layers.Conv2D(1,1,activation="linear",padding="same")(outputs)
    outputs = tf.keras.layers.add([outputs,inputs])
    return outputs

def iteration(input_shape, option=1, num_classes=2,kernel_size=4):
    inputs = tf.keras.Input(shape=input_shape)
    inputs_r = tf.keras.layers.Lambda(lambda x:tf.math.real(tf.signal.fft2d(tf.dtypes.complex(x,0.))))(inputs)
    inputs_i = tf.keras.layers.Lambda(lambda x:tf.math.imag(tf.signal.fft2d(tf.dtypes.complex(x,0.))))(inputs)
    
    outputs_r = fourier(inputs_r,option=option,num_classes=num_classes,typ='real')
    outputs_i = fourier(inputs_i,option=option,num_classes=num_classes,typ='imag')
    
    outputs = tf.keras.layers.Lambda(lambda x:tf.math.real(tf.signal.ifft2d(tf.dtypes.complex(x[0],x[1]))))([outputs_r,outputs_i])
    return tf.keras.models.Model(inputs, outputs)

# %%
it_lim = 10
class Model(tf.keras.Model):    

    def __init__(self, network):
        super(Model, self).__init__()
        self.network = network
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")

        
    def call(self, inputs):
        return self.network(inputs)

    def train_step(self, data):
        x, y = data
        z = x        

        with tf.GradientTape() as tape:
            loss = self._compute_loss(data,True)
            
        gradients = tape.gradient(loss, self.network.trainable_weights)
        
        self.optimizer.apply_gradients(
            zip(gradients, self.network.trainable_weights)
        )


        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}
    
    def test_step(self, data):
        
        x, y = data
        z = x
        
        for i in range(it_lim):
            z = self.network(z,training=False)
        loss = self._compute_loss((x, y),False)
        self.compiled_loss(y,z)

        # Update the metrics.
        self.compiled_metrics.update_state(y, z)
        
        return {"loss":loss}
        


    
    def _compute_loss(self, data,train):

        x, y = data
        z = x
        for i in range(it_lim):
            z = self.network(z,training=train)
            
        return tf.keras.losses.MeanSquaredError()(y,z)

# %%
denoising = iteration(input_shape=image_size + (1,), num_classes=1,)
model = Model(denoising)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
        loss='mse',)
denoising.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 256, 256, 1)  0           ['input_1[0][0]']
#
#  lambda_1 (Lambda)              (None, 256, 256, 1)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 32  544         ['lambda[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 32  544         ['lambda_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 32  128        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_11 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  32832       ['activation[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 64  32832       ['activation_11[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 64  256        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  activation_1 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_12 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  activation_13 (Activation)     (None, 128, 128, 64  0           ['activation_12[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 128, 128, 16  2064       ['activation_2[0][0]']
#  v2D)                           )
#
#  separable_conv2d_9 (SeparableC  (None, 128, 128, 16  2064       ['activation_13[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 16  64         ['separable_conv2d_9[0][0]']
#  ormalization)                  )
#
#  activation_3 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_14 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 128, 128, 16  528        ['activation_3[0][0]']
#  onv2D)                         )
#
#  separable_conv2d_10 (Separable  (None, 128, 128, 16  528        ['activation_14[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 16  64         ['separable_conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 16  64         ['separable_conv2d_10[0][0]']
#  ormalization)                  )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 16)   1040        ['activation_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 16)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 16)   1040        ['activation_12[0][0]']
#
#  add (Add)                      (None, 64, 64, 16)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 16)   0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 16)   0           ['add[0][0]']
#
#  activation_15 (Activation)     (None, 64, 64, 16)   0           ['add_7[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 64, 64, 32)  800         ['activation_4[0][0]']
#  onv2D)
#
#  separable_conv2d_11 (Separable  (None, 64, 64, 32)  800         ['activation_15[0][0]']
#  Conv2D)
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 32)  128         ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 32)  128         ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_4[0][0]']
#
#  activation_16 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 64, 64, 32)  1568        ['activation_5[0][0]']
#  onv2D)
#
#  separable_conv2d_12 (Separable  (None, 64, 64, 32)  1568        ['activation_16[0][0]']
#  Conv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 32)  128         ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 32)  128         ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 32)   544         ['add[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 32)   544         ['add_7[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 32)   0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  add_8 (Add)                    (None, 32, 32, 32)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 32)   0           ['add_1[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 32)   0           ['add_8[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 32, 32, 64)  2624        ['activation_6[0][0]']
#  onv2D)
#
#  separable_conv2d_13 (Separable  (None, 32, 32, 64)  2624        ['activation_17[0][0]']
#  Conv2D)
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 64)  256         ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 32, 32, 64)  5184        ['activation_7[0][0]']
#  onv2D)
#
#  separable_conv2d_14 (Separable  (None, 32, 32, 64)  5184        ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 64)   2112        ['add_1[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 64)   2112        ['add_8[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 64)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  add_9 (Add)                    (None, 16, 16, 64)   0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 64)   0           ['add_2[0][0]']
#
#  activation_19 (Activation)     (None, 16, 16, 64)   0           ['add_9[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 16, 16, 128)  9344       ['activation_8[0][0]']
#  onv2D)
#
#  separable_conv2d_15 (Separable  (None, 16, 16, 128)  9344       ['activation_19[0][0]']
#  Conv2D)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 128)  512        ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 128)  512        ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_8[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_19[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 16, 16, 128)  18560      ['activation_9[0][0]']
#  onv2D)
#
#  separable_conv2d_16 (Separable  (None, 16, 16, 128)  18560      ['activation_20[0][0]']
#  Conv2D)
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 128)  512        ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 128)  512        ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 128)    8320        ['add_2[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 128)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 128)    8320        ['add_9[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 128)    0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  add_10 (Add)                   (None, 8, 8, 128)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 8, 8, 1024)  134144      ['add_3[0][0]']
#  onv2D)
#
#  separable_conv2d_17 (Separable  (None, 8, 8, 1024)  134144      ['add_10[0][0]']
#  Conv2D)
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 1024)  4096        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 1024)  4096        ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_10[0][0]']
#
#  activation_21 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_21[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['activation_10[0][0]']
#  alAveragePooling2D)
#
#  lambda_3 (Lambda)              (None, 255, 256, 1)  0           ['lambda[0][0]']
#
#  lambda_4 (Lambda)              (None, 256, 255, 1)  0           ['lambda[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['activation_21[0][0]']
#  obalAveragePooling2D)
#
#  lambda_14 (Lambda)             (None, 255, 256, 1)  0           ['lambda_1[0][0]']
#
#  lambda_15 (Lambda)             (None, 256, 255, 1)  0           ['lambda_1[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  lambda_5 (Lambda)              (None, 256, 256, 1)  0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 256, 256, 1)  0           ['lambda_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  lambda_16 (Lambda)             (None, 256, 256, 1)  0           ['lambda_14[0][0]']
#
#  lambda_17 (Lambda)             (None, 256, 256, 1)  0           ['lambda_15[0][0]']
#
#  lambdas_real (Dense)           (None, 1)            1025        ['dropout[0][0]']
#
#  lambda_7 (Lambda)              (None, 256, 256, 1)  0           ['lambda_5[0][0]']
#
#  lambda_8 (Lambda)              (None, 256, 256, 1)  0           ['lambda_6[0][0]']
#
#  lambdas_imag (Dense)           (None, 1)            1025        ['dropout_1[0][0]']
#
#  lambda_18 (Lambda)             (None, 256, 256, 1)  0           ['lambda_16[0][0]']
#
#  lambda_19 (Lambda)             (None, 256, 256, 1)  0           ['lambda_17[0][0]']
#
#  lambda_2 (Lambda)              (None, 1)            0           ['lambdas_real[0][0]']
#
#  add_4 (Add)                    (None, 256, 256, 1)  0           ['lambda_7[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambdas_imag[0][0]']
#
#  add_11 (Add)                   (None, 256, 256, 1)  0           ['lambda_18[0][0]',
#                                                                   'lambda_19[0][0]']
#
#  multiply (Multiply)            (None, 256, 256, 1)  0           ['lambda_2[0][0]',
#                                                                   'add_4[0][0]']
#
#  multiply_3 (Multiply)          (None, 256, 256, 1)  0           ['lambda_13[0][0]',
#                                                                   'add_11[0][0]']
#
#  coeff_real (Lambda)            (None, 256, 256, 1)  0           ['multiply[0][0]']
#
#  coeff_imag (Lambda)            (None, 256, 256, 1)  0           ['multiply_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 256, 256, 1)  0           ['coeff_real[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 256, 256, 1)  0           ['coeff_real[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  multiply_4 (Multiply)          (None, 256, 256, 1)  0           ['coeff_imag[0][0]',
#                                                                   'lambda_16[0][0]']
#
#  multiply_5 (Multiply)          (None, 256, 256, 1)  0           ['coeff_imag[0][0]',
#                                                                   'lambda_17[0][0]']
#
#  lambda_9 (Lambda)              (None, 255, 256, 1)  0           ['multiply_1[0][0]']
#
#  lambda_10 (Lambda)             (None, 256, 255, 1)  0           ['multiply_2[0][0]']
#
#  lambda_20 (Lambda)             (None, 255, 256, 1)  0           ['multiply_4[0][0]']
#
#  lambda_21 (Lambda)             (None, 256, 255, 1)  0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 256, 256, 1)  0           ['lambda_9[0][0]']
#
#  lambda_12 (Lambda)             (None, 256, 256, 1)  0           ['lambda_10[0][0]']
#
#  lambda_22 (Lambda)             (None, 256, 256, 1)  0           ['lambda_20[0][0]']
#
#  lambda_23 (Lambda)             (None, 256, 256, 1)  0           ['lambda_21[0][0]']
#
#  add_5 (Add)                    (None, 256, 256, 1)  0           ['lambda_11[0][0]',
#                                                                   'lambda_12[0][0]']
#
#  add_12 (Add)                   (None, 256, 256, 1)  0           ['lambda_22[0][0]',
#                                                                   'lambda_23[0][0]']
#
#  add_6 (Add)                    (None, 256, 256, 1)  0           ['add_5[0][0]',
#                                                                   'lambda[0][0]']
#
#  add_13 (Add)                   (None, 256, 256, 1)  0           ['add_12[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_24 (Lambda)             (None, 256, 256, 1)  0           ['add_6[0][0]',
#                                                                   'add_13[0][0]']
#
# ==================================================================================================
# Total params: 455,266
# Trainable params: 448,866
# Non-trainable params: 6,400
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath= f"./checkpoints/deblurring_fourier_{var}",
    save_weights_only=True,
    verbose = True,
    save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1)
]

# %%
history = model.fit(
        gen_batch_train,
        epochs=5,
        steps_per_epoch=5,
        validation_data=gen_batch_val,
        validation_steps=2,
        shuffle=False,
        use_multiprocessing=True,
        callbacks=callbacks,
        workers=1
    )
# Out:
# Epoch 1/5
# 2022-10-26 19:28:06.738226: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8302
# 2022-10-26 19:28:07.791883: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 5/5 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 00001: val_loss improved from inf to 0.00484, saving model to ./checkpoints/deblurring_fourier_5
# 5/5 [==============================] - 31s 3s/step - loss: 0.0094 - val_loss: 0.0048 - lr: 0.0010
# Epoch 2/5
# 5/5 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 00002: val_loss did not improve from 0.00484
# 5/5 [==============================] - 6s 1s/step - loss: 0.0073 - val_loss: 0.0052 - lr: 0.0010
# Epoch 3/5
# 5/5 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 00003: val_loss improved from 0.00484 to 0.00316, saving model to ./checkpoints/deblurring_fourier_5
# 5/5 [==============================] - 6s 1s/step - loss: 0.0076 - val_loss: 0.0032 - lr: 0.0010
# Epoch 4/5
# 5/5 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00004: val_loss did not improve from 0.00316
# 5/5 [==============================] - 6s 1s/step - loss: 0.0059 - val_loss: 0.0047 - lr: 0.0010
# Epoch 5/5
# 5/5 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 00005: val_loss did not improve from 0.00316
# 5/5 [==============================] - 6s 1s/step - loss: 0.0063 - val_loss: 0.0045 - lr: 0.0010

# %% [markdown]
# # Results

# %%
n = len(glob('./history/debluring_fourier*'))
viridis = cm.get_cmap('viridis', 256)
colors = viridis(np.linspace(0, 1, n//2))
newcmp = ListedColormap(colors)


fig,axs = plt.subplots(nrows = 2,ncols=2,figsize=(15,7))
w = np.arange(4,15,1)
ylab = ['mse','mse']
titles = ['train loss','val loss']
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))
ct = [tuple(i) for i in colors]

trained = glob('./history/debluring_fourier*')
for m,i in enumerate(trained):
    hist = np.load(i)
    if '_2_kernel3.npy' in i:
        for j in range(len(hist)-1):
            c = int(i.split('_')[-3])-np.amin(w)
            if j%2 == 0:
                im = axs[1,j].plot(np.array(hist[j]),color = colors[c],label=str(w[c]))
            else:
                im = axs[1,j].plot(np.array(hist[j]),color = colors[c],label=str(w[c]))
                
            axs[1,j].set_title(f'{titles[j]}\noption 2')
            axs[1,j].set_xlabel('iterations')
            axs[1,j].set_ylabel(ylab[int(j%2)])
            

            
        
    else:
        for j in range(len(hist)-1):
            c = int(i.split('_')[-3])-np.amin(w)
            if j%2 == 0:
                axs[0,j].plot(np.array(hist[j]),color = colors[c],label=str(w[c]))
            else:
                axs[0,j].plot(np.array(hist[j]),color = colors[c],label=str(w[c]))
                
            axs[0,j].set_title(f'{titles[j]}\noption 1')
            axs[0,j].set_xlabel('iterations')
            axs[0,j].set_ylabel(ylab[int(j%2)])
    
    
    
for j in range(len(hist)-1):
    plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[0,j],label='kernel size')
    plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[1,j],label='kernel size')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Results with first function

# %%
denoising = iteration(input_shape=image_size + (1,), num_classes=1,option=2)
model = Model(denoising)

# %%
_ = np.random.choice(len(val))
skip = 3
fig,axs = plt.subplots(ncols = 5,nrows = int(np.ceil(len(w)/skip)),figsize=(15,20))

for i,m in enumerate(w):
    if i%skip != 0:
        continue
    
    model.load_weights(f"./checkpoints/deblurring_fourier_{int(w[i])}_1_kernel3")
    im = open_frame(val[_],var = w[i])
    IM = np.copy(im)
    psnr_0 = tf.image.psnr(np.array([np.expand_dims(im[0],axis=-1)]),np.array([np.expand_dims(im[1],axis=-1)]),1)[0]
    ssim_0 = tf.image.ssim(np.array([np.expand_dims(im[0],axis=-1)]),np.array([np.expand_dims(im[1],axis=-1)]),1)[0]
    clean = model(np.array([np.expand_dims(im[1],axis=-1)]))
    psnr = tf.image.psnr(np.array([np.expand_dims(im[0],axis=-1)]),clean,1)[0]
    ssim = tf.image.ssim(np.array([np.expand_dims(im[0],axis=-1)]),clean,1)[0]
    clean = np.squeeze(clean[0])
    inputs = tf.keras.Input(shape=image_size + (1,))
    visualization = tf.keras.models.Model(model.network.input,model.network.get_layer('coeff_real').output)
    vis = np.squeeze(visualization(np.array([np.expand_dims(im[1],axis=-1)]))[0])
    lambdas = tf.keras.models.Model(model.network.input,model.network.get_layer('lambdas_real').output)
    l = np.squeeze(lambdas(np.array([np.expand_dims(im[1],axis=-1)]))[0])
    
    axs[i//skip,0].imshow(im[1],cmap='gray')
    axs[i//skip,0].set_title(f'input\nvariance of noise: {int(100*m)/100}\nPSNR: {psnr_0}\nSSIM: {ssim_0}')
    axs[i//skip,0].set_xticks([])
    axs[i//skip,0].set_xticklabels([])
    axs[i//skip,0].set_yticks([])
    axs[i//skip,0].set_yticklabels([])
    axs[i//skip,1].imshow(im[0],cmap='gray')
    axs[i//skip,1].set_title(f'target')
    axs[i//skip,1].set_xticks([])
    axs[i//skip,1].set_xticklabels([])
    axs[i//skip,1].set_yticks([])
    axs[i//skip,1].set_yticklabels([])
    axs[i//skip,3].imshow(clean,cmap='gray')
    axs[i//skip,3].set_title(f'result\nPSNR: {psnr}\nSSIM: {ssim}')
    axs[i//skip,3].set_xticks([])
    axs[i//skip,3].set_xticklabels([])
    axs[i//skip,3].set_yticks([])
    axs[i//skip,3].set_yticklabels([])
    im = axs[i//skip,4].imshow(vis,cmap='gray',vmin=0,vmax=1)
    axs[i//skip,4].set_title(f'coefficient function\nlambda {np.abs(l)}')
    plt.colorbar(im,ax=axs[i//skip,4],fraction=0.05)
    axs[i//skip,4].set_xticks([])
    axs[i//skip,4].set_xticklabels([])
    axs[i//skip,4].set_yticks([])
    axs[i//skip,4].set_yticklabels([])
    
    pm = np.squeeze(anisodiff(IM[1],niter=10,lambd=0.001))
    axs[i//skip,2].imshow(pm,cmap='gray')
    pm = np.expand_dims(pm,axis=-1)
    text = f'Perona Malik \n psnr: {tf.image.psnr(np.expand_dims(IM[0],axis=-1),pm,1).numpy()}\nssim {tf.image.ssim(np.expand_dims(IM[0],axis=-1),pm,1)}'
    axs[i//skip,2].set_title(text)
    axs[i//skip,2].set_xticklabels([])
    axs[i//skip,2].set_xticks([])
    axs[i//skip,2].set_yticklabels([])
    axs[i//skip,2].set_yticks([])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Results with second function

# %%
denoising = iteration(input_shape=image_size + (1,), num_classes=1,option=2)
model = Model(denoising)

# %%
_ = np.random.choice(len(val))
skip = 3
fig,axs = plt.subplots(ncols = 5,nrows = int(np.ceil(len(w)/skip)),figsize=(15,20))

for i,m in enumerate(w):
    if i%skip != 0:
        continue
    
    model.load_weights(f"./checkpoints/deblurring_fourier_{int(w[i])}_2_kernel3")
    im = open_frame(val[_],var = w[i])
    IM = np.copy(im)
    psnr_0 = tf.image.psnr(np.array([np.expand_dims(im[0],axis=-1)]),np.array([np.expand_dims(im[1],axis=-1)]),1)[0]
    ssim_0 = tf.image.ssim(np.array([np.expand_dims(im[0],axis=-1)]),np.array([np.expand_dims(im[1],axis=-1)]),1)[0]
    clean = model(np.array([np.expand_dims(im[1],axis=-1)]))
    psnr = tf.image.psnr(np.array([np.expand_dims(im[0],axis=-1)]),clean,1)[0]
    ssim = tf.image.ssim(np.array([np.expand_dims(im[0],axis=-1)]),clean,1)[0]
    clean = np.squeeze(clean[0])
    inputs = tf.keras.Input(shape=image_size + (1,))
    visualization = tf.keras.models.Model(model.network.input,model.network.get_layer('coeff_real').output)
    vis = np.squeeze(visualization(np.array([np.expand_dims(im[1],axis=-1)]))[0])
    lambdas = tf.keras.models.Model(model.network.input,model.network.get_layer('lambdas_real').output)
    l = np.squeeze(lambdas(np.array([np.expand_dims(im[1],axis=-1)]))[0])
    
    axs[i//skip,0].imshow(im[1],cmap='gray')
    axs[i//skip,0].set_title(f'input\nvariance of noise: {int(100*m)/100}\nPSNR: {psnr_0}\nSSIM: {ssim_0}')
    axs[i//skip,0].set_xticks([])
    axs[i//skip,0].set_xticklabels([])
    axs[i//skip,0].set_yticks([])
    axs[i//skip,0].set_yticklabels([])
    axs[i//skip,1].imshow(im[0],cmap='gray')
    axs[i//skip,1].set_title(f'target')
    axs[i//skip,1].set_xticks([])
    axs[i//skip,1].set_xticklabels([])
    axs[i//skip,1].set_yticks([])
    axs[i//skip,1].set_yticklabels([])
    axs[i//skip,3].imshow(clean,cmap='gray')
    axs[i//skip,3].set_title(f'result\nPSNR: {psnr}\nSSIM: {ssim}')
    axs[i//skip,3].set_xticks([])
    axs[i//skip,3].set_xticklabels([])
    axs[i//skip,3].set_yticks([])
    axs[i//skip,3].set_yticklabels([])
    im = axs[i//skip,4].imshow(vis,cmap='gray',vmin=0,vmax=1)
    axs[i//skip,4].set_title(f'coefficient function\nlambda {np.abs(l)}')
    plt.colorbar(im,ax=axs[i//skip,4],fraction=0.05)
    axs[i//skip,4].set_xticks([])
    axs[i//skip,4].set_xticklabels([])
    axs[i//skip,4].set_yticks([])
    axs[i//skip,4].set_yticklabels([])
    
    pm = np.squeeze(anisodiff(IM[1],niter=10,lambd=0.001))
    axs[i//skip,2].imshow(pm,cmap='gray')
    pm = np.expand_dims(pm,axis=-1)
    text = f'Perona Malik \n psnr: {tf.image.psnr(np.expand_dims(IM[0],axis=-1),pm,1).numpy()}\nssim {tf.image.ssim(np.expand_dims(IM[0],axis=-1),pm,1)}'
    axs[i//skip,2].set_title(text)
    axs[i//skip,2].set_xticklabels([])
    axs[i//skip,2].set_xticks([])
    axs[i//skip,2].set_yticklabels([])
    axs[i//skip,2].set_yticks([])
    
plt.tight_layout()
plt.show()
