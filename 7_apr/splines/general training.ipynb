# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)
size = 5
pre_smoothing = False
conv = True
sigma = 0.1


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-04-11 11:59:05.554771: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 11:59:06.106893: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/:/home/joel/anaconda3/lib/
# 2023-04-11 11:59:06.107433: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/:/home/joel/anaconda3/lib/
# 2023-04-11 11:59:06.107438: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=30,var1_u=60,CROP1=CROP,BATCH_SIZE=5,N_REPEAT_FRAME1=10)
# Out:
# 2023-04-11 11:59:06.859742: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:06.859957: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:06.865041: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:06.865256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:06.865432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:06.865601: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:06.866105: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 11:59:07.003678: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.003860: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.004016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.004159: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.004301: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.004443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.549635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.549858: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.550073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.550255: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.550425: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.550573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22237 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-04-11 11:59:07.550841: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 11:59:07.550982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22328 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:43:00.0, compute capability: 8.6

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs))
        axs[i,2*j].imshow(np.squeeze(xs[_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        #axs[i,2*j].set_title(str(np.mean(xs[_])))
        
plt.show()

# %% [markdown]
# # Training

# %%
class losses:
    def Linfty(y_true,y_pred):
        error = tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(y_true-y_pred))))
        return error

    def W1infty(y_true,y_pred):
        error = tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(y_true-y_pred))))

        dx_true,dy_true = tf.image.image_gradients(y_true)
        dx_pred,dy_pred = tf.image.image_gradients(y_pred)

        error += tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(dx_true-dx_pred))))
        error += tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(dy_true-dy_pred))))


        return error

    def H1(y_true,y_pred):
        error = tf.math.reduce_mean(tf.pow(y_true-y_pred,2))

        dx_true,dy_true = tf.image.image_gradients(y_true)
        dx_pred,dy_pred = tf.image.image_gradients(y_pred)

        error += tf.math.reduce_mean(tf.pow(dx_true-dx_pred,2))
        error += tf.math.reduce_mean(tf.pow(dy_true-dy_pred,2))
        error = tf.sqrt(error)

        return error

    def L2(y_true,y_pred):
        error = tf.math.reduce_mean(tf.pow(y_true-y_pred,2))  

        return error
    
    def probability(y_true,y_pred):
        error = -tf.image.ssim(y_true,y_pred,1)

        return error
    
    def psnr(y_true,y_pred):
        return -tf.image.psnr(y_true,y_pred,1)


losses_names = ['H1','L2']

# %%
architectures = ['splines','decreasing','flux']

for N_REPEAT_FRAME1 in [1,10,30]:

    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=55,CROP1=CROP,BATCH_SIZE=30,
                                                   N_REPEAT_FRAME1=N_REPEAT_FRAME1)

    for arch in architectures:
        print(arch)

        for loss in losses_names:
            print(loss)

            order = 1
            for num_classes in [5,20,50]:
                print('num_classes: ',num_classes)
                
                if len(glob(f'../{arch}/history/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_f.npy')) > 0:
                    print(glob(f'../{arch}/history/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_f.npy'))
                    continue



                model = get_model(arch,it_lim=10,image_size=image_size,num_classes = num_classes,
                                 second=False)
                model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                        loss=getattr(losses,loss))

                callbacks = [tf.keras.callbacks.ModelCheckpoint(
                filepath= f"../{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_f",
                save_weights_only=True,
                verbose = True,
                save_best_only=True),
                tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1,patience=5),
                tf.keras.callbacks.TerminateOnNaN()

                ]

                history = model.fit(
                    gen_batch_train,
                    epochs=50,
                    steps_per_epoch=100,
                    validation_data=gen_batch_val,
                    validation_steps=10,
                    shuffle=False,
                    use_multiprocessing=True,
                    callbacks=callbacks,
                    workers=1
                )

                np.save(f'../{arch}/history/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_f.npy',np.array([history.history['loss'],history.history['val_loss']]))
# Out:
# splines
# H1
# num_classes:  5
# ['../splines/history/splinesH1_gaussian_5_1_f.npy']
# num_classes:  20
# ['../splines/history/splinesH1_gaussian_20_1_f.npy']
# num_classes:  50
# ['../splines/history/splinesH1_gaussian_50_1_f.npy']
# L2
# num_classes:  5
# ['../splines/history/splinesL2_gaussian_5_1_f.npy']
# num_classes:  20
# ['../splines/history/splinesL2_gaussian_20_1_f.npy']
# num_classes:  50
# ['../splines/history/splinesL2_gaussian_50_1_f.npy']
# decreasing
# H1
# num_classes:  5
# ['../decreasing/history/decreasingH1_gaussian_5_1_f.npy']
# num_classes:  20
# ['../decreasing/history/decreasingH1_gaussian_20_1_f.npy']
# num_classes:  50
# ['../decreasing/history/decreasingH1_gaussian_50_1_f.npy']
# L2
# num_classes:  5
# ['../decreasing/history/decreasingL2_gaussian_5_1_f.npy']
# num_classes:  20
# ['../decreasing/history/decreasingL2_gaussian_20_1_f.npy']
# num_classes:  50
# ['../decreasing/history/decreasingL2_gaussian_50_1_f.npy']
# flux
# H1
# num_classes:  5
# ['../flux/history/fluxH1_gaussian_5_1_f.npy']
# num_classes:  20
# ['../flux/history/fluxH1_gaussian_20_1_f.npy']
# num_classes:  50
# ['../flux/history/fluxH1_gaussian_50_1_f.npy']
# L2
# num_classes:  5
# ['../flux/history/fluxL2_gaussian_5_1_f.npy']
# num_classes:  20
# ['../flux/history/fluxL2_gaussian_20_1_f.npy']
# num_classes:  50
# ['../flux/history/fluxL2_gaussian_50_1_f.npy']
# splines
# H1
# num_classes:  5
# ['../splines/history/splinesH1_gaussian_5_10_f.npy']
# num_classes:  20
# ['../splines/history/splinesH1_gaussian_20_10_f.npy']
# num_classes:  50
# ['../splines/history/splinesH1_gaussian_50_10_f.npy']
# L2
# num_classes:  5
# ['../splines/history/splinesL2_gaussian_5_10_f.npy']
# num_classes:  20
# ['../splines/history/splinesL2_gaussian_20_10_f.npy']
# num_classes:  50
# ['../splines/history/splinesL2_gaussian_50_10_f.npy']
# decreasing
# H1
# num_classes:  5
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 8.7608
# Epoch 1: val_loss improved from inf to 0.10309, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_5_10_f
# 100/100 [==============================] - 35s 249ms/step - loss: 8.7608 - val_loss: 0.1031 - lr: 0.0010
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 8.0623
# Epoch 2: val_loss improved from 0.10309 to 0.09556, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_5_10_f
# 100/100 [==============================] - 23s 231ms/step - loss: 8.0623 - val_loss: 0.0956 - lr: 0.0010
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5304
# Epoch 3: val_loss did not improve from 0.09556
# 100/100 [==============================] - 23s 227ms/step - loss: 0.5304 - val_loss: 0.0961 - lr: 0.0010
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 28.1495
# Epoch 4: val_loss did not improve from 0.09556
# 100/100 [==============================] - 22s 219ms/step - loss: 28.1495 - val_loss: 904.8823 - lr: 0.0010
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 131.1272
# Epoch 5: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 131.1272 - val_loss: 216.9911 - lr: 0.0010
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 121.6739
# Epoch 6: val_loss did not improve from 0.09556
# 100/100 [==============================] - 22s 218ms/step - loss: 121.6739 - val_loss: 155.4222 - lr: 0.0010
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 92.4581
# Epoch 7: val_loss did not improve from 0.09556
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 100/100 [==============================] - 21s 214ms/step - loss: 92.4581 - val_loss: 124.0212 - lr: 0.0010
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 87.4653
# Epoch 8: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 87.4653 - val_loss: 128.5288 - lr: 2.0000e-04
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 84.8236
# Epoch 9: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 84.8236 - val_loss: 66.2964 - lr: 2.0000e-04
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 77.8766
# Epoch 10: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 77.8766 - val_loss: 86.7261 - lr: 2.0000e-04
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 73.8138
# Epoch 11: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 73.8138 - val_loss: 86.4053 - lr: 2.0000e-04
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 72.6884
# Epoch 12: val_loss did not improve from 0.09556
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 100/100 [==============================] - 21s 213ms/step - loss: 72.6884 - val_loss: 56.0050 - lr: 2.0000e-04
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 65.0051
# Epoch 13: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 65.0051 - val_loss: 59.3823 - lr: 4.0000e-05
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 65.7591
# Epoch 14: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 212ms/step - loss: 65.7591 - val_loss: 60.4232 - lr: 4.0000e-05
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 65.3760
# Epoch 15: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 215ms/step - loss: 65.3760 - val_loss: 62.8476 - lr: 4.0000e-05
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 64.0455
# Epoch 16: val_loss did not improve from 0.09556
# 100/100 [==============================] - 24s 239ms/step - loss: 64.0455 - val_loss: 111.9967 - lr: 4.0000e-05
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 65.1315
# Epoch 17: val_loss did not improve from 0.09556
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 100/100 [==============================] - 20s 203ms/step - loss: 65.1315 - val_loss: 37.2131 - lr: 4.0000e-05
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 63.7521
# Epoch 18: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 63.7521 - val_loss: 93.9869 - lr: 8.0000e-06
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 62.6591
# Epoch 19: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 62.6591 - val_loss: 80.0754 - lr: 8.0000e-06
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 64.2711
# Epoch 20: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 64.2711 - val_loss: 76.4006 - lr: 8.0000e-06
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 62.2072
# Epoch 21: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 215ms/step - loss: 62.2072 - val_loss: 81.2941 - lr: 8.0000e-06
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 62.3172
# Epoch 22: val_loss did not improve from 0.09556
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 100/100 [==============================] - 21s 213ms/step - loss: 62.3172 - val_loss: 97.2840 - lr: 8.0000e-06
# Epoch 23/50
# 100/100 [==============================] - ETA: 0s - loss: 60.5418
# Epoch 23: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 60.5418 - val_loss: 96.1320 - lr: 1.6000e-06
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 62.7893
# Epoch 24: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 62.7893 - val_loss: 83.5986 - lr: 1.6000e-06
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 61.3071
# Epoch 25: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 215ms/step - loss: 61.3071 - val_loss: 73.8921 - lr: 1.6000e-06
# Epoch 26/50
# 100/100 [==============================] - ETA: 0s - loss: 63.8379
# Epoch 26: val_loss did not improve from 0.09556
# 100/100 [==============================] - 22s 217ms/step - loss: 63.8379 - val_loss: 65.1463 - lr: 1.6000e-06
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 61.0591
# Epoch 27: val_loss did not improve from 0.09556
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 100/100 [==============================] - 21s 214ms/step - loss: 61.0591 - val_loss: 104.3656 - lr: 1.6000e-06
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 63.2913
# Epoch 28: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 215ms/step - loss: 63.2913 - val_loss: 54.6195 - lr: 3.2000e-07
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 64.6519
# Epoch 29: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 215ms/step - loss: 64.6519 - val_loss: 103.4696 - lr: 3.2000e-07
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 62.8591
# Epoch 30: val_loss did not improve from 0.09556
# 100/100 [==============================] - 24s 239ms/step - loss: 62.8591 - val_loss: 72.3003 - lr: 3.2000e-07
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 62.6279
# Epoch 31: val_loss did not improve from 0.09556
# 100/100 [==============================] - 19s 190ms/step - loss: 62.6279 - val_loss: 120.7433 - lr: 3.2000e-07
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 59.9617
# Epoch 32: val_loss did not improve from 0.09556
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 100/100 [==============================] - 21s 214ms/step - loss: 59.9617 - val_loss: 171.8956 - lr: 3.2000e-07
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 64.3174
# Epoch 33: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 64.3174 - val_loss: 77.8067 - lr: 6.4000e-08
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 63.2010
# Epoch 34: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 215ms/step - loss: 63.2010 - val_loss: 86.6721 - lr: 6.4000e-08
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 62.5128
# Epoch 35: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 211ms/step - loss: 62.5128 - val_loss: 96.4738 - lr: 6.4000e-08
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 65.4752
# Epoch 36: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 65.4752 - val_loss: 71.1689 - lr: 6.4000e-08
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 65.0263
# Epoch 37: val_loss did not improve from 0.09556
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 100/100 [==============================] - 21s 213ms/step - loss: 65.0263 - val_loss: 103.1952 - lr: 6.4000e-08
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 62.0879
# Epoch 38: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 62.0879 - val_loss: 66.5239 - lr: 1.2800e-08
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 62.7840
# Epoch 39: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 62.7840 - val_loss: 84.3839 - lr: 1.2800e-08
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 63.9137
# Epoch 40: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 63.9137 - val_loss: 88.6274 - lr: 1.2800e-08
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 62.0949
# Epoch 41: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 62.0949 - val_loss: 55.8699 - lr: 1.2800e-08
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 63.4732
# Epoch 42: val_loss did not improve from 0.09556
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 100/100 [==============================] - 21s 213ms/step - loss: 63.4732 - val_loss: 55.7316 - lr: 1.2800e-08
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 61.6917
# Epoch 43: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 61.6917 - val_loss: 91.7761 - lr: 2.5600e-09
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 62.5161
# Epoch 44: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 62.5161 - val_loss: 92.2320 - lr: 2.5600e-09
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 64.1609
# Epoch 45: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 216ms/step - loss: 64.1609 - val_loss: 56.6935 - lr: 2.5600e-09
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 61.7242
# Epoch 46: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 213ms/step - loss: 61.7242 - val_loss: 67.6460 - lr: 2.5600e-09
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 63.7215
# Epoch 47: val_loss did not improve from 0.09556
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 100/100 [==============================] - 21s 214ms/step - loss: 63.7215 - val_loss: 78.8102 - lr: 2.5600e-09
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 62.3092
# Epoch 48: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 62.3092 - val_loss: 67.6707 - lr: 5.1200e-10
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 62.0189
# Epoch 49: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 62.0189 - val_loss: 63.3365 - lr: 5.1200e-10
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 61.2257
# Epoch 50: val_loss did not improve from 0.09556
# 100/100 [==============================] - 21s 214ms/step - loss: 61.2257 - val_loss: 93.3489 - lr: 5.1200e-10
# num_classes:  20
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 2.9806
# Epoch 1: val_loss improved from inf to 0.13082, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 37s 274ms/step - loss: 2.9806 - val_loss: 0.1308 - lr: 0.0010
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5603
# Epoch 2: val_loss improved from 0.13082 to 0.08771, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5603 - val_loss: 0.0877 - lr: 0.0010
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0866
# Epoch 3: val_loss did not improve from 0.08771
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0866 - val_loss: 0.1006 - lr: 0.0010
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0859
# Epoch 4: val_loss did not improve from 0.08771
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0859 - val_loss: 0.1008 - lr: 0.0010
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0857
# Epoch 5: val_loss did not improve from 0.08771
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0857 - val_loss: 0.1015 - lr: 0.0010
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0846
# Epoch 6: val_loss did not improve from 0.08771
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0846 - val_loss: 0.0927 - lr: 0.0010
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0855
# Epoch 7: val_loss did not improve from 0.08771
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0855 - val_loss: 0.0906 - lr: 0.0010
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0823
# Epoch 8: val_loss did not improve from 0.08771
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0823 - val_loss: 0.0894 - lr: 2.0000e-04
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0844
# Epoch 9: val_loss improved from 0.08771 to 0.08299, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 267ms/step - loss: 0.0844 - val_loss: 0.0830 - lr: 2.0000e-04
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 10: val_loss improved from 0.08299 to 0.08046, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 268ms/step - loss: 0.0832 - val_loss: 0.0805 - lr: 2.0000e-04
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0838
# Epoch 11: val_loss did not improve from 0.08046
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0838 - val_loss: 0.0903 - lr: 2.0000e-04
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 12: val_loss did not improve from 0.08046
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0825 - val_loss: 0.0848 - lr: 2.0000e-04
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0829
# Epoch 13: val_loss improved from 0.08046 to 0.07936, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 267ms/step - loss: 0.0829 - val_loss: 0.0794 - lr: 2.0000e-04
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0847
# Epoch 14: val_loss did not improve from 0.07936
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0847 - val_loss: 0.0823 - lr: 2.0000e-04
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0834
# Epoch 15: val_loss improved from 0.07936 to 0.07802, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 267ms/step - loss: 0.0834 - val_loss: 0.0780 - lr: 2.0000e-04
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0840
# Epoch 16: val_loss did not improve from 0.07802
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0840 - val_loss: 0.0897 - lr: 2.0000e-04
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 17: val_loss did not improve from 0.07802
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0810 - val_loss: 0.0814 - lr: 2.0000e-04
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0837
# Epoch 18: val_loss did not improve from 0.07802
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0837 - val_loss: 0.0803 - lr: 2.0000e-04
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0806
# Epoch 19: val_loss improved from 0.07802 to 0.07485, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 267ms/step - loss: 0.0806 - val_loss: 0.0748 - lr: 2.0000e-04
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0835
# Epoch 20: val_loss did not improve from 0.07485
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0835 - val_loss: 0.0749 - lr: 2.0000e-04
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0827
# Epoch 21: val_loss did not improve from 0.07485
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0827 - val_loss: 0.0827 - lr: 2.0000e-04
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0813
# Epoch 22: val_loss did not improve from 0.07485
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0813 - val_loss: 0.0767 - lr: 2.0000e-04
# Epoch 23/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 23: val_loss did not improve from 0.07485
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0820 - val_loss: 0.0775 - lr: 2.0000e-04
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0802
# Epoch 24: val_loss did not improve from 0.07485
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0802 - val_loss: 0.0799 - lr: 2.0000e-04
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0800
# Epoch 25: val_loss did not improve from 0.07485
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0800 - val_loss: 0.0861 - lr: 4.0000e-05
# Epoch 26/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 26: val_loss did not improve from 0.07485
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0825 - val_loss: 0.0801 - lr: 4.0000e-05
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 27: val_loss did not improve from 0.07485
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0832 - val_loss: 0.0763 - lr: 4.0000e-05
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 28: val_loss did not improve from 0.07485
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0825 - val_loss: 0.0800 - lr: 4.0000e-05
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 29: val_loss did not improve from 0.07485
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0828 - val_loss: 0.0814 - lr: 4.0000e-05
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0807
# Epoch 30: val_loss did not improve from 0.07485
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0807 - val_loss: 0.0802 - lr: 8.0000e-06
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0818
# Epoch 31: val_loss did not improve from 0.07485
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0818 - val_loss: 0.0873 - lr: 8.0000e-06
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0811
# Epoch 32: val_loss did not improve from 0.07485
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0811 - val_loss: 0.0756 - lr: 8.0000e-06
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0802
# Epoch 33: val_loss improved from 0.07485 to 0.07434, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_20_10_f
# 100/100 [==============================] - 27s 268ms/step - loss: 0.0802 - val_loss: 0.0743 - lr: 8.0000e-06
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 34: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0832 - val_loss: 0.0812 - lr: 8.0000e-06
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0818
# Epoch 35: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0818 - val_loss: 0.0810 - lr: 8.0000e-06
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0823
# Epoch 36: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0823 - val_loss: 0.0808 - lr: 8.0000e-06
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0805
# Epoch 37: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0805 - val_loss: 0.0772 - lr: 8.0000e-06
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0816
# Epoch 38: val_loss did not improve from 0.07434
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0816 - val_loss: 0.0838 - lr: 8.0000e-06
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 39: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0810 - val_loss: 0.0787 - lr: 1.6000e-06
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0816
# Epoch 40: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0816 - val_loss: 0.0814 - lr: 1.6000e-06
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0827
# Epoch 41: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0827 - val_loss: 0.0797 - lr: 1.6000e-06
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 42: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0821 - val_loss: 0.0748 - lr: 1.6000e-06
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0808
# Epoch 43: val_loss did not improve from 0.07434
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0808 - val_loss: 0.0796 - lr: 1.6000e-06
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0800
# Epoch 44: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0800 - val_loss: 0.0759 - lr: 3.2000e-07
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0787
# Epoch 45: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0787 - val_loss: 0.0791 - lr: 3.2000e-07
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0818
# Epoch 46: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0818 - val_loss: 0.0841 - lr: 3.2000e-07
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 47: val_loss did not improve from 0.07434
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0821 - val_loss: 0.0831 - lr: 3.2000e-07
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0806
# Epoch 48: val_loss did not improve from 0.07434
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 100/100 [==============================] - 26s 265ms/step - loss: 0.0806 - val_loss: 0.0838 - lr: 3.2000e-07
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0822
# Epoch 49: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 265ms/step - loss: 0.0822 - val_loss: 0.0884 - lr: 6.4000e-08
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0809
# Epoch 50: val_loss did not improve from 0.07434
# 100/100 [==============================] - 27s 266ms/step - loss: 0.0809 - val_loss: 0.0809 - lr: 6.4000e-08
# num_classes:  50
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5667
# Epoch 1: val_loss improved from inf to 0.14605, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_50_10_f
# 100/100 [==============================] - 67s 567ms/step - loss: 0.5667 - val_loss: 0.1461 - lr: 0.0010
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.1221
# Epoch 2: val_loss did not improve from 0.14605
# 100/100 [==============================] - 56s 557ms/step - loss: 0.1221 - val_loss: 0.1469 - lr: 0.0010
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0862
# Epoch 3: val_loss did not improve from 0.14605
# 100/100 [==============================] - 56s 557ms/step - loss: 0.0862 - val_loss: 0.1611 - lr: 0.0010
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0837
# Epoch 4: val_loss did not improve from 0.14605
# 100/100 [==============================] - 56s 557ms/step - loss: 0.0837 - val_loss: 0.1677 - lr: 0.0010
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0824
# Epoch 5: val_loss did not improve from 0.14605
# 100/100 [==============================] - 56s 557ms/step - loss: 0.0824 - val_loss: 0.1756 - lr: 0.0010
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0802
# Epoch 6: val_loss improved from 0.14605 to 0.10380, saving model to ../decreasing/checkpoints/decreasingH1_gaussian_50_10_f
# 100/100 [==============================] - 56s 559ms/step - loss: 0.0802 - val_loss: 0.1038 - lr: 0.0010
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0932
# Epoch 7: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 0.0932 - val_loss: 0.1404 - lr: 0.0010
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 0.1615
# Epoch 8: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 0.1615 - val_loss: 3.1360 - lr: 0.0010
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 0.1394
# Epoch 9: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 0.1394 - val_loss: 0.2161 - lr: 0.0010
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 22.6703
# Epoch 10: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 22.6703 - val_loss: 10132097.0000 - lr: 0.0010
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 182.4580
# Epoch 11: val_loss did not improve from 0.10380
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 100/100 [==============================] - 56s 556ms/step - loss: 182.4580 - val_loss: 463.9547 - lr: 0.0010
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 130.2898
# Epoch 12: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 130.2898 - val_loss: 198.6100 - lr: 2.0000e-04
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 85.7560
# Epoch 13: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 85.7560 - val_loss: 100.0646 - lr: 2.0000e-04
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 54.8017
# Epoch 14: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 54.8017 - val_loss: 56.5259 - lr: 2.0000e-04
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 49.3487
# Epoch 15: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 49.3487 - val_loss: 58.5899 - lr: 2.0000e-04
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 42.6196
# Epoch 16: val_loss did not improve from 0.10380
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 100/100 [==============================] - 56s 557ms/step - loss: 42.6196 - val_loss: 44.0514 - lr: 2.0000e-04
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 40.8148
# Epoch 17: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.8148 - val_loss: 42.9193 - lr: 4.0000e-05
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 40.2868
# Epoch 18: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.2868 - val_loss: 33.9095 - lr: 4.0000e-05
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 40.6000
# Epoch 19: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.6000 - val_loss: 32.4740 - lr: 4.0000e-05
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 42.1155
# Epoch 20: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 42.1155 - val_loss: 46.3034 - lr: 4.0000e-05
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 39.9225
# Epoch 21: val_loss did not improve from 0.10380
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 100/100 [==============================] - 56s 557ms/step - loss: 39.9225 - val_loss: 58.7437 - lr: 4.0000e-05
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 40.1988
# Epoch 22: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.1988 - val_loss: 48.8862 - lr: 8.0000e-06
# Epoch 23/50
# 100/100 [==============================] - ETA: 0s - loss: 43.2300
# Epoch 23: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 43.2300 - val_loss: 37.2352 - lr: 8.0000e-06
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 40.6372
# Epoch 24: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.6372 - val_loss: 37.0135 - lr: 8.0000e-06
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 40.9630
# Epoch 25: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.9630 - val_loss: 47.4522 - lr: 8.0000e-06
# Epoch 26/50
# 100/100 [==============================] - ETA: 0s - loss: 40.1966
# Epoch 26: val_loss did not improve from 0.10380
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 100/100 [==============================] - 56s 557ms/step - loss: 40.1966 - val_loss: 36.0651 - lr: 8.0000e-06
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 40.2919
# Epoch 27: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.2919 - val_loss: 46.9547 - lr: 1.6000e-06
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 41.0253
# Epoch 28: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 41.0253 - val_loss: 39.2405 - lr: 1.6000e-06
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 40.0699
# Epoch 29: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.0699 - val_loss: 43.1748 - lr: 1.6000e-06
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 41.4639
# Epoch 30: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 41.4639 - val_loss: 43.9495 - lr: 1.6000e-06
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 41.1333
# Epoch 31: val_loss did not improve from 0.10380
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 100/100 [==============================] - 56s 557ms/step - loss: 41.1333 - val_loss: 41.9872 - lr: 1.6000e-06
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 40.6388
# Epoch 32: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.6388 - val_loss: 43.9284 - lr: 3.2000e-07
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 40.5849
# Epoch 33: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.5849 - val_loss: 40.9381 - lr: 3.2000e-07
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 39.9844
# Epoch 34: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 39.9844 - val_loss: 37.0743 - lr: 3.2000e-07
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 40.3937
# Epoch 35: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.3937 - val_loss: 34.3588 - lr: 3.2000e-07
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 41.7814
# Epoch 36: val_loss did not improve from 0.10380
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 100/100 [==============================] - 56s 557ms/step - loss: 41.7814 - val_loss: 30.9915 - lr: 3.2000e-07
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 40.0921
# Epoch 37: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.0921 - val_loss: 44.9484 - lr: 6.4000e-08
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 40.5591
# Epoch 38: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.5591 - val_loss: 45.5173 - lr: 6.4000e-08
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 41.2662
# Epoch 39: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 41.2662 - val_loss: 44.1390 - lr: 6.4000e-08
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 39.9224
# Epoch 40: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 39.9224 - val_loss: 38.5879 - lr: 6.4000e-08
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 39.5723
# Epoch 41: val_loss did not improve from 0.10380
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 100/100 [==============================] - 56s 557ms/step - loss: 39.5723 - val_loss: 36.6601 - lr: 6.4000e-08
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 41.3800
# Epoch 42: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 41.3800 - val_loss: 46.4589 - lr: 1.2800e-08
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 39.7142
# Epoch 43: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 39.7142 - val_loss: 33.1374 - lr: 1.2800e-08
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 40.0980
# Epoch 44: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.0980 - val_loss: 37.6694 - lr: 1.2800e-08
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 39.8930
# Epoch 45: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 39.8930 - val_loss: 33.0256 - lr: 1.2800e-08
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 40.9536
# Epoch 46: val_loss did not improve from 0.10380
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 100/100 [==============================] - 56s 557ms/step - loss: 40.9536 - val_loss: 37.0231 - lr: 1.2800e-08
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 40.6587
# Epoch 47: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 40.6587 - val_loss: 50.4518 - lr: 2.5600e-09
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 39.7881
# Epoch 48: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 39.7881 - val_loss: 41.3125 - lr: 2.5600e-09
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 39.9944
# Epoch 49: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 39.9944 - val_loss: 48.4056 - lr: 2.5600e-09
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 41.3598
# Epoch 50: val_loss did not improve from 0.10380
# 100/100 [==============================] - 56s 557ms/step - loss: 41.3598 - val_loss: 40.7532 - lr: 2.5600e-09
# L2
# num_classes:  5
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 0.1506
# Epoch 1: val_loss improved from inf to 0.00725, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
# 100/100 [==============================] - 34s 239ms/step - loss: 0.1506 - val_loss: 0.0073 - lr: 0.0010
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 2: val_loss did not improve from 0.00725
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0050 - val_loss: 0.0075 - lr: 0.0010
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 3: val_loss improved from 0.00725 to 0.00447, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
# 100/100 [==============================] - 23s 229ms/step - loss: 0.0043 - val_loss: 0.0045 - lr: 0.0010
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 4: val_loss improved from 0.00447 to 0.00314, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
# 100/100 [==============================] - 22s 219ms/step - loss: 0.0038 - val_loss: 0.0031 - lr: 0.0010
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 5: val_loss did not improve from 0.00314
# 100/100 [==============================] - 21s 213ms/step - loss: 0.0034 - val_loss: 0.0041 - lr: 0.0010
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 6: val_loss did not improve from 0.00314
# 100/100 [==============================] - 21s 216ms/step - loss: 0.0035 - val_loss: 0.0042 - lr: 0.0010
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 7: val_loss did not improve from 0.00314
# 100/100 [==============================] - 22s 217ms/step - loss: 0.0034 - val_loss: 0.0040 - lr: 0.0010
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 8: val_loss improved from 0.00314 to 0.00311, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
# 100/100 [==============================] - 21s 216ms/step - loss: 0.0031 - val_loss: 0.0031 - lr: 0.0010
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 9: val_loss improved from 0.00311 to 0.00308, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0031 - val_loss: 0.0031 - lr: 0.0010
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 10: val_loss improved from 0.00308 to 0.00276, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
# 100/100 [==============================] - 22s 216ms/step - loss: 0.0030 - val_loss: 0.0028 - lr: 2.0000e-04
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 11: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0030 - val_loss: 0.0029 - lr: 2.0000e-04
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 12: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0030 - val_loss: 0.0030 - lr: 2.0000e-04
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 13: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0029 - val_loss: 0.0030 - lr: 2.0000e-04
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 14: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0028 - val_loss: 0.0029 - lr: 2.0000e-04
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 15: val_loss did not improve from 0.00276
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0029 - val_loss: 0.0029 - lr: 2.0000e-04
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 16: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0029 - val_loss: 0.0030 - lr: 4.0000e-05
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 17: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 213ms/step - loss: 0.0030 - val_loss: 0.0028 - lr: 4.0000e-05
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 18: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0029 - val_loss: 0.0035 - lr: 4.0000e-05
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 19: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 213ms/step - loss: 0.0028 - val_loss: 0.0029 - lr: 4.0000e-05
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 20: val_loss did not improve from 0.00276
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0029 - val_loss: 0.0032 - lr: 4.0000e-05
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 21: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0029 - val_loss: 0.0029 - lr: 8.0000e-06
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 22: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 213ms/step - loss: 0.0029 - val_loss: 0.0028 - lr: 8.0000e-06
# Epoch 23/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 23: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0029 - val_loss: 0.0031 - lr: 8.0000e-06
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 24: val_loss did not improve from 0.00276
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0030 - val_loss: 0.0029 - lr: 8.0000e-06
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 25: val_loss improved from 0.00276 to 0.00275, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 100/100 [==============================] - 22s 218ms/step - loss: 0.0028 - val_loss: 0.0028 - lr: 8.0000e-06
# Epoch 26/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 26: val_loss did not improve from 0.00275
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0030 - val_loss: 0.0028 - lr: 1.6000e-06
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 27: val_loss did not improve from 0.00275
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0029 - val_loss: 0.0028 - lr: 1.6000e-06
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 28: val_loss did not improve from 0.00275
# 100/100 [==============================] - 21s 215ms/step - loss: 0.0030 - val_loss: 0.0029 - lr: 1.6000e-06
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 29: val_loss improved from 0.00275 to 0.00248, saving model to ../decreasing/checkpoints/decreasingL2_gaussian_5_10_f
# 100/100 [==============================] - 22s 217ms/step - loss: 0.0029 - val_loss: 0.0025 - lr: 1.6000e-06
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 30: val_loss did not improve from 0.00248
# 100/100 [==============================] - 22s 216ms/step - loss: 0.0029 - val_loss: 0.0034 - lr: 1.6000e-06
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 31: val_loss did not improve from 0.00248
# ...
# Epoch 27: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 325.8542 - val_loss: 218.1360 - lr: 3.2000e-07
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 327.8200
# Epoch 28: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 327.8200 - val_loss: 272.9319 - lr: 3.2000e-07
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 310.4624
# Epoch 29: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 310.4624 - val_loss: 555.7604 - lr: 3.2000e-07
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 320.0890
# Epoch 30: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 453ms/step - loss: 320.0890 - val_loss: 206.0661 - lr: 3.2000e-07
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 424.6912
# Epoch 31: val_loss did not improve from 0.00421
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 100/100 [==============================] - 45s 454ms/step - loss: 424.6912 - val_loss: 435.2932 - lr: 3.2000e-07
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 286.1226
# Epoch 32: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 286.1226 - val_loss: 517.4388 - lr: 6.4000e-08
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 325.5183
# Epoch 33: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 325.5183 - val_loss: 367.9763 - lr: 6.4000e-08
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 268.6193
# Epoch 34: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 268.6193 - val_loss: 277.6381 - lr: 6.4000e-08
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 311.1620
# Epoch 35: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 311.1620 - val_loss: 284.1980 - lr: 6.4000e-08
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 327.7407
# Epoch 36: val_loss did not improve from 0.00421
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 100/100 [==============================] - 45s 453ms/step - loss: 327.7407 - val_loss: 105.7812 - lr: 6.4000e-08
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 353.6006
# Epoch 37: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 453ms/step - loss: 353.6006 - val_loss: 104.2577 - lr: 1.2800e-08
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 322.6980
# Epoch 38: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 322.6980 - val_loss: 406.7993 - lr: 1.2800e-08
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 355.3375
# Epoch 39: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 453ms/step - loss: 355.3375 - val_loss: 271.7330 - lr: 1.2800e-08
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 305.9825
# Epoch 40: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 305.9825 - val_loss: 323.4555 - lr: 1.2800e-08
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 308.9724
# Epoch 41: val_loss did not improve from 0.00421
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 100/100 [==============================] - 45s 453ms/step - loss: 308.9724 - val_loss: 328.1084 - lr: 1.2800e-08
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 331.0671
# Epoch 42: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 331.0671 - val_loss: 259.8946 - lr: 2.5600e-09
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 298.1133
# Epoch 43: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 298.1133 - val_loss: 272.1474 - lr: 2.5600e-09
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 333.5847
# Epoch 44: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 453ms/step - loss: 333.5847 - val_loss: 171.4448 - lr: 2.5600e-09
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 330.6203
# Epoch 45: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 330.6203 - val_loss: 284.6969 - lr: 2.5600e-09
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 324.9666
# Epoch 46: val_loss did not improve from 0.00421
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 100/100 [==============================] - 45s 453ms/step - loss: 324.9666 - val_loss: 467.7395 - lr: 2.5600e-09
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 265.4717
# Epoch 47: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 265.4717 - val_loss: 147.3171 - lr: 5.1200e-10
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 295.9180
# Epoch 48: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 295.9180 - val_loss: 281.5572 - lr: 5.1200e-10
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 303.7875
# Epoch 49: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 454ms/step - loss: 303.7875 - val_loss: 410.3733 - lr: 5.1200e-10
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 350.3903
# Epoch 50: val_loss did not improve from 0.00421
# 100/100 [==============================] - 45s 453ms/step - loss: 350.3903 - val_loss: 543.1713 - lr: 5.1200e-10
# num_classes:  50
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 5.4781
# Epoch 1: val_loss improved from inf to 0.00427, saving model to ../flux/checkpoints/fluxL2_gaussian_50_10_f
# 100/100 [==============================] - 119s 1s/step - loss: 5.4781 - val_loss: 0.0043 - lr: 0.0010
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 36.5394
# Epoch 2: val_loss did not improve from 0.00427
# 100/100 [==============================] - 108s 1s/step - loss: 36.5394 - val_loss: 1.3957 - lr: 0.0010
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 28.2374
# Epoch 3: val_loss did not improve from 0.00427
# 100/100 [==============================] - 108s 1s/step - loss: 28.2374 - val_loss: 8.4196 - lr: 0.0010
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 188.5235
# Epoch 4: val_loss did not improve from 0.00427
# 100/100 [==============================] - 108s 1s/step - loss: 188.5235 - val_loss: 15.0585 - lr: 0.0010
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 163.5513
# Epoch 5: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 163.5513 - val_loss: 61.5215 - lr: 0.0010
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 146.8915
# Epoch 6: val_loss did not improve from 0.00427
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 100/100 [==============================] - 107s 1s/step - loss: 146.8915 - val_loss: 113.6473 - lr: 0.0010
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 129.5538
# Epoch 7: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 129.5538 - val_loss: 136.8434 - lr: 2.0000e-04
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 131.5451
# Epoch 8: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 131.5451 - val_loss: 113.7818 - lr: 2.0000e-04
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 123.4436
# Epoch 9: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 123.4436 - val_loss: 135.2658 - lr: 2.0000e-04
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 122.0518
# Epoch 10: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 122.0518 - val_loss: 119.9322 - lr: 2.0000e-04
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 115.0461
# Epoch 11: val_loss did not improve from 0.00427
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 100/100 [==============================] - 107s 1s/step - loss: 115.0461 - val_loss: 143.5327 - lr: 2.0000e-04
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 113.5636
# Epoch 12: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 113.5636 - val_loss: 115.7585 - lr: 4.0000e-05
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 110.9757
# Epoch 13: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 110.9757 - val_loss: 114.9678 - lr: 4.0000e-05
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 113.2682
# Epoch 14: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 113.2682 - val_loss: 104.5192 - lr: 4.0000e-05
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 115.8849
# Epoch 15: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 115.8849 - val_loss: 154.2491 - lr: 4.0000e-05
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 112.1012
# Epoch 16: val_loss did not improve from 0.00427
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 100/100 [==============================] - 107s 1s/step - loss: 112.1012 - val_loss: 127.4373 - lr: 4.0000e-05
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 115.5168
# Epoch 17: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 115.5168 - val_loss: 139.0129 - lr: 8.0000e-06
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 111.4916
# Epoch 18: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 111.4916 - val_loss: 122.5559 - lr: 8.0000e-06
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 114.0736
# Epoch 19: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 114.0736 - val_loss: 169.9890 - lr: 8.0000e-06
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 120.1271
# Epoch 20: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 120.1271 - val_loss: 136.1653 - lr: 8.0000e-06
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 123.8318
# Epoch 21: val_loss did not improve from 0.00427
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 100/100 [==============================] - 107s 1s/step - loss: 123.8318 - val_loss: 110.5084 - lr: 8.0000e-06
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 119.3307
# Epoch 22: val_loss did not improve from 0.00427
# 100/100 [==============================] - 107s 1s/step - loss: 119.3307 - val_loss: 158.5249 - lr: 1.6000e-06
# Epoch 23/50
#  22/100 [=====>........................] - ETA: 1:18 - loss: 123.9857
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2628460/460510188.py in <module>
#      37                 ]
#      38
# ---> 39                 history = model.fit(
#      40                     gen_batch_train,
#      41                     epochs=50,
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
architectures = ['splines','decreasing','flux']

for N_REPEAT_FRAME1 in [1,10,30]:

    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=55,CROP1=CROP,BATCH_SIZE=30,
                                                   N_REPEAT_FRAME1=N_REPEAT_FRAME1)

    for arch in architectures:
        print(arch)

        for loss in losses_names:
            print(loss)

            order = 1
            for num_classes in [5,20,50]:
                print('num_classes: ',num_classes)
                
                for degree in np.arange(3,17):
                    print(degree)



                    model = get_model(arch,it_lim=10,image_size=image_size,num_classes = num_classes,
                                     second=True,degree=degree)
                    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                            loss=getattr(losses,loss))

                    callbacks = [tf.keras.callbacks.ModelCheckpoint(
                    filepath= f"../{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_t{degree}",
                    save_weights_only=True,
                    verbose = True,
                    save_best_only=True),
                    tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1,patience=5),
                    tf.keras.callbacks.TerminateOnNaN()

                    ]

                    history = model.fit(
                        gen_batch_train,
                        epochs=50,
                        steps_per_epoch=100,
                        validation_data=gen_batch_val,
                        validation_steps=10,
                        shuffle=False,
                        use_multiprocessing=True,
                        callbacks=callbacks,
                        workers=1
                    )

                    np.save(f'../{arch}/history/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_t{degree}.npy',np.array([history.history['loss'],history.history['val_loss']]))
