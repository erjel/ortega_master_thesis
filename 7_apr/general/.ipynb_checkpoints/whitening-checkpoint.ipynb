# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl
import pandas as pd
from sklearn.mixture import GaussianMixture


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)
size = 5
pre_smoothing = False
conv = True
sigma = 0.1


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-05-24 01:48:03.812908: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-24 01:48:03.955739: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-05-24 01:48:03.955758: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-24 01:48:04.604483: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-05-24 01:48:04.604544: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-05-24 01:48:04.604550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gen_batch_train,gen_batch_val = get_generators(typ,0,100,BATCH_SIZE = 50,known_variance=True)

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())

# %%
_ = np.random.choice(len(xs['input']))

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(xs['input'][_],cmap='gray')
plt.title(xs['var'][_][0])
plt.colorbar()
plt.subplot(122)
plt.imshow(ys[_],cmap='gray')
plt.colorbar()
plt.show()

# %%
def classifier(inputs, option=1, num_classes=2,kernel_size=3,pool_size=3,CROP=256,latent_size=1024):
    
    
    x = tf.keras.layers.Conv2D(32, kernel_size, strides=2, padding="same")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.Conv2D(64, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [16,32,64,128]:
        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.MaxPooling2D(pool_size, strides=2, padding="same")(x)

        # Project residual
        residual = tf.keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = tf.keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = tf.keras.layers.SeparableConv2D(latent_size, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    
    return x

# %%
class function_type:
    def splines(y,num_classes,order):


        b_initial = tf.keras.layers.Dense(1,activation='linear')(y)
        b_initial = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_initial)

        a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)

        a = tf.keras.layers.Reshape((num_classes,order))(a)

        b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
        b = tf.pow(b,np.arange(1,order+1))
        b = tf.keras.layers.multiply([a,b])

        m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
        b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
        b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
        b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
        b = tf.keras.layers.Concatenate(axis=1)([b0,b])
        b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
        b = tf.keras.layers.add((b,b_initial))
        b = tf.expand_dims(b,axis=-1)

        return a,b

    def decreasing(y,num_classes,order):
        b_initial = tf.keras.layers.Dense(1,activation='linear')(y)
        b_initial = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_initial)
        a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)
        a = tf.keras.layers.Reshape((num_classes,order))(a)
        a = tf.keras.layers.Lambda(lambda z:-tf.math.pow(z,2))(a)

        b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
        b = tf.pow(b,np.arange(1,order+1))
        b = tf.keras.layers.multiply([a,b])

        m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
        b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
        b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
        b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
        b = tf.keras.layers.Concatenate(axis=1)([b0,b])
        b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
        b = tf.keras.layers.add((b,b_initial))
        b = tf.expand_dims(b,axis=-1)

        return a,b

    def flux(y,num_classes,order):
        b_initial = tf.keras.layers.Dense(1,activation='linear')(y)
        b_initial = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_initial)

        a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)
        a = tf.keras.layers.Reshape((num_classes,order))(a)
        #s0 = tf.keras.layers.Dense(1,activation='sigmoid')(y)
        s0 = tf.keras.layers.Lambda(lambda z: 0.5*tf.ones_like(z))(b_initial)

        b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
        b = tf.keras.layers.multiply((b,s0))
        b = tf.pow(b,np.arange(1,order+1))
        b = tf.keras.layers.multiply([a,b])

        m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
        b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
        b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
        b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
        b = tf.keras.layers.Concatenate(axis=1)([b0,b])
        b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
        b = tf.keras.layers.add((b,b_initial))
        b = tf.expand_dims(b,axis=-1)


        minimum = tf.ones_like(a)/(num_classes)
        fun = tf.keras.layers.multiply((s0,minimum,a))
        fun = tf.keras.layers.add((fun,b))
        coeffs = 2*(tf.cumsum(tf.ones_like(a)/(num_classes),axis=1))
        coeffs = tf.keras.layers.multiply((coeffs,s0,a))
        fun = tf.keras.layers.add((coeffs,fun))
        minimum = tf.keras.layers.Lambda(lambda z:-tf.reduce_min(z[...,0],axis=-1))(fun)
        minimum_neg = tf.keras.layers.Lambda(lambda z: tf.cast(tf.less_equal(-z,0),dtype=tf.float32))(minimum)
        minimum = tf.keras.layers.multiply((minimum,minimum_neg))

        b = tf.keras.layers.add((b,minimum))

        a_pos,b_pos = a,b

        b_middle = tf.keras.layers.Dense(1,activation='linear')(y)
        b_middle = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_middle)


        a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)
        a = tf.keras.layers.Reshape((num_classes,order))(a)
        s1 = tf.keras.layers.Lambda(lambda z: tf.ones_like(z)-z)(s0)

        b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
        b = tf.keras.layers.multiply((b,s1))
        b = tf.pow(b,np.arange(1,order+1))
        b = tf.keras.layers.multiply([a,b])

        m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
        b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
        b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
        b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
        b = tf.keras.layers.Concatenate(axis=1)([b0,b])
        b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
        b = tf.keras.layers.add((b,b_middle))
        b = tf.expand_dims(b,axis=-1)


        maximum = tf.ones_like(a)/(num_classes)
        fun = tf.keras.layers.multiply((s1,maximum,a))
        fun = tf.keras.layers.add((fun,b))
        coeffs = 2*(tf.cumsum(tf.ones_like(a)/(num_classes),axis=1))
        coeffs = tf.keras.layers.multiply((coeffs,s1))
        coeffs = tf.keras.layers.add((coeffs,s0))
        coeffs = tf.keras.layers.multiply((a,coeffs))
        fun = tf.keras.layers.add((coeffs,fun))
        maximum = tf.keras.layers.Lambda(lambda z:-tf.reduce_max(z[...,0],axis=-1))(fun)
        maximum_neg = tf.keras.layers.Lambda(lambda z: tf.cast(tf.greater_equal(-z,0),dtype=tf.float32))(maximum)
        maximum = tf.keras.layers.multiply((maximum,maximum_neg))
        maximum = tf.keras.layers.Lambda(lambda z:tf.expand_dims(z,axis=-1))(maximum)

        b = tf.keras.layers.add((b,maximum))

        a_neg,b_neg = a,b

        a = tf.keras.layers.Concatenate(axis=1)((a_pos,a_neg))
        b = tf.keras.layers.Concatenate(axis=1)((b_pos,b_neg))

        return a,b
    
    def fluxdecreasing(y,num_classes,order):
        b_initial = tf.keras.layers.Dense(1,activation='linear')(y)
        b_initial = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_initial)

        a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)
        a = tf.keras.layers.Reshape((num_classes,order))(a)
        a = tf.keras.layers.Lambda(lambda z:-tf.math.pow(z,2))(a)
        s0 = tf.keras.layers.Lambda(lambda z: 0.5*tf.ones_like(z))(b_initial)

        b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
        b = tf.keras.layers.multiply((b,s0))
        b = tf.pow(b,np.arange(1,order+1))
        b = tf.keras.layers.multiply([a,b])

        m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
        b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
        b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
        b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
        b = tf.keras.layers.Concatenate(axis=1)([b0,b])
        b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
        b = tf.keras.layers.add((b,b_initial))
        b = tf.expand_dims(b,axis=-1)


        minimum = tf.ones_like(a)/(num_classes)
        fun = tf.keras.layers.multiply((s0,minimum,a))
        fun = tf.keras.layers.add((fun,b))
        coeffs = 2*(tf.cumsum(tf.ones_like(a)/(num_classes),axis=1))
        coeffs = tf.keras.layers.multiply((coeffs,s0,a))
        fun = tf.keras.layers.add((coeffs,fun))
        minimum = tf.keras.layers.Lambda(lambda z:-tf.reduce_min(z[...,0],axis=-1))(fun)
        minimum_neg = tf.keras.layers.Lambda(lambda z: tf.cast(tf.less_equal(-z,0),dtype=tf.float32))(minimum)
        minimum = tf.keras.layers.multiply((minimum,minimum_neg))

        b = tf.keras.layers.add((b,minimum))

        a_pos,b_pos = a,b

        b_middle = tf.keras.layers.Dense(1,activation='linear')(y)
        b_middle = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_middle)


        a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)
        a = tf.keras.layers.Reshape((num_classes,order))(a)
        a = tf.keras.layers.Lambda(lambda z:-tf.math.pow(z,2))(a)
        s1 = tf.keras.layers.Lambda(lambda z: tf.ones_like(z)-z)(s0)

        b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
        b = tf.keras.layers.multiply((b,s1))
        b = tf.pow(b,np.arange(1,order+1))
        b = tf.keras.layers.multiply([a,b])

        m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
        b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
        b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
        b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
        b = tf.keras.layers.Concatenate(axis=1)([b0,b])
        b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
        b = tf.keras.layers.add((b,b_middle))
        b = tf.expand_dims(b,axis=-1)


        maximum = tf.ones_like(a)/(num_classes)
        fun = tf.keras.layers.multiply((s1,maximum,a))
        fun = tf.keras.layers.add((fun,b))
        coeffs = 2*(tf.cumsum(tf.ones_like(a)/(num_classes),axis=1))
        coeffs = tf.keras.layers.multiply((coeffs,s1))
        coeffs = tf.keras.layers.add((coeffs,s0))
        coeffs = tf.keras.layers.multiply((a,coeffs))
        fun = tf.keras.layers.add((coeffs,fun))
        maximum = tf.keras.layers.Lambda(lambda z:-tf.reduce_max(z[...,0],axis=-1))(fun)
        maximum_neg = tf.keras.layers.Lambda(lambda z: tf.cast(tf.greater_equal(-z,0),dtype=tf.float32))(maximum)
        maximum = tf.keras.layers.multiply((maximum,maximum_neg))
        maximum = tf.keras.layers.Lambda(lambda z:tf.expand_dims(z,axis=-1))(maximum)

        b = tf.keras.layers.add((b,maximum))

        a_neg,b_neg = a,b

        a = tf.keras.layers.Concatenate(axis=1)((a_pos,a_neg))
        b = tf.keras.layers.Concatenate(axis=1)((b_pos,b_neg))

        return a,b
    
    
def constraint(W):
    or_shape = W.shape
    shift = (2*degree+2)*((2*degree+1)//2)
    NW = []
    for w in tf.unstack(W,axis=-1):
        nw = tf.roll(tf.reshape(w,[(2*degree+1)**2]),shift=shift+1,axis=0)
        nw = tf.slice(nw,[1],[(2*degree+1)**2-1])
        nw = tf.abs(nw)
        center = -tf.expand_dims(tf.reduce_sum(nw),0)
        nw = tf.concat((center,nw),axis=0)
        nw = tf.roll(nw,shift,axis=0)
        nw = tf.reshape(nw,(2*degree+1,2*degree+1,1))
        NW.append(nw)

    return tf.stack(NW,axis=-1)


def regularizer(w):

    w1 = tf.abs(w[::-1,...])
    w = tf.abs(w) + w1 + tf.abs(w[:,::-1,...]) + w1[:,::-1]
    projections = tf.unstack(w,axis=-1)
    initial = 0

    for pr in range(len(projections)):
        for ps in range(len(projections)):
            if pr > ps:
                proj = tf.multiply(projections[pr],projections[ps])
                initial += tf.reduce_sum(tf.abs(proj)) - tf.reduce_sum(tf.abs(proj[degree,degree]))
                
                
    auto = tf.multiply(w,w1) - tf.multiply(w1,w1)
    initial += tf.reduce_sum(tf.math.log(1+auto))
    
    initial += (100)*tf.abs(1-tf.reduce_max(w1))
    
    return factor1 * initial

def differential_operator(input_shape,num_filters,polynomial_degree,typee):
    outputs = tf.keras.Input(shape=input_shape,name='input_differential')
    if (typee == 'diffop') or (typee == 'nopretrained'):
        diff_op1 = tf.keras.layers.Conv2D(num_filters,(2*degree+1,2*degree+1),padding='same',use_bias=False,
                            kernel_constraint=constraint,kernel_regularizer = regularizer, name='diff')(outputs)
    if (typee != 'diffop') and (typee != 'nopretrained'):
        diff_op1 = tf.keras.layers.Conv2D(num_filters,(2*degree+1,2*degree+1),padding='same',use_bias=False,name='diff')(outputs)
    
    diff_op1 = tf.keras.layers.Lambda(lambda z: tf.pow(z,2))(diff_op1)
    
    if typee != 'foe' and typee != 'foek':
        diff_op = tf.keras.layers.Conv2D(1,1,padding='same',name='no_train',activation='sigmoid')(diff_op1)
    if typee == 'foe':
        diff_op = tf.keras.layers.Conv2D(1,1,padding='same',name='no_train')(diff_op1)
        diff_op = tf.keras.layers.Dense(64,activation = 'relu')(diff_op)
        diff_op = tf.keras.layers.Dense(32,activation = 'relu')(diff_op)
        diff_op = tf.keras.layers.Dense(1,activation = 'relu')(diff_op)
        
    if typee == 'foek':
        diff_op = tf.keras.layers.Conv2D(1,5,padding='same',name='no_train')(diff_op1)
        diff_op = tf.keras.layers.Dense(64,activation = 'relu')(diff_op)
        diff_op = tf.keras.layers.Dense(32,activation = 'relu')(diff_op)
        diff_op = tf.keras.layers.Dense(1,activation = 'relu')(diff_op)

    return tf.keras.Model(outputs,diff_op)

# %%
def get_model(arch,it_lim,image_size,typ='gaussian',num_classes=1,CROP = 256,order = 1,gamma=1,second=True,degree1=3,
             factor=1,typee='noconstraints',known_variance=True,latent_size=1024):

    global factor1
    factor1 = factor
    
    global degree
    degree = degree1


    input_shape = image_size + (1,)   
    if typee != 'classic':
        num_filters = np.sum(2**np.arange(1,degree+1))
        differential_model = differential_operator(input_shape,num_filters,degree,typee)
        
        if typee == 'diffop':
            
            location = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/thesis/7_apr/general/checkpoints'
        
            differential_model.load_weights(f'/{location}/DifferentialClassifier_{degree}')
            
        #for layer in differential_model.layers:
        #    layer.trainable = False


    inputs = tf.keras.Input(shape=input_shape,name='input')
    
    
    x = classifier(inputs, num_classes=num_classes,CROP=CROP,latent_size=latent_size)
    y = tf.keras.layers.Flatten(name='y')(x)
    
    if known_variance:
        inputs_var = tf.keras.Input(shape=(1),name='var')
        embedded = tf.keras.layers.Embedding(100,output_size)(inputs_var)
        embedded = tf.keras.layers.Flatten(name='embedded')(embedded)
        y = tf.keras.layers.Lambda(lambda z:tf.multiply(z[0],z[1]))([y,embedded])
    
    a,b = getattr(function_type,arch)(y,num_classes,order)    
    b = tf.keras.layers.Lambda(lambda z: tf.multiply(tf.ones_like(z[0]),z[1]))([a,b])
    if 'flux' in arch:
        num_classes = 2*num_classes


    partition_low = tf.constant(np.power(np.linspace(0,1,num_classes+1),1)[:-1])
    partition_low = tf.expand_dims(tf.expand_dims(tf.expand_dims(partition_low,0),0),0)
    partition_low = tf.cast(partition_low,tf.float32)
    partition_up = tf.constant(np.power(np.linspace(0,1,num_classes+1),1)[1:])
    partition_up = tf.expand_dims(tf.expand_dims(tf.expand_dims(partition_up,0),0),0)
    partition_up = tf.cast(partition_up,tf.float32)


    ct = tf.keras.layers.Concatenate(name='coeff_spline')((b,a))
    ct = tf.keras.layers.Lambda(lambda z: tf.expand_dims(tf.expand_dims(z,axis=1),axis=1))(ct)

    outputs = inputs


    for num_it in range(it_lim):


        if typee != 'classic':            
            diff_op = differential_model(outputs)

            diff_op = tf.keras.layers.Lambda(lambda z: tf.pow(z,2))(diff_op)

        else:
            dS_n,dE_n = tf.keras.layers.Lambda(lambda z: tf.image.image_gradients(z))(outputs)
            dS = tf.keras.layers.Lambda(lambda z: tf.pow(z,2))(dS_n)
            dE = tf.keras.layers.Lambda(lambda z: tf.pow(z,2))(dE_n)
            diff_op = tf.keras.layers.add((dS,dE))



        ineq1 = tf.greater_equal(diff_op, partition_low)
        ineq2 = tf.less_equal(diff_op,partition_up)

        interval = tf.cast(tf.math.logical_and(ineq1,ineq2),tf.float32)

        power_norm = tf.constant(np.asarray(np.arange(1,order+1),dtype='float32'))
        power_norm = tf.keras.layers.Lambda(lambda z:tf.pow(z[0],z[1]))([diff_op,power_norm])
        cte = tf.ones_like(inputs)
        power_norm = tf.keras.layers.Concatenate(axis=-1)((cte,power_norm))
        power_norm = tf.keras.layers.Lambda(lambda z: tf.expand_dims(z,axis=-2))(power_norm)

        spline = tf.keras.layers.multiply([ct,power_norm])
        spline = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(spline)
        spline = tf.keras.layers.multiply([spline,interval])

        g = tf.keras.layers.Lambda(lambda z: tf.math.reduce_sum(z,axis=-1),name=f'g_{num_it}')(spline)
        g = tf.expand_dims(g,axis=-1)


        deltaS,deltaE = tf.keras.layers.Lambda(lambda z: tf.image.image_gradients(z))(outputs)
        E = tf.keras.layers.multiply((g,deltaE))
        S = tf.keras.layers.multiply((g,deltaS))

        NS = S
        EW = E
        zeros_y = tf.expand_dims(tf.zeros_like(outputs)[:,1],axis=-1)
        zeros_x = tf.expand_dims(tf.zeros_like(inputs)[:,1],axis=-3)
        NS = tf.keras.layers.Concatenate(axis=1)([zeros_x,NS])
        EW = tf.keras.layers.Concatenate(axis=2)([zeros_y,EW])
        NS = tf.keras.layers.Lambda(lambda z: z[:,1:] - z[:,:-1])(NS)
        EW = tf.keras.layers.Lambda(lambda z: z[:,:,1:] - z[:,:,:-1])(EW)

        mult = tf.keras.layers.Lambda(lambda z: tf.multiply(tf.cast(gamma,dtype=tf.float32),z))(tf.ones_like(NS))

        adding = tf.keras.layers.add([NS,EW])
        adding = tf.keras.layers.multiply((mult,adding))

        outputs = tf.keras.layers.add([outputs,adding])
       
    
    if known_variance:
        return tf.keras.models.Model([inputs,inputs_var], outputs)
    else:
        return tf.keras.models.Model(inputs, outputs)

# %%
model = get_model('splines',10,image_size,num_classes=10,known_variance=True)

# %%
model.summary()
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_96 (Conv2D)             (None, 128, 128, 32  320         ['input[0][0]']
#                                 )
#
#  batch_normalization_176 (Batch  (None, 128, 128, 32  128        ['conv2d_96[0][0]']
#  Normalization)                 )
#
#  activation_176 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_176[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 128, 128, 64  18496       ['activation_176[0][0]']
#                                 )
#
#  batch_normalization_177 (Batch  (None, 128, 128, 64  256        ['conv2d_97[0][0]']
#  Normalization)                 )
#
#  activation_177 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_177[0][0]']
#                                 )
#
#  activation_178 (Activation)    (None, 128, 128, 64  0           ['activation_177[0][0]']
#                                 )
#
#  separable_conv2d_144 (Separabl  (None, 128, 128, 16  1616       ['activation_178[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_178 (Batch  (None, 128, 128, 16  64         ['separable_conv2d_144[0][0]']
#  Normalization)                 )
#
#  activation_179 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_178[0][0]']
#                                 )
#
#  separable_conv2d_145 (Separabl  (None, 128, 128, 16  416        ['activation_179[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_179 (Batch  (None, 128, 128, 16  64         ['separable_conv2d_145[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_64 (MaxPooling2D  (None, 64, 64, 16)  0           ['batch_normalization_179[0][0]']
#  )
#
#  conv2d_98 (Conv2D)             (None, 64, 64, 16)   1040        ['activation_177[0][0]']
#
#  add_171 (Add)                  (None, 64, 64, 16)   0           ['max_pooling2d_64[0][0]',
#                                                                   'conv2d_98[0][0]']
#
#  activation_180 (Activation)    (None, 64, 64, 16)   0           ['add_171[0][0]']
#
#  separable_conv2d_146 (Separabl  (None, 64, 64, 32)  688         ['activation_180[0][0]']
#  eConv2D)
#
#  batch_normalization_180 (Batch  (None, 64, 64, 32)  128         ['separable_conv2d_146[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_180[0][0]']
#
#  separable_conv2d_147 (Separabl  (None, 64, 64, 32)  1344        ['activation_181[0][0]']
#  eConv2D)
#
#  batch_normalization_181 (Batch  (None, 64, 64, 32)  128         ['separable_conv2d_147[0][0]']
#  Normalization)
#
#  max_pooling2d_65 (MaxPooling2D  (None, 32, 32, 32)  0           ['batch_normalization_181[0][0]']
#  )
#
#  conv2d_99 (Conv2D)             (None, 32, 32, 32)   544         ['add_171[0][0]']
#
#  add_172 (Add)                  (None, 32, 32, 32)   0           ['max_pooling2d_65[0][0]',
#                                                                   'conv2d_99[0][0]']
#
#  activation_182 (Activation)    (None, 32, 32, 32)   0           ['add_172[0][0]']
#
#  separable_conv2d_148 (Separabl  (None, 32, 32, 64)  2400        ['activation_182[0][0]']
#  eConv2D)
#
#  batch_normalization_182 (Batch  (None, 32, 32, 64)  256         ['separable_conv2d_148[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_182[0][0]']
#
#  separable_conv2d_149 (Separabl  (None, 32, 32, 64)  4736        ['activation_183[0][0]']
#  eConv2D)
#
#  batch_normalization_183 (Batch  (None, 32, 32, 64)  256         ['separable_conv2d_149[0][0]']
#  Normalization)
#
#  max_pooling2d_66 (MaxPooling2D  (None, 16, 16, 64)  0           ['batch_normalization_183[0][0]']
#  )
#
#  conv2d_100 (Conv2D)            (None, 16, 16, 64)   2112        ['add_172[0][0]']
#
#  add_173 (Add)                  (None, 16, 16, 64)   0           ['max_pooling2d_66[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  activation_184 (Activation)    (None, 16, 16, 64)   0           ['add_173[0][0]']
#
#  separable_conv2d_150 (Separabl  (None, 16, 16, 128)  8896       ['activation_184[0][0]']
#  eConv2D)
#
#  batch_normalization_184 (Batch  (None, 16, 16, 128)  512        ['separable_conv2d_150[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_184[0][0]']
#
#  separable_conv2d_151 (Separabl  (None, 16, 16, 128)  17664      ['activation_185[0][0]']
#  eConv2D)
#
#  batch_normalization_185 (Batch  (None, 16, 16, 128)  512        ['separable_conv2d_151[0][0]']
#  Normalization)
#
#  max_pooling2d_67 (MaxPooling2D  (None, 8, 8, 128)   0           ['batch_normalization_185[0][0]']
#  )
#
#  conv2d_101 (Conv2D)            (None, 8, 8, 128)    8320        ['add_173[0][0]']
#
#  add_174 (Add)                  (None, 8, 8, 128)    0           ['max_pooling2d_67[0][0]',
#                                                                   'conv2d_101[0][0]']
#
#  separable_conv2d_152 (Separabl  (None, 8, 8, 1024)  133248      ['add_174[0][0]']
#  eConv2D)
#
#  batch_normalization_186 (Batch  (None, 8, 8, 1024)  4096        ['separable_conv2d_152[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 8, 8, 1024)   0           ['batch_normalization_186[0][0]']
#
#  var (InputLayer)               [(None, 1)]          0           []
#
#  global_average_pooling2d_16 (G  (None, 1024)        0           ['activation_186[0][0]']
#  lobalAveragePooling2D)
#
#  embedding_14 (Embedding)       (None, 1, 1024)      102400      ['var[0][0]']
#
#  y (Flatten)                    (None, 1024)         0           ['global_average_pooling2d_16[0][
#                                                                  0]']
#
#  embedded (Flatten)             (None, 1024)         0           ['embedding_14[0][0]']
#
#  lambda_472 (Lambda)            (None, 1024)         0           ['y[0][0]',
#                                                                   'embedded[0][0]']
#
#  dense_16 (Dense)               (None, 10)           10250       ['lambda_472[0][0]']
#
#  reshape_7 (Reshape)            (None, 10, 1)        0           ['dense_16[0][0]']
#
#  tf.compat.v1.shape_7 (TFOpLamb  (3,)                0           ['reshape_7[0][0]']
#  da)
#
#  lambda_474 (Lambda)            (None, 10, 1)        0           ['reshape_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (3,)                0           ['tf.compat.v1.shape_7[0][0]']
#  mbda)
#
#  tf.math.pow_7 (TFOpLambda)     (None, 10, 1)        0           ['lambda_474[0][0]']
#
#  tf.ones_7 (TFOpLambda)         (None, None, None)   0           ['tf.__operators__.add_7[0][0]']
#
#  multiply_269 (Multiply)        (None, 10, 1)        0           ['reshape_7[0][0]',
#                                                                   'tf.math.pow_7[0][0]']
#
#  tf.convert_to_tensor_7 (TFOpLa  (None, None, None)  0           ['tf.ones_7[0][0]']
#  mbda)
#
#  tf.compat.v1.transpose_7 (TFOp  (None, 1, 10)       0           ['multiply_269[0][0]']
#  Lambda)
#
#  tf.linalg.band_part_7 (TFOpLam  (None, None, None)  0           ['tf.convert_to_tensor_7[0][0]']
#  bda)
#
#  multiply_270 (Multiply)        (None, None, 10)     0           ['tf.compat.v1.transpose_7[0][0]'
#                                                                  , 'tf.linalg.band_part_7[0][0]']
#
#  lambda_475 (Lambda)            (None, None)         0           ['multiply_270[0][0]']
#
#  lambda_476 (Lambda)            (None, 1)            0           ['lambda_475[0][0]']
#
#  concatenate_157 (Concatenate)  (None, None)         0           ['lambda_476[0][0]',
#                                                                   'lambda_475[0][0]']
#
#  dense_15 (Dense)               (None, 1)            1025        ['lambda_472[0][0]']
#
#  lambda_477 (Lambda)            (None, None)         0           ['concatenate_157[0][0]']
#
#  lambda_473 (Lambda)            (None, 1)            0           ['dense_15[0][0]']
#
#  add_175 (Add)                  (None, None)         0           ['lambda_477[0][0]',
#                                                                   'lambda_473[0][0]']
#
#  model_23 (Functional)          (None, 256, 256, 1)  701         ['input[0][0]',
#                                                                   'add_177[0][0]',
#                                                                   'add_179[0][0]',
#                                                                   'add_181[0][0]',
#                                                                   'add_183[0][0]',
#                                                                   'add_185[0][0]',
#                                                                   'add_187[0][0]',
#                                                                   'add_189[0][0]',
#                                                                   'add_191[0][0]',
#                                                                   'add_193[0][0]']
#
#  tf.expand_dims_157 (TFOpLambda  (None, None, 1)     0           ['add_175[0][0]']
#  )
#
#  lambda_480 (Lambda)            (None, 256, 256, 1)  0           ['model_23[0][0]']
#
#  lambda_478 (Lambda)            (None, 10, 1)        0           ['reshape_7[0][0]',
#                                                                   'tf.expand_dims_157[0][0]']
#
#  tf.ones_like_100 (TFOpLambda)  (None, 256, 256, 1)  0           ['input[0][0]']
#
#  lambda_481 (Lambda)            (None, 256, 256, 1)  0           ['lambda_480[0][0]']
#
#  coeff_spline (Concatenate)     (None, 10, 2)        0           ['lambda_478[0][0]',
#                                                                   'reshape_7[0][0]']
#
#  concatenate_158 (Concatenate)  (None, 256, 256, 2)  0           ['tf.ones_like_100[0][0]',
#                                                                   'lambda_481[0][0]']
#
#  lambda_479 (Lambda)            (None, 1, 1, 10, 2)  0           ['coeff_spline[0][0]']
#
#  lambda_482 (Lambda)            (None, 256, 256, 1,  0           ['concatenate_158[0][0]']
#                                  2)
#
#  tf.math.greater_equal_50 (TFOp  (None, 256, 256, 10  0          ['lambda_480[0][0]']
#  Lambda)                        )
#
#  tf.math.less_equal_50 (TFOpLam  (None, 256, 256, 10  0          ['lambda_480[0][0]']
#  bda)                           )
#
#  multiply_271 (Multiply)        (None, 256, 256, 10  0           ['lambda_479[0][0]',
#                                 , 2)                              'lambda_482[0][0]']
#
#  tf.math.logical_and_50 (TFOpLa  (None, 256, 256, 10  0          ['tf.math.greater_equal_50[0][0]'
#  mbda)                          )                                , 'tf.math.less_equal_50[0][0]']
#
#  lambda_483 (Lambda)            (None, 256, 256, 10  0           ['multiply_271[0][0]']
#                                 )
#
#  tf.cast_50 (TFOpLambda)        (None, 256, 256, 10  0           ['tf.math.logical_and_50[0][0]']
#                                 )
#
#  multiply_272 (Multiply)        (None, 256, 256, 10  0           ['lambda_483[0][0]',
#                                 )                                 'tf.cast_50[0][0]']
#
#  tf.zeros_like_101 (TFOpLambda)  (None, 256, 256, 1)  0          ['input[0][0]']
#  g_0 (Lambda)                   (None, 256, 256)     0           ['multiply_272[0][0]']
#
#  tf.__operators__.getitem_109 (  (None, 256, 1)      0           ['tf.zeros_like_101[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_158 (TFOpLambda  (None, 256, 256, 1)  0          ['g_0[0][0]']
#  )
#
#  lambda_484 (Lambda)            ((None, 256, 256, 1  0           ['input[0][0]']
#                                 ),
#                                  (None, 256, 256, 1
#                                 ))
#
#  tf.zeros_like_100 (TFOpLambda)  (None, 256, 256, 1)  0          ['input[0][0]']
#
#  tf.expand_dims_160 (TFOpLambda  (None, 1, 256, 1)   0           ['tf.__operators__.getitem_109[0]
#  )                                                               [0]']
#
#  multiply_274 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_158[0][0]',
#                                                                   'lambda_484[0][0]']
#
#  tf.__operators__.getitem_108 (  (None, 256, 1)      0           ['tf.zeros_like_100[0][0]']
#  SlicingOpLambda)
#
#  concatenate_159 (Concatenate)  (None, 257, 256, 1)  0           ['tf.expand_dims_160[0][0]',
#                                                                   'multiply_274[0][0]']
#
#  tf.expand_dims_159 (TFOpLambda  (None, 256, 1, 1)   0           ['tf.__operators__.getitem_108[0]
#  )                                                               [0]']
#
#  multiply_273 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_158[0][0]',
#                                                                   'lambda_484[0][1]']
#
#  lambda_485 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_159[0][0]']
#
#  concatenate_160 (Concatenate)  (None, 256, 257, 1)  0           ['tf.expand_dims_159[0][0]',
#                                                                   'multiply_273[0][0]']
#
#  tf.ones_like_101 (TFOpLambda)  (None, 256, 256, 1)  0           ['lambda_485[0][0]']
#
#  lambda_486 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_160[0][0]']
#
#  lambda_487 (Lambda)            (None, 256, 256, 1)  0           ['tf.ones_like_101[0][0]']
#
#  add_176 (Add)                  (None, 256, 256, 1)  0           ['lambda_485[0][0]',
#                                                                   'lambda_486[0][0]']
#
#  multiply_275 (Multiply)        (None, 256, 256, 1)  0           ['lambda_487[0][0]',
#                                                                   'add_176[0][0]']
#
#  add_177 (Add)                  (None, 256, 256, 1)  0           ['input[0][0]',
#                                                                   'multiply_275[0][0]']
#
#  lambda_488 (Lambda)            (None, 256, 256, 1)  0           ['model_23[1][0]']
#
#  tf.ones_like_102 (TFOpLambda)  (None, 256, 256, 1)  0           ['input[0][0]']
#
#  lambda_489 (Lambda)            (None, 256, 256, 1)  0           ['lambda_488[0][0]']
#
#  concatenate_161 (Concatenate)  (None, 256, 256, 2)  0           ['tf.ones_like_102[0][0]',
#                                                                   'lambda_489[0][0]']
#
#  lambda_490 (Lambda)            (None, 256, 256, 1,  0           ['concatenate_161[0][0]']
#                                  2)
#
#  tf.math.greater_equal_51 (TFOp  (None, 256, 256, 10  0          ['lambda_488[0][0]']
#  Lambda)                        )
#
#  tf.math.less_equal_51 (TFOpLam  (None, 256, 256, 10  0          ['lambda_488[0][0]']
#  bda)                           )
#
#  multiply_276 (Multiply)        (None, 256, 256, 10  0           ['lambda_479[0][0]',
#                                 , 2)                              'lambda_490[0][0]']
#
#  tf.math.logical_and_51 (TFOpLa  (None, 256, 256, 10  0          ['tf.math.greater_equal_51[0][0]'
#  mbda)                          )                                , 'tf.math.less_equal_51[0][0]']
#
#  lambda_491 (Lambda)            (None, 256, 256, 10  0           ['multiply_276[0][0]']
#                                 )
#
#  tf.cast_51 (TFOpLambda)        (None, 256, 256, 10  0           ['tf.math.logical_and_51[0][0]']
#                                 )
#  multiply_277 (Multiply)        (None, 256, 256, 10  0           ['lambda_491[0][0]',
#                                 )                                 'tf.cast_51[0][0]']
#
#  tf.zeros_like_103 (TFOpLambda)  (None, 256, 256, 1)  0          ['input[0][0]']
#
#  g_1 (Lambda)                   (None, 256, 256)     0           ['multiply_277[0][0]']
#
#  tf.__operators__.getitem_111 (  (None, 256, 1)      0           ['tf.zeros_like_103[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_161 (TFOpLambda  (None, 256, 256, 1)  0          ['g_1[0][0]']
#  )
#
#  lambda_492 (Lambda)            ((None, 256, 256, 1  0           ['add_177[0][0]']
#                                 ),
#                                  (None, 256, 256, 1
#                                 ))
#
#  tf.zeros_like_102 (TFOpLambda)  (None, 256, 256, 1)  0          ['add_177[0][0]']
#
#  tf.expand_dims_163 (TFOpLambda  (None, 1, 256, 1)   0           ['tf.__operators__.getitem_111[0]
#  )                                                               [0]']
#
#  multiply_279 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_161[0][0]',
#                                                                   'lambda_492[0][0]']
#
#  tf.__operators__.getitem_110 (  (None, 256, 1)      0           ['tf.zeros_like_102[0][0]']
#  SlicingOpLambda)
#
#  concatenate_162 (Concatenate)  (None, 257, 256, 1)  0           ['tf.expand_dims_163[0][0]',
#                                                                   'multiply_279[0][0]']
#
#  tf.expand_dims_162 (TFOpLambda  (None, 256, 1, 1)   0           ['tf.__operators__.getitem_110[0]
#  )                                                               [0]']
#
#  multiply_278 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_161[0][0]',
#                                                                   'lambda_492[0][1]']
#
#  lambda_493 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_162[0][0]']
#
#  concatenate_163 (Concatenate)  (None, 256, 257, 1)  0           ['tf.expand_dims_162[0][0]',
#                                                                   'multiply_278[0][0]']
#
#  tf.ones_like_103 (TFOpLambda)  (None, 256, 256, 1)  0           ['lambda_493[0][0]']
#
#  lambda_494 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_163[0][0]']
#
#  lambda_495 (Lambda)            (None, 256, 256, 1)  0           ['tf.ones_like_103[0][0]']
#
#  add_178 (Add)                  (None, 256, 256, 1)  0           ['lambda_493[0][0]',
#                                                                   'lambda_494[0][0]']
#
#  multiply_280 (Multiply)        (None, 256, 256, 1)  0           ['lambda_495[0][0]',
#                                                                   'add_178[0][0]']
#
#  add_179 (Add)                  (None, 256, 256, 1)  0           ['add_177[0][0]',
#                                                                   'multiply_280[0][0]']
#
#  lambda_496 (Lambda)            (None, 256, 256, 1)  0           ['model_23[2][0]']
#
#  tf.ones_like_104 (TFOpLambda)  (None, 256, 256, 1)  0           ['input[0][0]']
#
#  lambda_497 (Lambda)            (None, 256, 256, 1)  0           ['lambda_496[0][0]']
#
#  concatenate_164 (Concatenate)  (None, 256, 256, 2)  0           ['tf.ones_like_104[0][0]',
#                                                                   'lambda_497[0][0]']
#
#  lambda_498 (Lambda)            (None, 256, 256, 1,  0           ['concatenate_164[0][0]']
#                                  2)
#
#  tf.math.greater_equal_52 (TFOp  (None, 256, 256, 10  0          ['lambda_496[0][0]']
#  Lambda)                        )
#
#  tf.math.less_equal_52 (TFOpLam  (None, 256, 256, 10  0          ['lambda_496[0][0]']
#  bda)                           )
#
#  multiply_281 (Multiply)        (None, 256, 256, 10  0           ['lambda_479[0][0]',
#                                 , 2)                              'lambda_498[0][0]']
#
#  tf.math.logical_and_52 (TFOpLa  (None, 256, 256, 10  0          ['tf.math.greater_equal_52[0][0]'
#  mbda)                          )                                , 'tf.math.less_equal_52[0][0]']
#
#  lambda_499 (Lambda)            (None, 256, 256, 10  0           ['multiply_281[0][0]']
#                                 )
#
#  tf.cast_52 (TFOpLambda)        (None, 256, 256, 10  0           ['tf.math.logical_and_52[0][0]']
#                                 )
#
#  multiply_282 (Multiply)        (None, 256, 256, 10  0           ['lambda_499[0][0]',
#                                 )                                 'tf.cast_52[0][0]']
#
#  tf.zeros_like_105 (TFOpLambda)  (None, 256, 256, 1)  0          ['input[0][0]']
#
#  g_2 (Lambda)                   (None, 256, 256)     0           ['multiply_282[0][0]']
#
#  tf.__operators__.getitem_113 (  (None, 256, 1)      0           ['tf.zeros_like_105[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_164 (TFOpLambda  (None, 256, 256, 1)  0          ['g_2[0][0]']
#  )
#
#  lambda_500 (Lambda)            ((None, 256, 256, 1  0           ['add_179[0][0]']
#                                 ),
#                                  (None, 256, 256, 1
#                                 ))
#
#  tf.zeros_like_104 (TFOpLambda)  (None, 256, 256, 1)  0          ['add_179[0][0]']
#
#  tf.expand_dims_166 (TFOpLambda  (None, 1, 256, 1)   0           ['tf.__operators__.getitem_113[0]
#  )                                                               [0]']
#
#  multiply_284 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_164[0][0]',
#                                                                   'lambda_500[0][0]']
#
#  tf.__operators__.getitem_112 (  (None, 256, 1)      0           ['tf.zeros_like_104[0][0]']
#  SlicingOpLambda)
#
#  concatenate_165 (Concatenate)  (None, 257, 256, 1)  0           ['tf.expand_dims_166[0][0]',
#                                                                   'multiply_284[0][0]']
#
#  tf.expand_dims_165 (TFOpLambda  (None, 256, 1, 1)   0           ['tf.__operators__.getitem_112[0]
#  )                                                               [0]']
#
#  multiply_283 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_164[0][0]',
#                                                                   'lambda_500[0][1]']
#
#  lambda_501 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_165[0][0]']
#
#  concatenate_166 (Concatenate)  (None, 256, 257, 1)  0           ['tf.expand_dims_165[0][0]',
#                                                                   'multiply_283[0][0]']
#
#  tf.ones_like_105 (TFOpLambda)  (None, 256, 256, 1)  0           ['lambda_501[0][0]']
#
#  lambda_502 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_166[0][0]']
#
#  lambda_503 (Lambda)            (None, 256, 256, 1)  0           ['tf.ones_like_105[0][0]']
#
#  add_180 (Add)                  (None, 256, 256, 1)  0           ['lambda_501[0][0]',
#                                                                   'lambda_502[0][0]']
#
#  multiply_285 (Multiply)        (None, 256, 256, 1)  0           ['lambda_503[0][0]',
#                                                                   'add_180[0][0]']
#
#  add_181 (Add)                  (None, 256, 256, 1)  0           ['add_179[0][0]',
#                                                                   'multiply_285[0][0]']
#
#  lambda_504 (Lambda)            (None, 256, 256, 1)  0           ['model_23[3][0]']
#
#  tf.ones_like_106 (TFOpLambda)  (None, 256, 256, 1)  0           ['input[0][0]']
#
#  lambda_505 (Lambda)            (None, 256, 256, 1)  0           ['lambda_504[0][0]']
#
#  concatenate_167 (Concatenate)  (None, 256, 256, 2)  0           ['tf.ones_like_106[0][0]',
#                                                                   'lambda_505[0][0]']
#
#  lambda_506 (Lambda)            (None, 256, 256, 1,  0           ['concatenate_167[0][0]']
# ...
#  bda)                           )
#
#  multiply_311 (Multiply)        (None, 256, 256, 10  0           ['lambda_479[0][0]',
#                                 , 2)                              'lambda_546[0][0]']
#
#  tf.math.logical_and_58 (TFOpLa  (None, 256, 256, 10  0          ['tf.math.greater_equal_58[0][0]'
#  mbda)                          )                                , 'tf.math.less_equal_58[0][0]']
#
#  lambda_547 (Lambda)            (None, 256, 256, 10  0           ['multiply_311[0][0]']
#                                 )
#
#  tf.cast_58 (TFOpLambda)        (None, 256, 256, 10  0           ['tf.math.logical_and_58[0][0]']
#                                 )
#
#  multiply_312 (Multiply)        (None, 256, 256, 10  0           ['lambda_547[0][0]',
#                                 )                                 'tf.cast_58[0][0]']
#
#  tf.zeros_like_117 (TFOpLambda)  (None, 256, 256, 1)  0          ['input[0][0]']
#
#  g_8 (Lambda)                   (None, 256, 256)     0           ['multiply_312[0][0]']
#
#  tf.__operators__.getitem_125 (  (None, 256, 1)      0           ['tf.zeros_like_117[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_182 (TFOpLambda  (None, 256, 256, 1)  0          ['g_8[0][0]']
#  )
#
#  lambda_548 (Lambda)            ((None, 256, 256, 1  0           ['add_191[0][0]']
#                                 ),
#                                  (None, 256, 256, 1
#                                 ))
#
#  tf.zeros_like_116 (TFOpLambda)  (None, 256, 256, 1)  0          ['add_191[0][0]']
#
#  tf.expand_dims_184 (TFOpLambda  (None, 1, 256, 1)   0           ['tf.__operators__.getitem_125[0]
#  )                                                               [0]']
#
#  multiply_314 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_182[0][0]',
#                                                                   'lambda_548[0][0]']
#
#  tf.__operators__.getitem_124 (  (None, 256, 1)      0           ['tf.zeros_like_116[0][0]']
#  SlicingOpLambda)
#
#  concatenate_183 (Concatenate)  (None, 257, 256, 1)  0           ['tf.expand_dims_184[0][0]',
#                                                                   'multiply_314[0][0]']
#
#  tf.expand_dims_183 (TFOpLambda  (None, 256, 1, 1)   0           ['tf.__operators__.getitem_124[0]
#  )                                                               [0]']
#
#  multiply_313 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_182[0][0]',
#                                                                   'lambda_548[0][1]']
#
#  lambda_549 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_183[0][0]']
#
#  concatenate_184 (Concatenate)  (None, 256, 257, 1)  0           ['tf.expand_dims_183[0][0]',
#                                                                   'multiply_313[0][0]']
#
#  tf.ones_like_117 (TFOpLambda)  (None, 256, 256, 1)  0           ['lambda_549[0][0]']
#
#  lambda_550 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_184[0][0]']
#
#  lambda_551 (Lambda)            (None, 256, 256, 1)  0           ['tf.ones_like_117[0][0]']
#
#  add_192 (Add)                  (None, 256, 256, 1)  0           ['lambda_549[0][0]',
#                                                                   'lambda_550[0][0]']
#
#  multiply_315 (Multiply)        (None, 256, 256, 1)  0           ['lambda_551[0][0]',
#                                                                   'add_192[0][0]']
#
#  add_193 (Add)                  (None, 256, 256, 1)  0           ['add_191[0][0]',
#                                                                   'multiply_315[0][0]']
#
#  lambda_552 (Lambda)            (None, 256, 256, 1)  0           ['model_23[9][0]']
#
#  tf.ones_like_118 (TFOpLambda)  (None, 256, 256, 1)  0           ['input[0][0]']
#
#  lambda_553 (Lambda)            (None, 256, 256, 1)  0           ['lambda_552[0][0]']
#
#  concatenate_185 (Concatenate)  (None, 256, 256, 2)  0           ['tf.ones_like_118[0][0]',
#                                                                   'lambda_553[0][0]']
#
#  lambda_554 (Lambda)            (None, 256, 256, 1,  0           ['concatenate_185[0][0]']
#                                  2)
#
#  tf.math.greater_equal_59 (TFOp  (None, 256, 256, 10  0          ['lambda_552[0][0]']
#  Lambda)                        )
#
#  tf.math.less_equal_59 (TFOpLam  (None, 256, 256, 10  0          ['lambda_552[0][0]']
#  bda)                           )
#
#  multiply_316 (Multiply)        (None, 256, 256, 10  0           ['lambda_479[0][0]',
#                                 , 2)                              'lambda_554[0][0]']
#
#  tf.math.logical_and_59 (TFOpLa  (None, 256, 256, 10  0          ['tf.math.greater_equal_59[0][0]'
#  mbda)                          )                                , 'tf.math.less_equal_59[0][0]']
#
#  lambda_555 (Lambda)            (None, 256, 256, 10  0           ['multiply_316[0][0]']
#                                 )
#
#  tf.cast_59 (TFOpLambda)        (None, 256, 256, 10  0           ['tf.math.logical_and_59[0][0]']
#                                 )
#
#  multiply_317 (Multiply)        (None, 256, 256, 10  0           ['lambda_555[0][0]',
#                                 )                                 'tf.cast_59[0][0]']
#
#  tf.zeros_like_119 (TFOpLambda)  (None, 256, 256, 1)  0          ['input[0][0]']
#
#  g_9 (Lambda)                   (None, 256, 256)     0           ['multiply_317[0][0]']
#
#  tf.__operators__.getitem_127 (  (None, 256, 1)      0           ['tf.zeros_like_119[0][0]']
#  SlicingOpLambda)
#
#  tf.expand_dims_185 (TFOpLambda  (None, 256, 256, 1)  0          ['g_9[0][0]']
#  )
#
#  lambda_556 (Lambda)            ((None, 256, 256, 1  0           ['add_193[0][0]']
#                                 ),
#                                  (None, 256, 256, 1
#                                 ))
#
#  tf.zeros_like_118 (TFOpLambda)  (None, 256, 256, 1)  0          ['add_193[0][0]']
#
#  tf.expand_dims_187 (TFOpLambda  (None, 1, 256, 1)   0           ['tf.__operators__.getitem_127[0]
#  )                                                               [0]']
#
#  multiply_319 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_185[0][0]',
#                                                                   'lambda_556[0][0]']
#
#  tf.__operators__.getitem_126 (  (None, 256, 1)      0           ['tf.zeros_like_118[0][0]']
#  SlicingOpLambda)
#
#  concatenate_186 (Concatenate)  (None, 257, 256, 1)  0           ['tf.expand_dims_187[0][0]',
#                                                                   'multiply_319[0][0]']
#
#  tf.expand_dims_186 (TFOpLambda  (None, 256, 1, 1)   0           ['tf.__operators__.getitem_126[0]
#  )                                                               [0]']
#
#  multiply_318 (Multiply)        (None, 256, 256, 1)  0           ['tf.expand_dims_185[0][0]',
#                                                                   'lambda_556[0][1]']
#
#  lambda_557 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_186[0][0]']
#
#  concatenate_187 (Concatenate)  (None, 256, 257, 1)  0           ['tf.expand_dims_186[0][0]',
#                                                                   'multiply_318[0][0]']
#  tf.ones_like_119 (TFOpLambda)  (None, 256, 256, 1)  0           ['lambda_557[0][0]']
#
#  lambda_558 (Lambda)            (None, 256, 256, 1)  0           ['concatenate_187[0][0]']
#
#  lambda_559 (Lambda)            (None, 256, 256, 1)  0           ['tf.ones_like_119[0][0]']
#
#  add_194 (Add)                  (None, 256, 256, 1)  0           ['lambda_557[0][0]',
#                                                                   'lambda_558[0][0]']
#
#  multiply_320 (Multiply)        (None, 256, 256, 1)  0           ['lambda_559[0][0]',
#                                                                   'add_194[0][0]']
#
#  add_195 (Add)                  (None, 256, 256, 1)  0           ['add_193[0][0]',
#                                                                   'multiply_320[0][0]']
#
# ==================================================================================================
# Total params: 322,616
# Trainable params: 319,416
# Non-trainable params: 3,200
# __________________________________________________________________________________________________
