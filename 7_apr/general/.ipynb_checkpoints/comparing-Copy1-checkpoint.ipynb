# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl
import pandas as pd
from sklearn.mixture import GaussianMixture


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)
size = 5
pre_smoothing = False
conv = True
sigma = 0.1


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-05-22 20:46:26.564240: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-22 20:46:27.132734: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# 2023-05-22 20:46:27.133289: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# 2023-05-22 20:46:27.133294: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = []

for i in tqdm(glob('/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr/general/results/*')):
    v = np.load(i)
    j = i[:-4]
    for w,var in enumerate(np.arange(10,55,2.5)):
        df.append(np.concatenate((j.split('/')[-1].split('_'),[var],v[w])))
        
columns = ['architecture','loss','num_classes','degree','factor','type','chance','variance','psnr','psnr std','ssim','ssim std']
df = pd.DataFrame(df,columns=columns)
# Out:
# 100%|████████████████████████████████████| 21574/21574 [00:43<00:00, 500.53it/s]

# %%
df = df.replace('nan',0)
df['variance'] = pd.to_numeric(df['variance'])
df['psnr'] = pd.to_numeric(df['psnr'])
df['psnr std'] = pd.to_numeric(df['psnr std'])
df['ssim'] = pd.to_numeric(df['ssim'])
df['ssim std'] = pd.to_numeric(df['ssim std'])
df = df[df['psnr'] > 0]
df
# Out:
#        architecture      loss num_classes degree factor     type chance  \
# 0        decreasing  Hproduct          10      1      0  classic      1
# 1        decreasing  Hproduct          10      1      0  classic      1
# 2        decreasing  Hproduct          10      1      0  classic      1
# 3        decreasing  Hproduct          10      1      0  classic      1
# 4        decreasing  Hproduct          10      1      0  classic      1
# ...             ...       ...         ...    ...    ...      ...    ...
# 388327      splines      psnr           5      6      0  classic      9
# 388328      splines      psnr           5      6      0  classic      9
# 388329      splines      psnr           5      6      0  classic      9
# 388330      splines      psnr           5      6      0  classic      9
# 388331      splines      psnr           5      6      0  classic      9
#
#         variance       psnr  psnr std      ssim  ssim std
# 0           10.0  31.507936  1.578282  0.856892  0.045294
# 1           12.5  30.265808  1.445921  0.824235  0.052465
# 2           15.0  29.194902  1.422778  0.804859  0.054819
# 3           17.5  28.585098  1.444715  0.782385  0.054004
# 4           20.0  27.834023  1.374692  0.763934  0.055094
# ...          ...        ...       ...       ...       ...
# 388327      42.5  24.303587  1.430074  0.629435  0.051402
# 388328      45.0  23.954830  1.463100  0.617889  0.056216
# 388329      47.5  23.638805  1.441240  0.600821  0.054526
# 388330      50.0  23.354053  1.349713  0.590816  0.055653
# 388331      52.5  23.131508  1.400079  0.581038  0.057937
#
# [343358 rows x 12 columns]

# %%
X = df.groupby(['architecture']).mean().reset_index()[['architecture','psnr','ssim']].values.T
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.scatter(X[0],X[1])
plt.xlabel('architecture')
plt.ylabel('psnr')
plt.subplot(122)
plt.scatter(X[0],X[2])
plt.xlabel('architecture')
plt.ylabel('ssim')
plt.show()

# %%
X = df.groupby(['loss']).mean().reset_index()[['loss','psnr','ssim']].values.T
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.scatter(X[0],X[1])
plt.xlabel('architecture')
plt.ylabel('psnr')
plt.subplot(122)
plt.scatter(X[0],X[2])
plt.xlabel('architecture')
plt.ylabel('ssim')
plt.show()

# %%
def gaussian(frame_num,var=1,CROP = 256):
    input_path = frame_num

    img = np.asarray(cv2.cvtColor(cv2.imread(input_path), cv2.COLOR_BGR2GRAY), dtype=np.float32)
    img = cv2.resize(img,(CROP,CROP))
    img = img - np.mean(img)
    gauss = np.random.normal(0,var,img.shape)
    gauss = gauss.reshape(img.shape[0],img.shape[1])
    img_gauss = np.clip(np.copy(img) + gauss- np.amin(img),0,255)
    img_gauss = np.asarray(img_gauss,dtype = np.float32)

    img = img - np.amin(img)
    input_channel = img/np.amax(img)
    img_gauss = np.clip(img_gauss/np.amax(img),0,1)

    return np.array([input_channel, img_gauss])

# %%
barbara = [47.86,42.92,37.19,32.83,30.22,28.32,27.04,23.15,21.39,19.77]
boats = [47.69,42.28,36.27,33.05,31.22,29.85,28.72,24.53,22.48,20.80]
house = [48.32,44.01,38.23,35.06,33.48,32.17,31.11,26.74,24.13,21.66]
peppers = [47.81,42.96,37.63,34.28,32.03,30.58,29.20,24.52,21.68,19.60]

foe = [house,peppers,barbara,boats]


variance = [1,2,5,10,15,20,25,50,75,100]
set12_256_l = ['../../images/Set12/02.png','../../images/Set12/03.png']
set12_512_l = ['../../images/Set12/09.png','../../images/Set12/10.png']


set12_256 = np.array([[gaussian(im,var=v,CROP=256) for v in variance] for im in set12_256_l])
ys_256,noisy_256 = set12_256[:,:,0],set12_256[:,:,1]
ys_256,noisy_256 = np.concatenate(ys_256),np.concatenate(noisy_256)
ys_256,noisy_256 = np.expand_dims(ys_256,axis=-1),np.expand_dims(noisy_256,axis=-1)

set12_512 = np.array([[gaussian(im,var=v,CROP=512) for v in variance] for im in set12_512_l])
ys_512,noisy_512 = set12_512[:,:,0],set12_512[:,:,1]
ys_512,noisy_512 = np.concatenate(ys_512),np.concatenate(noisy_512)
ys_512,noisy_512 = np.expand_dims(ys_512,axis=-1),np.expand_dims(noisy_512,axis=-1)

# %%
losses_names = ['product','psnr','Hpsnr','Hproduct']
architectures = ['splines','decreasing','flux','fluxdecreasing']
it_lim = 10

df = []



for arch in architectures:

    for loss in losses_names:

        order = 1
        for num_classes in [5,10,15,20,25,50]:

            for degree in np.arange(1,7):
                
                print(arch,loss,num_classes,degree)

                for f1,factor in enumerate([0.001]):

                    for typee in ['classic','noconstraints','nopretrained','diffop','foe','foek']:
                        
                        if len(glob(f"/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr/{arch}/checkpoints/{arch}_{loss}_{num_classes}_{degree}_{f1}_{typee}_0*"))==0:
                            continue

                        model_256 = get_model(arch,it_lim=it_lim,image_size=image_size,num_classes = num_classes,
                                                      second=True,degree1=degree,factor=factor,typee=typee)
                        model_256.load_weights(f"/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr/{arch}/checkpoints/{arch}_{loss}_{num_classes}_{degree}_{f1}_{typee}_0")


                        model_512 = get_model(arch,it_lim=it_lim,image_size=(512,512),num_classes = num_classes,
                                                      second=True,degree1=degree,factor=factor,typee=typee)
                        model_512.load_weights(f"/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr/{arch}/checkpoints/{arch}_{loss}_{num_classes}_{degree}_{f1}_{typee}_0")

                        denoised_256 = model_256(noisy_256)
                        denoised_512 = model_512(noisy_512)

                        psnr_256 = np.array(tf.image.psnr(denoised_256,ys_256,1))
                        psnr_512 = np.array(tf.image.psnr(denoised_512,ys_512,1))
                        h = psnr_256[:len(variance)]
                        p = psnr_256[len(variance):]
                        b = psnr_512[:len(variance)]
                        bo = psnr_512[len(variance):]

                        ih,ip,ib,ibo = h - house,p-peppers,b - barbara, bo - boats

                        for v,var in enumerate(variance):

                            df.append([arch,loss,num_classes,degree,factor,typee,var,ih[v],ip[v],ib[v],ibo[v]])
# Out:
# splines product 5 1
# splines product 5 2
# splines product 5 3
# splines product 5 4
# splines product 5 5
# splines product 5 6
# splines product 10 1
# splines product 10 2
# splines product 10 3
# splines product 10 4
# splines product 10 5
# splines product 10 6
# splines product 15 1
# splines product 15 2
# splines product 15 3
# splines product 15 4
# splines product 15 5
# splines product 15 6
# splines product 20 1
# splines product 20 2
# splines product 20 3
# splines product 20 4
# splines product 20 5
# splines product 20 6
# splines product 25 1
# splines product 25 2
# splines product 25 3
# splines product 25 4
# splines product 25 5
# splines product 25 6
# splines product 50 1
# splines product 50 2
# splines product 50 3
# splines product 50 4
# splines product 50 5
# splines product 50 6
# splines psnr 5 1
# splines psnr 5 2
# splines psnr 5 3
# splines psnr 5 4
# splines psnr 5 5
# splines psnr 5 6
# splines psnr 10 1
# splines psnr 10 2
# splines psnr 10 3
# splines psnr 10 4
# splines psnr 10 5
# splines psnr 10 6
# splines psnr 15 1
# splines psnr 15 2
# splines psnr 15 3
# splines psnr 15 4
# splines psnr 15 5
# splines psnr 15 6
# splines psnr 20 1
# splines psnr 20 2
# splines psnr 20 3
# splines psnr 20 4
# splines psnr 20 5
# splines psnr 20 6
# splines psnr 25 1
# splines psnr 25 2
# splines psnr 25 3
# splines psnr 25 4
# splines psnr 25 5
# splines psnr 25 6
# splines psnr 50 1
# splines psnr 50 2
# splines psnr 50 3
# splines psnr 50 4
# splines psnr 50 5
# splines psnr 50 6
# splines Hpsnr 5 1
# splines Hpsnr 5 2
# splines Hpsnr 5 3
# splines Hpsnr 5 4
# splines Hpsnr 5 5
# splines Hpsnr 5 6
# splines Hpsnr 10 1
# splines Hpsnr 10 2
# splines Hpsnr 10 3
# splines Hpsnr 10 4
# splines Hpsnr 10 5
# splines Hpsnr 10 6
# splines Hpsnr 15 1
# splines Hpsnr 15 2
# splines Hpsnr 15 3
# splines Hpsnr 15 4
# splines Hpsnr 15 5
# splines Hpsnr 15 6
# splines Hpsnr 20 1
# splines Hpsnr 20 2
# splines Hpsnr 20 3
# splines Hpsnr 20 4
# splines Hpsnr 20 5
# splines Hpsnr 20 6
# splines Hpsnr 25 1
# splines Hpsnr 25 2
# splines Hpsnr 25 3
# splines Hpsnr 25 4
# splines Hpsnr 25 5
# splines Hpsnr 25 6
# splines Hpsnr 50 1
# splines Hpsnr 50 2
# splines Hpsnr 50 3
# splines Hpsnr 50 4
# splines Hpsnr 50 5
# splines Hpsnr 50 6
# splines Hproduct 5 1
# splines Hproduct 5 2
# splines Hproduct 5 3
# splines Hproduct 5 4
# splines Hproduct 5 5
# splines Hproduct 5 6
# splines Hproduct 10 1
# splines Hproduct 10 2
# splines Hproduct 10 3
# splines Hproduct 10 4
# splines Hproduct 10 5
# splines Hproduct 10 6
# splines Hproduct 15 1
# splines Hproduct 15 2
# splines Hproduct 15 3
# splines Hproduct 15 4
# splines Hproduct 15 5
# splines Hproduct 15 6
# splines Hproduct 20 1
# splines Hproduct 20 2
# splines Hproduct 20 3
# splines Hproduct 20 4
# splines Hproduct 20 5
# splines Hproduct 20 6
# splines Hproduct 25 1
# splines Hproduct 25 2
# splines Hproduct 25 3
# splines Hproduct 25 4
# splines Hproduct 25 5
# splines Hproduct 25 6
# splines Hproduct 50 1
# splines Hproduct 50 2
# splines Hproduct 50 3
# splines Hproduct 50 4
# splines Hproduct 50 5
# splines Hproduct 50 6
# decreasing product 5 1
# decreasing product 5 2
# decreasing product 5 3
# decreasing product 5 4
# decreasing product 5 5
# decreasing product 5 6
# decreasing product 10 1
# decreasing product 10 2
# decreasing product 10 3
# decreasing product 10 4
# decreasing product 10 5
# decreasing product 10 6
# decreasing product 15 1
# decreasing product 15 2
# decreasing product 15 3
# decreasing product 15 4
# decreasing product 15 5
# decreasing product 15 6
# decreasing product 20 1
# decreasing product 20 2
# decreasing product 20 3
# decreasing product 20 4
# decreasing product 20 5
# decreasing product 20 6
# decreasing product 25 1
# decreasing product 25 2
# decreasing product 25 3
# decreasing product 25 4
# decreasing product 25 5
# decreasing product 25 6
# decreasing product 50 1
# decreasing product 50 2
# decreasing product 50 3
# decreasing product 50 4
# decreasing product 50 5
# decreasing product 50 6
# decreasing psnr 5 1
# decreasing psnr 5 2
# decreasing psnr 5 3
# decreasing psnr 5 4
# decreasing psnr 5 5
# decreasing psnr 5 6
# decreasing psnr 10 1
# decreasing psnr 10 2
# decreasing psnr 10 3
# decreasing psnr 10 4
# decreasing psnr 10 5
# decreasing psnr 10 6
# decreasing psnr 15 1
# decreasing psnr 15 2
# decreasing psnr 15 3
# decreasing psnr 15 4
# decreasing psnr 15 5
# decreasing psnr 15 6
# decreasing psnr 20 1
# decreasing psnr 20 2
# decreasing psnr 20 3
# decreasing psnr 20 4
# decreasing psnr 20 5
# decreasing psnr 20 6
# decreasing psnr 25 1
# decreasing psnr 25 2
# decreasing psnr 25 3
# decreasing psnr 25 4
# decreasing psnr 25 5
# decreasing psnr 25 6
# decreasing psnr 50 1
# decreasing psnr 50 2
# decreasing psnr 50 3
# decreasing psnr 50 4
# decreasing psnr 50 5
# decreasing psnr 50 6
# decreasing Hpsnr 5 1
# decreasing Hpsnr 5 2
# decreasing Hpsnr 5 3
# decreasing Hpsnr 5 4
# decreasing Hpsnr 5 5
# decreasing Hpsnr 5 6
# decreasing Hpsnr 10 1
# decreasing Hpsnr 10 2
# decreasing Hpsnr 10 3
# decreasing Hpsnr 10 4
# decreasing Hpsnr 10 5
# decreasing Hpsnr 10 6
# decreasing Hpsnr 15 1
# decreasing Hpsnr 15 2
# decreasing Hpsnr 15 3
# decreasing Hpsnr 15 4
# decreasing Hpsnr 15 5
# decreasing Hpsnr 15 6
# decreasing Hpsnr 20 1
# decreasing Hpsnr 20 2
# decreasing Hpsnr 20 3
# decreasing Hpsnr 20 4
# decreasing Hpsnr 20 5
# decreasing Hpsnr 20 6
# decreasing Hpsnr 25 1
# decreasing Hpsnr 25 2
# decreasing Hpsnr 25 3
# decreasing Hpsnr 25 4
# decreasing Hpsnr 25 5
# decreasing Hpsnr 25 6
# decreasing Hpsnr 50 1
# decreasing Hpsnr 50 2
# decreasing Hpsnr 50 3
# decreasing Hpsnr 50 4
# decreasing Hpsnr 50 5
# decreasing Hpsnr 50 6
# decreasing Hproduct 5 1
# decreasing Hproduct 5 2
# decreasing Hproduct 5 3
# decreasing Hproduct 5 4
# decreasing Hproduct 5 5
# decreasing Hproduct 5 6
# decreasing Hproduct 10 1
# decreasing Hproduct 10 2
# decreasing Hproduct 10 3
# decreasing Hproduct 10 4
# decreasing Hproduct 10 5
# decreasing Hproduct 10 6
# decreasing Hproduct 15 1
# decreasing Hproduct 15 2
# decreasing Hproduct 15 3
# decreasing Hproduct 15 4
# decreasing Hproduct 15 5
# decreasing Hproduct 15 6
# decreasing Hproduct 20 1
# decreasing Hproduct 20 2
# decreasing Hproduct 20 3
# decreasing Hproduct 20 4
# decreasing Hproduct 20 5
# decreasing Hproduct 20 6
# decreasing Hproduct 25 1
# decreasing Hproduct 25 2
# decreasing Hproduct 25 3
# decreasing Hproduct 25 4
# decreasing Hproduct 25 5
# decreasing Hproduct 25 6
# decreasing Hproduct 50 1
# decreasing Hproduct 50 2
# decreasing Hproduct 50 3
# decreasing Hproduct 50 4
# decreasing Hproduct 50 5
# decreasing Hproduct 50 6
# flux product 5 1
# flux product 5 2
# flux product 5 3
# flux product 5 4
# flux product 5 5
# flux product 5 6
# flux product 10 1
# flux product 10 2
# flux product 10 3
# flux product 10 4
# flux product 10 5
# flux product 10 6
# flux product 15 1
# flux product 15 2
# flux product 15 3
# flux product 15 4
# flux product 15 5
# flux product 15 6
# flux product 20 1
# flux product 20 2
# flux product 20 3
# flux product 20 4
# flux product 20 5
# flux product 20 6
# flux product 25 1
# flux product 25 2
# flux product 25 3
# flux product 25 4
# flux product 25 5
# flux product 25 6
# flux product 50 1
# flux product 50 2
# flux product 50 3
# flux product 50 4
# flux product 50 5
# flux product 50 6
# flux psnr 5 1
# flux psnr 5 2
# flux psnr 5 3
# flux psnr 5 4
# flux psnr 5 5
# flux psnr 5 6
# flux psnr 10 1
# flux psnr 10 2
# flux psnr 10 3
# flux psnr 10 4
# flux psnr 10 5
# flux psnr 10 6
# flux psnr 15 1
# flux psnr 15 2
# flux psnr 15 3
# flux psnr 15 4
# flux psnr 15 5
# flux psnr 15 6
# flux psnr 20 1
# flux psnr 20 2
# flux psnr 20 3
# flux psnr 20 4
# flux psnr 20 5
# flux psnr 20 6
# flux psnr 25 1
# flux psnr 25 2
# flux psnr 25 3
# flux psnr 25 4
# flux psnr 25 5
# flux psnr 25 6
# flux psnr 50 1
# flux psnr 50 2
# flux psnr 50 3
# flux psnr 50 4
# flux psnr 50 5
# flux psnr 50 6
# flux Hpsnr 5 1
# flux Hpsnr 5 2
# flux Hpsnr 5 3
# flux Hpsnr 5 4
# flux Hpsnr 5 5
# flux Hpsnr 5 6
# flux Hpsnr 10 1
# flux Hpsnr 10 2
# flux Hpsnr 10 3
# flux Hpsnr 10 4
# flux Hpsnr 10 5
# flux Hpsnr 10 6
# flux Hpsnr 15 1
# flux Hpsnr 15 2
# flux Hpsnr 15 3
# flux Hpsnr 15 4
# flux Hpsnr 15 5
# flux Hpsnr 15 6
# flux Hpsnr 20 1
# flux Hpsnr 20 2
# flux Hpsnr 20 3
# flux Hpsnr 20 4
# flux Hpsnr 20 5
# flux Hpsnr 20 6
# flux Hpsnr 25 1
# flux Hpsnr 25 2
# flux Hpsnr 25 3
# flux Hpsnr 25 4
# flux Hpsnr 25 5
# flux Hpsnr 25 6
# flux Hpsnr 50 1
# flux Hpsnr 50 2
# flux Hpsnr 50 3
# flux Hpsnr 50 4
# flux Hpsnr 50 5
# flux Hpsnr 50 6
# flux Hproduct 5 1
# flux Hproduct 5 2
# flux Hproduct 5 3
# flux Hproduct 5 4
# flux Hproduct 5 5
# flux Hproduct 5 6
# flux Hproduct 10 1
# flux Hproduct 10 2
# flux Hproduct 10 3
# flux Hproduct 10 4
# flux Hproduct 10 5
# flux Hproduct 10 6
# flux Hproduct 15 1
# flux Hproduct 15 2
# flux Hproduct 15 3
# flux Hproduct 15 4
# flux Hproduct 15 5
# flux Hproduct 15 6
# flux Hproduct 20 1
# flux Hproduct 20 2
# flux Hproduct 20 3
# flux Hproduct 20 4
# flux Hproduct 20 5
# flux Hproduct 20 6
# flux Hproduct 25 1
# flux Hproduct 25 2
# flux Hproduct 25 3
# flux Hproduct 25 4
# flux Hproduct 25 5
# flux Hproduct 25 6
# flux Hproduct 50 1
# flux Hproduct 50 2
# flux Hproduct 50 3
# flux Hproduct 50 4
# flux Hproduct 50 5
# flux Hproduct 50 6
# fluxdecreasing product 5 1
# fluxdecreasing product 5 2
# fluxdecreasing product 5 3
# fluxdecreasing product 5 4
# fluxdecreasing product 5 5
# fluxdecreasing product 5 6
# fluxdecreasing product 10 1
# fluxdecreasing product 10 2
# fluxdecreasing product 10 3
# fluxdecreasing product 10 4
# fluxdecreasing product 10 5
# fluxdecreasing product 10 6
# fluxdecreasing product 15 1
# fluxdecreasing product 15 2
# fluxdecreasing product 15 3
# fluxdecreasing product 15 4
# fluxdecreasing product 15 5
# fluxdecreasing product 15 6
# fluxdecreasing product 20 1
# fluxdecreasing product 20 2
# fluxdecreasing product 20 3
# fluxdecreasing product 20 4
# fluxdecreasing product 20 5
# fluxdecreasing product 20 6
# fluxdecreasing product 25 1
# fluxdecreasing product 25 2
# fluxdecreasing product 25 3
# fluxdecreasing product 25 4
# fluxdecreasing product 25 5
# fluxdecreasing product 25 6
# fluxdecreasing product 50 1
# fluxdecreasing product 50 2
# fluxdecreasing product 50 3
# fluxdecreasing product 50 4
# fluxdecreasing product 50 5
# fluxdecreasing product 50 6
# fluxdecreasing psnr 5 1
# fluxdecreasing psnr 5 2
# fluxdecreasing psnr 5 3
# fluxdecreasing psnr 5 4
# fluxdecreasing psnr 5 5
# fluxdecreasing psnr 5 6
# fluxdecreasing psnr 10 1
# fluxdecreasing psnr 10 2
# fluxdecreasing psnr 10 3
# fluxdecreasing psnr 10 4
# fluxdecreasing psnr 10 5
# fluxdecreasing psnr 10 6
# fluxdecreasing psnr 15 1
# fluxdecreasing psnr 15 2
# fluxdecreasing psnr 15 3
# fluxdecreasing psnr 15 4
# fluxdecreasing psnr 15 5
# fluxdecreasing psnr 15 6
# fluxdecreasing psnr 20 1
# fluxdecreasing psnr 20 2
# fluxdecreasing psnr 20 3
# fluxdecreasing psnr 20 4
# fluxdecreasing psnr 20 5
# fluxdecreasing psnr 20 6
# fluxdecreasing psnr 25 1
# fluxdecreasing psnr 25 2
# fluxdecreasing psnr 25 3
# fluxdecreasing psnr 25 4
# fluxdecreasing psnr 25 5
# fluxdecreasing psnr 25 6
# fluxdecreasing psnr 50 1
# fluxdecreasing psnr 50 2
# fluxdecreasing psnr 50 3
# fluxdecreasing psnr 50 4
# fluxdecreasing psnr 50 5
# fluxdecreasing psnr 50 6
# fluxdecreasing Hpsnr 5 1
# fluxdecreasing Hpsnr 5 2
# fluxdecreasing Hpsnr 5 3
# fluxdecreasing Hpsnr 5 4
# fluxdecreasing Hpsnr 5 5
# fluxdecreasing Hpsnr 5 6
# fluxdecreasing Hpsnr 10 1
# fluxdecreasing Hpsnr 10 2
# fluxdecreasing Hpsnr 10 3
# fluxdecreasing Hpsnr 10 4
# fluxdecreasing Hpsnr 10 5
# fluxdecreasing Hpsnr 10 6
# fluxdecreasing Hpsnr 15 1
# fluxdecreasing Hpsnr 15 2
# fluxdecreasing Hpsnr 15 3
# fluxdecreasing Hpsnr 15 4
# fluxdecreasing Hpsnr 15 5
# fluxdecreasing Hpsnr 15 6
# fluxdecreasing Hpsnr 20 1
# fluxdecreasing Hpsnr 20 2
# fluxdecreasing Hpsnr 20 3
# fluxdecreasing Hpsnr 20 4
# fluxdecreasing Hpsnr 20 5
# fluxdecreasing Hpsnr 20 6
# fluxdecreasing Hpsnr 25 1
# fluxdecreasing Hpsnr 25 2
# fluxdecreasing Hpsnr 25 3
# fluxdecreasing Hpsnr 25 4
# fluxdecreasing Hpsnr 25 5
# fluxdecreasing Hpsnr 25 6
# fluxdecreasing Hpsnr 50 1
# fluxdecreasing Hpsnr 50 2
# fluxdecreasing Hpsnr 50 3
# fluxdecreasing Hpsnr 50 4
# fluxdecreasing Hpsnr 50 5
# fluxdecreasing Hpsnr 50 6
# fluxdecreasing Hproduct 5 1
# fluxdecreasing Hproduct 5 2
# fluxdecreasing Hproduct 5 3
# fluxdecreasing Hproduct 5 4
# fluxdecreasing Hproduct 5 5
# fluxdecreasing Hproduct 5 6
# fluxdecreasing Hproduct 10 1
# fluxdecreasing Hproduct 10 2
# fluxdecreasing Hproduct 10 3
# fluxdecreasing Hproduct 10 4
# fluxdecreasing Hproduct 10 5
# fluxdecreasing Hproduct 10 6
# fluxdecreasing Hproduct 15 1
# fluxdecreasing Hproduct 15 2
# fluxdecreasing Hproduct 15 3
# fluxdecreasing Hproduct 15 4
# fluxdecreasing Hproduct 15 5
# fluxdecreasing Hproduct 15 6
# fluxdecreasing Hproduct 20 1
# fluxdecreasing Hproduct 20 2
# fluxdecreasing Hproduct 20 3
# fluxdecreasing Hproduct 20 4
# fluxdecreasing Hproduct 20 5
# fluxdecreasing Hproduct 20 6
# fluxdecreasing Hproduct 25 1
# fluxdecreasing Hproduct 25 2
# fluxdecreasing Hproduct 25 3
# fluxdecreasing Hproduct 25 4
# fluxdecreasing Hproduct 25 5
# fluxdecreasing Hproduct 25 6
# fluxdecreasing Hproduct 50 1
# fluxdecreasing Hproduct 50 2
# fluxdecreasing Hproduct 50 3
# fluxdecreasing Hproduct 50 4
# fluxdecreasing Hproduct 50 5
# fluxdecreasing Hproduct 50 6

# %%
columns = ['architecture','loss','num classes','degree','factor','type','variance','house','peppers','barbara','boat']
df = pd.DataFrame(df,columns=columns)
df.to_csv('./vsFoE.csv')

# %%
improvements = df.groupby(['architecture','loss','num classes','degree','factor','type']).mean().reset_index()


filters = ['architecture','loss','num classes','degree','type']
pictures = ['house','peppers','barbara','boat']

best = []

for p in pictures:

    best_filters = improvements[improvements[p] == improvements[p].max()][filters].values[0]
    best.append(df[(df['architecture'] == best_filters[0])&(df['loss']==best_filters[1])
  &(df['num classes']==best_filters[2])&(df['degree']==best_filters[3])
  &(df['type']==best_filters[4])])

# %%
fig,axs = plt.subplots(ncols=2,nrows=2,figsize=(15,8))

for i in range(4):
    for b in range(4):
        axs[i//2,i%2].scatter(foe[i],foe[i]+best[b][pictures[i]].values)
        m,M = np.amin(foe),np.amax(foe)
    axs[i//2,i%2].plot([m,M],[m,M],label='identity')
        
    axs[i//2,i%2].legend()
    axs[i//2,i%2].set_title(pictures[i])
    axs[i//2,i%2].set_xlabel('psnr\nFoE')
    axs[i//2,i%2].set_ylabel('psnr\nmy results')
    
plt.tight_layout()
plt.show()
