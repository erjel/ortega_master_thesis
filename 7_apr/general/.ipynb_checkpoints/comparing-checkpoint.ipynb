# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl
import pandas as pd
from sklearn.mixture import GaussianMixture


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)
size = 5
pre_smoothing = False
conv = True
sigma = 0.1


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-05-12 19:02:32.843929: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-12 19:02:33.399854: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# ...

# %%
df = []
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'
it_lim = 10

losses_names = ['H1','L2','W1infty','Linfty','product','psnr']
architectures = ['splines','decreasing','flux']



for var in np.arange(10,55,2.5):
    print(var)
    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=var,var1_u=var,CROP1=CROP,BATCH_SIZE=300,N_REPEAT_FRAME1=1)

    xs, ys = next(gen_batch_val.as_numpy_iterator())
    
    pm = np.array([anisodiff(im,niter = 3,lambd=50) for im in xs])
    pm = np.asarray(pm,dtype='float32')
    
    psnr = tf.reduce_mean(tf.image.psnr(ys,pm,1)).numpy()
    psnr_std = np.std(tf.image.psnr(ys,pm,1).numpy())
    ssim = tf.reduce_mean(tf.image.ssim(ys,pm,1)).numpy()
    ssim_std = np.std(tf.image.ssim(ys,pm,1).numpy())
    
    filling = -np.ones(7)
    df.append(np.concatenate((['pm',var,psnr,psnr_std,ssim,ssim_std,'NA'],filling)))
    
    for N_REPEAT_FRAME1 in np.arange(2,32,2):

            for arch in architectures:
                print(arch)

                for loss in losses_names:
                    print(loss)

                    order = 1
                    for num_classes in [5,10,15,20,25,50]:
                        print('num_classes: ',num_classes)
                        
                        if arch == 'flux' and num_classes >= 50:
                            continue

                        for degree in np.arange(1,6):

                            for f1,factor in enumerate([1]):

                                for use_polynomial in [True,False]:

                                    if use_polynomial:

                                        for polynomial_degree in range(1,3):
                                            
                                            if len(glob(f"{path}/{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_{it_lim}_t{degree}_{f1}_t{polynomial_degree}*")) > 0:
                                                model = get_model(arch,it_lim=it_lim,image_size=image_size,num_classes = num_classes,
                                                          second=True,degree1=degree,factor=factor)
                                                model.load_weights(f"{path}/{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_{it_lim}_t{degree}_{f1}_t{polynomial_degree}")
                                                
                                                p = model(xs)
                                                
                                                psnr = tf.reduce_mean(tf.image.psnr(ys,p,1)).numpy()
                                                psnr_std = np.std(tf.image.psnr(ys,p,1).numpy())
                                                ssim = tf.reduce_mean(tf.image.ssim(ys,p,1)).numpy()
                                                ssim_std = np.std(tf.image.ssim(ys,p,1).numpy())
                                                
                                                df.append([arch,var,psnr,psnr_std,ssim,ssim_std,'True',loss,num_classes,N_REPEAT_FRAME1,degree,factor,str(use_polynomial),polynomial_degree])
                                            
                                    else:
                                        if len(glob(f"{path}/{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_{it_lim}_t{degree}_{f1}_f*"))>0:
                                            
                                            
                                             
                                                
                                            model = get_model(arch,it_lim=it_lim,image_size=image_size,num_classes = num_classes,
                                                      second=True,degree1=degree,factor=factor)
                                            model.load_weights(f"{path}/{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_{it_lim}_t{degree}_{f1}_f")
                                            
                                            p = model(xs)
                                            
                                            psnr = tf.reduce_mean(tf.image.psnr(ys,p,1)).numpy()
                                            psnr_std = np.std(tf.image.psnr(ys,p,1).numpy())
                                            ssim = tf.reduce_mean(tf.image.ssim(ys,p,1)).numpy()
                                            ssim_std = np.std(tf.image.ssim(ys,p,1).numpy())

                                            df.append([arch,var,psnr,psnr_std,ssim,ssim_std,'True',loss,num_classes,N_REPEAT_FRAME1,degree,factor,str(use_polynomial),-1])

                                            
                        
                        if len(glob(f"{path}/{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_{it_lim}_f*")) > 0:
                            
                        
                            model = get_model(arch,it_lim=it_lim,image_size=image_size,num_classes = num_classes,second=False)
                            model.load_weights(f"{path}/{arch}/checkpoints/{arch}{loss}_{typ}_{num_classes}_{N_REPEAT_FRAME1}_{it_lim}_f")


                            p = model(xs)

                            psnr = tf.reduce_mean(tf.image.psnr(ys,p,1)).numpy()
                            psnr_std = np.std(tf.image.psnr(ys,p,1).numpy())
                            ssim = tf.reduce_mean(tf.image.ssim(ys,p,1)).numpy()
                            ssim_std = np.std(tf.image.ssim(ys,p,1).numpy())

                            df.append([arch,var,psnr,psnr_std,ssim,ssim_std,'False',loss,num_classes,N_REPEAT_FRAME1,-1,-1,-1,-1])
# Out:
# 10.0
# 2023-04-28 17:14:37.458691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-28 17:14:37.458909: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-28 17:14:37.464228: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-28 17:14:37.464450: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
df = pd.DataFrame(np.array(df),columns=['architecture','variance','psnr','psnr std','ssim','ssim std','second',
                                       'loss','num classes','num repeat','degree','factor','polynomial','polynomial degree'])
df = df.replace('nan',0)
df['variance'] = pd.to_numeric(df['variance'])
df['psnr'] = pd.to_numeric(df['psnr'])
df['psnr std'] = pd.to_numeric(df['psnr std'])
df['ssim'] = pd.to_numeric(df['ssim'])
df['ssim std'] = pd.to_numeric(df['ssim std'])
df['num classes'] = pd.to_numeric(df['num classes'])
df['num repeat'] = pd.to_numeric(df['num repeat'])
df['degree'] = pd.to_numeric(df['degree'])
df['factor'] = pd.to_numeric(df['factor'])
df['polynomial degree'] = pd.to_numeric(df['polynomial degree'])
#df.to_csv('./general_comparison_big.csv')


nn = df[df['architecture'] != 'pm']
df
# Out:
#       architecture  variance       psnr  psnr std      ssim  ssim std second  \
# 0               pm      10.0  31.545715  1.512135  0.881889  0.026082     NA
# 1          splines      10.0  30.925417  1.854711  0.854960  0.049516   True
# 2          splines      10.0  28.072699  5.023682  0.779169  0.177479   True
# 3          splines      10.0  31.081562  0.861710  0.815590  0.064510   True
# 4          splines      10.0  31.574312  0.795699  0.832718  0.058930   True
# ...            ...       ...        ...       ...       ...       ...    ...
# 98739   decreasing      50.0  23.419243  1.376060  0.602388  0.048515   True
# 98740   decreasing      50.0  23.209457  1.602644  0.587045  0.078789  False
# 98741   decreasing      50.0  23.370290  1.472157  0.610070  0.065843  False
# 98742   decreasing      50.0  23.381790  1.453101  0.606597  0.059802  False
# 98743   decreasing      50.0  23.387630  1.491934  0.600688  0.058733  False
#
# ...

# %%
X = nn[nn['psnr']>0].groupby(['architecture','variance']).mean().reset_index()[['architecture','variance','psnr','ssim']].values.T
XS = nn[nn['psnr']>0].groupby(['architecture','variance']).std().reset_index()[['architecture','variance','psnr','ssim']].values.T

archs = ['decreasing','splines','flux']

fig,axs = plt.subplots(ncols=2,figsize=(15,5))

for arch in archs:
    axs[0].errorbar(X[1][X[0]==arch],X[2][X[0]==arch],XS[2][X[0]==arch],label=arch)
    axs[1].errorbar(X[1][X[0]==arch],X[3][X[0]==arch],XS[3][X[0]==arch],label=arch)
    
axs[0].legend()
axs[1].legend()

axs[0].set_title('PSNR')
axs[1].set_title('SSIM')

axs[0].set_xlabel('noise variance')
axs[0].set_ylabel('psnr')

axs[1].set_xlabel('noise variance')
axs[1].set_ylabel('ssim')

plt.show()

# %%
index = nn.groupby(['architecture','loss','num repeat','second']).mean().reset_index()[['psnr','architecture','loss','num repeat','second']].values.T
index[:,np.argsort(index[0])[-3]]
# Out:
# array([26.249774833333333, 'splines', 'Linfty', 1.0, 'False'],
#       dtype=object)

# %%
example_1 = df[(df['architecture']=='splines')&(df['loss']=='psnr')&(df['num repeat']==1)&(df['second']=='False')]
example_2 = df[(df['architecture']=='decreasing')&(df['loss']=='H1')&(df['num repeat']==1)&(df['second']=='False')&
              (df['num classes']==50)]
example_3 = df[(df['architecture']=='splines')&(df['loss']=='Linfty')&(df['num repeat']==1)&(df['second']=='False')&
              (df['num classes']==20)]

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
x,y,s = df[df['architecture'] == 'pm'][['variance','psnr','psnr std']].values.T
plt.errorbar(x,y,s,label='Perona-Malik')
x,y,s = example_1[['variance','psnr','psnr std']].values.T
plt.errorbar(x,y,s,label='best nn')
x,y,s = example_2[['variance','psnr','psnr std']].values.T
plt.errorbar(x,y,s,label='second best nn')
x,y,s = example_3[['variance','psnr','psnr std']].values.T
plt.errorbar(x,y,s,label='third best nn')
plt.legend()
plt.title('Comparison of Perona-Malik vs.\nneural networks')
plt.xlabel('noise variance')
plt.ylabel('PSNR')
plt.subplot(122)
x,y,s = df[df['architecture'] == 'pm'][['variance','ssim','ssim std']].values.T
plt.errorbar(x,y,s,label='Perona-Malik')
x,y,s = example_1[['variance','ssim','ssim std']].values.T
plt.errorbar(x,y,s,label='best nn')
x,y,s = example_2[['variance','ssim','ssim std']].values.T
plt.errorbar(x,y,s,label='second best nn')
x,y,s = example_3[['variance','ssim','ssim std']].values.T
plt.errorbar(x,y,s,label='third best nn')
plt.legend()
plt.title('Comparison of Perona-Malik vs.\nneural networks')
plt.xlabel('noise variance')
plt.ylabel('SSIM')
plt.show()

# %%
num_classes,psnr,ssim = nn.groupby(['num classes']).mean().reset_index()[['num classes','psnr','ssim']].values.T
psnr_std,ssim_std = nn.groupby(['num classes']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.errorbar(num_classes,psnr,psnr_std)
plt.title('Denoising of neural networks vs.\nnumber of subintervals')
plt.xlabel('number of subintervals')
plt.ylabel('PSNR')
plt.subplot(122)
plt.errorbar(num_classes,ssim,ssim_std)
plt.title('Denoising of neural networks vs.\nnumber of subintervals')
plt.xlabel('number of subintervals')
plt.ylabel('SSIM')
plt.show()

# %%
num_repeat,psnr,ssim = nn.groupby(['num repeat']).mean().reset_index()[['num repeat','psnr','ssim']].values.T
psnr_std,ssim_std = nn.groupby(['num repeat']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.errorbar(num_repeat,psnr,psnr_std)
plt.title('Denoising of neural networks vs.\nnumber of iterations inside generator')
plt.xlabel('Number of repetitions')
plt.ylabel('PSNR')
plt.subplot(122)
plt.errorbar(num_repeat,ssim,ssim_std)
plt.title('Denoising of neural networks vs.\nnumber of iterations inside generator')
plt.xlabel('Number of repetitions')
plt.ylabel('SSIM')
plt.show()

# %%
factor,psnr,ssim = nn[nn['factor']>0].groupby(['factor']).mean().reset_index()[['factor','psnr','ssim']].values.T
psnr_std,ssim_std = nn[nn['factor']>0].groupby(['factor']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.errorbar(factor,psnr,psnr_std)
plt.title('Denoising neural network vs.\ncoefficient for the regularizer')
plt.xlabel('Coefficient on regularizer')
plt.ylabel('PSNR')
plt.subplot(122)
plt.errorbar(factor,ssim,ssim_std)
plt.title('Denoising neural network vs.\ncoefficient for the regularizer')
plt.xlabel('Coefficient on regularizer')
plt.ylabel('SSIM')
plt.show()

# %%
loss,psnr,ssim = nn.groupby(['loss']).mean().reset_index()[['loss','psnr','ssim']].values.T
psnr_std,ssim_std = nn.groupby(['loss']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.errorbar(loss,psnr,psnr_std)
plt.title('Denoising neural network vs. loss function')
plt.xlabel('Loss function')
plt.ylabel('PSNR')
plt.subplot(122)
plt.errorbar(loss,ssim,ssim_std)
plt.title('Denoising neural network vs. loss function')
plt.xlabel('Loss function')
plt.ylabel('SSIM')
plt.show()

# %%
loss,psnr,ssim = nn.groupby(['architecture']).mean().reset_index()[['architecture','psnr','ssim']].values.T
psnr_std,ssim_std = nn.groupby(['architecture']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.errorbar(loss,psnr,psnr_std)
plt.title('Denoising neural network vs. architecture')
plt.xlabel('Architecture')
plt.ylabel('PSNR')
plt.subplot(122)
plt.errorbar(loss,ssim,ssim_std)
plt.title('Denoising neural network vs. architecture')
plt.xlabel('Architecture')
plt.ylabel('SSIM')
plt.show()

# %%
poly_degree,psnr,ssim = nn[nn['polynomial degree']>0].groupby(['polynomial degree']).mean().reset_index()[['polynomial degree','psnr','ssim']].values.T
psnr_std,ssim_std = nn[nn['polynomial degree']>0].groupby(['polynomial degree']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.errorbar(poly_degree,psnr,psnr_std)
plt.title('Denoising neural network vs. polynomial degree')
plt.xlabel('Polynomial degree')
plt.ylabel('PSNR')
plt.subplot(122)
plt.errorbar(poly_degree,ssim,ssim_std)
plt.title('Denoising neural network vs. polynomial degree')
plt.xlabel('Polynomial degree')
plt.ylabel('SSIM')
plt.show()

# %%
degree,psnr,ssim = nn[(nn['degree']>0)&(nn['polynomial'] == 'True')].groupby(['degree']).mean().reset_index()[['degree','psnr','ssim']].values.T
psnr_std,ssim_std = nn[(nn['degree']>0)&(nn['polynomial'] == 'True')].groupby(['degree']).std().reset_index()[['psnr','ssim']].values.T

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.errorbar(degree,psnr,psnr_std)
plt.title("Denoising neural network vs. kernel's size\nUsing polynomial")
plt.xlabel("Kernel's size")
plt.ylabel('PSNR')
plt.subplot(222)
plt.errorbar(degree,ssim,ssim_std)
plt.title("Denoising neural network vs. kernel's size\nUsing polynomial")
plt.xlabel("Kernel's size")
plt.ylabel('SSIM')

degree,psnr,ssim = nn[(nn['degree']>0)&(nn['polynomial'] != 'True')].groupby(['degree']).mean().reset_index()[['degree','psnr','ssim']].values.T
psnr_std,ssim_std = nn[(nn['degree']>0)&(nn['polynomial'] != 'True')].groupby(['degree']).std().reset_index()[['psnr','ssim']].values.T

plt.subplot(223)
plt.errorbar(degree,psnr,psnr_std)
plt.title("Denoising neural network vs. kernel's size\nNot using polynomial")
plt.xlabel("Kernel's size")
plt.ylabel('PSNR')
plt.subplot(224)
plt.errorbar(degree,ssim,ssim_std)
plt.title("Denoising neural network vs. kernel's size\nNot using polynomial")
plt.xlabel("Kernel's size")
plt.ylabel('SSIM')

plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('./general_comparison.csv')

# %%
pd.plotting.parallel_coordinates(

    df[['loss','psnr','ssim','num classes','num repeat']], 'loss', color=('#556270', '#4ECDC4', '#C7F464')

)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Big training

# %%
trained = glob('/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr/general/results/*')

df = []
for t in tqdm(trained):
    l = []
    s = t.split('/')[-1][:-4].split('_')
    if 'splines' in s[0]:
        l.append('splines')
    elif 'decreasing' in s[0] and 'flux' not in s[0]:
        l.append('decreasing')
    elif 'fluxdecreasing' in s[0]:
        l.append('fluxdecreasing')
    else:
        l.append('flux')
    
    
    l.append(s[0][len(l[-1]):])
    if len(s) == 8:
        if s[-1] == '0':
            l = np.concatenate((l,['no pretrained'],s[-6:-1]))
        else:
            l = np.concatenate((l,['no constraints'],s[-6:-1]))
            
        l[-2] = l[-2][1:]
        l = np.concatenate((l[:5],l[6:]))
    elif len(s) == 6:
        l = np.concatenate((l,['classic'],s[-4:-1],[-1,-1]))
        l = np.concatenate((l[:5],l[6:]))
    else:
        l = np.concatenate((l,['diff op'],s[-5:]))
        l[-2] = l[-2][1:]
        l = np.concatenate((l[:4],l[5:]))
    
    

    
    v = np.load(t)
    if np.amin(v) < 0:
        continue
    for u,w in enumerate(v):
        df.append(np.concatenate((l,[np.arange(10,55,2.5)[u]],w)))
# Out:
# 100%|████████████████████████████████████| 25029/25029 [00:47<00:00, 527.61it/s]

# %%
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr/general/testing_dataset'

for var in tqdm(np.arange(10,55,2.5)):
    
    images = np.array([np.gradient(np.squeeze(np.load(i))) for i in glob(f'{path}/noisy/{var}*')])
    gradients = np.sqrt(np.sum(images**2,axis=1)).flatten()
    gradients = np.expand_dims(gradients,axis=-1)
    gm = GaussianMixture(n_components=2, random_state=0).fit(gradients)
    predictions = gm.predict(gradients)
    t = np.linspace(0,1,10000)
    ty = np.argmax(gm.means_.flatten())
    mean = gm.means_[ty]
    std = np.std(gradients[predictions==ty])
    normal_1 = np.exp(-(((t-mean)/std)**2)/2)/(std*np.sqrt(2*np.pi))
    lambd = t[np.argmax(normal_1)]
    
    pm,ys = [],[]
    for i in range(len(glob(f'{path}/noisy/{float(var)}*'))):
        noisy = np.load(f'{path}/noisy/{float(var)}_{i}.npy')
        original = np.load(f'{path}/original/{float(var)}_{i}.npy')
        pm.append(anisodiff(noisy,niter = 50,lambd=lambd))
        ys.append(original)
        
    pm = np.array(pm)
    ys = np.array(ys)
        
    psnr = tf.reduce_mean(tf.image.psnr(ys,pm,1)).numpy()
    psnr_std = np.std(tf.image.psnr(ys,pm,1).numpy())
    ssim = tf.reduce_mean(tf.image.ssim(ys,pm,1)).numpy()
    ssim_std = np.std(tf.image.ssim(ys,pm,1).numpy())

    
    df.append(['pm','NA','NA','NA','NA','NA',var,psnr,psnr_std,ssim,ssim_std])
# Out:
# 100%|███████████████████████████████████████████| 18/18 [10:24<00:00, 34.70s/it]

# %%
df = pd.DataFrame(np.array(df),columns=['architecture','loss','num classes','num repeat','degree','factor','variance',
                                       'psnr','psnr std','ssim','ssim std'])
"""
df = df.replace('nan',0)
df['variance'] = pd.to_numeric(df['variance'])
df['psnr'] = pd.to_numeric(df['psnr'])
df['psnr std'] = pd.to_numeric(df['psnr std'])
df['ssim'] = pd.to_numeric(df['ssim'])
df['ssim std'] = pd.to_numeric(df['ssim std'])
df['num classes'] = pd.to_numeric(df['num classes'])
df['num repeat'] = pd.to_numeric(df['num repeat'])
df['degree'] = pd.to_numeric(df['degree'])
df['factor'] = pd.to_numeric(df['factor'])
"""

#df.to_csv('./general_comparison_big.csv',index=False)
df = pd.read_csv('./general_comparison_big.csv')

# %%
nn = df[(df['architecture'] != 'pm')]
losses = np.unique(nn['loss'])
architectures = np.unique(nn['architecture'])

nn = nn.replace('nan',0)
nn['variance'] = pd.to_numeric(nn['variance'])
nn['psnr'] = pd.to_numeric(nn['psnr'])
nn['psnr std'] = pd.to_numeric(nn['psnr std'])
nn['ssim'] = pd.to_numeric(nn['ssim'])
nn['ssim std'] = pd.to_numeric(nn['ssim std'])
nn['num classes'] = pd.to_numeric(nn['num classes'])
nn['num repeat'] = pd.to_numeric(nn['num repeat'])
nn['degree'] = pd.to_numeric(nn['degree'])
nn['factor'] = pd.to_numeric(nn['factor'])


pm = df[df['architecture'] == 'pm'][['psnr']].values.flatten()


width = .4
width2 = .05

colors = cm.viridis(np.linspace(0,1,len(np.unique(nn['variance']))))

for arch in architectures:
    
    plt.figure(figsize=(20,5))

    x,th,sh,m = [],[],[],[]
    bth,bsh,bm = [],[],[]
    c = []

    for v,var in enumerate(np.unique(nn['variance'])):
        
    
        db = nn[(nn['variance'] == var)&(nn['architecture'] == arch)]
        db = db.replace('nan',0)
        db = db[db['psnr'] > 0]
        db = db[db['ssim'] < 1]
        
        existent_losses = np.unique(db['loss'])
        
        losses_it = [f'{l} {var}' for l in existent_losses]
        labs = np.unique(db['loss'])

        
        
        mins = db.groupby(['loss']).min().reset_index()[['psnr']]
        maxs = db.groupby(['loss']).max().reset_index()[['psnr']]
        stds = db.groupby(['loss']).std()[['psnr']]
        mean = db.groupby(['loss']).mean()[['psnr']]
        up_std = mean + stds
        down_std = mean - stds

        x.append(np.copy(losses_it))
        sh.append(np.copy((up_std-down_std).values.flatten()))
        th.append(np.copy((maxs-mins).values.flatten()))
        m.append(np.copy(0.5*(up_std-down_std).values.flatten()))

        bth.append(np.copy(mins.values.flatten()))
        bsh.append(np.copy(down_std.values.flatten()))
        bm.append(np.copy((mean-0.5*stds).values.flatten()))

        c.append(np.copy(np.repeat([colors[v]],len(x[-1]),axis=0)))


    x = np.concatenate(np.transpose(x))
    sh = np.nan_to_num(np.concatenate(np.transpose(sh)))
    th = np.nan_to_num(np.concatenate(np.transpose(th)))
    m = np.nan_to_num(np.concatenate(np.transpose(m)))
    bth = np.nan_to_num(np.concatenate(np.transpose(bth)))
    bsh = np.nan_to_num(np.concatenate(np.transpose(bsh)))
    bm = np.nan_to_num(np.concatenate(np.transpose(bm)))
    c = np.concatenate(np.transpose(c,axes=(1,0,2)))


    plt.bar(x,sh,width,bottom=bsh,color='white',edgecolor=c)
    plt.bar(x,m,width,bottom=bm,color=c)
    plt.bar(x,th,width2,bottom=bth,color=c)
    X,Y = x.reshape(np.repeat([pm],len(labs),axis=0).shape),np.repeat([pm],len(labs),axis=0)
    for i in range(len(X)):
        if i == 0:
            plt.plot(X[i],Y[i],color='b',label='Perona-Malik')
        else:
            plt.plot(X[i],Y[i],color='b')
            
    ticks = np.arange(len(x)//(2*len(labs)),len(x),len(x)//(len(labs)))
    plt.xticks(ticks,labs)
    nmax = np.amax(nn['variance'])
    nmin = np.amin(nn['variance'])
    plt.colorbar(cm.ScalarMappable(norm=mpl.colors.Normalize(vmin=nmin, vmax=nmax),cmap='viridis'),label='variance')
    plt.title(arch)
    plt.legend()

    plt.show()

# %%
nn = df[(df['architecture'] != 'pm')]
losses = np.unique(nn['loss'])
architectures = np.unique(nn['architecture'])

nn = nn.replace('nan',0)
nn['variance'] = pd.to_numeric(nn['variance'])
nn['psnr'] = pd.to_numeric(nn['psnr'])
nn['psnr std'] = pd.to_numeric(nn['psnr std'])
nn['ssim'] = pd.to_numeric(nn['ssim'])
nn['ssim std'] = pd.to_numeric(nn['ssim std'])
nn['num classes'] = pd.to_numeric(nn['num classes'])
nn['num repeat'] = pd.to_numeric(nn['num repeat'])
nn['degree'] = pd.to_numeric(nn['degree'])
nn['factor'] = pd.to_numeric(nn['factor'])

pm = df[df['architecture'] == 'pm'][['ssim']].values.flatten()


width = .4
width2 = .05

colors = cm.viridis(np.linspace(0,1,len(np.unique(nn['variance']))))

for arch in architectures:
    
    plt.figure(figsize=(20,5))

    x,th,sh,m = [],[],[],[]
    bth,bsh,bm = [],[],[]
    c = []

    for v,var in enumerate(np.unique(nn['variance'])):

        db = nn[(nn['variance'] == var)&(nn['architecture'] == arch)]
        db = db.replace('nan',0)
        db = db[db['psnr'] > 0]
        db = db[db['ssim'] < 1]
        
        existent_losses = np.unique(db['loss'])
        
        losses_it = [f'{l} {var}' for l in existent_losses]
        labs = np.unique(db['loss'])
        
        
        mins = db.groupby(['loss']).min().reset_index()[['ssim']]
        maxs = db.groupby(['loss']).max().reset_index()[['ssim']]
        stds = db.groupby(['loss']).std()[['ssim']]
        mean = db.groupby(['loss']).mean()[['ssim']]
        up_std = mean + stds
        down_std = mean - stds

        x.append(np.copy(losses_it))
        sh.append(np.copy((up_std-down_std).values.flatten()))
        th.append(np.copy((maxs-mins).values.flatten()))
        m.append(np.copy(0.5*(up_std-down_std).values.flatten()))

        bth.append(np.copy(mins.values.flatten()))
        bsh.append(np.copy(down_std.values.flatten()))
        bm.append(np.copy((mean-0.5*stds).values.flatten()))

        c.append(np.copy(np.repeat([colors[v]],len(x[-1]),axis=0)))


    x = np.concatenate(np.transpose(x))
    sh = np.nan_to_num(np.concatenate(np.transpose(sh)))
    th = np.nan_to_num(np.concatenate(np.transpose(th)))
    m = np.nan_to_num(np.concatenate(np.transpose(m)))
    bth = np.nan_to_num(np.concatenate(np.transpose(bth)))
    bsh = np.nan_to_num(np.concatenate(np.transpose(bsh)))
    bm = np.nan_to_num(np.concatenate(np.transpose(bm)))
    c = np.concatenate(np.transpose(c,axes=(1,0,2)))


    plt.bar(x,sh,width,bottom=bsh,color='white',edgecolor=c)
    plt.bar(x,m,width,bottom=bm,color=c)
    plt.bar(x,th,width2,bottom=bth,color=c)
    X,Y = x.reshape(np.repeat([pm],len(labs),axis=0).shape),np.repeat([pm],len(labs),axis=0)
    for i in range(len(X)):
        if i == 0:
            plt.plot(X[i],Y[i],color='b',label='Perona-Malik')
        else:
            plt.plot(X[i],Y[i],color='b')

    ticks = np.arange(len(x)//(2*len(labs)),len(x),len(x)//(len(labs)))
    plt.xticks(ticks,labs)
    nmax = np.amax(nn['variance'])
    nmin = np.amin(nn['variance'])
    plt.colorbar(cm.ScalarMappable(norm=mpl.colors.Normalize(vmin=nmin, vmax=nmax),cmap='viridis'),label='variance')
    plt.title(arch)
    plt.legend()

    plt.show()

# %%
nn = df[(df['architecture'] != 'pm')]
losses = np.unique(nn['loss'])
architectures = np.unique(nn['architecture'])

nn = nn.replace('nan',0)
nn['variance'] = pd.to_numeric(nn['variance'])
nn['psnr'] = pd.to_numeric(nn['psnr'])
nn['psnr std'] = pd.to_numeric(nn['psnr std'])
nn['ssim'] = pd.to_numeric(nn['ssim'])
nn['ssim std'] = pd.to_numeric(nn['ssim std'])
nn['num classes'] = pd.to_numeric(nn['num classes'])
nn['num repeat'] = pd.to_numeric(nn['num repeat'])
nn['degree'] = pd.to_numeric(nn['degree'])
nn['factor'] = pd.to_numeric(nn['factor'])
nn = nn[nn['psnr'] > 0]
nn = nn[nn['ssim'] < 1]
nn = nn[nn['num classes'] < 50]

pm = df[df['architecture'] == 'pm']

# %%
X = nn.groupby(['architecture','num classes']).mean().reset_index()[['architecture','num classes','psnr','ssim']].values.T


plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(np.asarray(X[2].reshape((len(architectures),len(np.unique(nn['num classes'])))),dtype='float'))
ticks = np.arange(len(architectures))
plt.yticks(ticks,architectures)
ticks = np.arange(len(np.unique(nn['num classes'])))
plt.xticks(ticks,np.unique(nn['num classes']))
plt.colorbar(fraction=0.05,label='PSNR')
plt.xlabel('Number of classes')
plt.ylabel('Architecture')

plt.subplot(122)
plt.imshow(np.asarray(X[3].reshape((len(architectures),len(np.unique(nn['num classes'])))),dtype='float'))
ticks = np.arange(len(architectures))
plt.yticks(ticks,architectures)
ticks = np.arange(len(np.unique(nn['num classes'])))
plt.xticks(ticks,np.unique(nn['num classes']))
plt.colorbar(fraction=0.05,label='SSIM')
plt.xlabel('Number of classes')
plt.ylabel('Architecture')

plt.tight_layout()
plt.show()

# %%
X = nn.groupby(['architecture','num repeat']).mean().reset_index()[['architecture','num repeat','psnr','ssim']].values.T


plt.figure(figsize=(15,8))
plt.subplot(211)
plt.imshow(np.asarray(X[2].reshape((len(architectures),len(np.unique(nn['num repeat'])))),dtype='float'))
ticks = np.arange(len(architectures))
plt.yticks(ticks,architectures)
ticks = np.arange(len(np.unique(nn['num repeat'])))
plt.xticks(ticks,np.unique(nn['num repeat']))
plt.colorbar(fraction=0.009,label='PSNR')
plt.xlabel('Number of repetitions')
plt.ylabel('Architecture')

plt.subplot(212)
plt.imshow(np.asarray(X[3].reshape((len(architectures),len(np.unique(nn['num repeat'])))),dtype='float'))
ticks = np.arange(len(architectures))
plt.yticks(ticks,architectures)
ticks = np.arange(len(np.unique(nn['num repeat'])))
plt.xticks(ticks,np.unique(nn['num repeat']))
plt.colorbar(fraction=0.009,label='SSIM')
plt.xlabel('Number of repetitions')
plt.ylabel('Architecture')

plt.tight_layout()
plt.show()

# %%
X = nn.groupby(['num repeat']).mean().reset_index()[['num repeat','psnr','ssim']].values.T
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(X[0],X[1])
plt.xlabel('Number of repetitions')
plt.ylabel('PSNR')
plt.subplot(122)
plt.plot(X[0],X[2])
plt.xlabel('Number of repetitions')
plt.ylabel('SSIM')
plt.show()

# %%
X = nn.groupby(['architecture','degree']).mean().reset_index()[['architecture','degree','psnr','ssim']].values.T


plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(np.asarray(X[2].reshape((len(architectures),len(np.unique(nn['degree'])))),dtype='float'))
ticks = np.arange(len(architectures))
plt.yticks(ticks,architectures)
ticks = np.arange(len(np.unique(nn['degree'])))
plt.xticks(ticks,np.unique(nn['degree']))
plt.colorbar(fraction=0.05,label='PSNR')
plt.xlabel('Degree')
plt.ylabel('Architecture')

plt.subplot(122)
plt.imshow(np.asarray(X[3].reshape((len(architectures),len(np.unique(nn['degree'])))),dtype='float'))
ticks = np.arange(len(architectures))
plt.yticks(ticks,architectures)
ticks = np.arange(len(np.unique(nn['degree'])))
plt.xticks(ticks,np.unique(nn['degree']))
plt.colorbar(fraction=0.05,label='SSIM')
plt.xlabel('Degree')
plt.ylabel('Architecture')

plt.tight_layout()
plt.show()

# %%
X = nn.groupby(['degree']).mean().reset_index()[['degree','psnr','ssim']].values.T
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(X[0],X[1])
plt.xlabel('Degree')
plt.ylabel('PSNR')
plt.subplot(122)
plt.plot(X[0],X[2])
plt.xlabel('Degree')
plt.ylabel('SSIM')
plt.show()

# %%
X = nn.groupby(['factor']).mean().reset_index()[['factor','psnr','ssim']].values.T
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(X[0],X[1])
plt.xlabel('Factor')
plt.ylabel('PSNR')
plt.subplot(122)
plt.plot(X[0],X[2])
plt.xlabel('Factor')
plt.ylabel('SSIM')
plt.show()

# %%
X = nn.groupby(['architecture']).mean().reset_index()[['architecture','psnr','ssim']].values.T
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(X[0],X[1])
plt.xlabel('Architecture')
plt.ylabel('PSNR')
plt.subplot(122)
plt.plot(X[0],X[2])
plt.xlabel('Architecture')
plt.ylabel('SSIM')
plt.show()

# %%
nn = df[(df['architecture'] != 'pm')]
losses = np.unique(nn['loss'])
architectures = np.unique(nn['architecture'])

nn = nn.replace('nan',0)
nn['variance'] = pd.to_numeric(nn['variance'])
nn['psnr'] = pd.to_numeric(nn['psnr'])
nn['psnr std'] = pd.to_numeric(nn['psnr std'])
nn['ssim'] = pd.to_numeric(nn['ssim'])
nn['ssim std'] = pd.to_numeric(nn['ssim std'])
nn['num classes'] = pd.to_numeric(nn['num classes'])
nn['num repeat'] = pd.to_numeric(nn['num repeat'])
nn['degree'] = pd.to_numeric(nn['degree'])
nn['factor'] = pd.to_numeric(nn['factor'])

X = nn.groupby(['architecture','loss','type','num classes','num repeat','degree','factor']).mean().reset_index()

path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'

best = []

for ty in np.unique(nn['type']):
    for A in np.unique(nn['architecture']):
        
        if ty == 'diff op':

            values = X[(X['architecture']==A)&(X['type']==ty)].values.T
            arch,loss,typee,nc,nr,de,fa = values.T[np.argmax(values[8])][:7]
            if A == 'decreasing':
                fa = 3
                

            best.append([arch,loss,nc,nr,de,fa])

            model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                              second=True,degree1=int(de),factor=fa)
            model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}")
            model.save_weights(f"./checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}")
            
        if ty == 'no pretrained':
            
            values = X[(X['architecture']==A)&(X['type']==ty)].values.T
            if len(values[0]) == 0:
                continue
            arch,loss,typee,nc,nr,de,fa = values.T[np.argmax(values[8])][:7]
                

            best.append([arch,loss,nc,nr,de,fa])

            model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                              second=True,degree1=int(de),factor=fa)
            model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}_0")
            model.save_weights(f"./checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}_0")
            
        if ty == 'no constraints':
            
            values = X[(X['architecture']==A)&(X['type']==ty)].values.T
            arch,loss,typee,nc,nr,de,fa = values.T[np.argmax(values[8])][:7]
                

            best.append([arch,loss,nc,nr,de,fa])

            model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                              second=True,degree1=int(de),factor=fa)
            model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}_noconstraints")
            model.save_weights(f"./checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}_noconstraints")
  
        if ty == 'classic':
            
            values = X[(X['architecture']==A)&(X['type']==ty)].values.T
            if len(values[0]) == 0:
                continue
            arch,loss,typee,nc,nr,de,fa = values.T[np.argmax(values[8])][:7]
                

            best.append([arch,loss,nc,nr,de,fa])

            model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                              second=False)
            model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_f")
            model.save_weights(f"./checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_f")

# %%
X = nn.groupby(['architecture','loss','num classes','num repeat','degree','factor']).mean().reset_index()

fig,axs = plt.subplots(ncols=2,figsize=(15,5))

best = []

for A in np.unique(nn['architecture']):

    values = X[X['architecture']==A].values.T
    arch,loss,nc,nr,de,fa = values.T[np.argmax(values[7])][:6]
    best.append([arch,loss,nc,nr,de,fa])

    Y = nn[(nn['architecture']==arch)&(nn['loss']==loss)&(nn['num classes']==nc)&(nn['num repeat']==nr)&
      (nn['degree']==de)&(nn['factor']==fa)]

    v,p,sp,s,ss = Y[['variance','psnr','psnr std','ssim','ssim std']].values.T
    
    axs[0].errorbar(v,p,sp,label=A)
    axs[1].errorbar(v,s,ss,label=A)
    
    
    
pm = df[df['architecture'] == 'pm']
v,p,sp,s,ss = pm[['variance','psnr','psnr std','ssim','ssim std']].values.T

axs[0].errorbar(v,p,sp,label='Perona Malik')
axs[1].errorbar(v,s,ss,label='Perona Malik')
axs[0].set_xlabel('Noise variance')
axs[0].set_ylabel('PSNR')
axs[1].set_xlabel('Noise variance')
axs[1].set_ylabel('SSIM')


axs[0].legend()
axs[1].legend()
plt.tight_layout()
plt.show()

# %%
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'

A,loss,nc,nr,de,fa = best[0]
model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}")
model.summary()
# Out:
# Model: "model_136"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_420 (Conv2D)            (None, 128, 128, 32  320         ['input[0][0]']
#                                 )
#
#  batch_normalization_770 (Batch  (None, 128, 128, 32  128        ['conv2d_420[0][0]']
#  Normalization)                 )
#
#  activation_770 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_770[0][0]']
#                                 )
#
#  conv2d_421 (Conv2D)            (None, 128, 128, 64  18496       ['activation_770[0][0]']
#                                 )
#
#  batch_normalization_771 (Batch  (None, 128, 128, 64  256        ['conv2d_421[0][0]']
#  Normalization)                 )
#
# ...

# %%
filters = model.get_layer('model_14').get_layer('diff').weights[0].numpy()
filters = np.squeeze(filters)
filters = filters[...,np.argsort(np.amax(np.abs(filters),axis=(0,1)))]

fig,axs = plt.subplots(ncols=filters.shape[-1],figsize=(15,5))

for f in range(filters.shape[-1]):
    im = axs[f].imshow(filters[...,f])
    plt.colorbar(im,ax=axs[f],fraction=0.05)
    axs[f].axis('off')
    axs[f].set_title(arch)
    
plt.tight_layout()
plt.show()

# %%
A,loss,nc,nr,de,fa = best[1]
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'
model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}")
model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 32  320         ['input[0][0]']
#                                 )
#
#  batch_normalization_66 (BatchN  (None, 128, 128, 32  128        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_66 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_66[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 64  18496       ['activation_66[0][0]']
#                                 )
#
#  batch_normalization_67 (BatchN  (None, 128, 128, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
# ...

# %%
filters = model.get_layer('model_12').get_layer('diff').weights[0].numpy()
filters = np.squeeze(filters)
filters = filters[...,np.argsort(np.amax(np.abs(filters),axis=(0,1)))]

fig,axs = plt.subplots(ncols=filters.shape[-1]//5,nrows=5,figsize=(15,8))

for f in range(filters.shape[-1]):
    im = axs[f//6,f%6].imshow(filters[...,f])
    plt.colorbar(im,ax=axs[f//6,f%6],fraction=0.05)
    axs[f//6,f%6].axis('off')
    axs[f//6,f%6].set_title(arch)
    
plt.tight_layout()
plt.show()

# %%
arch,loss,nc,nr,de,fa = best[2]
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'
model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}")
model.summary()
# Out:
# Model: "model_154"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_474 (Conv2D)            (None, 128, 128, 32  320         ['input[0][0]']
#                                 )
#
#  batch_normalization_869 (Batch  (None, 128, 128, 32  128        ['conv2d_474[0][0]']
#  Normalization)                 )
#
#  activation_869 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_869[0][0]']
#                                 )
#
#  conv2d_475 (Conv2D)            (None, 128, 128, 64  18496       ['activation_869[0][0]']
#                                 )
#
#  batch_normalization_870 (Batch  (None, 128, 128, 64  256        ['conv2d_475[0][0]']
#  Normalization)                 )
#
# ...

# %%
filters = model.get_layer('model_153').get_layer('diff').weights[0].numpy()
filters = np.squeeze(filters)
filters = filters[...,np.argsort(np.amax(np.abs(filters),axis=(0,1)))]

fig,axs = plt.subplots(ncols=filters.shape[-1],figsize=(15,4))

for f in range(filters.shape[-1]):
    im = axs[f].imshow(filters[...,f])
    plt.colorbar(im,ax=axs[f],fraction=0.05)
    axs[f].axis('off')
    axs[f].set_title(arch)
    
plt.tight_layout()
plt.show()

# %%
arch,loss,nc,nr,de,fa = best[3]
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'
model = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
model.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{int(nc)}_{int(nr)}_{10}_t{int(de)}_{int(fa)}")
model.summary()
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_48 (Conv2D)             (None, 128, 128, 32  320         ['input[0][0]']
#                                 )
#
#  batch_normalization_88 (BatchN  (None, 128, 128, 32  128        ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  activation_88 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_88[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 128, 128, 64  18496       ['activation_88[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 128, 128, 64  256        ['conv2d_49[0][0]']
#  ormalization)                  )
#
# ...

# %%
filters = model.get_layer('model_16').get_layer('diff').weights[0].numpy()
filters = np.squeeze(filters)
filters = filters[...,np.argsort(np.amax(np.abs(filters),axis=(0,1)))]

fig,axs = plt.subplots(ncols=filters.shape[-1],figsize=(15,4))

for f in range(filters.shape[-1]):
    im = axs[f].imshow(filters[...,f])
    plt.colorbar(im,ax=axs[f],fraction=0.05)
    axs[f].axis('off')
    axs[f].set_title(arch)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing with papers

# %%
path = '/home/joel/nmr-storage/fly_group_behavior/scripts/PeronaMalik/7_apr'
typ = 'gaussian'

A,loss,nc,nr,de,fa = best[0]
decreasing_model_256 = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
decreasing_model_256.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")
                                                
decreasing_model_512 = get_model(A,it_lim=10,image_size=(512,512),num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
decreasing_model_512.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")

A,loss,nc,nr,de,fa = best[1]
flux_model_256 = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
flux_model_256.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")
flux_model_512 = get_model(A,it_lim=10,image_size=(512,512),num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
flux_model_512.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")

A,loss,nc,nr,de,fa = best[2]
fluxdecreasing_model_256 = get_model('flux_decreasing',it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
fluxdecreasing_model_256.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")
fluxdecreasing_model_512 = get_model('flux_decreasing',it_lim=10,image_size=(512,512),num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
fluxdecreasing_model_512.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")

A,loss,nc,nr,de,fa = best[3]
splines_model_256 = get_model(A,it_lim=10,image_size=image_size,num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
splines_model_256.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")
splines_model_512 = get_model(A,it_lim=10,image_size=(512,512),num_classes = int(nc),
                                                          second=True,degree1=int(de),factor=fa)
splines_model_512.load_weights(f"{path}/{A}/checkpoints/{A}{loss}_{typ}_{nc}_{nr}_10_t{de}_{fa}")

models_256 = [decreasing_model_256,flux_model_256,fluxdecreasing_model_256,splines_model_256]
models_512 = [decreasing_model_512,flux_model_512,fluxdecreasing_model_512,splines_model_512]

# %%
set12_256 = ['../../images/Set12/02.png','../../images/Set12/03.png']
set12_512 = ['../../images/Set12/09.png','../../images/Set12/10.png']

set12_256 = np.array([cv2.cvtColor(cv2.imread(i), cv2.COLOR_BGR2GRAY) for i in set12_256])
set12_512 = np.array([cv2.cvtColor(cv2.imread(i), cv2.COLOR_BGR2GRAY) for i in set12_512])

set12_256 = np.expand_dims(set12_256,axis=-1)
set12_512 = np.expand_dims(set12_512,axis=-1)

set12_256 = set12_256 - np.amin(set12_256,axis=(1,2,3)).reshape((2,1,1,1))
set12_512 = set12_512 - np.amin(set12_512,axis=(1,2,3)).reshape((2,1,1,1))

ys_256 = np.array([set12_256 for v in variance])
ys_512 = np.array([set12_512 for v in variance])


variance = [1,2,5,10,15,20,25,50,75,100]
noises_256 = np.array([np.random.normal(0,v,set12_256.shape) for v in variance])
noisy_256 = np.clip(noises_256 + np.array([set12_256]),0,255)

noises_512 = np.array([np.random.normal(0,v,set12_512.shape) for v in variance])
noisy_512 = np.clip(noises_512 + np.array([set12_512]),0,255)

noisy_256 = noisy_256/np.amax(ys_256,axis=(2,3,4)).reshape((10,2,1,1,1))
noisy_512 = noisy_512/np.amax(ys_512,axis=(2,3,4)).reshape((10,2,1,1,1))

ys_256 = ys_256/np.amax(ys_256,axis=(2,3,4)).reshape((10,2,1,1,1))
ys_512 = ys_512/np.amax(ys_512,axis=(2,3,4)).reshape((10,2,1,1,1))

# %%
psnr = [[],[]]

for m in range(len(models_256)):
    denoised_256 = models_256[m](np.concatenate(noisy_256))
    psnr[0].append(np.array(tf.image.psnr(denoised_256,np.concatenate(ys_256),1)).reshape(10,2))
    
    denoised_512 = models_512[m](np.concatenate(noisy_512))
    psnr[1].append(np.array(tf.image.psnr(denoised_512,np.concatenate(ys_512),1)).reshape(10,2))
    
psnr = np.array(psnr)

# %%
barbara = [47.86,42.92,37.19,32.83,30.22,28.32,27.04,23.15,21.39,19.77]
boats = [47.69,42.28,36.27,33.05,31.22,29.85,28.72,24.53,22.48,20.80]
house = [48.32,44.01,38.23,35.06,33.48,32.17,31.11,26.74,24.13,21.66]
peppers = [47.81,42.96,37.63,34.28,32.03,30.58,29.20,24.52,21.68,19.60]

archs = ['decreasing','flux','fluxdecreasing','splines']

plt.figure(figsize=(15,8))
plt.subplot(221)
for q,p in enumerate(psnr[0]):
    plt.scatter(house,p[...,0],label=archs[q])
    
plt.legend()
plt.ylim(15,50)
plt.plot([15,50],[15,50])
    
plt.subplot(222)
for q,p in enumerate(psnr[0]):
    plt.scatter(peppers,p[...,1],label=archs[q])
    
plt.plot([15,50],[15,50])
plt.ylim(15,50)
plt.legend()
    
plt.subplot(223)
for q,p in enumerate(psnr[1]):
    plt.scatter(barbara,p[...,0],label=archs[q])
    
plt.ylim(15,50)
plt.plot([15,50],[15,50])
plt.legend()
    
plt.subplot(224)
for q,p in enumerate(psnr[1]):
    plt.scatter(boats,p[...,1],label=archs[q])
    
plt.ylim(15,50)
plt.plot([15,50],[15,50])
plt.legend()
    
plt.show()

# %%
n = np.clip(np.array([set12_256[1]+np.random.normal(0,30,set12_256[1].shape)]),0,255)
n = n/np.amax(set12_256[1])
psnr1 = []

for m in models_256:
    denoised = m(n)
    psnr1.append(tf.image.psnr(denoised,set12_256[1],1).numpy()[0])
print(psnr1)
# Out:
# [25.431332, 25.687277, 24.663803, 25.578339]

# %%
n1 = np.expand_dims(cv2.cvtColor(cv2.imread('../../images/Set12/06.png'), cv2.COLOR_BGR2GRAY),axis=-1)
n = np.clip(np.array([n1+np.random.normal(0,30,n1.shape)]),0,255)
n = n/np.amax(n1)

psnr1 = []

for m in models_256:
    denoised = m(n)
    psnr1.append(tf.image.psnr(denoised,n1,1).numpy()[0])
print(psnr1)
# Out:
# [19.7665, 20.162228, 20.28245, 20.544954]

# %%
plt.imshow(denoised[0],cmap='gray')
