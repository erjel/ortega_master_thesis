# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-02-06 00:38:42.800770: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-02-06 00:38:42.800841: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Data augmentation

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=20,var1_u=60,CROP1=CROP,BATCH_SIZE=10)
# Out:
# 2023-02-06 00:39:00.080796: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-02-06 00:39:00.080856: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-06 00:39:00.080913: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (joel-Latitude-5410): /proc/driver/nvidia/version does not exist
# 2023-02-06 00:39:00.142799: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs['input']))
        axs[i,2*j].imshow(np.squeeze(xs['input'][_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        axs[i,2*j].set_title(str(np.mean(xs['input_emb'][_])))
        
plt.show()

# %% [markdown]
# # Neural networks

# %%
strategy = tf.distribute.MirroredStrategy()
#strategy = tf.distribute.OneDeviceStrategy('/device:GPU:0')

# %% [markdown]
# ## Training

# %%
def loss(y_true,y_pred):
    error = tf.maximum(0.,1/tf.image.psnr(y_true,y_pred,1))
    error += 0.09*(1-tf.image.ssim(y_true,y_pred,1))
    error += tf.maximum(0.,tf.math.log(tf.keras.losses.MeanSquaredError()(y_true,y_pred)))
    return error

# %%
typ = "gaussian"
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=20,var1_u=60,CROP1=CROP,BATCH_SIZE=32)

order = 1
for num_classes in [5,10,15]:
    print('num_classes: ',num_classes)
    model = get_model("splines_cont",it_lim=3,image_size=image_size,num_classes = num_classes,order=order)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-2),
            loss=loss,)
    #model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")
    
    callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath= f"./checkpoints/splinescont_{typ}_{num_classes}",
    save_weights_only=True,
    verbose = True,
    save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1)
    ]
    
    history = model.fit(
        gen_batch_train,
        epochs=50,
        steps_per_epoch=25,
        validation_data=gen_batch_val,
        validation_steps=5,
        shuffle=False,
        use_multiprocessing=True,
        callbacks=callbacks,
        workers=1
    )
    
    np.save(f'./history/splinescont_{typ}_{num_classes}.npy',np.array([history.history['loss'],history.history['val_loss']]))
# Out:
# num_classes:  5
# Epoch 1/50
# 25/25 [==============================] - ETA: 0s - loss: 34.7162
# Epoch 1: val_loss improved from inf to 0.20088, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 179s 7s/step - loss: 34.7162 - val_loss: 0.2009 - lr: 0.0100
# Epoch 2/50
# 25/25 [==============================] - ETA: 0s - loss: 22.4852
# Epoch 2: val_loss did not improve from 0.20088
# 25/25 [==============================] - 178s 7s/step - loss: 22.4852 - val_loss: 0.8015 - lr: 0.0100
# Epoch 3/50
# 25/25 [==============================] - ETA: 0s - loss: 20.0143
# Epoch 3: val_loss did not improve from 0.20088
# 25/25 [==============================] - 177s 7s/step - loss: 20.0143 - val_loss: 13.7502 - lr: 0.0100
# Epoch 4/50
# 25/25 [==============================] - ETA: 0s - loss: 1.7021
# Epoch 4: val_loss did not improve from 0.20088
# 25/25 [==============================] - 177s 7s/step - loss: 1.7021 - val_loss: 6.4879 - lr: 0.0100
# Epoch 5/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1647
# Epoch 5: val_loss did not improve from 0.20088
# 25/25 [==============================] - 177s 7s/step - loss: 0.1647 - val_loss: 2.8927 - lr: 0.0100
# Epoch 6/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1541
# Epoch 6: val_loss did not improve from 0.20088
# 25/25 [==============================] - 177s 7s/step - loss: 0.1541 - val_loss: 0.8279 - lr: 0.0100
# Epoch 7/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1549
# Epoch 7: val_loss improved from 0.20088 to 0.16905, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.1549 - val_loss: 0.1690 - lr: 0.0100
# Epoch 8/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1013
# Epoch 8: val_loss improved from 0.16905 to 0.15432, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 178s 7s/step - loss: 0.1013 - val_loss: 0.1543 - lr: 0.0100
# Epoch 9/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0915
# Epoch 9: val_loss improved from 0.15432 to 0.13080, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0915 - val_loss: 0.1308 - lr: 0.0100
# Epoch 10/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0939
# Epoch 10: val_loss improved from 0.13080 to 0.12612, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 179s 7s/step - loss: 0.0939 - val_loss: 0.1261 - lr: 0.0100
# Epoch 11/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0907
# Epoch 11: val_loss improved from 0.12612 to 0.11206, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 180s 7s/step - loss: 0.0907 - val_loss: 0.1121 - lr: 0.0100
# Epoch 12/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0921
# Epoch 12: val_loss improved from 0.11206 to 0.10528, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 178s 7s/step - loss: 0.0921 - val_loss: 0.1053 - lr: 0.0100
# Epoch 13/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0905
# Epoch 13: val_loss improved from 0.10528 to 0.09977, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 178s 7s/step - loss: 0.0905 - val_loss: 0.0998 - lr: 0.0100
# Epoch 14/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0911
# Epoch 14: val_loss did not improve from 0.09977
# 25/25 [==============================] - 177s 7s/step - loss: 0.0911 - val_loss: 0.1016 - lr: 0.0100
# Epoch 15/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0904
# Epoch 15: val_loss improved from 0.09977 to 0.09336, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0904 - val_loss: 0.0934 - lr: 0.0100
# Epoch 16/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0901
# Epoch 16: val_loss improved from 0.09336 to 0.09120, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0901 - val_loss: 0.0912 - lr: 0.0100
# Epoch 17/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0913
# Epoch 17: val_loss improved from 0.09120 to 0.08755, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 178s 7s/step - loss: 0.0913 - val_loss: 0.0876 - lr: 0.0100
# Epoch 18/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0898
# Epoch 18: val_loss improved from 0.08755 to 0.08640, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0898 - val_loss: 0.0864 - lr: 0.0100
# Epoch 19/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0927
# Epoch 19: val_loss did not improve from 0.08640
# 25/25 [==============================] - 177s 7s/step - loss: 0.0927 - val_loss: 0.0876 - lr: 0.0100
# Epoch 20/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0865
# Epoch 20: val_loss did not improve from 0.08640
# 25/25 [==============================] - 177s 7s/step - loss: 0.0865 - val_loss: 0.0866 - lr: 0.0100
# Epoch 21/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0883
# Epoch 21: val_loss improved from 0.08640 to 0.08563, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0883 - val_loss: 0.0856 - lr: 0.0100
# Epoch 22/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0883
# Epoch 22: val_loss improved from 0.08563 to 0.08558, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0883 - val_loss: 0.0856 - lr: 0.0100
# Epoch 23/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0866
# Epoch 23: val_loss improved from 0.08558 to 0.08516, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0866 - val_loss: 0.0852 - lr: 0.0100
# Epoch 24/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0858
# Epoch 24: val_loss improved from 0.08516 to 0.08495, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0858 - val_loss: 0.0850 - lr: 0.0100
# Epoch 25/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0866
# Epoch 25: val_loss improved from 0.08495 to 0.08427, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 179s 7s/step - loss: 0.0866 - val_loss: 0.0843 - lr: 0.0100
# Epoch 26/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0915
# Epoch 26: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0915 - val_loss: 0.0863 - lr: 0.0100
# Epoch 27/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0911
# Epoch 27: val_loss did not improve from 0.08427
# 25/25 [==============================] - 178s 7s/step - loss: 0.0911 - val_loss: 0.0882 - lr: 0.0100
# Epoch 28/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0967
# Epoch 28: val_loss did not improve from 0.08427
# 25/25 [==============================] - 179s 7s/step - loss: 0.0967 - val_loss: 0.0949 - lr: 0.0100
# Epoch 29/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0974
# Epoch 29: val_loss did not improve from 0.08427
# 25/25 [==============================] - 178s 7s/step - loss: 0.0974 - val_loss: 0.0898 - lr: 0.0100
# Epoch 30/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0952
# Epoch 30: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0952 - val_loss: 0.0928 - lr: 0.0100
# Epoch 31/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0952
# Epoch 31: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0952 - val_loss: 0.0929 - lr: 0.0100
# Epoch 32/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0942
# Epoch 32: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0942 - val_loss: 0.0911 - lr: 0.0100
# Epoch 33/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0954
# Epoch 33: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0954 - val_loss: 0.0931 - lr: 0.0100
# Epoch 34/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0951
# Epoch 34: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0951 - val_loss: 0.0920 - lr: 0.0100
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0909
# Epoch 35: val_loss did not improve from 0.08427
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 25/25 [==============================] - 177s 7s/step - loss: 0.0909 - val_loss: 0.0889 - lr: 0.0100
# Epoch 36/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0916
# Epoch 36: val_loss did not improve from 0.08427
# 25/25 [==============================] - 176s 7s/step - loss: 0.0916 - val_loss: 0.0896 - lr: 0.0020
# Epoch 37/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0900
# Epoch 37: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0900 - val_loss: 0.0870 - lr: 0.0020
# Epoch 38/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0932
# Epoch 38: val_loss did not improve from 0.08427
# 25/25 [==============================] - 178s 7s/step - loss: 0.0932 - val_loss: 0.0886 - lr: 0.0020
# Epoch 39/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0905
# Epoch 39: val_loss did not improve from 0.08427
# 25/25 [==============================] - 178s 7s/step - loss: 0.0905 - val_loss: 0.0895 - lr: 0.0020
# Epoch 40/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0912
# Epoch 40: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0912 - val_loss: 0.0998 - lr: 0.0020
# Epoch 41/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0935
# Epoch 41: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0935 - val_loss: 0.0870 - lr: 0.0020
# Epoch 42/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0915
# Epoch 42: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0915 - val_loss: 0.0885 - lr: 0.0020
# Epoch 43/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0906
# Epoch 43: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0906 - val_loss: 0.0885 - lr: 0.0020
# Epoch 44/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0918
# Epoch 44: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0918 - val_loss: 0.0991 - lr: 0.0020
# Epoch 45/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0927
# Epoch 45: val_loss did not improve from 0.08427
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 25/25 [==============================] - 177s 7s/step - loss: 0.0927 - val_loss: 0.0880 - lr: 0.0020
# Epoch 46/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0918
# Epoch 46: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0918 - val_loss: 0.0883 - lr: 4.0000e-04
# Epoch 47/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0946
# Epoch 47: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0946 - val_loss: 0.0865 - lr: 4.0000e-04
# Epoch 48/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0903
# Epoch 48: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0903 - val_loss: 0.0854 - lr: 4.0000e-04
# Epoch 49/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0906
# Epoch 49: val_loss did not improve from 0.08427
# 25/25 [==============================] - 177s 7s/step - loss: 0.0906 - val_loss: 0.0877 - lr: 4.0000e-04
# Epoch 50/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0918
# Epoch 50: val_loss improved from 0.08427 to 0.08378, saving model to ./checkpoints/splinescont_gaussian_5
# 25/25 [==============================] - 177s 7s/step - loss: 0.0918 - val_loss: 0.0838 - lr: 4.0000e-04
# num_classes:  10
# Epoch 1/50
# 25/25 [==============================] - ETA: 0s - loss: 35.6348
# Epoch 1: val_loss improved from inf to 3.57967, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 210s 8s/step - loss: 35.6348 - val_loss: 3.5797 - lr: 0.0100
# Epoch 2/50
# 25/25 [==============================] - ETA: 0s - loss: 6.3792
# Epoch 2: val_loss improved from 3.57967 to 0.51174, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 201s 8s/step - loss: 6.3792 - val_loss: 0.5117 - lr: 0.0100
# Epoch 3/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1359
# Epoch 3: val_loss improved from 0.51174 to 0.46784, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.1359 - val_loss: 0.4678 - lr: 0.0100
# Epoch 4/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1460
# Epoch 4: val_loss improved from 0.46784 to 0.39071, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.1460 - val_loss: 0.3907 - lr: 0.0100
# Epoch 5/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1194
# Epoch 5: val_loss did not improve from 0.39071
# 25/25 [==============================] - 200s 8s/step - loss: 0.1194 - val_loss: 0.3999 - lr: 0.0100
# Epoch 6/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1025
# Epoch 6: val_loss improved from 0.39071 to 0.33141, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.1025 - val_loss: 0.3314 - lr: 0.0100
# Epoch 7/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1020
# Epoch 7: val_loss improved from 0.33141 to 0.26038, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.1020 - val_loss: 0.2604 - lr: 0.0100
# Epoch 8/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0926
# Epoch 8: val_loss improved from 0.26038 to 0.18451, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0926 - val_loss: 0.1845 - lr: 0.0100
# Epoch 9/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0903
# Epoch 9: val_loss improved from 0.18451 to 0.15107, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0903 - val_loss: 0.1511 - lr: 0.0100
# Epoch 10/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0916
# Epoch 10: val_loss improved from 0.15107 to 0.13051, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0916 - val_loss: 0.1305 - lr: 0.0100
# Epoch 11/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0899
# Epoch 11: val_loss improved from 0.13051 to 0.11962, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0899 - val_loss: 0.1196 - lr: 0.0100
# Epoch 12/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0901
# Epoch 12: val_loss improved from 0.11962 to 0.10599, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0901 - val_loss: 0.1060 - lr: 0.0100
# Epoch 13/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0902
# Epoch 13: val_loss improved from 0.10599 to 0.08630, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0902 - val_loss: 0.0863 - lr: 0.0100
# Epoch 14/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0904
# Epoch 14: val_loss did not improve from 0.08630
# 25/25 [==============================] - 199s 8s/step - loss: 0.0904 - val_loss: 0.0902 - lr: 0.0100
# Epoch 15/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0844
# Epoch 15: val_loss did not improve from 0.08630
# 25/25 [==============================] - 199s 8s/step - loss: 0.0844 - val_loss: 0.0891 - lr: 0.0100
# Epoch 16/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2444
# Epoch 16: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.2444 - val_loss: 0.2987 - lr: 0.0100
# Epoch 17/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2699
# Epoch 17: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.2699 - val_loss: 0.1089 - lr: 0.0100
# Epoch 18/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1804
# Epoch 18: val_loss did not improve from 0.08630
# 25/25 [==============================] - 199s 8s/step - loss: 0.1804 - val_loss: 0.0976 - lr: 0.0100
# Epoch 19/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1618
# Epoch 19: val_loss did not improve from 0.08630
# 25/25 [==============================] - 199s 8s/step - loss: 0.1618 - val_loss: 0.1010 - lr: 0.0100
# Epoch 20/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1314
# Epoch 20: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.1314 - val_loss: 0.1162 - lr: 0.0100
# Epoch 21/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1211
# Epoch 21: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.1211 - val_loss: 0.1065 - lr: 0.0100
# Epoch 22/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1100
# Epoch 22: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.1100 - val_loss: 0.1032 - lr: 0.0100
# Epoch 23/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1038
# Epoch 23: val_loss did not improve from 0.08630
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 25/25 [==============================] - 199s 8s/step - loss: 0.1038 - val_loss: 0.1046 - lr: 0.0100
# Epoch 24/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0974
# Epoch 24: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0974 - val_loss: 0.1044 - lr: 0.0020
# Epoch 25/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0972
# Epoch 25: val_loss did not improve from 0.08630
# 25/25 [==============================] - 199s 8s/step - loss: 0.0972 - val_loss: 0.1023 - lr: 0.0020
# Epoch 26/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0932
# Epoch 26: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0932 - val_loss: 0.0998 - lr: 0.0020
# Epoch 27/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0930
# Epoch 27: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0930 - val_loss: 0.0983 - lr: 0.0020
# Epoch 28/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0928
# Epoch 28: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0928 - val_loss: 0.0967 - lr: 0.0020
# Epoch 29/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0935
# Epoch 29: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0935 - val_loss: 0.0961 - lr: 0.0020
# Epoch 30/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0920
# Epoch 30: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0920 - val_loss: 0.0925 - lr: 0.0020
# Epoch 31/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0913
# Epoch 31: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0913 - val_loss: 0.0951 - lr: 0.0020
# Epoch 32/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0912
# Epoch 32: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0912 - val_loss: 0.0940 - lr: 0.0020
# Epoch 33/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0915
# Epoch 33: val_loss did not improve from 0.08630
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 25/25 [==============================] - 200s 8s/step - loss: 0.0915 - val_loss: 0.0928 - lr: 0.0020
# Epoch 34/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0884
# Epoch 34: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0884 - val_loss: 0.0893 - lr: 4.0000e-04
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0886
# Epoch 35: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0886 - val_loss: 0.0915 - lr: 4.0000e-04
# Epoch 36/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0889
# Epoch 36: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0889 - val_loss: 0.0888 - lr: 4.0000e-04
# Epoch 37/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 37: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0872 - val_loss: 0.0904 - lr: 4.0000e-04
# Epoch 38/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0867
# Epoch 38: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0867 - val_loss: 0.0880 - lr: 4.0000e-04
# Epoch 39/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0880
# Epoch 39: val_loss did not improve from 0.08630
# 25/25 [==============================] - 201s 8s/step - loss: 0.0880 - val_loss: 0.0896 - lr: 4.0000e-04
# Epoch 40/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0870
# Epoch 40: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0870 - val_loss: 0.0896 - lr: 4.0000e-04
# Epoch 41/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0879
# Epoch 41: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0879 - val_loss: 0.0882 - lr: 4.0000e-04
# Epoch 42/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0888
# Epoch 42: val_loss did not improve from 0.08630
# 25/25 [==============================] - 200s 8s/step - loss: 0.0888 - val_loss: 0.0879 - lr: 4.0000e-04
# Epoch 43/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0870
# Epoch 43: val_loss did not improve from 0.08630
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 25/25 [==============================] - 200s 8s/step - loss: 0.0870 - val_loss: 0.0875 - lr: 4.0000e-04
# Epoch 44/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0870
# Epoch 44: val_loss improved from 0.08630 to 0.08561, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 200s 8s/step - loss: 0.0870 - val_loss: 0.0856 - lr: 8.0000e-05
# Epoch 45/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0877
# Epoch 45: val_loss improved from 0.08561 to 0.08527, saving model to ./checkpoints/splinescont_gaussian_10
# 25/25 [==============================] - 203s 8s/step - loss: 0.0877 - val_loss: 0.0853 - lr: 8.0000e-05
# Epoch 46/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0857
# Epoch 46: val_loss did not improve from 0.08527
# 25/25 [==============================] - 200s 8s/step - loss: 0.0857 - val_loss: 0.0872 - lr: 8.0000e-05
# Epoch 47/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0879
# Epoch 47: val_loss did not improve from 0.08527
# 25/25 [==============================] - 200s 8s/step - loss: 0.0879 - val_loss: 0.0868 - lr: 8.0000e-05
# Epoch 48/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0869
# Epoch 48: val_loss did not improve from 0.08527
# 25/25 [==============================] - 200s 8s/step - loss: 0.0869 - val_loss: 0.0867 - lr: 8.0000e-05
# Epoch 49/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 49: val_loss did not improve from 0.08527
# 25/25 [==============================] - 200s 8s/step - loss: 0.0872 - val_loss: 0.0877 - lr: 8.0000e-05
# Epoch 50/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0873
# Epoch 50: val_loss did not improve from 0.08527
# 25/25 [==============================] - 200s 8s/step - loss: 0.0873 - val_loss: 0.0868 - lr: 8.0000e-05
# num_classes:  15
# Epoch 1/50
# 25/25 [==============================] - ETA: 0s - loss: 32.7306
# Epoch 1: val_loss improved from inf to 1.48978, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 250s 9s/step - loss: 32.7306 - val_loss: 1.4898 - lr: 0.0100
# Epoch 2/50
# 25/25 [==============================] - ETA: 0s - loss: 1.2710
# Epoch 2: val_loss did not improve from 1.48978
# 25/25 [==============================] - 234s 9s/step - loss: 1.2710 - val_loss: 16.3585 - lr: 0.0100
# Epoch 3/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2606
# Epoch 3: val_loss did not improve from 1.48978
# 25/25 [==============================] - 229s 9s/step - loss: 0.2606 - val_loss: 8.9412 - lr: 0.0100
# Epoch 4/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1973
# Epoch 4: val_loss improved from 1.48978 to 0.24542, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 227s 9s/step - loss: 0.1973 - val_loss: 0.2454 - lr: 0.0100
# Epoch 5/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1461
# Epoch 5: val_loss did not improve from 0.24542
# 25/25 [==============================] - 228s 9s/step - loss: 0.1461 - val_loss: 0.2673 - lr: 0.0100
# Epoch 6/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4612
# Epoch 6: val_loss improved from 0.24542 to 0.20320, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 229s 9s/step - loss: 0.4612 - val_loss: 0.2032 - lr: 0.0100
# Epoch 7/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1154
# Epoch 7: val_loss improved from 0.20320 to 0.20093, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 227s 9s/step - loss: 0.1154 - val_loss: 0.2009 - lr: 0.0100
# Epoch 8/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0978
# Epoch 8: val_loss improved from 0.20093 to 0.16446, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 226s 9s/step - loss: 0.0978 - val_loss: 0.1645 - lr: 0.0100
# Epoch 9/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0897
# Epoch 9: val_loss improved from 0.16446 to 0.12617, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 228s 9s/step - loss: 0.0897 - val_loss: 0.1262 - lr: 0.0100
# Epoch 10/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0869
# Epoch 10: val_loss improved from 0.12617 to 0.10267, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 227s 9s/step - loss: 0.0869 - val_loss: 0.1027 - lr: 0.0100
# Epoch 11/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0852
# Epoch 11: val_loss improved from 0.10267 to 0.08807, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 231s 9s/step - loss: 0.0852 - val_loss: 0.0881 - lr: 0.0100
# Epoch 12/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0858
# Epoch 12: val_loss improved from 0.08807 to 0.07777, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 230s 9s/step - loss: 0.0858 - val_loss: 0.0778 - lr: 0.0100
# Epoch 13/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0823
# Epoch 13: val_loss did not improve from 0.07777
# 25/25 [==============================] - 226s 9s/step - loss: 0.0823 - val_loss: 0.0798 - lr: 0.0100
# Epoch 14/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 14: val_loss did not improve from 0.07777
# 25/25 [==============================] - 227s 9s/step - loss: 0.0820 - val_loss: 0.0811 - lr: 0.0100
# Epoch 15/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0811
# Epoch 15: val_loss did not improve from 0.07777
# 25/25 [==============================] - 227s 9s/step - loss: 0.0811 - val_loss: 0.0823 - lr: 0.0100
# Epoch 16/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0811
# Epoch 16: val_loss did not improve from 0.07777
# 25/25 [==============================] - 227s 9s/step - loss: 0.0811 - val_loss: 0.0812 - lr: 0.0100
# Epoch 17/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0804
# Epoch 17: val_loss did not improve from 0.07777
# 25/25 [==============================] - 226s 9s/step - loss: 0.0804 - val_loss: 0.0843 - lr: 0.0100
# Epoch 18/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 18: val_loss did not improve from 0.07777
# 25/25 [==============================] - 227s 9s/step - loss: 0.0810 - val_loss: 0.0854 - lr: 0.0100
# Epoch 19/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0797
# Epoch 19: val_loss did not improve from 0.07777
# 25/25 [==============================] - 227s 9s/step - loss: 0.0797 - val_loss: 0.0807 - lr: 0.0100
# Epoch 20/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0795
# Epoch 20: val_loss did not improve from 0.07777
# 25/25 [==============================] - 227s 9s/step - loss: 0.0795 - val_loss: 0.0781 - lr: 0.0100
# Epoch 21/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0795
# Epoch 21: val_loss did not improve from 0.07777
# 25/25 [==============================] - 226s 9s/step - loss: 0.0795 - val_loss: 0.0780 - lr: 0.0100
# Epoch 22/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0796
# Epoch 22: val_loss improved from 0.07777 to 0.07757, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 228s 9s/step - loss: 0.0796 - val_loss: 0.0776 - lr: 0.0100
# Epoch 23/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0803
# Epoch 23: val_loss did not improve from 0.07757
# 25/25 [==============================] - 228s 9s/step - loss: 0.0803 - val_loss: 0.0802 - lr: 0.0100
# Epoch 24/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0788
# Epoch 24: val_loss did not improve from 0.07757
# 25/25 [==============================] - 226s 9s/step - loss: 0.0788 - val_loss: 0.0780 - lr: 0.0100
# Epoch 25/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0783
# Epoch 25: val_loss improved from 0.07757 to 0.07629, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 227s 9s/step - loss: 0.0783 - val_loss: 0.0763 - lr: 0.0100
# Epoch 26/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0793
# Epoch 26: val_loss improved from 0.07629 to 0.07536, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 227s 9s/step - loss: 0.0793 - val_loss: 0.0754 - lr: 0.0100
# Epoch 27/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0786
# Epoch 27: val_loss improved from 0.07536 to 0.07486, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 227s 9s/step - loss: 0.0786 - val_loss: 0.0749 - lr: 0.0100
# Epoch 28/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0786
# Epoch 28: val_loss did not improve from 0.07486
# 25/25 [==============================] - 227s 9s/step - loss: 0.0786 - val_loss: 0.0751 - lr: 0.0100
# Epoch 29/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 29: val_loss did not improve from 0.07486
# 25/25 [==============================] - 227s 9s/step - loss: 0.0773 - val_loss: 0.0771 - lr: 0.0100
# Epoch 30/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0788
# Epoch 30: val_loss did not improve from 0.07486
# 25/25 [==============================] - 227s 9s/step - loss: 0.0788 - val_loss: 0.0758 - lr: 0.0100
# Epoch 31/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0786
# Epoch 31: val_loss did not improve from 0.07486
# 25/25 [==============================] - 228s 9s/step - loss: 0.0786 - val_loss: 0.0760 - lr: 0.0100
# Epoch 32/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0785
# Epoch 32: val_loss did not improve from 0.07486
# 25/25 [==============================] - 227s 9s/step - loss: 0.0785 - val_loss: 0.0789 - lr: 0.0100
# Epoch 33/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0783
# Epoch 33: val_loss did not improve from 0.07486
# 25/25 [==============================] - 227s 9s/step - loss: 0.0783 - val_loss: 0.0755 - lr: 0.0100
# Epoch 34/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0778
# Epoch 34: val_loss did not improve from 0.07486
# 25/25 [==============================] - 227s 9s/step - loss: 0.0778 - val_loss: 0.0751 - lr: 0.0100
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0782
# Epoch 35: val_loss improved from 0.07486 to 0.07441, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 228s 9s/step - loss: 0.0782 - val_loss: 0.0744 - lr: 0.0100
# Epoch 36/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0770
# Epoch 36: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0770 - val_loss: 0.0767 - lr: 0.0100
# Epoch 37/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0772
# Epoch 37: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0772 - val_loss: 0.0763 - lr: 0.0100
# Epoch 38/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 38: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0779 - val_loss: 0.0779 - lr: 0.0100
# Epoch 39/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 39: val_loss did not improve from 0.07441
# 25/25 [==============================] - 225s 9s/step - loss: 0.0779 - val_loss: 0.0760 - lr: 0.0100
# Epoch 40/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 40: val_loss did not improve from 0.07441
# 25/25 [==============================] - 225s 9s/step - loss: 0.0773 - val_loss: 0.0774 - lr: 0.0100
# Epoch 41/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0769
# Epoch 41: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0769 - val_loss: 0.0757 - lr: 0.0100
# Epoch 42/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 42: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0777 - val_loss: 0.0773 - lr: 0.0100
# Epoch 43/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0781
# Epoch 43: val_loss did not improve from 0.07441
# 25/25 [==============================] - 228s 9s/step - loss: 0.0781 - val_loss: 0.0754 - lr: 0.0100
# Epoch 44/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0772
# Epoch 44: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0772 - val_loss: 0.0751 - lr: 0.0100
# Epoch 45/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 45: val_loss did not improve from 0.07441
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 25/25 [==============================] - 226s 9s/step - loss: 0.0773 - val_loss: 0.0745 - lr: 0.0100
# Epoch 46/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 46: val_loss did not improve from 0.07441
# 25/25 [==============================] - 225s 9s/step - loss: 0.0777 - val_loss: 0.0763 - lr: 0.0020
# Epoch 47/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0764
# Epoch 47: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0764 - val_loss: 0.0760 - lr: 0.0020
# Epoch 48/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 48: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0779 - val_loss: 0.0755 - lr: 0.0020
# Epoch 49/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 49: val_loss did not improve from 0.07441
# 25/25 [==============================] - 226s 9s/step - loss: 0.0773 - val_loss: 0.0758 - lr: 0.0020
# Epoch 50/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 50: val_loss improved from 0.07441 to 0.07340, saving model to ./checkpoints/splinescont_gaussian_15
# 25/25 [==============================] - 228s 9s/step - loss: 0.0777 - val_loss: 0.0734 - lr: 0.0020

# %%
typ = "gaussian"
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=1,var1_u=7,CROP1=CROP,BATCH_SIZE=32)

order = 1
num_classes = 15
model = get_model("splines_cont",it_lim=4,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/splinescont_{typ}_{num_classes}")

# %%
out = model(xs)

# %%
_ = np.random.choice(len(xs['input']))
plt.imshow(out[_],cmap='gray')
plt.show()
print(tf.image.psnr(out[_],ys[_],1))
print(tf.image.psnr(anisodiff(xs['input'][_],niter=4,lambd=50),ys[_],1))
# Out:
# tf.Tensor(25.028425, shape=(), dtype=float32)
# tf.Tensor(23.950354, shape=(), dtype=float32)

# %%
trained = glob(f'./history/splinescont_*')
w = [int(i.split('_')[-1].split('.')[0]) for i in trained]
n = len(trained)+1
viridis = cm.get_cmap('viridis', 256)
colors = viridis(np.linspace(0, 1, np.amax(w)-np.amin(w)+1))
newcmp = ListedColormap(colors)
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols=2,figsize=(20,5))

for j,i in enumerate(trained):
    
    v = np.load(i)
    axs[0].plot(v[0],alpha=0.75,color = colors[w[j]-np.amin(w)])
    axs[1].plot(v[1],alpha=0.75,color = colors[w[j]-np.amin(w)])
    
axs[0].set_title("training loss")
axs[1].set_title("validation loss")


axs[0].set_xlabel('iteration')
axs[0].set_ylabel('loss')

axs[1].set_xlabel('iteration')
axs[1].set_ylabel('loss')
    
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[0],label='partition cardinality')
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[1],label='partition cardinality')

    
plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# # Results with first function

# %%
order = 1
num_classes = 10
model = get_model("splines_cont",it_lim=4,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/splinescont_{typ}_{num_classes}")

w = [10,20,50]
fig,axs = plt.subplots(ncols = 5,nrows = int(np.ceil(len(w))),figsize=(15,4*len(w)))
for i,m in enumerate(w):

    
    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=5)
    ims = next(gen_batch_val.as_numpy_iterator())
    p = model(ims[0])
    _ = np.random.choice(len(p))


    psnr_0 = tf.image.psnr(ims[0]['input'][_],ims[1][_],1).numpy()
    ssim_0 = tf.image.ssim(ims[0]['input'][_],ims[1][_],1).numpy()
    clean = p[_]
    psnr = tf.image.psnr(ims[1][_],clean,1).numpy()
    ssim = tf.image.ssim(ims[1][_],clean,1).numpy()
    clean = np.squeeze(clean)
    inputs = tf.keras.Input(shape=image_size + (1,))
    get_lambdas = tf.keras.models.Model(model.input,model.get_layer('coeff_spline').output)
    spline = np.squeeze(get_lambdas(ims[0])[_])
    visualization = tf.keras.models.Model(model.input,model.get_layer('gS_0').output)
    vis = np.squeeze(visualization(ims[0])[_])


    psnr_0,ssim_0 = int(100*psnr_0)/100,int(100*ssim_0)/100
    psnr,ssim = int(100*psnr)/100,int(100*ssim)/100
    
    
    axs[i,0].imshow(ims[0]['input'][_],cmap='gray')
    axs[i,0].set_title(f'input\nvariance {int(100*m)/100}\nPSNR: {psnr_0}\nSSIM: {ssim_0}')
    axs[i,0].set_xticks([])
    axs[i,0].set_xticklabels([])
    axs[i,0].set_yticks([])
    axs[i,0].set_yticklabels([])
    axs[i,1].imshow(ims[1][_],cmap='gray')
    axs[i,1].set_title('target')
    axs[i,1].set_xticks([])
    axs[i,1].set_xticklabels([])
    axs[i,1].set_yticks([])
    axs[i,1].set_yticklabels([])
    axs[i,2].imshow(clean,cmap='gray')
    axs[i,2].set_title(f'result\nPSNR: {psnr}\nSSIM: {ssim}')
    axs[i,2].set_xticks([])
    axs[i,2].set_xticklabels([])
    axs[i,2].set_yticks([])
    axs[i,2].set_yticklabels([])
    im = axs[i,3].imshow(vis,cmap='gray')
    axs[i,3].set_title('coefficient function')
    plt.colorbar(im,ax=axs[i,3])
    axs[i,3].set_xticks([])
    axs[i,3].set_xticklabels([])
    axs[i,3].set_yticks([])
    axs[i,3].set_yticklabels([])
    
    partition = np.linspace(0,1,num_classes+1)
    x,s = [],[]


    for p in range(1,len(partition)):
        xp = np.linspace(partition[p-1],partition[p],100)
        linear = spline[p-1][1]*np.mod(xp,1/num_classes) + spline[p-1][0]
        s.append(np.copy(linear))
        x.append(np.copy(xp))

    s = np.concatenate(s)
    x = np.concatenate(x)
    
    
    axs[i,4].scatter(x,s)
    axs[i,4].set_xlabel("argument")
    axs[i,4].set_ylabel("coefficient value")
    axs[i,4].set_title(f"spline\npartition of {num_classes}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing against Perona Malik

# %%
order = 1
num_classes = 50
model = get_model("splines",it_lim=1,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")

w = np.linspace(20,70,10)
psnr_nn_1,psnr_nn_s_1 = [],[]
ssim_nn_1,ssim_nn_s_1 = [],[]

psnr_pm_1,psnr_pm_s_1 = [],[]
ssim_pm_1,ssim_pm_s_1 = [],[]

psnr_or_1,psnr_or_s_1 = [],[]
ssim_or_1,ssim_or_s_1 = [],[]


for i,m in enumerate(w):
    gen_batch_train,gen_batch_val = get_generators('gaussian',0,w[i],CROP1=CROP,BATCH_SIZE=100)
    ims = next(gen_batch_val.as_numpy_iterator())
    
    res = model(ims[0]) 
    #res = res/np.expand_dims(np.expand_dims(np.amax(res,axis=(1,2)),axis=-2),axis=-2)
    psnr = tf.image.psnr(res,ims[1],1).numpy()
    ssim = tf.image.ssim(res,ims[1],1).numpy()
    #psnr = [tf.image.psnr(res[j],ims[1][j],1).numpy() for j in range(len(res))]
    #ssim = [tf.image.ssim(res[j],ims[1][j],1).numpy() for j in range(len(res))]
    psnr_nn_1.append(np.mean(psnr))
    psnr_nn_s_1.append(np.std(psnr))
    ssim_nn_1.append(np.mean(ssim))
    ssim_nn_s_1.append(np.std(ssim))
    
    pm = np.array([anisodiff(im,niter = 5) for im in ims[0]['input']])
    pm = np.asarray(pm,dtype='float32')
    psnr = [tf.image.psnr(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
    ssim = [tf.image.ssim(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
    psnr_pm_1.append(np.mean(psnr))
    psnr_pm_s_1.append(np.std(psnr))
    ssim_pm_1.append(np.mean(ssim))
    ssim_pm_s_1.append(np.std(ssim))
    
    psnr = tf.image.psnr(ims[0]['input'],ims[1],1).numpy()
    ssim = tf.image.ssim(ims[0]['input'],ims[1],1).numpy()
    psnr_or_1.append(np.mean(psnr))
    psnr_or_s_1.append(np.std(psnr))
    ssim_or_1.append(np.mean(ssim))
    ssim_or_s_1.append(np.std(ssim))
    
    

plt.figure(figsize=(15,7))
plt.subplot(121)
plt.errorbar(w,psnr_nn_1,psnr_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,psnr_pm_1,psnr_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,psnr_or_1,psnr_or_s_1,label='noisy',alpha=0.5)

#plt.errorbar(w,psnr_nn_2,psnr_nn_s_2,label='network\nfunction 2',alpha=0.5)
#plt.errorbar(w,psnr_pm_2,psnr_pm_s_2,label='pm\nfunction 2',alpha=0.5)
plt.xlabel('variance of noise')
plt.ylabel('psnr')
plt.title('PSNR as function of variance in noise')
plt.legend()

plt.subplot(122)
plt.errorbar(w,ssim_nn_1,ssim_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,ssim_pm_1,ssim_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,ssim_or_1,ssim_or_s_1,label='noisy',alpha=0.5)


plt.xlabel('variance of noise')
plt.ylabel('ssim')
plt.title('SSIM as function of variance in noise')
plt.legend()
plt.show()

# %%
order = 1
w = np.linspace(2,7,10)
w = np.asarray(100*w,dtype='int')/100
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/splines_{typ}_*.index")])


hist_psnr,hist_ssim = [],[]

for num_classes in ncl:

    psnr_nn_1,ssim_nn_1 = [],[]
    model = get_model("splines",it_lim=1,image_size=image_size,num_classes = num_classes,order=order)
    for i,m in enumerate(w):
        
        model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")
        gen_batch_train,gen_batch_val = get_generators(typ,0,w[i],CROP1=CROP,BATCH_SIZE=100)
        ims = np.array(next(gen_batch_val.as_numpy_iterator()))

        res = model(ims[0])
        res = res/np.expand_dims(np.expand_dims(np.amax(res,axis=(1,2)),axis=-2),axis=-2)
        psnr = [tf.image.psnr(res[j],ims[1][j],1).numpy() for j in range(len(res))]
        ssim = [tf.image.ssim(res[j],ims[1][j],1).numpy() for j in range(len(res))]
        psnr_nn_1.append(np.mean(psnr))
        ssim_nn_1.append(np.mean(ssim))


    hist_psnr.append(np.copy(psnr_nn_1))
    hist_ssim.append(np.copy(ssim_nn_1))
    

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(hist_psnr)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('PSNR')
plt.colorbar(label='PSNR')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.subplot(122)
plt.imshow(hist_ssim)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('SSIM')
plt.colorbar(label='SSIM')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.show()

# %% [markdown]
# # Analizing functions for coefficients

# %%
order = 1
w = np.linspace(2,10,20)
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/splines_{typ}_*.index")])
xR,R = [],[]

for num_classes in ncl:
    model = get_model("splines",it_lim=10,image_size=image_size,num_classes = num_classes,order=order)
    model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")
    R.append([])
    xR.append([])
    for i,m in enumerate(w):


        gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=100)
        ims = next(gen_batch_val.as_numpy_iterator())
        p = model(ims[0])
        _ = np.random.choice(len(p))


        psnr_0 = tf.image.psnr(ims[0]['input'][_],ims[1][_],1).numpy()
        ssim_0 = tf.image.ssim(ims[0]['input'][_],ims[1][_],1).numpy()
        clean = p[_]
        psnr = tf.image.psnr(ims[1][_],clean,1).numpy()
        ssim = tf.image.ssim(ims[1][_],clean,1).numpy()
        clean = np.squeeze(clean)
        inputs = tf.keras.Input(shape=image_size + (1,))
        get_lambdas = tf.keras.models.Model(model.input,model.get_layer('coeff_spline_0').output)
        spline = np.squeeze(get_lambdas(ims[0]))
        spline = np.mean(spline,axis=0)

        partition = np.linspace(0,1,num_classes+1)
        x,s = [],[]


        for p in range(1,len(partition)):
            xp = np.linspace(partition[p-1],partition[p],100)
            linear = spline[p-1][1]*xp + spline[p-1][0]
            s.append(np.copy(linear))
            x.append(np.copy(xp))

        s = np.concatenate(s)
        x = np.concatenate(x)
    
    
        R[-1].append(np.copy(s))
        xR[-1].append(np.copy(x))

# %%
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols = 2,nrows = 3,figsize=(15,10))

for col in range(len(R)):
        
    if len(R[col]) == 0:
        continue

    viridis = cm.get_cmap('viridis', 256)
    colors = viridis(np.linspace(0, 1, len(R[col])))
    newcmp = ListedColormap(colors)

    for i in range(len(R[col])):

        #m,s = R[col][i].T

        #axs[col].errorbar(np.arange(len(m))/ncl[col],m,s,color=colors[i])
        axs[col//2,col%2].plot(xR[col][i],R[col][i],color=colors[i])

    axs[col//2,col%2].set_title(f"Mean function\nOrder: {1}\nNum of intervals: {ncl[col]}")
    axs[col//2,col%2].set_xlabel("fraction of maximum gradient norm")
    axs[col//2,col%2].set_ylabel("function value")
    plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[col//2,col%2],label='noise variance')

plt.tight_layout()        
plt.show()

# %% [markdown]
# # Plot the model

# %%
order = 1
model = get_model("splines",it_lim=1,image_size=image_size,num_classes = 5,order=order)

# %%
tf.keras.utils.plot_model(model,
    to_file="splines.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=False,)
