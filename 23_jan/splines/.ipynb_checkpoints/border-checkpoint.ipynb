# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)
size = 5
pre_smoothing = False
conv = True
sigma = 0.1


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-03-29 22:56:36.114503: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 22:56:36.702810: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# 2023-03-29 22:56:36.703316: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# 2023-03-29 22:56:36.703321: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=10,var1_u=60,CROP1=CROP,BATCH_SIZE=50,
                                               autoencoder=False)
# Out:
# 2023-03-29 22:56:37.426471: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.426688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.431937: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.432190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.432382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.432559: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.433078: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 22:56:37.636979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.637189: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.637371: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.637541: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.637710: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:37.637879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.250316: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.250594: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.250836: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.251062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.251281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.251466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19630 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-03-29 22:56:38.251794: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 22:56:38.251971: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22328 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:43:00.0, compute capability: 8.6

# %%
xs, ys = next(gen_batch_train.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs))
        axs[i,2*j].imshow(np.squeeze(xs[_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        
plt.show()

# %% [markdown]
# # Encoder

# %%
dim = 32*32
def classifier(inputs, option=1, num_classes=2,kernel_size=3,pool_size=3,CROP=256):
    
    inputs = inputs
    x = tf.keras.layers.Conv2D(32, kernel_size, strides=2, padding="same")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.Conv2D(64, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [16,32,64,128]:
        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.MaxPooling2D(pool_size, strides=2, padding="same")(x)

        # Project residual
        residual = tf.keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = tf.keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = tf.keras.layers.SeparableConv2D(dim, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    
    return tf.keras.Model(inputs,x)

input_shape = image_size + (1,)
embedding = classifier(tf.keras.layers.Input(input_shape))
embedding.load_weights('../border/checkpoints/embedding')

for layer in embedding.layers:
    layer.trainable = False

# %% [markdown]
# # Denoising

# %%
"""
Creating the model
"""
def conv_block(x, n_filt, size_conv=(5,5), n_conv=3):
    """
    Applies n_conv convolutions to the input with specified size and number of filters.
    """
    for c in range(n_conv):
        x = tf.keras.layers.Conv2D(n_filt, size_conv, padding="same", activation=None)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('relu')(x)
    return x

def u_encoder(x, n_filt):
    """
    Applies conv_block and returnes max pooled and skip-connection.
    """
    x = conv_block(x, n_filt)
    return tf.keras.layers.MaxPool2D()(x), x

def u_decoder(pooled, skipped, n_filt):
    """
    Upsamples pooled and concats with skiped.
    """
    upsampled = tf.keras.layers.Convolution2DTranspose(n_filt, (2,2), strides=(2,2), padding='same')(pooled)
    return conv_block(tf.keras.layers.concatenate([upsampled, skipped]), n_filt)
    
    
def make_unet(inp, depth=3, output_channels=1):
    skipped = []
    p = inp
    for _ in range(depth):
        p, s = u_encoder(p, 2**(1+_))
        #p, s = u_encoder(p, 2*(1+_))
        skipped.append(s)
    p = conv_block(p, 2**(2+depth))
    for _ in reversed(range(depth)):
        p = u_decoder(p, skipped[_], 2**(2+_))  
        #p = u_decoder(p, skipped[_], (2**3)*(1+_))  
    p = tf.keras.layers.Conv2D(output_channels, (1,1), activation='sigmoid')(p)
    return p

def get_model(inp):
    """
    Takes network Input layer 
    """
    outp = make_unet(inp)
    return tf.keras.models.Model(inp, outp)

border = get_model(tf.keras.layers.Input(shape=(CROP,CROP, 1)))
border.load_weights(f"../border/checkpoints/borders_{typ}")

for layer in border.layers:
    layer.trainable = False

# %%
input_shape = image_size + (1,)
it_lim = 3
num_classes=10
order1 = 1
gamma=1
pre_smoothing=False
size=5
order = order1

inputs = tf.keras.Input(shape=input_shape,name='input')


#x = classifier(inputs, num_classes=num_classes,CROP=CROP)
x = embedding(inputs)

y = tf.keras.layers.Flatten(name='y')(x)

partition_low = tf.constant(np.power(np.linspace(0,1,num_classes+1),1)[:-1])
partition_low = tf.expand_dims(tf.expand_dims(tf.expand_dims(partition_low,0),0),0)
partition_low = tf.cast(partition_low,tf.float32)
partition_up = tf.constant(np.power(np.linspace(0,1,num_classes+1),1)[1:])
partition_up = tf.expand_dims(tf.expand_dims(tf.expand_dims(partition_up,0),0),0)
partition_up = tf.cast(partition_up,tf.float32)

deltaS = tf.keras.layers.Lambda(lambda z:tf.zeros_like(z))(inputs)
deltaE = tf.keras.layers.Lambda(lambda z:tf.zeros_like(z))(inputs)
NS = tf.keras.layers.Lambda(lambda z:tf.zeros_like(z))(inputs)
EW = tf.keras.layers.Lambda(lambda z:tf.zeros_like(z))(inputs)
gS = tf.keras.layers.Lambda(lambda z:tf.ones_like(z))(inputs)
gE = tf.keras.layers.Lambda(lambda z:tf.ones_like(z))(inputs)


b_initial = tf.keras.layers.Dense(1,activation='linear')(y)
b_initial = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(b_initial)

a = tf.keras.layers.Dense(num_classes*order,activation = 'linear')(y)

a = tf.keras.layers.Reshape((num_classes,order))(a)

b = tf.keras.layers.Lambda(lambda z:tf.multiply(np.asarray(1/num_classes,dtype=np.float32),tf.ones_like(z)))(a)
b = tf.pow(b,np.arange(1,order+1))
b = tf.keras.layers.multiply([a,b])

m = tf.linalg.LinearOperatorLowerTriangular(tf.ones(tf.shape(a)+(0,0,num_classes-1))).to_dense()
b = tf.keras.layers.multiply([tf.transpose(b,perm=(0,2,1)),m])
b = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(b)
b0 = tf.keras.layers.Lambda(lambda z:tf.expand_dims(tf.zeros_like(z[:,0]),axis=-1))(b)
b = tf.keras.layers.Concatenate(axis=1)([b0,b])
b = tf.keras.layers.Lambda(lambda z:z[:,:-1])(b)
b = tf.keras.layers.add((b,b_initial))
b = tf.expand_dims(b,axis=-1)


ct = tf.keras.layers.Concatenate(name='coeff_spline')((b,a))
ct = tf.keras.layers.Lambda(lambda z: tf.expand_dims(tf.expand_dims(z,axis=1),axis=1))(ct)

outputs = tf.keras.layers.Lambda(lambda z: tf.identity(z))(inputs)



for num_it in range(it_lim):


    difS = tf.keras.layers.Lambda(lambda z: tf.experimental.numpy.diff(z,axis=1))(outputs)
    difE = tf.keras.layers.Lambda(lambda z: tf.experimental.numpy.diff(z,axis=2))(outputs)
    zeros_y = tf.expand_dims(tf.zeros_like(outputs)[:,1],axis=-1)
    zeros_x = tf.expand_dims(tf.zeros_like(inputs)[:,1],axis=-3)
    #deltaS = tf.keras.layers.Concatenate(axis=1)([difS,zeros_x])
    #deltaE = tf.keras.layers.Concatenate(axis=2)([difE,zeros_y])
    deltaS = border(outputs)
    deltaE = border(outputs)

    dS_n = tf.keras.layers.Lambda(lambda z: tf.math.abs(z)/tf.reduce_max(tf.math.abs(z)))(deltaS)
    dE_n = tf.keras.layers.Lambda(lambda z: tf.math.abs(z)/tf.reduce_max(tf.math.abs(z)))(deltaE)

    dS2 = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2),name=f'dx_{num_it}')(dS_n)
    dE2 = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(dE_n)

    ineq1_S = tf.greater_equal(dS2, partition_low)
    ineq2_S = tf.less_equal(dS2,partition_up)
    ineq1_E = tf.greater_equal(dE2, partition_low)
    ineq2_E = tf.less_equal(dE2,partition_up)

    interval_S = tf.cast(tf.math.logical_and(ineq1_S,ineq2_S),tf.float32)
    interval_E = tf.cast(tf.math.logical_and(ineq1_E,ineq2_E),tf.float32)

    power_norm_S = tf.pow(dS2,tf.constant(np.asarray(np.arange(1,order+1),dtype='float32')))
    power_norm_S = tf.keras.layers.Lambda(lambda z:tf.math.mod(z,1/num_classes))(power_norm_S)
    cte_S = tf.ones_like(inputs)
    power_norm_S = tf.keras.layers.Concatenate(axis=-1)((cte_S,power_norm_S))
    power_norm_S = tf.keras.layers.Lambda(lambda z: tf.expand_dims(z,axis=-2))(power_norm_S)
    power_norm_E = tf.pow(dE2,tf.constant(np.asarray(np.arange(1,order+1),dtype='float32')))
    power_norm_E = tf.keras.layers.Lambda(lambda z:tf.math.mod(z,1/num_classes))(power_norm_E)
    cte_E = tf.ones_like(inputs)
    power_norm_E = tf.keras.layers.Concatenate(axis=-1)((cte_E,power_norm_E))
    power_norm_E = tf.keras.layers.Lambda(lambda z: tf.expand_dims(z,axis=-2))(power_norm_E)


    spline_S = tf.keras.layers.multiply([ct,power_norm_S])
    spline_S = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(spline_S)
    spline_S = tf.keras.layers.multiply([spline_S,interval_S])
    spline_E = tf.keras.layers.multiply([ct,power_norm_E])
    spline_E = tf.keras.layers.Lambda(lambda z:tf.math.reduce_sum(z,axis=-1))(spline_E)
    spline_E = tf.keras.layers.multiply([spline_E,interval_E])


    gS = tf.keras.layers.Lambda(lambda z: tf.math.reduce_sum(z,axis=-1),name=f'gS_{num_it}')(spline_S)
    gS = tf.expand_dims(gS,axis=-1)
    gE = tf.keras.layers.Lambda(lambda z: tf.math.reduce_sum(z,axis=-1),name=f'gE_{num_it}')(spline_E)
    gE = tf.expand_dims(gE,axis=-1)

    difS = tf.keras.layers.Lambda(lambda z: tf.experimental.numpy.diff(z,axis=1))(outputs)
    difE = tf.keras.layers.Lambda(lambda z: tf.experimental.numpy.diff(z,axis=2))(outputs)
    deltaS = tf.keras.layers.Concatenate(axis=1)([difS,zeros_x])
    deltaE = tf.keras.layers.Concatenate(axis=2)([difE,zeros_y])
    E = tf.keras.layers.multiply((gE,deltaE))
    S = tf.keras.layers.multiply((gS,deltaS))

    NS = S
    EW = E
    NS = tf.keras.layers.Concatenate(axis=1)([zeros_x,NS])
    EW = tf.keras.layers.Concatenate(axis=2)([zeros_y,EW])
    NS = tf.keras.layers.Lambda(lambda z: tf.experimental.numpy.diff(z,axis=1))(NS)
    EW = tf.keras.layers.Lambda(lambda z: tf.experimental.numpy.diff(z,axis=2))(EW)

    mult = tf.keras.layers.Lambda(lambda z: tf.multiply(tf.cast(gamma,dtype=tf.float32),z))(tf.ones_like(NS))
    NS_mod = NS
    EW_mod = EW

    adding = tf.keras.layers.add([NS,EW])
    adding = tf.keras.layers.multiply((mult,adding))

    outputs = tf.keras.layers.add([outputs,adding])


        
model = tf.keras.models.Model(inputs, outputs)

# %%
def loss(y_true,y_pred):
    error = tf.reduce_mean(tf.pow(y_pred - y_true,2),axis=(1,2,3))
    return error

model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
            loss=loss,)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
                filepath= f"./checkpoints/splinesborder_{typ}_{num_classes}",
                save_weights_only=True,
                verbose = True,
                save_best_only=True),
                            tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1,patience=5),
                            tf.keras.callbacks.TerminateOnNaN()

                ]

# %%
history = model.fit(
        gen_batch_train,
        epochs=200,
        steps_per_epoch=50,
        validation_data=gen_batch_val,
        validation_steps=10,
        shuffle=False,
        use_multiprocessing=True,
        callbacks=callbacks,
        workers=1
    )
# Out:
# Epoch 1/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0538
# Epoch 1: val_loss improved from inf to 0.00958, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 36s 590ms/step - loss: 0.0538 - val_loss: 0.0096 - lr: 1.0000e-04
# Epoch 2/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 2: val_loss improved from 0.00958 to 0.00665, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 563ms/step - loss: 0.0084 - val_loss: 0.0066 - lr: 1.0000e-04
# Epoch 3/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 3: val_loss improved from 0.00665 to 0.00619, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 567ms/step - loss: 0.0067 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 4/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 4: val_loss did not improve from 0.00619
# 50/50 [==============================] - 28s 563ms/step - loss: 0.0059 - val_loss: 0.0070 - lr: 1.0000e-04
# Epoch 5/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 5: val_loss improved from 0.00619 to 0.00501, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 568ms/step - loss: 0.0056 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 6/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 6: val_loss improved from 0.00501 to 0.00462, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 569ms/step - loss: 0.0053 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 7/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 7: val_loss did not improve from 0.00462
# 50/50 [==============================] - 28s 564ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 8/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 8: val_loss did not improve from 0.00462
# 50/50 [==============================] - 28s 562ms/step - loss: 0.0050 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 9/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 9: val_loss did not improve from 0.00462
# 50/50 [==============================] - 28s 562ms/step - loss: 0.0046 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 10/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 10: val_loss improved from 0.00462 to 0.00438, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 566ms/step - loss: 0.0047 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 11/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 11: val_loss did not improve from 0.00438
# 50/50 [==============================] - 28s 563ms/step - loss: 0.0045 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 12/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 12: val_loss did not improve from 0.00438
# 50/50 [==============================] - 28s 563ms/step - loss: 0.0044 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 13/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 13: val_loss improved from 0.00438 to 0.00436, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 567ms/step - loss: 0.0043 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 14/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 14: val_loss improved from 0.00436 to 0.00431, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 567ms/step - loss: 0.0044 - val_loss: 0.0043 - lr: 1.0000e-04
# Epoch 15/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 15: val_loss improved from 0.00431 to 0.00394, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 28s 566ms/step - loss: 0.0043 - val_loss: 0.0039 - lr: 1.0000e-04
# Epoch 16/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 16: val_loss improved from 0.00394 to 0.00393, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 526ms/step - loss: 0.0041 - val_loss: 0.0039 - lr: 1.0000e-04
# Epoch 17/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 17: val_loss improved from 0.00393 to 0.00390, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 525ms/step - loss: 0.0042 - val_loss: 0.0039 - lr: 1.0000e-04
# Epoch 18/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 18: val_loss did not improve from 0.00390
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0041 - val_loss: 0.0042 - lr: 1.0000e-04
# Epoch 19/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 19: val_loss did not improve from 0.00390
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0040 - val_loss: 0.0040 - lr: 1.0000e-04
# Epoch 20/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 20: val_loss improved from 0.00390 to 0.00380, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 525ms/step - loss: 0.0039 - val_loss: 0.0038 - lr: 1.0000e-04
# Epoch 21/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 21: val_loss did not improve from 0.00380
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0039 - val_loss: 0.0039 - lr: 1.0000e-04
# Epoch 22/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 22: val_loss did not improve from 0.00380
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0038 - val_loss: 0.0042 - lr: 1.0000e-04
# Epoch 23/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 23: val_loss improved from 0.00380 to 0.00354, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 526ms/step - loss: 0.0039 - val_loss: 0.0035 - lr: 1.0000e-04
# Epoch 24/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 24: val_loss improved from 0.00354 to 0.00349, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 526ms/step - loss: 0.0038 - val_loss: 0.0035 - lr: 1.0000e-04
# Epoch 25/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 25: val_loss did not improve from 0.00349
# 50/50 [==============================] - 26s 519ms/step - loss: 0.0039 - val_loss: 0.0036 - lr: 1.0000e-04
# Epoch 26/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 26: val_loss improved from 0.00349 to 0.00347, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 527ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 1.0000e-04
# Epoch 27/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 27: val_loss improved from 0.00347 to 0.00340, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 525ms/step - loss: 0.0038 - val_loss: 0.0034 - lr: 1.0000e-04
# Epoch 28/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 28: val_loss did not improve from 0.00340
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0036 - lr: 1.0000e-04
# Epoch 29/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 29: val_loss did not improve from 0.00340
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0038 - val_loss: 0.0034 - lr: 1.0000e-04
# Epoch 30/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 30: val_loss did not improve from 0.00340
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.0000e-04
# Epoch 31/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 31: val_loss did not improve from 0.00340
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.0000e-04
# Epoch 32/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 32: val_loss did not improve from 0.00340
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.0000e-04
# Epoch 33/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 33: val_loss did not improve from 0.00340
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 2.0000e-05
# Epoch 34/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 34: val_loss improved from 0.00340 to 0.00334, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 527ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 2.0000e-05
# Epoch 35/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 35: val_loss did not improve from 0.00334
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.0000e-05
# Epoch 36/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 36: val_loss did not improve from 0.00334
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.0000e-05
# Epoch 37/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 37: val_loss did not improve from 0.00334
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.0000e-05
# Epoch 38/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 38: val_loss did not improve from 0.00334
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 4.0000e-06
# Epoch 39/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 39: val_loss improved from 0.00334 to 0.00331, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 526ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 4.0000e-06
# Epoch 40/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 40: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 4.0000e-06
# Epoch 41/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 41: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 4.0000e-06
# Epoch 42/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 42: val_loss did not improve from 0.00331
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 4.0000e-06
# Epoch 43/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 43: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.0000e-07
# Epoch 44/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 44: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 8.0000e-07
# Epoch 45/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 45: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 8.0000e-07
# Epoch 46/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 46: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 519ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.0000e-07
# Epoch 47/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 47: val_loss did not improve from 0.00331
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 8.0000e-07
# Epoch 48/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 48: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.6000e-07
# Epoch 49/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 49: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 1.6000e-07
# Epoch 50/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 50: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 1.6000e-07
# Epoch 51/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 51: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 1.6000e-07
# Epoch 52/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 52: val_loss did not improve from 0.00331
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 1.6000e-07
# Epoch 53/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 53: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 3.2000e-08
# Epoch 54/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 54: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 3.2000e-08
# Epoch 55/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 55: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 3.2000e-08
# Epoch 56/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 56: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0037 - lr: 3.2000e-08
# Epoch 57/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 57: val_loss did not improve from 0.00331
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 3.2000e-08
# Epoch 58/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 58: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 6.4000e-09
# Epoch 59/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 59: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 6.4000e-09
# Epoch 60/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 60: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 6.4000e-09
# Epoch 61/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 61: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 6.4000e-09
# Epoch 62/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 62: val_loss did not improve from 0.00331
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0036 - lr: 6.4000e-09
# Epoch 63/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 63: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 1.2800e-09
# Epoch 64/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 64: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 519ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 1.2800e-09
# Epoch 65/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 65: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 1.2800e-09
# Epoch 66/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 66: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 1.2800e-09
# Epoch 67/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 67: val_loss did not improve from 0.00331
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 2.55999976772614e-10.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 1.2800e-09
# Epoch 68/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 68: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.5600e-10
# Epoch 69/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 69: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.5600e-10
# Epoch 70/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 70: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 2.5600e-10
# Epoch 71/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 71: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 2.5600e-10
# Epoch 72/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 72: val_loss did not improve from 0.00331
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 5.119999424429978e-11.
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0035 - val_loss: 0.0034 - lr: 2.5600e-10
# Epoch 73/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 73: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 5.1200e-11
# Epoch 74/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 74: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0035 - val_loss: 0.0036 - lr: 5.1200e-11
# Epoch 75/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 75: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 524ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 5.1200e-11
# Epoch 76/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 76: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 5.1200e-11
# Epoch 77/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 77: val_loss did not improve from 0.00331
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.0239999126415712e-11.
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0037 - lr: 5.1200e-11
# Epoch 78/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 78: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 1.0240e-11
# Epoch 79/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 79: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0037 - val_loss: 0.0036 - lr: 1.0240e-11
# Epoch 80/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 80: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 1.0240e-11
# Epoch 81/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 81: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.0240e-11
# Epoch 82/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 82: val_loss did not improve from 0.00331
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 2.0479997905886727e-12.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.0240e-11
# Epoch 83/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 83: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 2.0480e-12
# Epoch 84/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 84: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 2.0480e-12
# Epoch 85/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 85: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.0480e-12
# Epoch 86/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 86: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 2.0480e-12
# Epoch 87/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 87: val_loss did not improve from 0.00331
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 4.0959995811773456e-13.
# 50/50 [==============================] - 26s 519ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 2.0480e-12
# Epoch 88/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 88: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 4.0960e-13
# Epoch 89/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 89: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 4.0960e-13
# Epoch 90/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 90: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0033 - lr: 4.0960e-13
# Epoch 91/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 91: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 4.0960e-13
# Epoch 92/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 92: val_loss did not improve from 0.00331
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 8.191999053934474e-14.
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 4.0960e-13
# Epoch 93/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 93: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.1920e-14
# Epoch 94/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 94: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 8.1920e-14
# Epoch 95/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 95: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.1920e-14
# Epoch 96/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 96: val_loss did not improve from 0.00331
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.1920e-14
# Epoch 97/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 97: val_loss did not improve from 0.00331
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.638399837891949e-14.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 8.1920e-14
# Epoch 98/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 98: val_loss improved from 0.00331 to 0.00328, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 528ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 1.6384e-14
# Epoch 99/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 99: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.6384e-14
# Epoch 100/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 100: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.6384e-14
# Epoch 101/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 101: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.6384e-14
# Epoch 102/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 102: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0035 - val_loss: 0.0035 - lr: 1.6384e-14
# Epoch 103/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 103: val_loss did not improve from 0.00328
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 3.27679981130917e-15.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 1.6384e-14
# Epoch 104/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 104: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 3.2768e-15
# Epoch 105/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 105: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 3.2768e-15
# Epoch 106/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 106: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 3.2768e-15
# Epoch 107/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 107: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 3.2768e-15
# Epoch 108/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 108: val_loss did not improve from 0.00328
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 6.553599792024929e-16.
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0039 - lr: 3.2768e-15
# Epoch 109/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 109: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 6.5536e-16
# Epoch 110/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 110: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 6.5536e-16
# Epoch 111/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 111: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 6.5536e-16
# Epoch 112/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 112: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 6.5536e-16
# Epoch 113/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 113: val_loss did not improve from 0.00328
#
# Epoch 113: ReduceLROnPlateau reducing learning rate to 1.3107199584049857e-16.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 6.5536e-16
# Epoch 114/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 114: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0035 - val_loss: 0.0037 - lr: 1.3107e-16
# Epoch 115/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 115: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.3107e-16
# Epoch 116/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 116: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0033 - lr: 1.3107e-16
# Epoch 117/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 117: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 1.3107e-16
# Epoch 118/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 118: val_loss did not improve from 0.00328
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 2.6214399168099714e-17.
# 50/50 [==============================] - 26s 524ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 1.3107e-16
# Epoch 119/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 119: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0033 - lr: 2.6214e-17
# Epoch 120/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 120: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.6214e-17
# Epoch 121/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 121: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 2.6214e-17
# Epoch 122/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 122: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.6214e-17
# Epoch 123/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 123: val_loss did not improve from 0.00328
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 5.2428798336199434e-18.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 2.6214e-17
# Epoch 124/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 124: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0035 - val_loss: 0.0034 - lr: 5.2429e-18
# Epoch 125/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 125: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 5.2429e-18
# Epoch 126/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 126: val_loss did not improve from 0.00328
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 5.2429e-18
# Epoch 127/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 127: val_loss improved from 0.00328 to 0.00326, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 526ms/step - loss: 0.0037 - val_loss: 0.0033 - lr: 5.2429e-18
# Epoch 128/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 128: val_loss did not improve from 0.00326
#
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1.0485759998112131e-18.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0037 - lr: 5.2429e-18
# Epoch 129/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 129: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 1.0486e-18
# Epoch 130/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 130: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 1.0486e-18
# Epoch 131/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 131: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.0486e-18
# Epoch 132/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 132: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 1.0486e-18
# Epoch 133/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 133: val_loss did not improve from 0.00326
#
# Epoch 133: ReduceLROnPlateau reducing learning rate to 2.0971520409814568e-19.
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 1.0486e-18
# Epoch 134/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 134: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.0972e-19
# Epoch 135/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 135: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 524ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.0972e-19
# Epoch 136/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 136: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.0972e-19
# Epoch 137/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 137: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.0972e-19
# Epoch 138/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 138: val_loss did not improve from 0.00326
#
# Epoch 138: ReduceLROnPlateau reducing learning rate to 4.1943040819629136e-20.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 2.0972e-19
# Epoch 139/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 139: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 4.1943e-20
# Epoch 140/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 140: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 4.1943e-20
# Epoch 141/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 141: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 4.1943e-20
# Epoch 142/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 142: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 4.1943e-20
# Epoch 143/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 143: val_loss did not improve from 0.00326
#
# Epoch 143: ReduceLROnPlateau reducing learning rate to 8.388607905431887e-21.
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 4.1943e-20
# Epoch 144/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 144: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 8.3886e-21
# Epoch 145/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 145: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 8.3886e-21
# Epoch 146/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 146: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 8.3886e-21
# Epoch 147/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 147: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 8.3886e-21
# Epoch 148/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 148: val_loss did not improve from 0.00326
#
# Epoch 148: ReduceLROnPlateau reducing learning rate to 1.6777216457098625e-21.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.3886e-21
# Epoch 149/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 149: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0035 - val_loss: 0.0035 - lr: 1.6777e-21
# Epoch 150/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 150: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.6777e-21
# Epoch 151/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 151: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 519ms/step - loss: 0.0035 - val_loss: 0.0034 - lr: 1.6777e-21
# Epoch 152/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 152: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 1.6777e-21
# Epoch 153/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 153: val_loss did not improve from 0.00326
#
# Epoch 153: ReduceLROnPlateau reducing learning rate to 3.3554432106403683e-22.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 1.6777e-21
# Epoch 154/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 154: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0037 - lr: 3.3554e-22
# Epoch 155/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 155: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 3.3554e-22
# Epoch 156/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 156: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0033 - lr: 3.3554e-22
# Epoch 157/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 157: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0038 - lr: 3.3554e-22
# Epoch 158/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 158: val_loss did not improve from 0.00326
#
# Epoch 158: ReduceLROnPlateau reducing learning rate to 6.710886421280737e-23.
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0035 - val_loss: 0.0035 - lr: 3.3554e-22
# Epoch 159/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 159: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 6.7109e-23
# Epoch 160/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 160: val_loss improved from 0.00326 to 0.00326, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 525ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 6.7109e-23
# Epoch 161/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 161: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 523ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 6.7109e-23
# Epoch 162/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 162: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 6.7109e-23
# Epoch 163/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 163: val_loss did not improve from 0.00326
#
# Epoch 163: ReduceLROnPlateau reducing learning rate to 1.3421772842561475e-23.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 6.7109e-23
# Epoch 164/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 164: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.3422e-23
# Epoch 165/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 165: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.3422e-23
# Epoch 166/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 166: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.3422e-23
# Epoch 167/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 167: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.3422e-23
# Epoch 168/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 168: val_loss did not improve from 0.00326
#
# Epoch 168: ReduceLROnPlateau reducing learning rate to 2.6843545054034223e-24.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 1.3422e-23
# Epoch 169/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 169: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 2.6844e-24
# Epoch 170/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 170: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 2.6844e-24
# Epoch 171/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 171: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.6844e-24
# Epoch 172/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 172: val_loss did not improve from 0.00326
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 2.6844e-24
# Epoch 173/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 173: val_loss did not improve from 0.00326
#
# Epoch 173: ReduceLROnPlateau reducing learning rate to 5.368708853034664e-25.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 2.6844e-24
# Epoch 174/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 174: val_loss improved from 0.00326 to 0.00321, saving model to ./checkpoints/splinesborder_gaussian_10
# 50/50 [==============================] - 26s 527ms/step - loss: 0.0035 - val_loss: 0.0032 - lr: 5.3687e-25
# Epoch 175/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 175: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 5.3687e-25
# Epoch 176/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 176: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0033 - lr: 5.3687e-25
# Epoch 177/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 177: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 5.3687e-25
# Epoch 178/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 178: val_loss did not improve from 0.00321
#
# Epoch 178: ReduceLROnPlateau reducing learning rate to 1.07374175088541e-25.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 5.3687e-25
# Epoch 179/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 179: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0036 - lr: 1.0737e-25
# Epoch 180/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 180: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 1.0737e-25
# Epoch 181/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 181: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0036 - lr: 1.0737e-25
# Epoch 182/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 182: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.0737e-25
# Epoch 183/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 183: val_loss did not improve from 0.00321
#
# Epoch 183: ReduceLROnPlateau reducing learning rate to 2.1474835017708202e-26.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 1.0737e-25
# Epoch 184/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 184: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.1475e-26
# Epoch 185/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 185: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.1475e-26
# Epoch 186/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 186: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 2.1475e-26
# Epoch 187/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 187: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 2.1475e-26
# Epoch 188/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 188: val_loss did not improve from 0.00321
#
# Epoch 188: ReduceLROnPlateau reducing learning rate to 4.2949670651713984e-27.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 2.1475e-26
# Epoch 189/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 189: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 4.2950e-27
# Epoch 190/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 190: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 4.2950e-27
# Epoch 191/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 191: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0037 - val_loss: 0.0034 - lr: 4.2950e-27
# Epoch 192/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 192: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0033 - lr: 4.2950e-27
# Epoch 193/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 193: val_loss did not improve from 0.00321
#
# Epoch 193: ReduceLROnPlateau reducing learning rate to 8.589934130342796e-28.
# 50/50 [==============================] - 26s 521ms/step - loss: 0.0036 - val_loss: 0.0037 - lr: 4.2950e-27
# Epoch 194/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 194: val_loss did not improve from 0.00321
# 50/50 [==============================] - 27s 549ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 8.5899e-28
# Epoch 195/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 195: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 519ms/step - loss: 0.0036 - val_loss: 0.0034 - lr: 8.5899e-28
# Epoch 196/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 196: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 8.5899e-28
# Epoch 197/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 197: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 8.5899e-28
# Epoch 198/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 198: val_loss did not improve from 0.00321
#
# Epoch 198: ReduceLROnPlateau reducing learning rate to 1.7179869031057572e-28.
# 50/50 [==============================] - 26s 522ms/step - loss: 0.0036 - val_loss: 0.0036 - lr: 8.5899e-28
# Epoch 199/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 199: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 524ms/step - loss: 0.0036 - val_loss: 0.0035 - lr: 1.7180e-28
# Epoch 200/200
# 50/50 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 200: val_loss did not improve from 0.00321
# 50/50 [==============================] - 26s 520ms/step - loss: 0.0037 - val_loss: 0.0035 - lr: 1.7180e-28

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())
p = model(xs)

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs))
        axs[i,2*j].imshow(np.squeeze(xs[_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(p[_]),cmap='gray')
        
plt.show()
