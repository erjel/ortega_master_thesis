# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)


import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
"""
Creating the model
"""
def conv_block(x, n_filt, size_conv=(5,5), n_conv=3):
    """
    Applies n_conv convolutions to the input with specified size and number of filters.
    """
    for c in range(n_conv):
        x = tf.keras.layers.Conv2D(n_filt, size_conv, padding="same", activation=None)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('relu')(x)
    return x

def u_encoder(x, n_filt):
    """
    Applies conv_block and returnes max pooled and skip-connection.
    """
    x = conv_block(x, n_filt)
    return tf.keras.layers.MaxPool2D()(x), x

def u_decoder(pooled, skipped, n_filt):
    """
    Upsamples pooled and concats with skiped.
    """
    upsampled = tf.keras.layers.Convolution2DTranspose(n_filt, (2,2), strides=(2,2), padding='same')(pooled)
    return conv_block(tf.keras.layers.concatenate([upsampled, skipped]), n_filt)
    
    
def make_unet(inp, depth=3, output_channels=1):
    skipped = []
    p = inp
    for _ in range(depth):
        p, s = u_encoder(p, 2**(1+_))
        skipped.append(s)
    p = conv_block(p, 2**(2+depth))
    for _ in reversed(range(depth)):
        p = u_decoder(p, skipped[_], 2**(2+_))  
    p = tf.keras.layers.Conv2D(output_channels, (1,1), activation='sigmoid')(p)
    return p

def get_unet(inp):
    """
    Takes network Input layer 
    """
    outp = make_unet(inp)
    return tf.keras.models.Model(inp, outp)



def classifier(inputs, option=1, num_classes=2,kernel_size=3,pool_size=3,CROP=256):
    
    
    x = tf.keras.layers.Conv2D(32, kernel_size, strides=2, padding="same")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.Conv2D(64, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [16,32,64,128]:
        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, kernel_size, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.MaxPooling2D(pool_size, strides=2, padding="same")(x)

        # Project residual
        residual = tf.keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = tf.keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = tf.keras.layers.SeparableConv2D(1024, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    
    return x

# %%
input_shape = image_size +(1,)
inputs = tf.keras.Input(shape=input_shape,name='input')
input_emb = tf.keras.layers.Input(shape = (1),name='input_emb')

emb = tf.keras.layers.Dense(num_classes,activation='relu')(input_emb)
emb = tf.keras.layers.Dense(num_classes,activation='sigmoid',name='embedding')(emb)
x = classifier(inputs, num_classes=num_classes,CROP=CROP)

y = tf.keras.layers.Flatten()(x)

y1 = y

dx = tf.keras.layers.Lambda(lambda z: z[:,:-2,1:-1] - z[:,1:-1,1:-1])(inputs)
dy = tf.keras.layers.Lambda(lambda z: z[:,2:,1:-1] - z[:,1:-1,1:-1])(inputs)
dx_n = tf.keras.layers.Lambda(lambda z: tf.math.abs(z)/tf.reduce_max(tf.math.abs(z)))(dx)
dy_n = tf.keras.layers.Lambda(lambda z: tf.math.abs(z)/tf.reduce_max(tf.math.abs(z)))(dy)
dx_n = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(dx_n)
dy_n = tf.keras.layers.Lambda(lambda z:tf.math.pow(z,2))(dy_n)

cte = tf.keras.layers.Dense(1,activation = 'relu')(y1)
cte_emb = tf.keras.layers.Dense(1,activation = 'relu')(emb)
cte = tf.keras.layers.add([cte,cte_emb])
cte = tf.keras.layers.Lambda(lambda z: tf.math.pow(z,2))(cte)

linear = tf.keras.layers.Dense(1,activation = 'relu')(y1)
linear_emb = tf.keras.layers.Dense(1,activation = 'relu')(emb)
linear = tf.keras.layers.add([linear,linear_emb])
quad = tf.keras.layers.Dense(num_classes-2,activation='linear')(y1)
quad_emb = tf.keras.layers.Dense(num_classes-2,activation='linear')(emb)
quad = tf.keras.layers.add([quad,quad_emb])

fact = tf.constant(np.arange(2,num_classes,1),dtype=tf.float32)
fact = tf.stack([fact for it in range(num_classes-2)],axis=-2)-1
triangular = tf.linalg.LinearOperatorLowerTriangular(tf.ones_like(fact)).to_dense()
fact = tf.keras.layers.multiply([triangular,fact])+1
fact = tf.keras.layers.Lambda(lambda z: tf.math.reduce_prod(z,axis=-1))(fact)
quad = tf.keras.layers.Lambda(lambda z: z[0]/z[1],name='quad')([quad,fact])
sum_quad = tf.keras.layers.add(tf.unstack(quad,axis=-1))

for dim in range(2):
    quad = tf.keras.layers.Lambda(lambda z: tf.expand_dims(z,axis=1))(quad)

val_quad_x = tf.pow(dx_n,tf.constant(np.asarray(np.arange(1,num_classes-1),dtype='float32')))
val_quad_y = tf.pow(dy_n,tf.constant(np.asarray(np.arange(1,num_classes-1),dtype='float32')))

quad_val_x = tf.keras.layers.multiply([quad,val_quad_x])
quad_val_x = tf.keras.layers.Lambda(lambda z: tf.unstack(z,axis=-1))(quad_val_x)
quad_val_x = tf.keras.layers.add(quad_val_x)
quad_val_y = tf.keras.layers.multiply([quad,val_quad_y])
quad_val_y = tf.keras.layers.Lambda(lambda z: tf.unstack(z,axis=-1))(quad_val_y)
quad_val_y = tf.keras.layers.add(quad_val_y)

bound_x = tf.reduce_max(quad_val_x,axis=(1,2))
bound_y = tf.reduce_max(quad_val_y,axis=(1,2))
bound = tf.math.abs(tf.reduce_max([bound_x,bound_y],axis=0))

linear = tf.keras.layers.add((linear,tf.expand_dims(bound,axis=-1)),name='linear')
linear = tf.keras.layers.Lambda(lambda z: -z)(linear)

#sum_quad = tf.keras.layers.add(quad)
negative = tf.keras.layers.add([cte,linear,sum_quad])
negative = tf.cast(tf.less(negative,0),dtype=tf.float32)
negative = tf.keras.layers.multiply([sum_quad,negative])
cte = tf.keras.layers.add([cte,-negative],name='cte')

# %%
cte
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'cte')>

# %% [markdown]
# ## Data augmentation

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=1,var1_u=7,CROP1=CROP,BATCH_SIZE=50)

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs['input']))
        axs[i,2*j].imshow(np.squeeze(xs['input'][_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        axs[i,2*j].set_title(str(np.mean(xs['input_emb'][_])))
        
plt.show()

# %% [markdown]
# # Neural networks

# %%
strategy = tf.distribute.MirroredStrategy()
#strategy = tf.distribute.OneDeviceStrategy('/device:GPU:0')

# %% [markdown]
# ## Training

# %%
def loss(y_true,y_pred):
    return 1/(tf.image.psnr(y_true,y_pred,1)) + 1/(tf.math.tan(np.pi*tf.image.ssim(y_true,y_pred,1)/2))

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=1,var1_u=7,CROP1=CROP,BATCH_SIZE=50)

order = 1
for num_classes in [5,10,15,20,50]:
    print('num_classes: ',num_classes)
    model = get_model("decreasing_taylor",it_lim=1,image_size=image_size,num_classes = num_classes)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
            loss=loss,)
    #model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")
    
    callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath= f"./checkpoints/dectaylor_{typ}_{num_classes}",
    save_weights_only=True,
    verbose = True,
    save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1)
    ]
    
    history = model.fit(
        gen_batch_train,
        epochs=50,
        steps_per_epoch=10,
        validation_data=gen_batch_val,
        validation_steps=5,
        shuffle=False,
        use_multiprocessing=True,
        callbacks=callbacks,
        workers=1
    )
    
    np.save(f'./history/dectaylor_{typ}_{num_classes}.npy',np.array([history.history['loss'],history.history['val_loss']]))
# Out:
# num_classes:  5
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 2.3137
# Epoch 00001: val_loss improved from inf to 2.93927, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 15s 1s/step - loss: 2.3137 - val_loss: 2.9393 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4710
# Epoch 00002: val_loss improved from 2.93927 to 2.91377, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.4710 - val_loss: 2.9138 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2923
# Epoch 00003: val_loss did not improve from 2.91377
# 10/10 [==============================] - 12s 1s/step - loss: 1.2923 - val_loss: 2.9403 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2432
# Epoch 00004: val_loss improved from 2.91377 to 2.80920, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2432 - val_loss: 2.8092 - lr: 0.0010
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2114
# Epoch 00005: val_loss did not improve from 2.80920
# 10/10 [==============================] - 12s 1s/step - loss: 1.2114 - val_loss: 2.9904 - lr: 0.0010
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2869
# Epoch 00006: val_loss improved from 2.80920 to 2.75197, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2869 - val_loss: 2.7520 - lr: 0.0010
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3006
# Epoch 00007: val_loss improved from 2.75197 to 2.60516, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.3006 - val_loss: 2.6052 - lr: 0.0010
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2562
# Epoch 00008: val_loss did not improve from 2.60516
# 10/10 [==============================] - 12s 1s/step - loss: 1.2562 - val_loss: 2.6579 - lr: 0.0010
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2210
# Epoch 00009: val_loss improved from 2.60516 to 2.53755, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2210 - val_loss: 2.5376 - lr: 0.0010
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2229
# Epoch 00010: val_loss did not improve from 2.53755
# 10/10 [==============================] - 12s 1s/step - loss: 1.2229 - val_loss: 2.6848 - lr: 0.0010
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2120
# Epoch 00011: val_loss improved from 2.53755 to 2.51248, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2120 - val_loss: 2.5125 - lr: 0.0010
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3234
# Epoch 00012: val_loss improved from 2.51248 to 2.47282, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.3234 - val_loss: 2.4728 - lr: 0.0010
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2448
# Epoch 00013: val_loss improved from 2.47282 to 2.26922, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2448 - val_loss: 2.2692 - lr: 0.0010
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2109
# Epoch 00014: val_loss improved from 2.26922 to 2.24749, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2109 - val_loss: 2.2475 - lr: 0.0010
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2375
# Epoch 00015: val_loss did not improve from 2.24749
# 10/10 [==============================] - 12s 1s/step - loss: 1.2375 - val_loss: 2.3317 - lr: 0.0010
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2773
# Epoch 00016: val_loss did not improve from 2.24749
# 10/10 [==============================] - 12s 1s/step - loss: 1.2773 - val_loss: 2.3845 - lr: 0.0010
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2983
# Epoch 00017: val_loss did not improve from 2.24749
# 10/10 [==============================] - 12s 1s/step - loss: 1.2983 - val_loss: 2.2756 - lr: 0.0010
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2585
# Epoch 00018: val_loss improved from 2.24749 to 2.02207, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2585 - val_loss: 2.0221 - lr: 0.0010
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2213
# Epoch 00019: val_loss improved from 2.02207 to 2.01149, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2213 - val_loss: 2.0115 - lr: 0.0010
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2285
# Epoch 00020: val_loss improved from 2.01149 to 1.88839, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2285 - val_loss: 1.8884 - lr: 0.0010
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2619
# Epoch 00021: val_loss improved from 1.88839 to 1.82827, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2619 - val_loss: 1.8283 - lr: 0.0010
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2391
# Epoch 00022: val_loss improved from 1.82827 to 1.80027, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2391 - val_loss: 1.8003 - lr: 0.0010
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2594
# Epoch 00023: val_loss improved from 1.80027 to 1.69031, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2594 - val_loss: 1.6903 - lr: 0.0010
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2191
# Epoch 00024: val_loss improved from 1.69031 to 1.59188, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2191 - val_loss: 1.5919 - lr: 0.0010
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2483
# Epoch 00025: val_loss improved from 1.59188 to 1.51595, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2483 - val_loss: 1.5159 - lr: 0.0010
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2616
# Epoch 00026: val_loss improved from 1.51595 to 1.46972, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2616 - val_loss: 1.4697 - lr: 0.0010
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2631
# Epoch 00027: val_loss improved from 1.46972 to 1.30504, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2631 - val_loss: 1.3050 - lr: 0.0010
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2703
# Epoch 00028: val_loss did not improve from 1.30504
# 10/10 [==============================] - 12s 1s/step - loss: 1.2703 - val_loss: 1.3536 - lr: 0.0010
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2542
# Epoch 00029: val_loss improved from 1.30504 to 1.25977, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2542 - val_loss: 1.2598 - lr: 0.0010
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2293
# Epoch 00030: val_loss improved from 1.25977 to 1.19497, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2293 - val_loss: 1.1950 - lr: 0.0010
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2179
# Epoch 00031: val_loss improved from 1.19497 to 1.17689, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2179 - val_loss: 1.1769 - lr: 0.0010
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2803
# Epoch 00032: val_loss did not improve from 1.17689
# 10/10 [==============================] - 12s 1s/step - loss: 1.2803 - val_loss: 1.1819 - lr: 0.0010
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2309
# Epoch 00033: val_loss did not improve from 1.17689
# 10/10 [==============================] - 12s 1s/step - loss: 1.2309 - val_loss: 1.1875 - lr: 0.0010
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2548
# Epoch 00034: val_loss improved from 1.17689 to 1.15513, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2548 - val_loss: 1.1551 - lr: 0.0010
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2423
# Epoch 00035: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2423 - val_loss: 1.1788 - lr: 0.0010
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2239
# Epoch 00036: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2239 - val_loss: 1.1779 - lr: 0.0010
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2357
# Epoch 00037: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2357 - val_loss: 1.2136 - lr: 0.0010
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2677
# Epoch 00038: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2677 - val_loss: 1.1996 - lr: 0.0010
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1900
# Epoch 00039: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.1900 - val_loss: 1.2248 - lr: 0.0010
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3123
# Epoch 00040: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.3123 - val_loss: 1.2056 - lr: 0.0010
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2573
# Epoch 00041: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2573 - val_loss: 1.1930 - lr: 0.0010
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2298
# Epoch 00042: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2298 - val_loss: 1.2403 - lr: 0.0010
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2605
# Epoch 00043: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2605 - val_loss: 1.1839 - lr: 0.0010
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2389
# Epoch 00044: val_loss did not improve from 1.15513
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 10/10 [==============================] - 12s 1s/step - loss: 1.2389 - val_loss: 1.2006 - lr: 0.0010
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2831
# Epoch 00045: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2831 - val_loss: 1.2307 - lr: 2.0000e-04
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2689
# Epoch 00046: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2689 - val_loss: 1.2153 - lr: 2.0000e-04
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2912
# Epoch 00047: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2912 - val_loss: 1.2014 - lr: 2.0000e-04
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2265
# Epoch 00048: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2265 - val_loss: 1.2247 - lr: 2.0000e-04
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2708
# Epoch 00049: val_loss did not improve from 1.15513
# 10/10 [==============================] - 12s 1s/step - loss: 1.2708 - val_loss: 1.2222 - lr: 2.0000e-04
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2374
# Epoch 00050: val_loss improved from 1.15513 to 1.12244, saving model to ./checkpoints/dectaylor_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.2374 - val_loss: 1.1224 - lr: 2.0000e-04
# num_classes:  10
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 2.2209
# Epoch 00001: val_loss improved from inf to 2.27852, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 15s 1s/step - loss: 2.2209 - val_loss: 2.2785 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4874
# Epoch 00002: val_loss did not improve from 2.27852
# 10/10 [==============================] - 12s 1s/step - loss: 1.4874 - val_loss: 2.3511 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3487
# Epoch 00003: val_loss did not improve from 2.27852
# 10/10 [==============================] - 12s 1s/step - loss: 1.3487 - val_loss: 2.4845 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2867
# Epoch 00004: val_loss did not improve from 2.27852
# 10/10 [==============================] - 12s 1s/step - loss: 1.2867 - val_loss: 2.3561 - lr: 0.0010
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2893
# Epoch 00005: val_loss did not improve from 2.27852
# 10/10 [==============================] - 12s 1s/step - loss: 1.2893 - val_loss: 2.3299 - lr: 0.0010
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2392
# Epoch 00006: val_loss did not improve from 2.27852
# 10/10 [==============================] - 12s 1s/step - loss: 1.2392 - val_loss: 2.4535 - lr: 0.0010
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2348
# Epoch 00007: val_loss did not improve from 2.27852
# 10/10 [==============================] - 12s 1s/step - loss: 1.2348 - val_loss: 2.3613 - lr: 0.0010
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2465
# Epoch 00008: val_loss improved from 2.27852 to 2.25638, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2465 - val_loss: 2.2564 - lr: 0.0010
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2644
# Epoch 00009: val_loss did not improve from 2.25638
# 10/10 [==============================] - 12s 1s/step - loss: 1.2644 - val_loss: 2.3851 - lr: 0.0010
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2202
# Epoch 00010: val_loss did not improve from 2.25638
# 10/10 [==============================] - 12s 1s/step - loss: 1.2202 - val_loss: 2.3038 - lr: 0.0010
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2626
# Epoch 00011: val_loss did not improve from 2.25638
# 10/10 [==============================] - 12s 1s/step - loss: 1.2626 - val_loss: 2.2873 - lr: 0.0010
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2843
# Epoch 00012: val_loss improved from 2.25638 to 2.19183, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2843 - val_loss: 2.1918 - lr: 0.0010
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2823
# Epoch 00013: val_loss improved from 2.19183 to 2.09880, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 13s 1s/step - loss: 1.2823 - val_loss: 2.0988 - lr: 0.0010
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2303
# Epoch 00014: val_loss did not improve from 2.09880
# 10/10 [==============================] - 12s 1s/step - loss: 1.2303 - val_loss: 2.2755 - lr: 0.0010
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2603
# Epoch 00015: val_loss improved from 2.09880 to 2.08344, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2603 - val_loss: 2.0834 - lr: 0.0010
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1983
# Epoch 00016: val_loss improved from 2.08344 to 2.00261, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.1983 - val_loss: 2.0026 - lr: 0.0010
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2097
# Epoch 00017: val_loss improved from 2.00261 to 1.98287, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2097 - val_loss: 1.9829 - lr: 0.0010
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2372
# Epoch 00018: val_loss improved from 1.98287 to 1.87557, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2372 - val_loss: 1.8756 - lr: 0.0010
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2768
# Epoch 00019: val_loss improved from 1.87557 to 1.86386, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2768 - val_loss: 1.8639 - lr: 0.0010
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2305
# Epoch 00020: val_loss improved from 1.86386 to 1.81758, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2305 - val_loss: 1.8176 - lr: 0.0010
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2382
# Epoch 00021: val_loss did not improve from 1.81758
# 10/10 [==============================] - 12s 1s/step - loss: 1.2382 - val_loss: 1.8624 - lr: 0.0010
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2472
# Epoch 00022: val_loss improved from 1.81758 to 1.73600, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2472 - val_loss: 1.7360 - lr: 0.0010
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2607
# Epoch 00023: val_loss improved from 1.73600 to 1.64531, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 13s 1s/step - loss: 1.2607 - val_loss: 1.6453 - lr: 0.0010
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2251
# Epoch 00024: val_loss did not improve from 1.64531
# 10/10 [==============================] - 12s 1s/step - loss: 1.2251 - val_loss: 1.6922 - lr: 0.0010
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2298
# Epoch 00025: val_loss improved from 1.64531 to 1.60845, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2298 - val_loss: 1.6084 - lr: 0.0010
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2563
# Epoch 00026: val_loss improved from 1.60845 to 1.60119, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2563 - val_loss: 1.6012 - lr: 0.0010
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1993
# Epoch 00027: val_loss improved from 1.60119 to 1.55160, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.1993 - val_loss: 1.5516 - lr: 0.0010
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1996
# Epoch 00028: val_loss improved from 1.55160 to 1.51275, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.1996 - val_loss: 1.5128 - lr: 0.0010
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2392
# Epoch 00029: val_loss did not improve from 1.51275
# 10/10 [==============================] - 12s 1s/step - loss: 1.2392 - val_loss: 1.5996 - lr: 0.0010
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2028
# Epoch 00030: val_loss did not improve from 1.51275
# 10/10 [==============================] - 12s 1s/step - loss: 1.2028 - val_loss: 1.5495 - lr: 0.0010
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2198
# Epoch 00031: val_loss improved from 1.51275 to 1.50119, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2198 - val_loss: 1.5012 - lr: 0.0010
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2367
# Epoch 00032: val_loss improved from 1.50119 to 1.45103, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2367 - val_loss: 1.4510 - lr: 0.0010
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1985
# Epoch 00033: val_loss did not improve from 1.45103
# 10/10 [==============================] - 12s 1s/step - loss: 1.1985 - val_loss: 1.4668 - lr: 0.0010
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2058
# Epoch 00034: val_loss did not improve from 1.45103
# 10/10 [==============================] - 12s 1s/step - loss: 1.2058 - val_loss: 1.4929 - lr: 0.0010
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2444
# Epoch 00035: val_loss improved from 1.45103 to 1.42725, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2444 - val_loss: 1.4273 - lr: 0.0010
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2205
# Epoch 00036: val_loss did not improve from 1.42725
# 10/10 [==============================] - 12s 1s/step - loss: 1.2205 - val_loss: 1.5461 - lr: 0.0010
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2185
# Epoch 00037: val_loss did not improve from 1.42725
# 10/10 [==============================] - 12s 1s/step - loss: 1.2185 - val_loss: 1.5397 - lr: 0.0010
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2418
# Epoch 00038: val_loss did not improve from 1.42725
# 10/10 [==============================] - 12s 1s/step - loss: 1.2418 - val_loss: 1.4371 - lr: 0.0010
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1938
# Epoch 00039: val_loss did not improve from 1.42725
# 10/10 [==============================] - 12s 1s/step - loss: 1.1938 - val_loss: 1.4439 - lr: 0.0010
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2521
# Epoch 00040: val_loss did not improve from 1.42725
# 10/10 [==============================] - 12s 1s/step - loss: 1.2521 - val_loss: 1.4552 - lr: 0.0010
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2197
# Epoch 00041: val_loss did not improve from 1.42725
# 10/10 [==============================] - 12s 1s/step - loss: 1.2197 - val_loss: 1.4444 - lr: 0.0010
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2128
# Epoch 00042: val_loss improved from 1.42725 to 1.41381, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2128 - val_loss: 1.4138 - lr: 0.0010
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2629
# Epoch 00043: val_loss did not improve from 1.41381
# 10/10 [==============================] - 12s 1s/step - loss: 1.2629 - val_loss: 1.4391 - lr: 0.0010
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2656
# Epoch 00044: val_loss improved from 1.41381 to 1.33609, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 13s 1s/step - loss: 1.2656 - val_loss: 1.3361 - lr: 0.0010
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2516
# Epoch 00045: val_loss did not improve from 1.33609
# 10/10 [==============================] - 12s 1s/step - loss: 1.2516 - val_loss: 1.3565 - lr: 0.0010
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1946
# Epoch 00046: val_loss did not improve from 1.33609
# 10/10 [==============================] - 12s 1s/step - loss: 1.1946 - val_loss: 1.3571 - lr: 0.0010
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2935
# Epoch 00047: val_loss improved from 1.33609 to 1.32592, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2935 - val_loss: 1.3259 - lr: 0.0010
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2462
# Epoch 00048: val_loss improved from 1.32592 to 1.29435, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2462 - val_loss: 1.2944 - lr: 0.0010
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2379
# Epoch 00049: val_loss did not improve from 1.29435
# 10/10 [==============================] - 12s 1s/step - loss: 1.2379 - val_loss: 1.3403 - lr: 0.0010
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2298
# Epoch 00050: val_loss improved from 1.29435 to 1.27071, saving model to ./checkpoints/dectaylor_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.2298 - val_loss: 1.2707 - lr: 0.0010
# num_classes:  15
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4856
# Epoch 00001: val_loss improved from inf to 2.33632, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 16s 1s/step - loss: 1.4856 - val_loss: 2.3363 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2162
# Epoch 00002: val_loss improved from 2.33632 to 2.31820, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2162 - val_loss: 2.3182 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2574
# Epoch 00003: val_loss improved from 2.31820 to 2.14860, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2574 - val_loss: 2.1486 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2015
# Epoch 00004: val_loss did not improve from 2.14860
# 10/10 [==============================] - 12s 1s/step - loss: 1.2015 - val_loss: 2.1821 - lr: 0.0010
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2358
# Epoch 00005: val_loss did not improve from 2.14860
# 10/10 [==============================] - 12s 1s/step - loss: 1.2358 - val_loss: 2.1880 - lr: 0.0010
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2793
# Epoch 00006: val_loss did not improve from 2.14860
# 10/10 [==============================] - 12s 1s/step - loss: 1.2793 - val_loss: 2.1619 - lr: 0.0010
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2328
# Epoch 00007: val_loss improved from 2.14860 to 2.11842, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2328 - val_loss: 2.1184 - lr: 0.0010
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2224
# Epoch 00008: val_loss improved from 2.11842 to 2.09480, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2224 - val_loss: 2.0948 - lr: 0.0010
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2258
# Epoch 00009: val_loss did not improve from 2.09480
# 10/10 [==============================] - 13s 1s/step - loss: 1.2258 - val_loss: 2.1705 - lr: 0.0010
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2863
# Epoch 00010: val_loss improved from 2.09480 to 1.99080, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2863 - val_loss: 1.9908 - lr: 0.0010
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2854
# Epoch 00011: val_loss did not improve from 1.99080
# 10/10 [==============================] - 13s 1s/step - loss: 1.2854 - val_loss: 2.0558 - lr: 0.0010
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2245
# Epoch 00012: val_loss did not improve from 1.99080
# 10/10 [==============================] - 13s 1s/step - loss: 1.2245 - val_loss: 2.0275 - lr: 0.0010
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2096
# Epoch 00013: val_loss did not improve from 1.99080
# 10/10 [==============================] - 13s 1s/step - loss: 1.2096 - val_loss: 1.9920 - lr: 0.0010
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2410
# Epoch 00014: val_loss did not improve from 1.99080
# 10/10 [==============================] - 13s 1s/step - loss: 1.2410 - val_loss: 2.0614 - lr: 0.0010
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2833
# Epoch 00015: val_loss did not improve from 1.99080
# 10/10 [==============================] - 12s 1s/step - loss: 1.2833 - val_loss: 2.0702 - lr: 0.0010
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2528
# Epoch 00016: val_loss did not improve from 1.99080
# 10/10 [==============================] - 13s 1s/step - loss: 1.2528 - val_loss: 2.0474 - lr: 0.0010
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2137
# Epoch 00017: val_loss improved from 1.99080 to 1.93948, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2137 - val_loss: 1.9395 - lr: 0.0010
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2567
# Epoch 00018: val_loss improved from 1.93948 to 1.87668, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2567 - val_loss: 1.8767 - lr: 0.0010
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2218
# Epoch 00019: val_loss did not improve from 1.87668
# 10/10 [==============================] - 13s 1s/step - loss: 1.2218 - val_loss: 1.8846 - lr: 0.0010
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2193
# Epoch 00020: val_loss improved from 1.87668 to 1.85706, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2193 - val_loss: 1.8571 - lr: 0.0010
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2344
# Epoch 00021: val_loss did not improve from 1.85706
# 10/10 [==============================] - 12s 1s/step - loss: 1.2344 - val_loss: 1.9079 - lr: 0.0010
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2075
# Epoch 00022: val_loss improved from 1.85706 to 1.76131, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2075 - val_loss: 1.7613 - lr: 0.0010
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2202
# Epoch 00023: val_loss did not improve from 1.76131
# 10/10 [==============================] - 12s 1s/step - loss: 1.2202 - val_loss: 1.9598 - lr: 0.0010
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2225
# Epoch 00024: val_loss improved from 1.76131 to 1.75841, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2225 - val_loss: 1.7584 - lr: 0.0010
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1915
# Epoch 00025: val_loss did not improve from 1.75841
# 10/10 [==============================] - 13s 1s/step - loss: 1.1915 - val_loss: 1.7663 - lr: 0.0010
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2101
# Epoch 00026: val_loss improved from 1.75841 to 1.68883, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2101 - val_loss: 1.6888 - lr: 0.0010
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2284
# Epoch 00027: val_loss did not improve from 1.68883
# 10/10 [==============================] - 13s 1s/step - loss: 1.2284 - val_loss: 1.6905 - lr: 0.0010
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2605
# Epoch 00028: val_loss improved from 1.68883 to 1.56359, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2605 - val_loss: 1.5636 - lr: 0.0010
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2357
# Epoch 00029: val_loss did not improve from 1.56359
# 10/10 [==============================] - 13s 1s/step - loss: 1.2357 - val_loss: 1.6490 - lr: 0.0010
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1942
# Epoch 00030: val_loss did not improve from 1.56359
# 10/10 [==============================] - 13s 1s/step - loss: 1.1942 - val_loss: 1.5693 - lr: 0.0010
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1912
# Epoch 00031: val_loss improved from 1.56359 to 1.53235, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.1912 - val_loss: 1.5323 - lr: 0.0010
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2413
# Epoch 00032: val_loss did not improve from 1.53235
# 10/10 [==============================] - 12s 1s/step - loss: 1.2413 - val_loss: 1.6338 - lr: 0.0010
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2110
# Epoch 00033: val_loss improved from 1.53235 to 1.52182, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2110 - val_loss: 1.5218 - lr: 0.0010
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2228
# Epoch 00034: val_loss did not improve from 1.52182
# 10/10 [==============================] - 12s 1s/step - loss: 1.2228 - val_loss: 1.5256 - lr: 0.0010
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1959
# Epoch 00035: val_loss improved from 1.52182 to 1.41489, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.1959 - val_loss: 1.4149 - lr: 0.0010
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2541
# Epoch 00036: val_loss did not improve from 1.41489
# 10/10 [==============================] - 12s 1s/step - loss: 1.2541 - val_loss: 1.5287 - lr: 0.0010
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1881
# Epoch 00037: val_loss did not improve from 1.41489
# 10/10 [==============================] - 12s 1s/step - loss: 1.1881 - val_loss: 1.4545 - lr: 0.0010
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2739
# Epoch 00038: val_loss did not improve from 1.41489
# 10/10 [==============================] - 12s 1s/step - loss: 1.2739 - val_loss: 1.4779 - lr: 0.0010
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2036
# Epoch 00039: val_loss did not improve from 1.41489
# 10/10 [==============================] - 13s 1s/step - loss: 1.2036 - val_loss: 1.4703 - lr: 0.0010
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2120
# Epoch 00040: val_loss did not improve from 1.41489
# 10/10 [==============================] - 12s 1s/step - loss: 1.2120 - val_loss: 1.4533 - lr: 0.0010
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2017
# Epoch 00041: val_loss improved from 1.41489 to 1.39633, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2017 - val_loss: 1.3963 - lr: 0.0010
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2690
# Epoch 00042: val_loss improved from 1.39633 to 1.35693, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2690 - val_loss: 1.3569 - lr: 0.0010
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2522
# Epoch 00043: val_loss did not improve from 1.35693
# 10/10 [==============================] - 12s 1s/step - loss: 1.2522 - val_loss: 1.3862 - lr: 0.0010
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2561
# Epoch 00044: val_loss did not improve from 1.35693
# 10/10 [==============================] - 12s 1s/step - loss: 1.2561 - val_loss: 1.4104 - lr: 0.0010
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2232
# Epoch 00045: val_loss did not improve from 1.35693
# 10/10 [==============================] - 12s 1s/step - loss: 1.2232 - val_loss: 1.4682 - lr: 0.0010
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1782
# Epoch 00046: val_loss did not improve from 1.35693
# 10/10 [==============================] - 12s 1s/step - loss: 1.1782 - val_loss: 1.3757 - lr: 0.0010
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2002
# Epoch 00047: val_loss improved from 1.35693 to 1.34825, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2002 - val_loss: 1.3482 - lr: 0.0010
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2618
# Epoch 00048: val_loss improved from 1.34825 to 1.28215, saving model to ./checkpoints/dectaylor_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.2618 - val_loss: 1.2821 - lr: 0.0010
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2550
# Epoch 00049: val_loss did not improve from 1.28215
# 10/10 [==============================] - 12s 1s/step - loss: 1.2550 - val_loss: 1.4487 - lr: 0.0010
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2090
# Epoch 00050: val_loss did not improve from 1.28215
# 10/10 [==============================] - 12s 1s/step - loss: 1.2090 - val_loss: 1.2911 - lr: 0.0010
# num_classes:  20
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6282
# Epoch 00001: val_loss improved from inf to 2.09078, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 16s 1s/step - loss: 1.6282 - val_loss: 2.0908 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2474
# Epoch 00002: val_loss did not improve from 2.09078
# 10/10 [==============================] - 13s 1s/step - loss: 1.2474 - val_loss: 2.1877 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2419
# Epoch 00003: val_loss did not improve from 2.09078
# 10/10 [==============================] - 13s 1s/step - loss: 1.2419 - val_loss: 2.1231 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2698
# Epoch 00004: val_loss improved from 2.09078 to 2.05398, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2698 - val_loss: 2.0540 - lr: 0.0010
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2021
# Epoch 00005: val_loss did not improve from 2.05398
# 10/10 [==============================] - 12s 1s/step - loss: 1.2021 - val_loss: 2.0776 - lr: 0.0010
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1977
# Epoch 00006: val_loss did not improve from 2.05398
# 10/10 [==============================] - 12s 1s/step - loss: 1.1977 - val_loss: 2.0843 - lr: 0.0010
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2530
# Epoch 00007: val_loss improved from 2.05398 to 1.94325, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2530 - val_loss: 1.9433 - lr: 0.0010
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2251
# Epoch 00008: val_loss did not improve from 1.94325
# 10/10 [==============================] - 13s 1s/step - loss: 1.2251 - val_loss: 2.0500 - lr: 0.0010
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2464
# Epoch 00009: val_loss did not improve from 1.94325
# 10/10 [==============================] - 13s 1s/step - loss: 1.2464 - val_loss: 2.0335 - lr: 0.0010
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1777
# Epoch 00010: val_loss improved from 1.94325 to 1.89844, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.1777 - val_loss: 1.8984 - lr: 0.0010
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2101
# Epoch 00011: val_loss did not improve from 1.89844
# 10/10 [==============================] - 12s 1s/step - loss: 1.2101 - val_loss: 1.9592 - lr: 0.0010
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2820
# Epoch 00012: val_loss did not improve from 1.89844
# 10/10 [==============================] - 13s 1s/step - loss: 1.2820 - val_loss: 1.9357 - lr: 0.0010
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2893
# Epoch 00013: val_loss did not improve from 1.89844
# 10/10 [==============================] - 12s 1s/step - loss: 1.2893 - val_loss: 1.9149 - lr: 0.0010
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1721
# Epoch 00014: val_loss improved from 1.89844 to 1.84879, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.1721 - val_loss: 1.8488 - lr: 0.0010
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1482
# Epoch 00015: val_loss did not improve from 1.84879
# 10/10 [==============================] - 13s 1s/step - loss: 1.1482 - val_loss: 1.9446 - lr: 0.0010
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2033
# Epoch 00016: val_loss improved from 1.84879 to 1.77807, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2033 - val_loss: 1.7781 - lr: 0.0010
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2759
# Epoch 00017: val_loss did not improve from 1.77807
# 10/10 [==============================] - 13s 1s/step - loss: 1.2759 - val_loss: 1.8834 - lr: 0.0010
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2102
# Epoch 00018: val_loss did not improve from 1.77807
# 10/10 [==============================] - 13s 1s/step - loss: 1.2102 - val_loss: 1.8781 - lr: 0.0010
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1880
# Epoch 00019: val_loss did not improve from 1.77807
# 10/10 [==============================] - 12s 1s/step - loss: 1.1880 - val_loss: 1.9029 - lr: 0.0010
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2257
# Epoch 00020: val_loss improved from 1.77807 to 1.68666, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2257 - val_loss: 1.6867 - lr: 0.0010
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2418
# Epoch 00021: val_loss did not improve from 1.68666
# 10/10 [==============================] - 12s 1s/step - loss: 1.2418 - val_loss: 1.7081 - lr: 0.0010
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2360
# Epoch 00022: val_loss did not improve from 1.68666
# 10/10 [==============================] - 13s 1s/step - loss: 1.2360 - val_loss: 1.8056 - lr: 0.0010
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2380
# Epoch 00023: val_loss did not improve from 1.68666
# 10/10 [==============================] - 13s 1s/step - loss: 1.2380 - val_loss: 1.7378 - lr: 0.0010
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2655
# Epoch 00024: val_loss did not improve from 1.68666
# 10/10 [==============================] - 12s 1s/step - loss: 1.2655 - val_loss: 1.6876 - lr: 0.0010
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2487
# Epoch 00025: val_loss did not improve from 1.68666
# 10/10 [==============================] - 13s 1s/step - loss: 1.2487 - val_loss: 1.7232 - lr: 0.0010
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1867
# Epoch 00026: val_loss improved from 1.68666 to 1.68223, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.1867 - val_loss: 1.6822 - lr: 0.0010
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1825
# Epoch 00027: val_loss did not improve from 1.68223
# 10/10 [==============================] - 13s 1s/step - loss: 1.1825 - val_loss: 1.7710 - lr: 0.0010
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2939
# Epoch 00028: val_loss improved from 1.68223 to 1.64263, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2939 - val_loss: 1.6426 - lr: 0.0010
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1756
# Epoch 00029: val_loss did not improve from 1.64263
# 10/10 [==============================] - 13s 1s/step - loss: 1.1756 - val_loss: 1.6923 - lr: 0.0010
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2437
# Epoch 00030: val_loss improved from 1.64263 to 1.61300, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2437 - val_loss: 1.6130 - lr: 0.0010
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2128
# Epoch 00031: val_loss improved from 1.61300 to 1.61064, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2128 - val_loss: 1.6106 - lr: 0.0010
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1913
# Epoch 00032: val_loss did not improve from 1.61064
# 10/10 [==============================] - 12s 1s/step - loss: 1.1913 - val_loss: 1.6310 - lr: 0.0010
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2422
# Epoch 00033: val_loss improved from 1.61064 to 1.49382, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2422 - val_loss: 1.4938 - lr: 0.0010
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2257
# Epoch 00034: val_loss did not improve from 1.49382
# 10/10 [==============================] - 13s 1s/step - loss: 1.2257 - val_loss: 1.5814 - lr: 0.0010
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2032
# Epoch 00035: val_loss did not improve from 1.49382
# 10/10 [==============================] - 13s 1s/step - loss: 1.2032 - val_loss: 1.4955 - lr: 0.0010
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2316
# Epoch 00036: val_loss did not improve from 1.49382
# 10/10 [==============================] - 13s 1s/step - loss: 1.2316 - val_loss: 1.5057 - lr: 0.0010
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2310
# Epoch 00037: val_loss did not improve from 1.49382
# 10/10 [==============================] - 13s 1s/step - loss: 1.2310 - val_loss: 1.4954 - lr: 0.0010
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2309
# Epoch 00038: val_loss improved from 1.49382 to 1.48408, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2309 - val_loss: 1.4841 - lr: 0.0010
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2167
# Epoch 00039: val_loss improved from 1.48408 to 1.47349, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2167 - val_loss: 1.4735 - lr: 0.0010
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2154
# Epoch 00040: val_loss did not improve from 1.47349
# 10/10 [==============================] - 12s 1s/step - loss: 1.2154 - val_loss: 1.4788 - lr: 0.0010
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2126
# Epoch 00041: val_loss improved from 1.47349 to 1.45638, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2126 - val_loss: 1.4564 - lr: 0.0010
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2005
# Epoch 00042: val_loss improved from 1.45638 to 1.44016, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2005 - val_loss: 1.4402 - lr: 0.0010
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1982
# Epoch 00043: val_loss did not improve from 1.44016
# 10/10 [==============================] - 13s 1s/step - loss: 1.1982 - val_loss: 1.4758 - lr: 0.0010
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2309
# Epoch 00044: val_loss improved from 1.44016 to 1.42337, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2309 - val_loss: 1.4234 - lr: 0.0010
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2304
# Epoch 00045: val_loss improved from 1.42337 to 1.40737, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2304 - val_loss: 1.4074 - lr: 0.0010
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2579
# Epoch 00046: val_loss improved from 1.40737 to 1.35120, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2579 - val_loss: 1.3512 - lr: 0.0010
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2226
# Epoch 00047: val_loss improved from 1.35120 to 1.30905, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.2226 - val_loss: 1.3090 - lr: 0.0010
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2280
# Epoch 00048: val_loss did not improve from 1.30905
# 10/10 [==============================] - 13s 1s/step - loss: 1.2280 - val_loss: 1.4389 - lr: 0.0010
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1906
# Epoch 00049: val_loss improved from 1.30905 to 1.25017, saving model to ./checkpoints/dectaylor_gaussian_20
# 10/10 [==============================] - 13s 1s/step - loss: 1.1906 - val_loss: 1.2502 - lr: 0.0010
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2355
# Epoch 00050: val_loss did not improve from 1.25017
# 10/10 [==============================] - 13s 1s/step - loss: 1.2355 - val_loss: 1.2953 - lr: 0.0010
# num_classes:  50
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4510
# Epoch 00001: val_loss improved from inf to 2.25789, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 19s 2s/step - loss: 1.4510 - val_loss: 2.2579 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2825
# Epoch 00002: val_loss did not improve from 2.25789
# 10/10 [==============================] - 14s 1s/step - loss: 1.2825 - val_loss: 2.2825 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2196
# Epoch 00003: val_loss improved from 2.25789 to 2.03654, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2196 - val_loss: 2.0365 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2423
# Epoch 00004: val_loss did not improve from 2.03654
# 10/10 [==============================] - 14s 1s/step - loss: 1.2423 - val_loss: 2.1963 - lr: 0.0010
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3090
# Epoch 00005: val_loss did not improve from 2.03654
# 10/10 [==============================] - 14s 1s/step - loss: 1.3090 - val_loss: 2.1362 - lr: 0.0010
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2138
# Epoch 00006: val_loss did not improve from 2.03654
# 10/10 [==============================] - 14s 1s/step - loss: 1.2138 - val_loss: 2.0774 - lr: 0.0010
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2367
# Epoch 00007: val_loss did not improve from 2.03654
# 10/10 [==============================] - 14s 1s/step - loss: 1.2367 - val_loss: 2.0660 - lr: 0.0010
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2389
# Epoch 00008: val_loss improved from 2.03654 to 2.00585, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2389 - val_loss: 2.0059 - lr: 0.0010
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2340
# Epoch 00009: val_loss did not improve from 2.00585
# 10/10 [==============================] - 14s 1s/step - loss: 1.2340 - val_loss: 2.1209 - lr: 0.0010
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2347
# Epoch 00010: val_loss did not improve from 2.00585
# 10/10 [==============================] - 14s 1s/step - loss: 1.2347 - val_loss: 2.0236 - lr: 0.0010
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2533
# Epoch 00011: val_loss improved from 2.00585 to 1.91608, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2533 - val_loss: 1.9161 - lr: 0.0010
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1869
# Epoch 00012: val_loss did not improve from 1.91608
# 10/10 [==============================] - 14s 1s/step - loss: 1.1869 - val_loss: 1.9720 - lr: 0.0010
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2288
# Epoch 00013: val_loss improved from 1.91608 to 1.75152, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2288 - val_loss: 1.7515 - lr: 0.0010
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2639
# Epoch 00014: val_loss did not improve from 1.75152
# 10/10 [==============================] - 14s 1s/step - loss: 1.2639 - val_loss: 1.8870 - lr: 0.0010
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2148
# Epoch 00015: val_loss did not improve from 1.75152
# 10/10 [==============================] - 13s 1s/step - loss: 1.2148 - val_loss: 1.8128 - lr: 0.0010
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1946
# Epoch 00016: val_loss improved from 1.75152 to 1.73023, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.1946 - val_loss: 1.7302 - lr: 0.0010
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2598
# Epoch 00017: val_loss did not improve from 1.73023
# 10/10 [==============================] - 14s 1s/step - loss: 1.2598 - val_loss: 1.7464 - lr: 0.0010
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2237
# Epoch 00018: val_loss did not improve from 1.73023
# 10/10 [==============================] - 14s 1s/step - loss: 1.2237 - val_loss: 1.7453 - lr: 0.0010
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1989
# Epoch 00019: val_loss improved from 1.73023 to 1.65718, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.1989 - val_loss: 1.6572 - lr: 0.0010
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2312
# Epoch 00020: val_loss did not improve from 1.65718
# 10/10 [==============================] - 14s 1s/step - loss: 1.2312 - val_loss: 1.7785 - lr: 0.0010
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2434
# Epoch 00021: val_loss did not improve from 1.65718
# 10/10 [==============================] - 14s 1s/step - loss: 1.2434 - val_loss: 1.6607 - lr: 0.0010
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2607
# Epoch 00022: val_loss improved from 1.65718 to 1.59331, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2607 - val_loss: 1.5933 - lr: 0.0010
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2438
# Epoch 00023: val_loss did not improve from 1.59331
# 10/10 [==============================] - 14s 1s/step - loss: 1.2438 - val_loss: 1.6501 - lr: 0.0010
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2166
# Epoch 00024: val_loss improved from 1.59331 to 1.56684, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2166 - val_loss: 1.5668 - lr: 0.0010
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2418
# Epoch 00025: val_loss improved from 1.56684 to 1.52450, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2418 - val_loss: 1.5245 - lr: 0.0010
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2468
# Epoch 00026: val_loss improved from 1.52450 to 1.49521, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2468 - val_loss: 1.4952 - lr: 0.0010
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2379
# Epoch 00027: val_loss did not improve from 1.49521
# 10/10 [==============================] - 14s 1s/step - loss: 1.2379 - val_loss: 1.5015 - lr: 0.0010
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2517
# Epoch 00028: val_loss did not improve from 1.49521
# 10/10 [==============================] - 14s 1s/step - loss: 1.2517 - val_loss: 1.5623 - lr: 0.0010
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1976
# Epoch 00029: val_loss improved from 1.49521 to 1.45917, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.1976 - val_loss: 1.4592 - lr: 0.0010
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2305
# Epoch 00030: val_loss improved from 1.45917 to 1.40172, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2305 - val_loss: 1.4017 - lr: 0.0010
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2307
# Epoch 00031: val_loss did not improve from 1.40172
# 10/10 [==============================] - 14s 1s/step - loss: 1.2307 - val_loss: 1.4578 - lr: 0.0010
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2077
# Epoch 00032: val_loss improved from 1.40172 to 1.37186, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2077 - val_loss: 1.3719 - lr: 0.0010
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2205
# Epoch 00033: val_loss improved from 1.37186 to 1.36075, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2205 - val_loss: 1.3607 - lr: 0.0010
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2243
# Epoch 00034: val_loss did not improve from 1.36075
# 10/10 [==============================] - 14s 1s/step - loss: 1.2243 - val_loss: 1.3841 - lr: 0.0010
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2138
# Epoch 00035: val_loss improved from 1.36075 to 1.34501, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2138 - val_loss: 1.3450 - lr: 0.0010
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2334
# Epoch 00036: val_loss improved from 1.34501 to 1.31833, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2334 - val_loss: 1.3183 - lr: 0.0010
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2327
# Epoch 00037: val_loss did not improve from 1.31833
# 10/10 [==============================] - 14s 1s/step - loss: 1.2327 - val_loss: 1.3380 - lr: 0.0010
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2150
# Epoch 00038: val_loss improved from 1.31833 to 1.30184, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2150 - val_loss: 1.3018 - lr: 0.0010
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1710
# Epoch 00039: val_loss did not improve from 1.30184
# 10/10 [==============================] - 14s 1s/step - loss: 1.1710 - val_loss: 1.3044 - lr: 0.0010
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2535
# Epoch 00040: val_loss improved from 1.30184 to 1.28275, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2535 - val_loss: 1.2827 - lr: 0.0010
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2477
# Epoch 00041: val_loss improved from 1.28275 to 1.22976, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2477 - val_loss: 1.2298 - lr: 0.0010
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1719
# Epoch 00042: val_loss improved from 1.22976 to 1.20369, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.1719 - val_loss: 1.2037 - lr: 0.0010
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2643
# Epoch 00043: val_loss did not improve from 1.20369
# 10/10 [==============================] - 14s 1s/step - loss: 1.2643 - val_loss: 1.2719 - lr: 0.0010
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2462
# Epoch 00044: val_loss did not improve from 1.20369
# 10/10 [==============================] - 14s 1s/step - loss: 1.2462 - val_loss: 1.2783 - lr: 0.0010
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2293
# Epoch 00045: val_loss did not improve from 1.20369
# 10/10 [==============================] - 13s 1s/step - loss: 1.2293 - val_loss: 1.2547 - lr: 0.0010
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2133
# Epoch 00046: val_loss improved from 1.20369 to 1.20330, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2133 - val_loss: 1.2033 - lr: 0.0010
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1879
# Epoch 00047: val_loss improved from 1.20330 to 1.19902, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.1879 - val_loss: 1.1990 - lr: 0.0010
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2089
# Epoch 00048: val_loss improved from 1.19902 to 1.17555, saving model to ./checkpoints/dectaylor_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2089 - val_loss: 1.1755 - lr: 0.0010
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2457
# Epoch 00049: val_loss did not improve from 1.17555
# 10/10 [==============================] - 14s 1s/step - loss: 1.2457 - val_loss: 1.1860 - lr: 0.0010
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2107
# Epoch 00050: val_loss did not improve from 1.17555
# 10/10 [==============================] - 13s 1s/step - loss: 1.2107 - val_loss: 1.2705 - lr: 0.0010

# %%
trained = glob(f'./history/dectaylor_*')
w = [int(i.split('_')[-1].split('.')[0]) for i in trained]
n = len(trained)+1
viridis = cm.get_cmap('viridis', 256)
colors = viridis(np.linspace(0, 1, np.amax(w)-np.amin(w)+1))
newcmp = ListedColormap(colors)
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols=2,figsize=(20,5))

for j,i in enumerate(trained):
    
    v = np.load(i)
    axs[0].plot(v[0],alpha=0.75,color = colors[w[j]-np.amin(w)])
    axs[1].plot(v[1],alpha=0.75,color = colors[w[j]-np.amin(w)])
    
axs[0].set_title("training loss with classifier")
axs[1].set_title("validation loss with classifier")
    
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[0],label='partition cardinality')
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[1],label='partition cardinality')
    
plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# # Results with first function

# %%
order = 1
num_classes = 50
model = get_model("decreasing",it_lim=10,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")

w = np.linspace(5,10,4)
fig,axs = plt.subplots(ncols = 5,nrows = int(np.ceil(len(w))),figsize=(15,4*len(w)))
for i,m in enumerate(w):

    
    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=5)
    ims = next(gen_batch_val.as_numpy_iterator())
    p = model(ims[0])
    _ = np.random.choice(len(p))


    psnr_0 = tf.image.psnr(ims[0]['input'][_],ims[1][_],1).numpy()
    ssim_0 = tf.image.ssim(ims[0]['input'][_],ims[1][_],1).numpy()
    clean = p[_]
    psnr = tf.image.psnr(ims[1][_],clean,1).numpy()
    ssim = tf.image.ssim(ims[1][_],clean,1).numpy()
    clean = np.squeeze(clean)
    inputs = tf.keras.Input(shape=image_size + (1,))
    get_lambdas = tf.keras.models.Model(model.input,model.get_layer('simple_extract').output)
    spline = np.squeeze(get_lambdas(ims[0])[_])
    visualization = tf.keras.models.Model(model.input,model.get_layer('coeff_x_0').output)
    vis = np.squeeze(visualization(ims[0])[_])


    psnr_0,ssim_0 = int(100*psnr_0)/100,int(100*ssim_0)/100
    psnr,ssim = int(100*psnr)/100,int(100*ssim)/100
    
    
    axs[i,0].imshow(ims[0]['input'][_],cmap='gray')
    axs[i,0].set_title(f'input\nvariance {int(100*m)/100}\nPSNR: {psnr_0}\nSSIM: {ssim_0}')
    axs[i,0].set_xticks([])
    axs[i,0].set_xticklabels([])
    axs[i,0].set_yticks([])
    axs[i,0].set_yticklabels([])
    axs[i,1].imshow(ims[1][_],cmap='gray')
    axs[i,1].set_title('target')
    axs[i,1].set_xticks([])
    axs[i,1].set_xticklabels([])
    axs[i,1].set_yticks([])
    axs[i,1].set_yticklabels([])
    axs[i,2].imshow(clean,cmap='gray')
    axs[i,2].set_title(f'result\nPSNR: {psnr}\nSSIM: {ssim}')
    axs[i,2].set_xticks([])
    axs[i,2].set_xticklabels([])
    axs[i,2].set_yticks([])
    axs[i,2].set_yticklabels([])
    im = axs[i,3].imshow(vis,cmap='gray')
    axs[i,3].set_title('coefficient function')
    plt.colorbar(im,ax=axs[i,3])
    axs[i,3].set_xticks([])
    axs[i,3].set_xticklabels([])
    axs[i,3].set_yticks([])
    axs[i,3].set_yticklabels([])
    
    partition = np.linspace(0,1,num_classes+1)
    x,s = [],[]

    for p in range(1,len(partition)):
        xp = np.linspace(partition[p-1],partition[p],100)
        linear = spline[p-1]*np.ones(len(xp))
        s.append(np.copy(linear))
        x.append(np.copy(xp))

    s = np.concatenate(s)
    x = np.concatenate(x)
    
    
    axs[i,4].scatter(x,s)
    axs[i,4].set_xlabel("argument")
    axs[i,4].set_ylabel("coefficient value")
    axs[i,4].set_title(f"spline\npartition of {num_classes}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing against Perona Malik

# %%
num_classes = 50
model = get_model("decreasing",it_lim=1,image_size=image_size,num_classes = num_classes)
model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")

w = np.linspace(2,7,10)
psnr_nn_1,psnr_nn_s_1 = [],[]
ssim_nn_1,ssim_nn_s_1 = [],[]

psnr_pm_1,psnr_pm_s_1 = [],[]
ssim_pm_1,ssim_pm_s_1 = [],[]

psnr_or_1,psnr_or_s_1 = [],[]
ssim_or_1,ssim_or_s_1 = [],[]


for i,m in enumerate(w):
    gen_batch_train,gen_batch_val = get_generators(typ,0,w[i],CROP1=CROP,BATCH_SIZE=10)
    
    psnr_nn_1.append([])
    psnr_nn_s_1.append([])
    ssim_nn_1.append([])
    ssim_nn_s_1.append([])
    psnr_pm_1.append([])
    psnr_pm_s_1.append([])
    ssim_pm_1.append([])
    ssim_pm_s_1.append([])
    psnr_or_1.append([])
    psnr_or_s_1.append([])
    ssim_or_1.append([])
    ssim_or_s_1.append([])
    
    for it in range(10):
        ims = next(gen_batch_val.as_numpy_iterator())

        res = model(ims[0])
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_nn_1[-1].append(np.copy(psnr))
        psnr_nn_s_1[-1].append(np.copy(psnr))
        ssim_nn_1[-1].append(np.copy(ssim))
        ssim_nn_s_1[-1].append(np.copy(ssim))

        pm = np.array([anisodiff(im,niter = 1) for im in ims[0]['input']])
        pm = np.asarray(pm,dtype='float32')
        psnr = [tf.image.psnr(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        ssim = [tf.image.ssim(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        psnr_pm_1[-1].append(np.copy(psnr))
        psnr_pm_s_1[-1].append(np.copy(psnr))
        ssim_pm_1[-1].append(np.copy(ssim))
        ssim_pm_s_1[-1].append(np.copy(ssim))

        psnr = tf.image.psnr(ims[0]['input'],ims[1],1).numpy()
        ssim = tf.image.ssim(ims[0]['input'],ims[1],1).numpy()
        psnr_or_1[-1].append(np.copy(psnr))
        psnr_or_s_1[-1].append(np.copy(psnr))
        ssim_or_1[-1].append(np.copy(ssim))
        ssim_or_s_1[-1].append(np.copy(ssim))
        
    psnr_nn_1[-1] = np.concatenate(psnr_nn_1[-1])
    psnr_nn_s_1[-1] = np.concatenate(psnr_nn_s_1[-1])
    ssim_nn_1[-1] = np.concatenate(ssim_nn_1[-1])
    ssim_nn_s_1[-1] = np.concatenate(ssim_nn_s_1[-1])
    
    psnr_pm_1[-1] = np.concatenate(psnr_pm_1[-1])
    psnr_pm_s_1[-1] = np.concatenate(psnr_pm_s_1[-1])
    ssim_pm_1[-1] = np.concatenate(ssim_pm_1[-1])
    ssim_pm_s_1[-1] = np.concatenate(ssim_pm_s_1[-1])
    
    psnr_or_1[-1] = np.concatenate(psnr_or_1[-1])
    psnr_or_s_1[-1] = np.concatenate(psnr_or_s_1[-1])
    ssim_or_1[-1] = np.concatenate(ssim_or_1[-1])
    ssim_or_s_1[-1] = np.concatenate(ssim_or_s_1[-1])
    
    


psnr_nn_1 = np.mean(psnr_nn_1,axis=-1)
psnr_nn_s_1 = np.std(psnr_nn_s_1,axis=-1)
ssim_nn_1 = np.mean(ssim_nn_1,axis=-1)
ssim_nn_s_1 = np.std(ssim_nn_s_1,axis=-1)
psnr_pm_1 = np.mean(psnr_pm_1,axis=-1)
psnr_pm_s_1 = np.std(psnr_pm_s_1,axis=-1)
ssim_pm_1 = np.mean(ssim_pm_1,axis=-1)
ssim_pm_s_1 = np.std(ssim_pm_s_1,axis=-1)
psnr_or_1 = np.mean(psnr_or_1,axis=-1)
psnr_or_s_1 = np.std(psnr_or_s_1,axis=-1)
ssim_or_1 = np.mean(ssim_or_1,axis=-1)
ssim_or_s_1 = np.std(ssim_or_s_1,axis=-1)

plt.figure(figsize=(15,7))
plt.subplot(121)
plt.errorbar(w,psnr_nn_1,psnr_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,psnr_pm_1,psnr_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,psnr_or_1,psnr_or_s_1,label='noisy',alpha=0.5)


plt.xlabel('variance of noise')
plt.ylabel('psnr')
plt.title('PSNR as function of variance in noise')
plt.legend()

plt.subplot(122)
plt.errorbar(w,ssim_nn_1,ssim_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,ssim_pm_1,ssim_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,ssim_or_1,ssim_or_s_1,label='noisy',alpha=0.5)


plt.xlabel('variance of noise')
plt.ylabel('ssim')
plt.title('SSIM as function of variance in noise')
plt.legend()
plt.show()

# %%
order = 1
w = np.linspace(2,7,10)
w = np.asarray(100*w,dtype='int')/100
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/dec_{typ}_*.index")])


hist_psnr,hist_ssim = [],[]

for num_classes in ncl:

    psnr_nn_1,ssim_nn_1 = [],[]
    model = get_model("decreasing",it_lim=1,image_size=image_size,num_classes = num_classes,order=order)
    for i,m in enumerate(w):
        
        model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")
        gen_batch_train,gen_batch_val = get_generators(typ,0,w[i],CROP1=CROP,BATCH_SIZE=10)
        
        psnr_nn_1.append([])
        ssim_nn_1.append([])
        for it in range(10):
            ims = np.array(next(gen_batch_val.as_numpy_iterator()))

            res = model(ims[0])
            res = res/np.expand_dims(np.expand_dims(np.amax(res,axis=(1,2)),axis=-2),axis=-2)
            psnr = [tf.image.psnr(res[j],ims[1][j],1).numpy() for j in range(len(res))]
            ssim = [tf.image.ssim(res[j],ims[1][j],1).numpy() for j in range(len(res))]
            psnr_nn_1[-1].append(psnr)
            ssim_nn_1[-1].append(ssim)
            
        psnr_nn_1[-1] = np.mean(psnr_nn_1[-1])
        ssim_nn_1[-1] = np.mean(ssim_nn_1[-1])


    hist_psnr.append(np.copy(psnr_nn_1))
    hist_ssim.append(np.copy(ssim_nn_1))
    

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(hist_psnr)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('PSNR')
plt.colorbar(label='PSNR')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.subplot(122)
plt.imshow(hist_ssim)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('SSIM')
plt.colorbar(label='SSIM')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.show()
# Out:
# /tmp/ipykernel_7865/1301504080.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ims = np.array(next(gen_batch_val.as_numpy_iterator()))

# %% [markdown]
# # Analizing functions for coefficients

# %%
order = 1
w = np.linspace(2,10,20)
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/dec_{typ}_*.index")])
xR,R = [],[]

for num_classes in ncl:
    model = get_model("decreasing",it_lim=10,image_size=image_size,num_classes = num_classes)
    model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")
    get_lambdas = tf.keras.models.Model(model.input,model.get_layer('simple_extract').output)
    
    R.append([])
    xR.append([])
    for i,m in enumerate(w):


        gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=10)
        
        spline = []
        for it in range(10):
        
            ims = next(gen_batch_val.as_numpy_iterator())
            spline.append(np.squeeze(get_lambdas(ims[0])))
        
        spline = np.concatenate(spline,axis=0)
        spline = np.mean(spline,axis=0)

        partition = np.linspace(0,1,num_classes+1)
        x,s = [],[]


        for p in range(1,len(partition)):
            xp = np.linspace(partition[p-1],partition[p],100)
            linear = spline[p-1]*np.ones(len(xp))
            s.append(np.copy(linear))
            x.append(np.copy(xp))

        s = np.concatenate(s)
        x = np.concatenate(x)
    
    
        R[-1].append(np.copy(s))
        xR[-1].append(np.copy(x))

# %%
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols = 2,nrows = 3,figsize=(15,10))

for col in range(len(R)):
        
    if len(R[col]) == 0:
        continue

    viridis = cm.get_cmap('viridis', 256)
    colors = viridis(np.linspace(0, 1, len(R[col])))
    newcmp = ListedColormap(colors)

    for i in range(len(R[col])):

        #m,s = R[col][i].T

        #axs[col].errorbar(np.arange(len(m))/ncl[col],m,s,color=colors[i])
        axs[col//2,col%2].plot(xR[col][i],R[col][i],color=colors[i])

    axs[col//2,col%2].set_title(f"Mean function\nNum of intervals: {ncl[col]}")
    axs[col//2,col%2].set_xlabel("fraction of maximum gradient norm")
    axs[col//2,col%2].set_ylabel("function value")
    plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[col//2,col%2],label='noise variance')

plt.tight_layout()        
plt.show()
