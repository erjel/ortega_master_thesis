# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)


import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2023-04-03 20:30:36.671034: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 20:30:37.218227: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# 2023-04-03 20:30:37.218793: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/joel/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.2/lib64::/home/joel/anaconda3/lib/
# 2023-04-03 20:30:37.218800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Data augmentation

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=30,var1_u=60,CROP1=CROP,BATCH_SIZE=10)
# Out:
# 2023-04-03 20:30:43.486995: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.487211: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.492246: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.492462: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.492638: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.492806: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.493284: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 20:30:43.632734: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.632916: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.633069: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.633213: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.633354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:43.633495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.178691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.178911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.179100: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.179279: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.179448: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.179594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22237 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-04-03 20:30:44.179906: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:30:44.180046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22328 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:43:00.0, compute capability: 8.6

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs))
        axs[i,2*j].imshow(np.squeeze(xs[_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        #axs[i,2*j].set_title(str(np.mean(xs[_])))
        
plt.show()

# %% [markdown]
# # Neural networks

# %%
strategy = tf.distribute.MirroredStrategy()
#strategy = tf.distribute.OneDeviceStrategy('/device:GPU:0')

# %% [markdown]
# ## Training

# %%
class losses:
    def Linfty(y_true,y_pred):
        error = tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(y_true-y_pred))))
        return error

    def W1infty(y_true,y_pred):
        error = tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(y_true-y_pred))))

        dx_true,dy_true = tf.image.image_gradients(y_true)
        dx_pred,dy_pred = tf.image.image_gradients(y_pred)

        error += tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(dx_true-dx_pred))))
        error += tf.math.log(tf.math.reduce_mean(tf.exp(tf.abs(dy_true-dy_pred))))


        return error

    def H1(y_true,y_pred):
        error = tf.math.reduce_mean(tf.pow(y_true-y_pred,2))

        dx_true,dy_true = tf.image.image_gradients(y_true)
        dx_pred,dy_pred = tf.image.image_gradients(y_pred)

        error += tf.math.reduce_mean(tf.pow(dx_true-dx_pred,2))
        error += tf.math.reduce_mean(tf.pow(dy_true-dy_pred,2))
        error = tf.sqrt(error)

        return error

    def L2(y_true,y_pred):
        error = tf.math.reduce_mean(tf.pow(y_true-y_pred,2))  

        return error
    
    def probability(y_true,y_pred):
        error = -tf.image.ssim(y_true,y_pred,1)

        return error


losses_names = ['Linfty','W1infty','H1','L2','probability']

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=5,var1_u=55,CROP1=CROP,BATCH_SIZE=10)

for loss in losses_names:
    print(loss)
    order = 1
    for num_classes in [5,10,15,20,50]:
        print('num_classes: ',num_classes)

        model = get_model("decreasing",it_lim=3,image_size=image_size,num_classes = num_classes,
                            with_embedding = True, boundary_detector=True)
        model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                loss=getattr(losses,loss))

        callbacks = [tf.keras.callbacks.ModelCheckpoint(
        filepath= f"./checkpoints/dec{loss}tt_{typ}_{num_classes}",
        save_weights_only=True,
        verbose = True,
        save_best_only=True),
        tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1,patience=5),
        tf.keras.callbacks.TerminateOnNaN()

        ]

        history = model.fit(
            gen_batch_train,
            epochs=50,
            steps_per_epoch=30,
            validation_data=gen_batch_val,
            validation_steps=10,
            shuffle=False,
            use_multiprocessing=True,
            callbacks=callbacks,
            workers=1
        )

        np.save(f'./history/dec{loss}tt_{typ}_{num_classes}.npy',np.array([history.history['loss'],history.history['val_loss']]))
# Out:
# Linfty
# num_classes:  5
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 1: val_loss improved from inf to 0.05044, saving model to ./checkpoints/decLinftytt_gaussian_5
# 30/30 [==============================] - 37s 1s/step - loss: 0.0825 - val_loss: 0.0504 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0486
# Epoch 2: val_loss improved from 0.05044 to 0.04488, saving model to ./checkpoints/decLinftytt_gaussian_5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0486 - val_loss: 0.0449 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 3: val_loss did not improve from 0.04488
# 30/30 [==============================] - 33s 1s/step - loss: 0.0451 - val_loss: 0.0489 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0464
# Epoch 4: val_loss improved from 0.04488 to 0.04407, saving model to ./checkpoints/decLinftytt_gaussian_5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0464 - val_loss: 0.0441 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 5: val_loss did not improve from 0.04407
# 30/30 [==============================] - 32s 1s/step - loss: 0.0441 - val_loss: 0.0460 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 6: val_loss did not improve from 0.04407
# 30/30 [==============================] - 32s 1s/step - loss: 0.0435 - val_loss: 0.0445 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0470
# Epoch 7: val_loss did not improve from 0.04407
# 30/30 [==============================] - 35s 1s/step - loss: 0.0470 - val_loss: 0.0456 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 8: val_loss did not improve from 0.04407
# 30/30 [==============================] - 32s 1s/step - loss: 0.0456 - val_loss: 0.0463 - lr: 0.0010
# Epoch 9/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 9: val_loss did not improve from 0.04407
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0446 - val_loss: 0.0569 - lr: 0.0010
# Epoch 10/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 10: val_loss did not improve from 0.04407
# 30/30 [==============================] - 32s 1s/step - loss: 0.0458 - val_loss: 0.0466 - lr: 2.0000e-04
# Epoch 11/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 11: val_loss improved from 0.04407 to 0.04045, saving model to ./checkpoints/decLinftytt_gaussian_5
# 30/30 [==============================] - 35s 1s/step - loss: 0.0447 - val_loss: 0.0404 - lr: 2.0000e-04
# Epoch 12/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 12: val_loss did not improve from 0.04045
# 30/30 [==============================] - 32s 1s/step - loss: 0.0456 - val_loss: 0.0423 - lr: 2.0000e-04
# Epoch 13/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 13: val_loss did not improve from 0.04045
# 30/30 [==============================] - 33s 1s/step - loss: 0.0451 - val_loss: 0.0425 - lr: 2.0000e-04
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0429
# Epoch 14: val_loss did not improve from 0.04045
# 30/30 [==============================] - 32s 1s/step - loss: 0.0429 - val_loss: 0.0431 - lr: 2.0000e-04
# Epoch 15/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 15: val_loss did not improve from 0.04045
# 30/30 [==============================] - 31s 1s/step - loss: 0.0446 - val_loss: 0.0445 - lr: 2.0000e-04
# Epoch 16/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 16: val_loss did not improve from 0.04045
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 30/30 [==============================] - 30s 1s/step - loss: 0.0462 - val_loss: 0.0415 - lr: 2.0000e-04
# Epoch 17/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0423
# Epoch 17: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 990ms/step - loss: 0.0423 - val_loss: 0.0433 - lr: 4.0000e-05
# Epoch 18/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 18: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 966ms/step - loss: 0.0437 - val_loss: 0.0421 - lr: 4.0000e-05
# Epoch 19/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 19: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 964ms/step - loss: 0.0447 - val_loss: 0.0442 - lr: 4.0000e-05
# Epoch 20/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 20: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 960ms/step - loss: 0.0435 - val_loss: 0.0445 - lr: 4.0000e-05
# Epoch 21/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 21: val_loss did not improve from 0.04045
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 30/30 [==============================] - 29s 962ms/step - loss: 0.0440 - val_loss: 0.0457 - lr: 4.0000e-05
# Epoch 22/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 22: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 960ms/step - loss: 0.0437 - val_loss: 0.0453 - lr: 8.0000e-06
# Epoch 23/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 23: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 965ms/step - loss: 0.0435 - val_loss: 0.0440 - lr: 8.0000e-06
# Epoch 24/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 24: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 960ms/step - loss: 0.0435 - val_loss: 0.0452 - lr: 8.0000e-06
# Epoch 25/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 25: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 959ms/step - loss: 0.0444 - val_loss: 0.0422 - lr: 8.0000e-06
# Epoch 26/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 26: val_loss did not improve from 0.04045
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 30/30 [==============================] - 29s 961ms/step - loss: 0.0440 - val_loss: 0.0427 - lr: 8.0000e-06
# Epoch 27/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0432
# Epoch 27: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 962ms/step - loss: 0.0432 - val_loss: 0.0423 - lr: 1.6000e-06
# Epoch 28/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0421
# Epoch 28: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 978ms/step - loss: 0.0421 - val_loss: 0.0411 - lr: 1.6000e-06
# Epoch 29/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 29: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 958ms/step - loss: 0.0439 - val_loss: 0.0413 - lr: 1.6000e-06
# Epoch 30/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 30: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0433 - val_loss: 0.0430 - lr: 1.6000e-06
# Epoch 31/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0420
# Epoch 31: val_loss did not improve from 0.04045
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0420 - val_loss: 0.0413 - lr: 1.6000e-06
# Epoch 32/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 32: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 958ms/step - loss: 0.0438 - val_loss: 0.0419 - lr: 3.2000e-07
# Epoch 33/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0429
# Epoch 33: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 955ms/step - loss: 0.0429 - val_loss: 0.0424 - lr: 3.2000e-07
# Epoch 34/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 34: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 956ms/step - loss: 0.0438 - val_loss: 0.0463 - lr: 3.2000e-07
# Epoch 35/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 35: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 956ms/step - loss: 0.0440 - val_loss: 0.0424 - lr: 3.2000e-07
# Epoch 36/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 36: val_loss did not improve from 0.04045
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 30/30 [==============================] - 29s 974ms/step - loss: 0.0428 - val_loss: 0.0452 - lr: 3.2000e-07
# Epoch 37/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 37: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 958ms/step - loss: 0.0436 - val_loss: 0.0415 - lr: 6.4000e-08
# Epoch 38/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 38: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 955ms/step - loss: 0.0435 - val_loss: 0.0408 - lr: 6.4000e-08
# Epoch 39/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 39: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 955ms/step - loss: 0.0433 - val_loss: 0.0437 - lr: 6.4000e-08
# Epoch 40/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0425
# Epoch 40: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 959ms/step - loss: 0.0425 - val_loss: 0.0433 - lr: 6.4000e-08
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 41: val_loss did not improve from 0.04045
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 30/30 [==============================] - 28s 956ms/step - loss: 0.0449 - val_loss: 0.0417 - lr: 6.4000e-08
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 42: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0438 - val_loss: 0.0436 - lr: 1.2800e-08
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 43: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0448 - val_loss: 0.0431 - lr: 1.2800e-08
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 44: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 959ms/step - loss: 0.0447 - val_loss: 0.0443 - lr: 1.2800e-08
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 45: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0449 - val_loss: 0.0454 - lr: 1.2800e-08
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 46: val_loss did not improve from 0.04045
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 30/30 [==============================] - 29s 959ms/step - loss: 0.0436 - val_loss: 0.0415 - lr: 1.2800e-08
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0423
# Epoch 47: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 954ms/step - loss: 0.0423 - val_loss: 0.0407 - lr: 2.5600e-09
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 48: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 956ms/step - loss: 0.0440 - val_loss: 0.0441 - lr: 2.5600e-09
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 49: val_loss did not improve from 0.04045
# 30/30 [==============================] - 29s 959ms/step - loss: 0.0428 - val_loss: 0.0420 - lr: 2.5600e-09
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0460
# Epoch 50: val_loss did not improve from 0.04045
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0460 - val_loss: 0.0429 - lr: 2.5600e-09
# num_classes:  10
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0708
# Epoch 1: val_loss improved from inf to 0.05176, saving model to ./checkpoints/decLinftytt_gaussian_10
# 30/30 [==============================] - 37s 1s/step - loss: 0.0708 - val_loss: 0.0518 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0534
# Epoch 2: val_loss improved from 0.05176 to 0.04551, saving model to ./checkpoints/decLinftytt_gaussian_10
# 30/30 [==============================] - 31s 1s/step - loss: 0.0534 - val_loss: 0.0455 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0509
# Epoch 3: val_loss did not improve from 0.04551
# 30/30 [==============================] - 31s 1s/step - loss: 0.0509 - val_loss: 0.0494 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0522
# Epoch 4: val_loss did not improve from 0.04551
# 30/30 [==============================] - 31s 1s/step - loss: 0.0522 - val_loss: 0.0493 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0496
# Epoch 5: val_loss did not improve from 0.04551
# 30/30 [==============================] - 31s 1s/step - loss: 0.0496 - val_loss: 0.0468 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 6: val_loss did not improve from 0.04551
# 30/30 [==============================] - 31s 1s/step - loss: 0.0491 - val_loss: 0.0488 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0500
# Epoch 7: val_loss did not improve from 0.04551
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0500 - val_loss: 0.0488 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 8: val_loss improved from 0.04551 to 0.04453, saving model to ./checkpoints/decLinftytt_gaussian_10
# 30/30 [==============================] - 31s 1s/step - loss: 0.0478 - val_loss: 0.0445 - lr: 2.0000e-04
# Epoch 9/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 9: val_loss did not improve from 0.04453
# 30/30 [==============================] - 31s 1s/step - loss: 0.0452 - val_loss: 0.0463 - lr: 2.0000e-04
# Epoch 10/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0472
# Epoch 10: val_loss improved from 0.04453 to 0.04124, saving model to ./checkpoints/decLinftytt_gaussian_10
# 30/30 [==============================] - 32s 1s/step - loss: 0.0472 - val_loss: 0.0412 - lr: 2.0000e-04
# Epoch 11/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 11: val_loss did not improve from 0.04124
# 30/30 [==============================] - 32s 1s/step - loss: 0.0462 - val_loss: 0.0439 - lr: 2.0000e-04
# Epoch 12/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 12: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0450 - val_loss: 0.0459 - lr: 2.0000e-04
# Epoch 13/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0476
# Epoch 13: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0476 - val_loss: 0.0465 - lr: 2.0000e-04
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 14: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0448 - val_loss: 0.0442 - lr: 2.0000e-04
# Epoch 15/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 15: val_loss did not improve from 0.04124
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0440 - val_loss: 0.0464 - lr: 2.0000e-04
# Epoch 16/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 16: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0448 - val_loss: 0.0456 - lr: 4.0000e-05
# Epoch 17/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0453
# Epoch 17: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0453 - val_loss: 0.0429 - lr: 4.0000e-05
# Epoch 18/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 18: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0438 - val_loss: 0.0461 - lr: 4.0000e-05
# Epoch 19/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0467
# Epoch 19: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0467 - val_loss: 0.0429 - lr: 4.0000e-05
# Epoch 20/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 20: val_loss did not improve from 0.04124
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0455 - val_loss: 0.0455 - lr: 4.0000e-05
# Epoch 21/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0474
# Epoch 21: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0474 - val_loss: 0.0457 - lr: 8.0000e-06
# Epoch 22/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 22: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0448 - val_loss: 0.0474 - lr: 8.0000e-06
# Epoch 23/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 23: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0442 - val_loss: 0.0436 - lr: 8.0000e-06
# Epoch 24/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 24: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0444 - val_loss: 0.0473 - lr: 8.0000e-06
# Epoch 25/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 25: val_loss did not improve from 0.04124
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0458 - val_loss: 0.0421 - lr: 8.0000e-06
# Epoch 26/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0431
# Epoch 26: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0431 - val_loss: 0.0429 - lr: 1.6000e-06
# Epoch 27/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 27: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0448 - val_loss: 0.0433 - lr: 1.6000e-06
# Epoch 28/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0454
# Epoch 28: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0454 - val_loss: 0.0429 - lr: 1.6000e-06
# Epoch 29/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 29: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0450 - val_loss: 0.0440 - lr: 1.6000e-06
# Epoch 30/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 30: val_loss did not improve from 0.04124
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0441 - val_loss: 0.0429 - lr: 1.6000e-06
# Epoch 31/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 31: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0450 - val_loss: 0.0444 - lr: 3.2000e-07
# Epoch 32/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 32: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0448 - val_loss: 0.0454 - lr: 3.2000e-07
# Epoch 33/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 33: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0449 - val_loss: 0.0438 - lr: 3.2000e-07
# Epoch 34/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 34: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0452 - val_loss: 0.0456 - lr: 3.2000e-07
# Epoch 35/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 35: val_loss did not improve from 0.04124
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0448 - val_loss: 0.0436 - lr: 3.2000e-07
# Epoch 36/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 36: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0455 - val_loss: 0.0444 - lr: 6.4000e-08
# Epoch 37/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 37: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0442 - val_loss: 0.0463 - lr: 6.4000e-08
# Epoch 38/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0443
# Epoch 38: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0443 - val_loss: 0.0419 - lr: 6.4000e-08
# Epoch 39/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0445
# Epoch 39: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0445 - val_loss: 0.0427 - lr: 6.4000e-08
# Epoch 40/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 40: val_loss did not improve from 0.04124
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 30/30 [==============================] - 31s 1s/step - loss: 0.0462 - val_loss: 0.0441 - lr: 6.4000e-08
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 41: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0451 - val_loss: 0.0421 - lr: 1.2800e-08
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 42: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0450 - val_loss: 0.0421 - lr: 1.2800e-08
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 43: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0455 - val_loss: 0.0455 - lr: 1.2800e-08
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 44: val_loss did not improve from 0.04124
# 30/30 [==============================] - 32s 1s/step - loss: 0.0451 - val_loss: 0.0444 - lr: 1.2800e-08
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0454
# Epoch 45: val_loss did not improve from 0.04124
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 30/30 [==============================] - 32s 1s/step - loss: 0.0454 - val_loss: 0.0428 - lr: 1.2800e-08
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 46: val_loss did not improve from 0.04124
# 30/30 [==============================] - 31s 1s/step - loss: 0.0436 - val_loss: 0.0446 - lr: 2.5600e-09
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 47: val_loss improved from 0.04124 to 0.04089, saving model to ./checkpoints/decLinftytt_gaussian_10
# 30/30 [==============================] - 31s 1s/step - loss: 0.0436 - val_loss: 0.0409 - lr: 2.5600e-09
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 48: val_loss did not improve from 0.04089
# 30/30 [==============================] - 31s 1s/step - loss: 0.0450 - val_loss: 0.0410 - lr: 2.5600e-09
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 49: val_loss did not improve from 0.04089
# 30/30 [==============================] - 31s 1s/step - loss: 0.0452 - val_loss: 0.0468 - lr: 2.5600e-09
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 50: val_loss did not improve from 0.04089
# 30/30 [==============================] - 31s 1s/step - loss: 0.0455 - val_loss: 0.0425 - lr: 2.5600e-09
# num_classes:  15
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0742
# Epoch 1: val_loss improved from inf to 0.05340, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 38s 1s/step - loss: 0.0742 - val_loss: 0.0534 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0495
# Epoch 2: val_loss improved from 0.05340 to 0.04937, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0495 - val_loss: 0.0494 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0484
# Epoch 3: val_loss improved from 0.04937 to 0.04452, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0484 - val_loss: 0.0445 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0459
# Epoch 4: val_loss did not improve from 0.04452
# 30/30 [==============================] - 34s 1s/step - loss: 0.0459 - val_loss: 0.0462 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 5: val_loss improved from 0.04452 to 0.04312, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0482 - val_loss: 0.0431 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 6: val_loss did not improve from 0.04312
# 30/30 [==============================] - 34s 1s/step - loss: 0.0449 - val_loss: 0.0511 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 7: val_loss improved from 0.04312 to 0.04264, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0473 - val_loss: 0.0426 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0471
# Epoch 8: val_loss did not improve from 0.04264
# 30/30 [==============================] - 34s 1s/step - loss: 0.0471 - val_loss: 0.0427 - lr: 0.0010
# Epoch 9/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0432
# Epoch 9: val_loss did not improve from 0.04264
# 30/30 [==============================] - 35s 1s/step - loss: 0.0432 - val_loss: 0.0472 - lr: 0.0010
# Epoch 10/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0457
# Epoch 10: val_loss did not improve from 0.04264
# 30/30 [==============================] - 35s 1s/step - loss: 0.0457 - val_loss: 0.0470 - lr: 0.0010
# Epoch 11/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 11: val_loss improved from 0.04264 to 0.04231, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0428 - val_loss: 0.0423 - lr: 0.0010
# Epoch 12/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 12: val_loss did not improve from 0.04231
# 30/30 [==============================] - 34s 1s/step - loss: 0.0456 - val_loss: 0.0433 - lr: 0.0010
# Epoch 13/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0469
# Epoch 13: val_loss did not improve from 0.04231
# 30/30 [==============================] - 34s 1s/step - loss: 0.0469 - val_loss: 0.0499 - lr: 0.0010
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 14: val_loss did not improve from 0.04231
# 30/30 [==============================] - 35s 1s/step - loss: 0.0450 - val_loss: 0.0443 - lr: 0.0010
# Epoch 15/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 15: val_loss did not improve from 0.04231
# 30/30 [==============================] - 34s 1s/step - loss: 0.0441 - val_loss: 0.0463 - lr: 0.0010
# Epoch 16/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 16: val_loss did not improve from 0.04231
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 30/30 [==============================] - 35s 1s/step - loss: 0.0449 - val_loss: 0.0427 - lr: 0.0010
# Epoch 17/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 17: val_loss improved from 0.04231 to 0.04163, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0446 - val_loss: 0.0416 - lr: 2.0000e-04
# Epoch 18/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 18: val_loss did not improve from 0.04163
# 30/30 [==============================] - 34s 1s/step - loss: 0.0441 - val_loss: 0.0423 - lr: 2.0000e-04
# Epoch 19/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 19: val_loss did not improve from 0.04163
# 30/30 [==============================] - 35s 1s/step - loss: 0.0441 - val_loss: 0.0440 - lr: 2.0000e-04
# Epoch 20/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0430
# Epoch 20: val_loss did not improve from 0.04163
# 30/30 [==============================] - 34s 1s/step - loss: 0.0430 - val_loss: 0.0465 - lr: 2.0000e-04
# Epoch 21/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 21: val_loss improved from 0.04163 to 0.03923, saving model to ./checkpoints/decLinftytt_gaussian_15
# 30/30 [==============================] - 35s 1s/step - loss: 0.0442 - val_loss: 0.0392 - lr: 2.0000e-04
# Epoch 22/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 22: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0435 - val_loss: 0.0409 - lr: 2.0000e-04
# Epoch 23/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 23: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0439 - val_loss: 0.0443 - lr: 2.0000e-04
# Epoch 24/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 24: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0437 - val_loss: 0.0428 - lr: 2.0000e-04
# Epoch 25/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 25: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0419 - val_loss: 0.0406 - lr: 2.0000e-04
# Epoch 26/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 26: val_loss did not improve from 0.03923
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 30/30 [==============================] - 35s 1s/step - loss: 0.0446 - val_loss: 0.0440 - lr: 2.0000e-04
# Epoch 27/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0427
# Epoch 27: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0427 - val_loss: 0.0423 - lr: 4.0000e-05
# Epoch 28/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0426
# Epoch 28: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0426 - val_loss: 0.0446 - lr: 4.0000e-05
# Epoch 29/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 29: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0444 - val_loss: 0.0407 - lr: 4.0000e-05
# Epoch 30/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0434
# Epoch 30: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0434 - val_loss: 0.0425 - lr: 4.0000e-05
# Epoch 31/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0425
# Epoch 31: val_loss did not improve from 0.03923
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 30/30 [==============================] - 34s 1s/step - loss: 0.0425 - val_loss: 0.0419 - lr: 4.0000e-05
# Epoch 32/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 32: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0447 - val_loss: 0.0411 - lr: 8.0000e-06
# Epoch 33/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 33: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0449 - val_loss: 0.0450 - lr: 8.0000e-06
# Epoch 34/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0430
# Epoch 34: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0430 - val_loss: 0.0425 - lr: 8.0000e-06
# Epoch 35/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 35: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0440 - val_loss: 0.0413 - lr: 8.0000e-06
# Epoch 36/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 36: val_loss did not improve from 0.03923
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 30/30 [==============================] - 34s 1s/step - loss: 0.0428 - val_loss: 0.0415 - lr: 8.0000e-06
# Epoch 37/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 37: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0455 - val_loss: 0.0431 - lr: 1.6000e-06
# Epoch 38/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 38: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0422 - val_loss: 0.0419 - lr: 1.6000e-06
# Epoch 39/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0426
# Epoch 39: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0426 - val_loss: 0.0431 - lr: 1.6000e-06
# Epoch 40/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0418
# Epoch 40: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0418 - val_loss: 0.0462 - lr: 1.6000e-06
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0434
# Epoch 41: val_loss did not improve from 0.03923
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 30/30 [==============================] - 35s 1s/step - loss: 0.0434 - val_loss: 0.0447 - lr: 1.6000e-06
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0423
# Epoch 42: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0423 - val_loss: 0.0449 - lr: 3.2000e-07
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 43: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0447 - val_loss: 0.0395 - lr: 3.2000e-07
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 44: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0440 - val_loss: 0.0411 - lr: 3.2000e-07
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 45: val_loss did not improve from 0.03923
# 30/30 [==============================] - 34s 1s/step - loss: 0.0433 - val_loss: 0.0425 - lr: 3.2000e-07
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 46: val_loss did not improve from 0.03923
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 30/30 [==============================] - 34s 1s/step - loss: 0.0435 - val_loss: 0.0420 - lr: 3.2000e-07
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0431
# Epoch 47: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0431 - val_loss: 0.0436 - lr: 6.4000e-08
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 48: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0428 - val_loss: 0.0452 - lr: 6.4000e-08
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0443
# Epoch 49: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0443 - val_loss: 0.0432 - lr: 6.4000e-08
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0424
# Epoch 50: val_loss did not improve from 0.03923
# 30/30 [==============================] - 35s 1s/step - loss: 0.0424 - val_loss: 0.0407 - lr: 6.4000e-08
# num_classes:  20
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 1: val_loss improved from inf to 0.06023, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 39s 1s/step - loss: 0.0665 - val_loss: 0.0602 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0571
# Epoch 2: val_loss improved from 0.06023 to 0.06003, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 36s 1s/step - loss: 0.0571 - val_loss: 0.0600 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0503
# Epoch 3: val_loss improved from 0.06003 to 0.04427, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 36s 1s/step - loss: 0.0503 - val_loss: 0.0443 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0486
# Epoch 4: val_loss did not improve from 0.04427
# 30/30 [==============================] - 36s 1s/step - loss: 0.0486 - val_loss: 0.0450 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0492
# Epoch 5: val_loss improved from 0.04427 to 0.04403, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 36s 1s/step - loss: 0.0492 - val_loss: 0.0440 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 6: val_loss improved from 0.04403 to 0.04348, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 36s 1s/step - loss: 0.0482 - val_loss: 0.0435 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0468
# Epoch 7: val_loss did not improve from 0.04348
# 30/30 [==============================] - 36s 1s/step - loss: 0.0468 - val_loss: 0.0482 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0464
# Epoch 8: val_loss did not improve from 0.04348
# 30/30 [==============================] - 36s 1s/step - loss: 0.0464 - val_loss: 0.0448 - lr: 0.0010
# Epoch 9/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 9: val_loss did not improve from 0.04348
# 30/30 [==============================] - 36s 1s/step - loss: 0.0446 - val_loss: 0.0458 - lr: 0.0010
# Epoch 10/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 10: val_loss did not improve from 0.04348
# 30/30 [==============================] - 36s 1s/step - loss: 0.0444 - val_loss: 0.0463 - lr: 0.0010
# Epoch 11/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0512
# Epoch 11: val_loss did not improve from 0.04348
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 30/30 [==============================] - 36s 1s/step - loss: 0.0512 - val_loss: 0.0443 - lr: 0.0010
# Epoch 12/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 12: val_loss improved from 0.04348 to 0.04344, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 36s 1s/step - loss: 0.0437 - val_loss: 0.0434 - lr: 2.0000e-04
# Epoch 13/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0432
# Epoch 13: val_loss improved from 0.04344 to 0.04064, saving model to ./checkpoints/decLinftytt_gaussian_20
# 30/30 [==============================] - 36s 1s/step - loss: 0.0432 - val_loss: 0.0406 - lr: 2.0000e-04
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 14: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0450 - val_loss: 0.0416 - lr: 2.0000e-04
# Epoch 15/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 15: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0422 - val_loss: 0.0414 - lr: 2.0000e-04
# Epoch 16/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 16: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0448 - val_loss: 0.0445 - lr: 2.0000e-04
# Epoch 17/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 17: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0436 - val_loss: 0.0464 - lr: 2.0000e-04
# Epoch 18/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0459
# Epoch 18: val_loss did not improve from 0.04064
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 30/30 [==============================] - 36s 1s/step - loss: 0.0459 - val_loss: 0.0437 - lr: 2.0000e-04
# Epoch 19/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 19: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0433 - val_loss: 0.0477 - lr: 4.0000e-05
# Epoch 20/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 20: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0437 - val_loss: 0.0442 - lr: 4.0000e-05
# Epoch 21/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 21: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0450 - val_loss: 0.0450 - lr: 4.0000e-05
# Epoch 22/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 22: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0449 - val_loss: 0.0445 - lr: 4.0000e-05
# Epoch 23/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0420
# Epoch 23: val_loss did not improve from 0.04064
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 30/30 [==============================] - 36s 1s/step - loss: 0.0420 - val_loss: 0.0425 - lr: 4.0000e-05
# Epoch 24/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 24: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0436 - val_loss: 0.0423 - lr: 8.0000e-06
# Epoch 25/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 25: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0428 - val_loss: 0.0422 - lr: 8.0000e-06
# Epoch 26/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0432
# Epoch 26: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0432 - val_loss: 0.0433 - lr: 8.0000e-06
# Epoch 27/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 27: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0436 - val_loss: 0.0430 - lr: 8.0000e-06
# Epoch 28/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0427
# Epoch 28: val_loss did not improve from 0.04064
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 30/30 [==============================] - 36s 1s/step - loss: 0.0427 - val_loss: 0.0418 - lr: 8.0000e-06
# Epoch 29/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 29: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0448 - val_loss: 0.0428 - lr: 1.6000e-06
# Epoch 30/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 30: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0442 - val_loss: 0.0421 - lr: 1.6000e-06
# Epoch 31/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 31: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0456 - val_loss: 0.0444 - lr: 1.6000e-06
# Epoch 32/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0445
# Epoch 32: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0445 - val_loss: 0.0425 - lr: 1.6000e-06
# Epoch 33/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0426
# Epoch 33: val_loss did not improve from 0.04064
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 30/30 [==============================] - 36s 1s/step - loss: 0.0426 - val_loss: 0.0455 - lr: 1.6000e-06
# Epoch 34/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 34: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0441 - val_loss: 0.0432 - lr: 3.2000e-07
# Epoch 35/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0430
# Epoch 35: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0430 - val_loss: 0.0432 - lr: 3.2000e-07
# Epoch 36/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 36: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0435 - val_loss: 0.0438 - lr: 3.2000e-07
# Epoch 37/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0416
# Epoch 37: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0416 - val_loss: 0.0458 - lr: 3.2000e-07
# Epoch 38/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0432
# Epoch 38: val_loss did not improve from 0.04064
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 30/30 [==============================] - 36s 1s/step - loss: 0.0432 - val_loss: 0.0458 - lr: 3.2000e-07
# Epoch 39/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0413
# Epoch 39: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0413 - val_loss: 0.0444 - lr: 6.4000e-08
# Epoch 40/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0410
# Epoch 40: val_loss did not improve from 0.04064
# 30/30 [==============================] - 45s 2s/step - loss: 0.0410 - val_loss: 0.0437 - lr: 6.4000e-08
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0440
# Epoch 41: val_loss did not improve from 0.04064
# 30/30 [==============================] - 36s 1s/step - loss: 0.0440 - val_loss: 0.0447 - lr: 6.4000e-08
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 42: val_loss did not improve from 0.04064
# 30/30 [==============================] - 38s 1s/step - loss: 0.0438 - val_loss: 0.0447 - lr: 6.4000e-08
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 43: val_loss did not improve from 0.04064
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 30/30 [==============================] - 37s 1s/step - loss: 0.0449 - val_loss: 0.0411 - lr: 6.4000e-08
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 44: val_loss did not improve from 0.04064
# 30/30 [==============================] - 37s 1s/step - loss: 0.0441 - val_loss: 0.0423 - lr: 1.2800e-08
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0423
# Epoch 45: val_loss did not improve from 0.04064
# ...
# Epoch 37: val_loss did not improve from -0.67402
# 30/30 [==============================] - 74s 2s/step - loss: -0.6420 - val_loss: -0.6218 - lr: 1.6000e-06
# Epoch 38/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6425
# Epoch 38: val_loss did not improve from -0.67402
# 30/30 [==============================] - 74s 2s/step - loss: -0.6425 - val_loss: -0.6652 - lr: 1.6000e-06
# Epoch 39/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6369
# Epoch 39: val_loss did not improve from -0.67402
# 30/30 [==============================] - 74s 2s/step - loss: -0.6369 - val_loss: -0.6490 - lr: 1.6000e-06
# Epoch 40/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6210
# Epoch 40: val_loss did not improve from -0.67402
# 30/30 [==============================] - 74s 2s/step - loss: -0.6210 - val_loss: -0.6271 - lr: 1.6000e-06
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6402
# Epoch 41: val_loss did not improve from -0.67402
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 30/30 [==============================] - 74s 2s/step - loss: -0.6402 - val_loss: -0.6449 - lr: 1.6000e-06
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6532
# Epoch 42: val_loss did not improve from -0.67402
# 30/30 [==============================] - 74s 2s/step - loss: -0.6532 - val_loss: -0.6216 - lr: 3.2000e-07
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6576
# Epoch 43: val_loss improved from -0.67402 to -0.67406, saving model to ./checkpoints/decprobabilitytt_gaussian_20
# 30/30 [==============================] - 74s 2s/step - loss: -0.6576 - val_loss: -0.6741 - lr: 3.2000e-07
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6575
# Epoch 44: val_loss did not improve from -0.67406
# 30/30 [==============================] - 74s 2s/step - loss: -0.6575 - val_loss: -0.6517 - lr: 3.2000e-07
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6472
# Epoch 45: val_loss did not improve from -0.67406
# 30/30 [==============================] - 74s 2s/step - loss: -0.6472 - val_loss: -0.6164 - lr: 3.2000e-07
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6382
# Epoch 46: val_loss improved from -0.67406 to -0.67512, saving model to ./checkpoints/decprobabilitytt_gaussian_20
# 30/30 [==============================] - 74s 2s/step - loss: -0.6382 - val_loss: -0.6751 - lr: 3.2000e-07
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6360
# Epoch 47: val_loss did not improve from -0.67512
# 30/30 [==============================] - 74s 2s/step - loss: -0.6360 - val_loss: -0.6523 - lr: 3.2000e-07
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6562
# Epoch 48: val_loss did not improve from -0.67512
# 30/30 [==============================] - 74s 2s/step - loss: -0.6562 - val_loss: -0.6344 - lr: 3.2000e-07
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6507
# Epoch 49: val_loss did not improve from -0.67512
# 30/30 [==============================] - 74s 2s/step - loss: -0.6507 - val_loss: -0.6585 - lr: 3.2000e-07
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6494
# Epoch 50: val_loss improved from -0.67512 to -0.68525, saving model to ./checkpoints/decprobabilitytt_gaussian_20
# 30/30 [==============================] - 74s 2s/step - loss: -0.6494 - val_loss: -0.6853 - lr: 3.2000e-07
# num_classes:  50
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: -0.4808
# Epoch 1: val_loss improved from inf to -0.54078, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 96s 3s/step - loss: -0.4808 - val_loss: -0.5408 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - ETA: 0s - loss: -0.5785
# Epoch 2: val_loss improved from -0.54078 to -0.57960, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 91s 3s/step - loss: -0.5785 - val_loss: -0.5796 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - ETA: 0s - loss: -0.5913
# Epoch 3: val_loss improved from -0.57960 to -0.63820, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 91s 3s/step - loss: -0.5913 - val_loss: -0.6382 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6168
# Epoch 4: val_loss did not improve from -0.63820
# 30/30 [==============================] - 92s 3s/step - loss: -0.6168 - val_loss: -0.6373 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6045
# Epoch 5: val_loss did not improve from -0.63820
# 30/30 [==============================] - 91s 3s/step - loss: -0.6045 - val_loss: -0.6146 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6109
# Epoch 6: val_loss did not improve from -0.63820
# 30/30 [==============================] - 91s 3s/step - loss: -0.6109 - val_loss: -0.6095 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - ETA: 0s - loss: -0.5751
# Epoch 7: val_loss did not improve from -0.63820
# 30/30 [==============================] - 91s 3s/step - loss: -0.5751 - val_loss: -0.5733 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - ETA: 0s - loss: -0.5898
# Epoch 8: val_loss did not improve from -0.63820
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 30/30 [==============================] - 91s 3s/step - loss: -0.5898 - val_loss: -0.6161 - lr: 0.0010
# Epoch 9/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6141
# Epoch 9: val_loss improved from -0.63820 to -0.64356, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 91s 3s/step - loss: -0.6141 - val_loss: -0.6436 - lr: 2.0000e-04
# Epoch 10/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6303
# Epoch 10: val_loss improved from -0.64356 to -0.67066, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 91s 3s/step - loss: -0.6303 - val_loss: -0.6707 - lr: 2.0000e-04
# Epoch 11/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6367
# Epoch 11: val_loss did not improve from -0.67066
# 30/30 [==============================] - 91s 3s/step - loss: -0.6367 - val_loss: -0.6375 - lr: 2.0000e-04
# Epoch 12/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6319
# Epoch 12: val_loss did not improve from -0.67066
# 30/30 [==============================] - 92s 3s/step - loss: -0.6319 - val_loss: -0.6163 - lr: 2.0000e-04
# Epoch 13/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6252
# Epoch 13: val_loss did not improve from -0.67066
# 30/30 [==============================] - 91s 3s/step - loss: -0.6252 - val_loss: -0.6492 - lr: 2.0000e-04
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6460
# Epoch 14: val_loss did not improve from -0.67066
# 30/30 [==============================] - 91s 3s/step - loss: -0.6460 - val_loss: -0.6202 - lr: 2.0000e-04
# Epoch 15/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6320
# Epoch 15: val_loss improved from -0.67066 to -0.67791, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 91s 3s/step - loss: -0.6320 - val_loss: -0.6779 - lr: 2.0000e-04
# Epoch 16/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6418
# Epoch 16: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6418 - val_loss: -0.6438 - lr: 2.0000e-04
# Epoch 17/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6447
# Epoch 17: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6447 - val_loss: -0.6574 - lr: 2.0000e-04
# Epoch 18/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6465
# Epoch 18: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6465 - val_loss: -0.6338 - lr: 2.0000e-04
# Epoch 19/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6229
# Epoch 19: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6229 - val_loss: -0.6474 - lr: 2.0000e-04
# Epoch 20/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6402
# Epoch 20: val_loss did not improve from -0.67791
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 30/30 [==============================] - 91s 3s/step - loss: -0.6402 - val_loss: -0.6449 - lr: 2.0000e-04
# Epoch 21/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6291
# Epoch 21: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6291 - val_loss: -0.6337 - lr: 4.0000e-05
# Epoch 22/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6441
# Epoch 22: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6441 - val_loss: -0.6477 - lr: 4.0000e-05
# Epoch 23/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6510
# Epoch 23: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6510 - val_loss: -0.6393 - lr: 4.0000e-05
# Epoch 24/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6525
# Epoch 24: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6525 - val_loss: -0.6474 - lr: 4.0000e-05
# Epoch 25/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6293
# Epoch 25: val_loss did not improve from -0.67791
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 30/30 [==============================] - 91s 3s/step - loss: -0.6293 - val_loss: -0.6643 - lr: 4.0000e-05
# Epoch 26/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6402
# Epoch 26: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6402 - val_loss: -0.6402 - lr: 8.0000e-06
# Epoch 27/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6467
# Epoch 27: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6467 - val_loss: -0.6333 - lr: 8.0000e-06
# Epoch 28/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6329
# Epoch 28: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6329 - val_loss: -0.6704 - lr: 8.0000e-06
# Epoch 29/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6458
# Epoch 29: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6458 - val_loss: -0.6352 - lr: 8.0000e-06
# Epoch 30/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6285
# Epoch 30: val_loss did not improve from -0.67791
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 30/30 [==============================] - 91s 3s/step - loss: -0.6285 - val_loss: -0.6136 - lr: 8.0000e-06
# Epoch 31/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6394
# Epoch 31: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6394 - val_loss: -0.6469 - lr: 1.6000e-06
# Epoch 32/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6250
# Epoch 32: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6250 - val_loss: -0.6451 - lr: 1.6000e-06
# Epoch 33/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6264
# Epoch 33: val_loss did not improve from -0.67791
# 30/30 [==============================] - 92s 3s/step - loss: -0.6264 - val_loss: -0.6580 - lr: 1.6000e-06
# Epoch 34/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6697
# Epoch 34: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6697 - val_loss: -0.6576 - lr: 1.6000e-06
# Epoch 35/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6403
# Epoch 35: val_loss did not improve from -0.67791
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 30/30 [==============================] - 91s 3s/step - loss: -0.6403 - val_loss: -0.6342 - lr: 1.6000e-06
# Epoch 36/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6430
# Epoch 36: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6430 - val_loss: -0.6260 - lr: 3.2000e-07
# Epoch 37/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6495
# Epoch 37: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6495 - val_loss: -0.6559 - lr: 3.2000e-07
# Epoch 38/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6551
# Epoch 38: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6551 - val_loss: -0.6364 - lr: 3.2000e-07
# Epoch 39/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6443
# Epoch 39: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6443 - val_loss: -0.6618 - lr: 3.2000e-07
# Epoch 40/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6348
# Epoch 40: val_loss did not improve from -0.67791
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 30/30 [==============================] - 91s 3s/step - loss: -0.6348 - val_loss: -0.6337 - lr: 3.2000e-07
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6374
# Epoch 41: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6374 - val_loss: -0.6490 - lr: 6.4000e-08
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6533
# Epoch 42: val_loss did not improve from -0.67791
# 30/30 [==============================] - 91s 3s/step - loss: -0.6533 - val_loss: -0.6176 - lr: 6.4000e-08
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6434
# Epoch 43: val_loss improved from -0.67791 to -0.68615, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 92s 3s/step - loss: -0.6434 - val_loss: -0.6861 - lr: 6.4000e-08
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6447
# Epoch 44: val_loss did not improve from -0.68615
# 30/30 [==============================] - 92s 3s/step - loss: -0.6447 - val_loss: -0.6533 - lr: 6.4000e-08
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6443
# Epoch 45: val_loss did not improve from -0.68615
# 30/30 [==============================] - 91s 3s/step - loss: -0.6443 - val_loss: -0.6187 - lr: 6.4000e-08
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6491
# Epoch 46: val_loss improved from -0.68615 to -0.68855, saving model to ./checkpoints/decprobabilitytt_gaussian_50
# 30/30 [==============================] - 92s 3s/step - loss: -0.6491 - val_loss: -0.6886 - lr: 6.4000e-08
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6211
# Epoch 47: val_loss did not improve from -0.68855
# 30/30 [==============================] - 91s 3s/step - loss: -0.6211 - val_loss: -0.6565 - lr: 6.4000e-08
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6263
# Epoch 48: val_loss did not improve from -0.68855
# 30/30 [==============================] - 95s 3s/step - loss: -0.6263 - val_loss: -0.6465 - lr: 6.4000e-08
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6398
# Epoch 49: val_loss did not improve from -0.68855
# 30/30 [==============================] - 98s 3s/step - loss: -0.6398 - val_loss: -0.6402 - lr: 6.4000e-08
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: -0.6433
# Epoch 50: val_loss did not improve from -0.68855
# 30/30 [==============================] - 97s 3s/step - loss: -0.6433 - val_loss: -0.6340 - lr: 6.4000e-08

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=5,var1_u=55,CROP1=CROP,BATCH_SIZE=10)

for loss in losses_names:
    print(loss)
    order = 1
    for num_classes in [5,10,15,20,50]:
        print('num_classes: ',num_classes)
        

        
        model = get_model("decreasing",it_lim=3,image_size=image_size,num_classes = num_classes,
                            with_embedding = False, boundary_detector=False)
        model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                loss=getattr(losses,loss))

        callbacks = [tf.keras.callbacks.ModelCheckpoint(
        filepath= f"./checkpoints/dec{loss}ff_{typ}_{num_classes}",
        save_weights_only=True,
        verbose = True,
        save_best_only=True),
        tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1,patience=5),
        tf.keras.callbacks.TerminateOnNaN()

        ]

        history = model.fit(
            gen_batch_train,
            epochs=50,
            steps_per_epoch=30,
            validation_data=gen_batch_val,
            validation_steps=10,
            shuffle=False,
            use_multiprocessing=True,
            callbacks=callbacks,
            workers=1
        )

        np.save(f'./history/dec{loss}ff_{typ}_{num_classes}.npy',np.array([history.history['loss'],history.history['val_loss']]))

# %%
trained = glob(f'./history/dec_*')
w = [int(i.split('_')[-1].split('.')[0]) for i in trained]
n = len(trained)+1
viridis = cm.get_cmap('viridis', 256)
colors = viridis(np.linspace(0, 1, np.amax(w)-np.amin(w)+1))
newcmp = ListedColormap(colors)
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols=2,figsize=(20,5))

for j,i in enumerate(trained):
    
    v = np.load(i)
    axs[0].plot(v[0],alpha=0.75,color = colors[w[j]-np.amin(w)])
    axs[1].plot(v[1],alpha=0.75,color = colors[w[j]-np.amin(w)])
    
axs[0].set_title("training loss with classifier")
axs[1].set_title("validation loss with classifier")

axs[0].set_xlabel('iteration')
axs[0].set_ylabel('loss')

axs[1].set_xlabel('iteration')
axs[1].set_ylabel('loss')
    
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[0],label='partition cardinality')
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[1],label='partition cardinality')
    
plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# # Results with first function

# %%
order = 1
num_classes = 50
model = get_model("decreasing",it_lim=3,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/decW1inftytt_{typ}_{num_classes}")

w = [10,20,50]
fig,axs = plt.subplots(ncols = 5,nrows = int(np.ceil(len(w))),figsize=(15,4*len(w)))
for i,m in enumerate(w):

    
    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=w[i],var1_u=w[i],CROP1=CROP,BATCH_SIZE=50)
    ims = next(gen_batch_val.as_numpy_iterator())
    p = np.clip(model(ims[0]),0,1)
    _ = np.random.choice(len(p))

    psnr_0 = tf.image.psnr(ims[0][_],ims[1][_],1).numpy()
    ssim_0 = tf.image.ssim(ims[0][_],ims[1][_],1).numpy()
    clean = p[_]
    psnr = tf.image.psnr(ims[1][_],clean,1).numpy()
    ssim = tf.image.ssim(ims[1][_],clean,1).numpy()
    clean = np.squeeze(clean)
    inputs = tf.keras.Input(shape=image_size + (1,))
    get_lambdas = tf.keras.models.Model(model.input,model.get_layer('coeff_spline').output)
    spline = np.squeeze(get_lambdas(ims[0])[_])
    visualization = tf.keras.models.Model(model.input,model.get_layer('gS_0').output)
    vis = np.squeeze(visualization(ims[0])[_])
    axx_layers = tf.keras.models.Model(model.input,model.get_layer('dx_0').output)
    axx = np.squeeze(axx_layers(ims[0])[_])


    psnr_0,ssim_0 = int(100*psnr_0)/100,int(100*ssim_0)/100
    psnr,ssim = int(100*psnr)/100,int(100*ssim)/100
    
    
    axs[i,0].imshow(ims[0][_],cmap='gray')
    axs[i,0].set_title(f'input\nvariance {int(100*m)/100}\nPSNR: {psnr_0}\nSSIM: {ssim_0}')
    axs[i,0].set_xticks([])
    axs[i,0].set_xticklabels([])
    axs[i,0].set_yticks([])
    axs[i,0].set_yticklabels([])
    axs[i,1].imshow(ims[1][_],cmap='gray')
    axs[i,1].set_title('target')
    axs[i,1].set_xticks([])
    axs[i,1].set_xticklabels([])
    axs[i,1].set_yticks([])
    axs[i,1].set_yticklabels([])
    axs[i,2].imshow(clean,cmap='gray')
    axs[i,2].set_title(f'result\nPSNR: {psnr}\nSSIM: {ssim}')
    axs[i,2].set_xticks([])
    axs[i,2].set_xticklabels([])
    axs[i,2].set_yticks([])
    axs[i,2].set_yticklabels([])
    im = axs[i,3].imshow(vis,cmap='gray')
    axs[i,3].set_title('coefficient function')
    plt.colorbar(im,ax=axs[i,3])
    axs[i,3].set_xticks([])
    axs[i,3].set_xticklabels([])
    axs[i,3].set_yticks([])
    axs[i,3].set_yticklabels([])
    
    x = np.ndarray.flatten(axx)
    s = np.ndarray.flatten(vis)
    
    
    axs[i,4].scatter(x,s)
    axs[i,4].set_xlabel("argument")
    axs[i,4].set_ylabel("coefficient value")
    axs[i,4].set_title(f"spline\npartition of {num_classes}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing against Perona Malik

# %%
#losses_names = ['Linfty','W1infty','H1','L2','probability']
losses_names = ['Linfty','W1infty']


order = 1
fig,axs = plt.subplots(ncols=2,nrows=5,figsize=(15,20))



for n,num_classes in enumerate([5,10,15,20,50]):
    
    models = []
    for loss in losses_names:
        model = get_model("decreasing",it_lim=3,image_size=image_size,num_classes = num_classes)
        model.load_weights(f"./checkpoints/dec{loss}tt_{typ}_{num_classes}")
        models.append(model)
    
    w = np.linspace(10,55,10)
    psnr_nn_1,psnr_nn_s_1 = [[] for l in losses_names],[[] for l in losses_names]
    ssim_nn_1,ssim_nn_s_1 = [[] for l in losses_names],[[] for l in losses_names]

    psnr_pm_1,psnr_pm_s_1 = [],[]
    ssim_pm_1,ssim_pm_s_1 = [],[]

    psnr_or_1,psnr_or_s_1 = [],[]
    ssim_or_1,ssim_or_s_1 = [],[]


    for i,m in enumerate(w):
        gen_batch_train,gen_batch_val = get_generators('gaussian',w[i],w[i],CROP1=CROP,BATCH_SIZE=100)
        ims = next(gen_batch_val.as_numpy_iterator())
        
        for l,loss in enumerate(losses_names):
            
        
            res = models[l](ims[0])
            psnr = tf.image.psnr(res,ims[1],1).numpy()
            ssim = tf.image.ssim(res,ims[1],1).numpy()
            psnr_nn_1[l].append(np.mean(psnr))
            psnr_nn_s_1[l].append(np.std(psnr))
            ssim_nn_1[l].append(np.mean(ssim))
            ssim_nn_s_1[l].append(np.std(ssim))
        
        
        pm = np.array([anisodiff(im,niter = 3,lambd=50) for im in ims[0]])
        pm = np.asarray(pm,dtype='float32')
        psnr = [tf.image.psnr(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        ssim = [tf.image.ssim(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        psnr_pm_1.append(np.mean(psnr))
        psnr_pm_s_1.append(np.std(psnr))
        ssim_pm_1.append(np.mean(ssim))
        ssim_pm_s_1.append(np.std(ssim))

        psnr = tf.image.psnr(ims[0],ims[1],1).numpy()
        ssim = tf.image.ssim(ims[0],ims[1],1).numpy()
        psnr_or_1.append(np.mean(psnr))
        psnr_or_s_1.append(np.std(psnr))
        ssim_or_1.append(np.mean(ssim))
        ssim_or_s_1.append(np.std(ssim))

    


    for l,loss in enumerate(losses_names):
        axs[n,0].errorbar(w,psnr_nn_1[l],psnr_nn_s_1[l],label=loss,alpha=0.5)

    axs[n,0].errorbar(w,psnr_pm_1,psnr_pm_s_1,label='pm\nfunction 1',alpha=0.5)
    axs[n,0].errorbar(w,psnr_or_1,psnr_or_s_1,label='noisy',alpha=0.5)


    axs[n,0].set_xlabel('variance of noise')
    axs[n,0].set_ylabel('psnr')
    axs[n,0].set_title(f'PSNR as function of variance in noise\nNumber of classes: {num_classes}')
    axs[n,0].legend()


    for l,loss in enumerate(losses_names):
        axs[n,1].errorbar(w,ssim_nn_1[l],ssim_nn_s_1[l],label=loss,alpha=0.5)
    
    axs[n,1].errorbar(w,ssim_pm_1,ssim_pm_s_1,label='pm\nfunction 1',alpha=0.5)
    axs[n,1].errorbar(w,ssim_or_1,ssim_or_s_1,label='noisy',alpha=0.5)


    axs[n,1].set_xlabel('variance of noise')
    axs[n,1].set_ylabel('ssim')
    axs[n,1].set_title(f'SSIM as function of variance in noise\nNumber of classes: {num_classes}')
    axs[n,1].legend()
    
plt.tight_layout()
plt.show()

# %%
order = 1
fig,axs = plt.subplots(ncols=2,nrows=5,figsize=(15,20))

for n,num_classes in enumerate([5,10,15,20,50]):
    
    
    model_H1 = get_model("decreasing",it_lim=3,image_size=image_size,num_classes=num_classes,order=order,
                          pre_smoothing=False,size=3)
    model_H1.load_weights(f"./checkpoints/decH1_{typ}_{num_classes}")
    
    model_L2 = get_model("decreasing",it_lim=3,image_size=image_size,num_classes=num_classes,order=order,
                          pre_smoothing=False,size=3)
    model_L2.load_weights(f"./checkpoints/decL2_{typ}_{num_classes}")
    
    model_Linfty = get_model("decreasing",it_lim=3,image_size=image_size,num_classes=num_classes,order=order,
                          pre_smoothing=False,size=3)
    model_Linfty.load_weights(f"./checkpoints/decLinfty_{typ}_{num_classes}")
    
    model_prob = get_model("decreasing",it_lim=3,image_size=image_size,num_classes=num_classes,order=order,
                          pre_smoothing=False,size=3)
    model_prob.load_weights(f"./checkpoints/decprobability_{typ}_{num_classes}")
    
    model_W1infty = get_model("decreasing",it_lim=3,image_size=image_size,num_classes=num_classes,order=order,
                          pre_smoothing=False,size=3)
    model_W1infty.load_weights(f"./checkpoints/decW1infty_{typ}_{num_classes}")
    
    

    w = np.linspace(10,55,10)
    psnr_Linfty_1,psnr_Linfty_s_1 = [],[]
    ssim_Linfty_1,ssim_Linfty_s_1 = [],[]
    
    psnr_H1_1,psnr_H1_s_1 = [],[]
    ssim_H1_1,ssim_H1_s_1 = [],[]
    
    psnr_L2_1,psnr_L2_s_1 = [],[]
    ssim_L2_1,ssim_L2_s_1 = [],[]
    
    psnr_prob_1,psnr_prob_s_1 = [],[]
    ssim_prob_1,ssim_prob_s_1 = [],[]
    
    psnr_W1infty_1,psnr_W1infty_s_1 = [],[]
    ssim_W1infty_1,ssim_W1infty_s_1 = [],[]
    
    psnr_pm_1,psnr_pm_s_1 = [],[]
    ssim_pm_1,ssim_pm_s_1 = [],[]

    psnr_or_1,psnr_or_s_1 = [],[]
    ssim_or_1,ssim_or_s_1 = [],[]
    

    for i,m in enumerate(w):
        gen_batch_train,gen_batch_val = get_generators('gaussian',w[i],w[i],CROP1=CROP,BATCH_SIZE=10)
        ims = next(gen_batch_val.as_numpy_iterator())
        
        
        res = model_Linfty(ims[0])
        res = np.asarray(res,dtype='float32')
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_Linfty_1.append(np.mean(psnr))
        psnr_Linfty_s_1.append(np.std(psnr))
        ssim_Linfty_1.append(np.mean(ssim))
        ssim_Linfty_s_1.append(np.std(ssim))
        
        res = model_H1(ims[0])
        res = np.asarray(res,dtype='float32')
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_H1_1.append(np.mean(psnr))
        psnr_H1_s_1.append(np.std(psnr))
        ssim_H1_1.append(np.mean(ssim))
        ssim_H1_s_1.append(np.std(ssim))
        
        res = model_L2(ims[0])
        res = np.asarray(res,dtype='float32')
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_L2_1.append(np.mean(psnr))
        psnr_L2_s_1.append(np.std(psnr))
        ssim_L2_1.append(np.mean(ssim))
        ssim_L2_s_1.append(np.std(ssim))
        
        
        res = model_prob(ims[0])
        res = np.asarray(res,dtype='float32')
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_prob_1.append(np.mean(psnr))
        psnr_prob_s_1.append(np.std(psnr))
        ssim_prob_1.append(np.mean(ssim))
        ssim_prob_s_1.append(np.std(ssim))
        
        res = model_W1infty(ims[0])
        res = np.asarray(res,dtype='float32')
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_W1infty_1.append(np.mean(psnr))
        psnr_W1infty_s_1.append(np.std(psnr))
        ssim_W1infty_1.append(np.mean(ssim))
        ssim_W1infty_s_1.append(np.std(ssim))
        
        
        pm = np.array([anisodiff(im,niter = 3,lambd=50) for im in ims[0]])
        pm = np.asarray(pm,dtype='float32')
        psnr = [tf.image.psnr(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        ssim = [tf.image.ssim(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        psnr_pm_1.append(np.mean(psnr))
        psnr_pm_s_1.append(np.std(psnr))
        ssim_pm_1.append(np.mean(ssim))
        ssim_pm_s_1.append(np.std(ssim))

        psnr = tf.image.psnr(ims[0],ims[1],1).numpy()
        ssim = tf.image.ssim(ims[0],ims[1],1).numpy()
        psnr_or_1.append(np.mean(psnr))
        psnr_or_s_1.append(np.std(psnr))
        ssim_or_1.append(np.mean(ssim))
        ssim_or_s_1.append(np.std(ssim))

    

    axs[n,0].errorbar(w,psnr_Linfty_1,psnr_Linfty_s_1,label='network\nL infty',alpha=0.5)
    axs[n,0].errorbar(w,psnr_L2_1,psnr_L2_s_1,label='network\nL 2',alpha=0.5)
    axs[n,0].errorbar(w,psnr_H1_1,psnr_H1_s_1,label='network\nH1',alpha=0.5)
    axs[n,0].errorbar(w,psnr_W1infty_1,psnr_W1infty_s_1,label='network\nW1infty',alpha=0.5)
    axs[n,0].errorbar(w,psnr_pm_1,psnr_pm_s_1,label='pm\nfunction 1',alpha=0.5)
    axs[n,0].errorbar(w,psnr_or_1,psnr_or_s_1,label='noisy',alpha=0.5)


    axs[n,0].set_xlabel('variance of noise')
    axs[n,0].set_ylabel('psnr')
    axs[n,0].set_title(f'PSNR as function of variance in noise\nNUmber of classes: {num_classes}')
    axs[n,0].legend()


    axs[n,1].errorbar(w,ssim_Linfty_1,ssim_Linfty_s_1,label='network\nL infty',alpha=0.5)
    axs[n,1].errorbar(w,ssim_L2_1,ssim_L2_s_1,label='network\nL 2',alpha=0.5)
    axs[n,1].errorbar(w,ssim_H1_1,ssim_H1_s_1,label='network\nH1',alpha=0.5)
    axs[n,1].errorbar(w,ssim_W1infty_1,ssim_W1infty_s_1,label='network\nW1infty',alpha=0.5)
    axs[n,1].errorbar(w,ssim_pm_1,ssim_pm_s_1,label='pm\nfunction 1',alpha=0.5)
    axs[n,1].errorbar(w,ssim_or_1,ssim_or_s_1,label='noisy',alpha=0.5)


    axs[n,1].set_xlabel('variance of noise')
    axs[n,1].set_ylabel('ssim')
    axs[n,1].set_title(f'SSIM as function of variance in noise\nNUmber of classes: {num_classes}')
    axs[n,1].legend()
    
plt.tight_layout()
plt.show()

# %%
num_classes = 50
model = get_model("decreasing",it_lim=1,image_size=image_size,num_classes = num_classes)
model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")

w = np.linspace(2,7,10)
psnr_nn_1,psnr_nn_s_1 = [],[]
ssim_nn_1,ssim_nn_s_1 = [],[]

psnr_pm_1,psnr_pm_s_1 = [],[]
ssim_pm_1,ssim_pm_s_1 = [],[]

psnr_or_1,psnr_or_s_1 = [],[]
ssim_or_1,ssim_or_s_1 = [],[]


for i,m in enumerate(w):
    gen_batch_train,gen_batch_val = get_generators(typ,0,w[i],CROP1=CROP,BATCH_SIZE=10)
    
    psnr_nn_1.append([])
    psnr_nn_s_1.append([])
    ssim_nn_1.append([])
    ssim_nn_s_1.append([])
    psnr_pm_1.append([])
    psnr_pm_s_1.append([])
    ssim_pm_1.append([])
    ssim_pm_s_1.append([])
    psnr_or_1.append([])
    psnr_or_s_1.append([])
    ssim_or_1.append([])
    ssim_or_s_1.append([])
    
    for it in range(10):
        ims = next(gen_batch_val.as_numpy_iterator())

        res = model(ims[0])
        psnr = tf.image.psnr(res,ims[1],1).numpy()
        ssim = tf.image.ssim(res,ims[1],1).numpy()
        psnr_nn_1[-1].append(np.copy(psnr))
        psnr_nn_s_1[-1].append(np.copy(psnr))
        ssim_nn_1[-1].append(np.copy(ssim))
        ssim_nn_s_1[-1].append(np.copy(ssim))

        pm = np.array([anisodiff(im,niter = 1) for im in ims[0]['input']])
        pm = np.asarray(pm,dtype='float32')
        psnr = [tf.image.psnr(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        ssim = [tf.image.ssim(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
        psnr_pm_1[-1].append(np.copy(psnr))
        psnr_pm_s_1[-1].append(np.copy(psnr))
        ssim_pm_1[-1].append(np.copy(ssim))
        ssim_pm_s_1[-1].append(np.copy(ssim))

        psnr = tf.image.psnr(ims[0]['input'],ims[1],1).numpy()
        ssim = tf.image.ssim(ims[0]['input'],ims[1],1).numpy()
        psnr_or_1[-1].append(np.copy(psnr))
        psnr_or_s_1[-1].append(np.copy(psnr))
        ssim_or_1[-1].append(np.copy(ssim))
        ssim_or_s_1[-1].append(np.copy(ssim))
        
    psnr_nn_1[-1] = np.concatenate(psnr_nn_1[-1])
    psnr_nn_s_1[-1] = np.concatenate(psnr_nn_s_1[-1])
    ssim_nn_1[-1] = np.concatenate(ssim_nn_1[-1])
    ssim_nn_s_1[-1] = np.concatenate(ssim_nn_s_1[-1])
    
    psnr_pm_1[-1] = np.concatenate(psnr_pm_1[-1])
    psnr_pm_s_1[-1] = np.concatenate(psnr_pm_s_1[-1])
    ssim_pm_1[-1] = np.concatenate(ssim_pm_1[-1])
    ssim_pm_s_1[-1] = np.concatenate(ssim_pm_s_1[-1])
    
    psnr_or_1[-1] = np.concatenate(psnr_or_1[-1])
    psnr_or_s_1[-1] = np.concatenate(psnr_or_s_1[-1])
    ssim_or_1[-1] = np.concatenate(ssim_or_1[-1])
    ssim_or_s_1[-1] = np.concatenate(ssim_or_s_1[-1])
    
    


psnr_nn_1 = np.mean(psnr_nn_1,axis=-1)
psnr_nn_s_1 = np.std(psnr_nn_s_1,axis=-1)
ssim_nn_1 = np.mean(ssim_nn_1,axis=-1)
ssim_nn_s_1 = np.std(ssim_nn_s_1,axis=-1)
psnr_pm_1 = np.mean(psnr_pm_1,axis=-1)
psnr_pm_s_1 = np.std(psnr_pm_s_1,axis=-1)
ssim_pm_1 = np.mean(ssim_pm_1,axis=-1)
ssim_pm_s_1 = np.std(ssim_pm_s_1,axis=-1)
psnr_or_1 = np.mean(psnr_or_1,axis=-1)
psnr_or_s_1 = np.std(psnr_or_s_1,axis=-1)
ssim_or_1 = np.mean(ssim_or_1,axis=-1)
ssim_or_s_1 = np.std(ssim_or_s_1,axis=-1)

plt.figure(figsize=(15,7))
plt.subplot(121)
plt.errorbar(w,psnr_nn_1,psnr_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,psnr_pm_1,psnr_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,psnr_or_1,psnr_or_s_1,label='noisy',alpha=0.5)


plt.xlabel('variance of noise')
plt.ylabel('psnr')
plt.title('PSNR as function of variance in noise')
plt.legend()

plt.subplot(122)
plt.errorbar(w,ssim_nn_1,ssim_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,ssim_pm_1,ssim_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,ssim_or_1,ssim_or_s_1,label='noisy',alpha=0.5)


plt.xlabel('variance of noise')
plt.ylabel('ssim')
plt.title('SSIM as function of variance in noise')
plt.legend()
plt.show()

# %%
order = 1
w = np.linspace(2,7,10)
w = np.asarray(100*w,dtype='int')/100
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/dec_{typ}_*.index")])


hist_psnr,hist_ssim = [],[]

for num_classes in ncl:

    psnr_nn_1,ssim_nn_1 = [],[]
    model = get_model("decreasing",it_lim=1,image_size=image_size,num_classes = num_classes,order=order)
    for i,m in enumerate(w):
        
        model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")
        gen_batch_train,gen_batch_val = get_generators(typ,0,w[i],CROP1=CROP,BATCH_SIZE=10)
        
        psnr_nn_1.append([])
        ssim_nn_1.append([])
        for it in range(10):
            ims = np.array(next(gen_batch_val.as_numpy_iterator()))

            res = model(ims[0])
            res = res/np.expand_dims(np.expand_dims(np.amax(res,axis=(1,2)),axis=-2),axis=-2)
            psnr = [tf.image.psnr(res[j],ims[1][j],1).numpy() for j in range(len(res))]
            ssim = [tf.image.ssim(res[j],ims[1][j],1).numpy() for j in range(len(res))]
            psnr_nn_1[-1].append(psnr)
            ssim_nn_1[-1].append(ssim)
            
        psnr_nn_1[-1] = np.mean(psnr_nn_1[-1])
        ssim_nn_1[-1] = np.mean(ssim_nn_1[-1])


    hist_psnr.append(np.copy(psnr_nn_1))
    hist_ssim.append(np.copy(ssim_nn_1))
    

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(hist_psnr)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('PSNR')
plt.colorbar(label='PSNR')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.subplot(122)
plt.imshow(hist_ssim)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('SSIM')
plt.colorbar(label='SSIM')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.show()
# Out:
# /tmp/ipykernel_7865/1301504080.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ims = np.array(next(gen_batch_val.as_numpy_iterator()))

# %% [markdown]
# # Analizing functions for coefficients

# %%
order = 1
w = np.linspace(2,10,20)
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/dec_{typ}_*.index")])
xR,R = [],[]

for num_classes in ncl:
    model = get_model("decreasing",it_lim=10,image_size=image_size,num_classes = num_classes)
    model.load_weights(f"./checkpoints/dec_{typ}_{num_classes}")
    get_lambdas = tf.keras.models.Model(model.input,model.get_layer('simple_extract').output)
    
    R.append([])
    xR.append([])
    for i,m in enumerate(w):


        gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=10)
        
        spline = []
        for it in range(10):
        
            ims = next(gen_batch_val.as_numpy_iterator())
            spline.append(np.squeeze(get_lambdas(ims[0])))
        
        spline = np.concatenate(spline,axis=0)
        spline = np.mean(spline,axis=0)

        partition = np.linspace(0,1,num_classes+1)
        x,s = [],[]


        for p in range(1,len(partition)):
            xp = np.linspace(partition[p-1],partition[p],100)
            linear = spline[p-1]*np.ones(len(xp))
            s.append(np.copy(linear))
            x.append(np.copy(xp))

        s = np.concatenate(s)
        x = np.concatenate(x)
    
    
        R[-1].append(np.copy(s))
        xR[-1].append(np.copy(x))

# %%
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols = 2,nrows = 3,figsize=(15,10))

for col in range(len(R)):
        
    if len(R[col]) == 0:
        continue

    viridis = cm.get_cmap('viridis', 256)
    colors = viridis(np.linspace(0, 1, len(R[col])))
    newcmp = ListedColormap(colors)

    for i in range(len(R[col])):

        #m,s = R[col][i].T

        #axs[col].errorbar(np.arange(len(m))/ncl[col],m,s,color=colors[i])
        axs[col//2,col%2].plot(xR[col][i],R[col][i],color=colors[i])

    axs[col//2,col%2].set_title(f"Mean function\nNum of intervals: {ncl[col]}")
    axs[col//2,col%2].set_xlabel("fraction of maximum gradient norm")
    axs[col//2,col%2].set_ylabel("function value")
    plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[col//2,col%2],label='noise variance')

plt.tight_layout()        
plt.show()

# %% [markdown]
# # Plot the model

# %%
model = get_model("decreasing",it_lim=1,image_size=image_size,num_classes = 5)

# %%
tf.keras.utils.plot_model(model,
    to_file="decresing.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=False,)
