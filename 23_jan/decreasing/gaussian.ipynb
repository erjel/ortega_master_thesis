# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import skimage.io as io
import skimage.filters as flt
from skimage.metrics import structural_similarity as SSIM
# %matplotlib inline
# since we can't use imports
import numpy as np
import scipy.ndimage.filters as flt
import warnings
import cv2
from glob import glob 

import pylab as pl
from time import sleep
import tensorflow as tf
from tqdm import tqdm
from collections import Counter
from matplotlib import cm
from matplotlib.colors import ListedColormap
import matplotlib as mpl


import sys
sys.path.append('../../scripts')
import open_frame
from pm_algorithm import anisodiff
from data_augmentation import get_generators
from architectures import get_model


CROP = 256
image_size = (CROP,CROP)
typ = "gaussian"
open_frame = getattr(open_frame,typ)


import logging
tf.get_logger().setLevel(logging.ERROR)

# %% [markdown]
# ## Data augmentation

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=1,var1_u=7,CROP1=CROP,BATCH_SIZE=50)

# %%
xs, ys = next(gen_batch_val.as_numpy_iterator())

# %%
nrows,ncols = 2,4
fig,axs = plt.subplots(nrows=nrows,ncols=ncols,figsize=(20,10))

for i in range(nrows):
    for j in range(ncols//2):
        _ = np.random.choice(len(xs['input']))
        axs[i,2*j].imshow(np.squeeze(xs['input'][_]),cmap='gray')
        axs[i,2*j+1].imshow(np.squeeze(ys[_]),cmap='gray')
        axs[i,2*j].set_title(str(np.mean(xs['input_emb'][_])))
        
plt.show()

# %% [markdown]
# # Neural networks

# %%
strategy = tf.distribute.MirroredStrategy()
#strategy = tf.distribute.OneDeviceStrategy('/device:GPU:0')

# %% [markdown]
# ## Training

# %%
def loss(y_true,y_pred):
    return 1/(tf.image.psnr(y_true,y_pred,1)) + 1/(tf.math.tan(np.pi*tf.image.ssim(y_true,y_pred,1)/2))

# %%
gen_batch_train,gen_batch_val = get_generators(typ,var1_d=1,var1_u=7,CROP1=CROP,BATCH_SIZE=50)

order = 1
for num_classes in [5,10,15,20,50]:
    print('num_classes: ',num_classes)
    model = get_model("decreasing",it_lim=1,image_size=image_size,num_classes = num_classes)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
            loss=loss,)
    #model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")
    
    callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath= f"./checkpoints/dec_{typ}_{num_classes}",
    save_weights_only=True,
    verbose = True,
    save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, verbose=1)
    ]
    
    history = model.fit(
        gen_batch_train,
        epochs=50,
        steps_per_epoch=10,
        validation_data=gen_batch_val,
        validation_steps=5,
        shuffle=False,
        use_multiprocessing=True,
        callbacks=callbacks,
        workers=1
    )
    
    np.save(f'./history/dec_{typ}_{num_classes}.npy',np.array([history.history['loss'],history.history['val_loss']]))
# Out:
# num_classes:  5
# Epoch 1/50
# 2023-01-27 19:39:31.946709: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-01-27 19:39:32.046010: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8302
# 10/10 [==============================] - ETA: 0s - loss: 2.8946
# Epoch 00001: val_loss improved from inf to 2.48199, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 16s 1s/step - loss: 2.8946 - val_loss: 2.4820 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 2.7975
# Epoch 00002: val_loss improved from 2.48199 to 2.37377, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 2.7975 - val_loss: 2.3738 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 2.5087
# Epoch 00003: val_loss did not improve from 2.37377
# 10/10 [==============================] - 12s 1s/step - loss: 2.5087 - val_loss: 2.6228 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss:
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.7058
# Epoch 00023: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.7058 - val_loss: 2.3573 - lr: 2.0000e-04
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6143
# Epoch 00024: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.6143 - val_loss: 2.3528 - lr: 2.0000e-04
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6805
# Epoch 00025: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.6805 - val_loss: 2.4551 - lr: 2.0000e-04
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6652
# Epoch 00026: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.6652 - val_loss: 2.3235 - lr: 2.0000e-04
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6215
# Epoch 00027: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.6215 - val_loss: 2.2748 - lr: 2.0000e-04
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6042
# Epoch 00028: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.6042 - val_loss: 2.2989 - lr: 2.0000e-04
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6237
# Epoch 00029: val_loss did not improve from 2.26475
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 10/10 [==============================] - 12s 1s/step - loss: 1.6237 - val_loss: 2.2864 - lr: 2.0000e-04
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6416
# Epoch 00030: val_loss did not improve from 2.26475
# 10/10 [==============================] - 12s 1s/step - loss: 1.6416 - val_loss: 2.3072 - lr: 4.0000e-05
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6587
# Epoch 00031: val_loss improved from 2.26475 to 2.07682, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.6587 - val_loss: 2.0768 - lr: 4.0000e-05
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6618
# Epoch 00032: val_loss did not improve from 2.07682
# 10/10 [==============================] - 12s 1s/step - loss: 1.6618 - val_loss: 2.2358 - lr: 4.0000e-05
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5783
# Epoch 00033: val_loss did not improve from 2.07682
# 10/10 [==============================] - 12s 1s/step - loss: 1.5783 - val_loss: 2.1098 - lr: 4.0000e-05
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6093
# Epoch 00034: val_loss did not improve from 2.07682
# 10/10 [==============================] - 12s 1s/step - loss: 1.6093 - val_loss: 2.1195 - lr: 4.0000e-05
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.7032
# Epoch 00035: val_loss improved from 2.07682 to 2.04263, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.7032 - val_loss: 2.0426 - lr: 4.0000e-05
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6324
# Epoch 00036: val_loss improved from 2.04263 to 1.92811, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.6324 - val_loss: 1.9281 - lr: 4.0000e-05
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5710
# Epoch 00037: val_loss improved from 1.92811 to 1.91562, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.5710 - val_loss: 1.9156 - lr: 4.0000e-05
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6136
# Epoch 00038: val_loss improved from 1.91562 to 1.89903, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.6136 - val_loss: 1.8990 - lr: 4.0000e-05
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6221
# Epoch 00039: val_loss improved from 1.89903 to 1.72135, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.6221 - val_loss: 1.7214 - lr: 4.0000e-05
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6355
# Epoch 00040: val_loss did not improve from 1.72135
# 10/10 [==============================] - 12s 1s/step - loss: 1.6355 - val_loss: 1.7523 - lr: 4.0000e-05
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6532
# Epoch 00041: val_loss improved from 1.72135 to 1.69734, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.6532 - val_loss: 1.6973 - lr: 4.0000e-05
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6902
# Epoch 00042: val_loss improved from 1.69734 to 1.61785, saving model to ./checkpoints/dec_gaussian_5
# 10/10 [==============================] - 12s 1s/step - loss: 1.6902 - val_loss: 1.6178 - lr: 4.0000e-05
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5768
# Epoch 00043: val_loss did not improve from 1.61785
# 10/10 [==============================] - 12s 1s/step - loss: 1.5768 - val_loss: 1.7185 - lr: 4.0000e-05
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5550
# Epoch 00039: val_loss improved from 1.68435 to 1.65608, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 13s 1s/step - loss: 1.5550 - val_loss: 1.6561 - lr: 2.0000e-04
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5390
# Epoch 00040: val_loss improved from 1.65608 to 1.60837, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.5390 - val_loss: 1.6084 - lr: 2.0000e-04
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5271
# Epoch 00041: val_loss did not improve from 1.60837
# 10/10 [==============================] - 12s 1s/step - loss: 1.5271 - val_loss: 1.6397 - lr: 2.0000e-04
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5235
# Epoch 00042: val_loss improved from 1.60837 to 1.56397, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.5235 - val_loss: 1.5640 - lr: 2.0000e-04
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5669
# Epoch 00043: val_loss improved from 1.56397 to 1.47686, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.5669 - val_loss: 1.4769 - lr: 2.0000e-04
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5059
# Epoch 00044: val_loss did not improve from 1.47686
# 10/10 [==============================] - 12s 1s/step - loss: 1.5059 - val_loss: 1.5077 - lr: 2.0000e-04
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5138
# Epoch 00045: val_loss improved from 1.47686 to 1.43193, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.5138 - val_loss: 1.4319 - lr: 2.0000e-04
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4480
# Epoch 00046: val_loss did not improve from 1.43193
# 10/10 [==============================] - 12s 1s/step - loss: 1.4480 - val_loss: 1.4683 - lr: 2.0000e-04
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5058
# Epoch 00047: val_loss improved from 1.43193 to 1.37943, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.5058 - val_loss: 1.3794 - lr: 2.0000e-04
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4732
# Epoch 00048: val_loss did not improve from 1.37943
# 10/10 [==============================] - 12s 1s/step - loss: 1.4732 - val_loss: 1.4301 - lr: 2.0000e-04
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4172
# Epoch 00049: val_loss improved from 1.37943 to 1.35393, saving model to ./checkpoints/dec_gaussian_10
# 10/10 [==============================] - 12s 1s/step - loss: 1.4172 - val_loss: 1.3539 - lr: 2.0000e-04
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4703
# Epoch 00050: val_loss did not improve from 1.35393
# 10/10 [==============================] - 12s 1s/step - loss: 1.4703 - val_loss: 1.3976 - lr: 2.0000e-04
# num_classes:  15
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 2.3199
# Epoch 00001: val_loss improved from inf to 2.47063, saving model to ./checkpoints/dec_gaussian_15
# 10/10 [==============================] - 15s 1s/step - loss: 2.3199 - val_loss: 2.4706 - lr: 0.0010
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 1.7633
# Epoch 00002: val_loss improved from 2.47063 to 2.46213, saving model to ./checkpoints/dec_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.7633 - val_loss: 2.4621 - lr: 0.0010
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6955
# Epoch 00003: val_loss did not improve from 2.46213
# 10/10 [==============================] - 13s 1s/step - loss: 1.6955 - val_loss: 2.5318 - lr: 0.0010
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6122
# Epoch 00004: val_loss did not improve from 2.46213
# 10/10 [==============================] - 12s 1s/step - loss: 1.6122 - val_loss: 2.4953 - lr: 0.0010
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6185
# Epoch 00005: val_loss improved from 2.46213 to 2.39299, saving model to ./checkpoints/dec_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.6185 - val_loss: 2.3930 - lr: 0.0010
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4284
# Epoch 00006: val_loss improved from 2.39299 to 2.36604, saving model to ./checkpoints/dec_gaussian_15
# 10/10 [==============================] - 13s 1s/step - loss: 1.4284 - val_loss: 2.3660 - lr: 0.0010
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3904
# Epoch 00007: val_loss did not improve from 2.36604
# 10/10 [==============================] - 12s 1s/step - loss: 1.3904 - val_loss: 2.4476 - lr: 0.0010
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4010
# Epoch 00008: val_loss did not improve from 2.36604
# 10/10 [==============================] - 12s 1s/step - loss: 1.4010 - val_loss: 2.4959 - lr: 0.0010
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 1.4111
# Epoch 00009: val_loss did not improve from 2.36604
# 10/10 [==============================] - 12s 1s/step - loss: 1.4111 - val_loss: 2.4177 - lr: 0.0010
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 1.
saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2407 - val_loss: 1.6709 - lr: 0.0010
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2755
# Epoch 00020: val_loss improved from 1.67093 to 1.46657, saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 13s 1s/step - loss: 1.2755 - val_loss: 1.4666 - lr: 0.0010
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2754
# Epoch 00021: val_loss improved from 1.46657 to 1.44288, saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 13s 1s/step - loss: 1.2754 - val_loss: 1.4429 - lr: 0.0010
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2581
# Epoch 00022: val_loss improved from 1.44288 to 1.32967, saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2581 - val_loss: 1.3297 - lr: 0.0010
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2535
# Epoch 00023: val_loss improved from 1.32967 to 1.26017, saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2535 - val_loss: 1.2602 - lr: 0.0010
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2785
# Epoch 00024: val_loss improved from 1.26017 to 1.17354, saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2785 - val_loss: 1.1735 - lr: 0.0010
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2760
# Epoch 00025: val_loss did not improve from 1.17354
# 10/10 [==============================] - 13s 1s/step - loss: 1.2760 - val_loss: 1.1795 - lr: 0.0010
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2539
# Epoch 00026: val_loss improved from 1.17354 to 1.17167, saving model to ./checkpoints/dec_gaussian_50
# 10/10 [==============================] - 14s 1s/step - loss: 1.2539 - val_loss: 1.1717 - lr: 0.0010
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2051
# Epoch 00027: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2051 - val_loss: 1.1881 - lr: 0.0010
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2121
# Epoch 00028: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2121 - val_loss: 1.2448 - lr: 0.0010
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2196
# Epoch 00029: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2196 - val_loss: 1.4691 - lr: 0.0010
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2421
# Epoch 00030: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2421 - val_loss: 1.4195 - lr: 0.0010
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2470
# Epoch 00031: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2470 - val_loss: 1.8460 - lr: 0.0010
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2309
# Epoch 00032: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2309 - val_loss: 1.6491 - lr: 0.0010
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2466
# Epoch 00033: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2466 - val_loss: 1.8934 - lr: 0.0010
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1772
# Epoch 00034: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.1772 - val_loss: 1.8133 - lr: 0.0010
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2652
# Epoch 00035: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2652 - val_loss: 1.7902 - lr: 0.0010
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1928
# Epoch 00036: val_loss did not improve from 1.17167
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 10/10 [==============================] - 13s 1s/step - loss: 1.1928 - val_loss: 2.0911 - lr: 0.0010
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1989
# Epoch 00037: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.1989 - val_loss: 2.1092 - lr: 2.0000e-04
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2142
# Epoch 00038: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2142 - val_loss: 2.0759 - lr: 2.0000e-04
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2318
# Epoch 00039: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2318 - val_loss: 2.3718 - lr: 2.0000e-04
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1847
# Epoch 00040: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.1847 - val_loss: 2.1370 - lr: 2.0000e-04
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2632
# Epoch 00041: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2632 - val_loss: 2.2481 - lr: 2.0000e-04
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2424
# Epoch 00042: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2424 - val_loss: 2.2934 - lr: 2.0000e-04
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2463
# Epoch 00043: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2463 - val_loss: 2.2005 - lr: 2.0000e-04
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1896
# Epoch 00044: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.1896 - val_loss: 2.3084 - lr: 2.0000e-04
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2382
# Epoch 00045: val_loss did not improve from 1.17167
# 10/10 [==============================] - 14s 1s/step - loss: 1.2382 - val_loss: 2.0183 - lr: 2.0000e-04
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2556
# Epoch 00046: val_loss did not improve from 1.17167
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 10/10 [==============================] - 13s 1s/step - loss: 1.2556 - val_loss: 2.0990 - lr: 2.0000e-04
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2468
# Epoch 00047: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2468 - val_loss: 1.9121 - lr: 4.0000e-05
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2359
# Epoch 00048: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2359 - val_loss: 1.9464 - lr: 4.0000e-05
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2615
# Epoch 00049: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2615 - val_loss: 1.8541 - lr: 4.0000e-05
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 1.2004
# Epoch 00050: val_loss did not improve from 1.17167
# 10/10 [==============================] - 13s 1s/step - loss: 1.2004 - val_loss: 1.8941 - lr: 4.0000e-05

# %%
trained = glob(f'./history/dec_*')
w = [int(i.split('_')[-1].split('.')[0]) for i in trained]
n = len(trained)+1
viridis = cm.get_cmap('viridis', 256)
colors = viridis(np.linspace(0, 1, np.amax(w)-np.amin(w)+1))
newcmp = ListedColormap(colors)
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols=2,figsize=(20,5))

for j,i in enumerate(trained):
    
    v = np.load(i)
    axs[0].plot(v[0],alpha=0.75,color = colors[w[j]-np.amin(w)])
    axs[1].plot(v[1],alpha=0.75,color = colors[w[j]-np.amin(w)])
    
axs[0].set_title("training loss with classifier")
axs[1].set_title("validation loss with classifier")
    
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[0],label='partition cardinality')
plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[1],label='partition cardinality')
    
plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# # Results with first function

# %%
order = 1
num_classes = 20
model = get_model("splines",it_lim=10,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")

w = np.linspace(5,10,4)
fig,axs = plt.subplots(ncols = 5,nrows = int(np.ceil(len(w))),figsize=(15,4*len(w)))
for i,m in enumerate(w):

    
    gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=5)
    ims = next(gen_batch_val.as_numpy_iterator())
    p = model(ims[0])
    _ = np.random.choice(len(p))


    psnr_0 = tf.image.psnr(ims[0]['input'][_],ims[1][_],1).numpy()
    ssim_0 = tf.image.ssim(ims[0]['input'][_],ims[1][_],1).numpy()
    clean = p[_]
    psnr = tf.image.psnr(ims[1][_],clean,1).numpy()
    ssim = tf.image.ssim(ims[1][_],clean,1).numpy()
    clean = np.squeeze(clean)
    inputs = tf.keras.Input(shape=image_size + (1,))
    get_lambdas = tf.keras.models.Model(model.input,model.get_layer('coeff_spline_0').output)
    spline = np.squeeze(get_lambdas(ims[0])[_])
    visualization = tf.keras.models.Model(model.input,model.get_layer('coeff_x_0').output)
    vis = np.squeeze(visualization(ims[0])[_])


    psnr_0,ssim_0 = int(100*psnr_0)/100,int(100*ssim_0)/100
    psnr,ssim = int(100*psnr)/100,int(100*ssim)/100
    
    
    axs[i,0].imshow(ims[0]['input'][_],cmap='gray')
    axs[i,0].set_title(f'input\nvariance {int(100*m)/100}\nPSNR: {psnr_0}\nSSIM: {ssim_0}')
    axs[i,0].set_xticks([])
    axs[i,0].set_xticklabels([])
    axs[i,0].set_yticks([])
    axs[i,0].set_yticklabels([])
    axs[i,1].imshow(ims[1][_],cmap='gray')
    axs[i,1].set_title('target')
    axs[i,1].set_xticks([])
    axs[i,1].set_xticklabels([])
    axs[i,1].set_yticks([])
    axs[i,1].set_yticklabels([])
    axs[i,2].imshow(clean,cmap='gray')
    axs[i,2].set_title(f'result\nPSNR: {psnr}\nSSIM: {ssim}')
    axs[i,2].set_xticks([])
    axs[i,2].set_xticklabels([])
    axs[i,2].set_yticks([])
    axs[i,2].set_yticklabels([])
    im = axs[i,3].imshow(vis,cmap='gray')
    axs[i,3].set_title('coefficient function')
    plt.colorbar(im,ax=axs[i,3])
    axs[i,3].set_xticks([])
    axs[i,3].set_xticklabels([])
    axs[i,3].set_yticks([])
    axs[i,3].set_yticklabels([])
    
    partition = np.linspace(0,1,num_classes+1)
    x,s = [],[]


    for p in range(1,len(partition)):
        xp = np.linspace(partition[p-1],partition[p],100)
        linear = spline[p-1][0]*xp + spline[p-1][1]
        s.append(np.copy(linear))
        x.append(np.copy(xp))

    s = np.concatenate(s)
    x = np.concatenate(x)
    
    
    axs[i,4].scatter(x,s)
    axs[i,4].set_xlabel("argument")
    axs[i,4].set_ylabel("coefficient value")
    axs[i,4].set_title(f"spline\npartition of {num_classes}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing against Perona Malik

# %%
order = 1
num_classes = 50
model = get_model("splines",it_lim=1,image_size=image_size,num_classes = num_classes,order=order)
model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")

w = np.linspace(2,7,10)
psnr_nn_1,psnr_nn_s_1 = [],[]
ssim_nn_1,ssim_nn_s_1 = [],[]

psnr_pm_1,psnr_pm_s_1 = [],[]
ssim_pm_1,ssim_pm_s_1 = [],[]

psnr_or_1,psnr_or_s_1 = [],[]
ssim_or_1,ssim_or_s_1 = [],[]


for i,m in enumerate(w):
    gen_batch_train,gen_batch_val = get_generators('gaussian',0,w[i],CROP1=CROP,BATCH_SIZE=100)
    ims = next(gen_batch_val.as_numpy_iterator())
    
    res = model(ims[0])
    #res = res/np.expand_dims(np.expand_dims(np.amax(res,axis=(1,2)),axis=-2),axis=-2)
    psnr = tf.image.psnr(res,ims[1],1).numpy()
    ssim = tf.image.ssim(res,ims[1],1).numpy()
    #psnr = [tf.image.psnr(res[j],ims[1][j],1).numpy() for j in range(len(res))]
    #ssim = [tf.image.ssim(res[j],ims[1][j],1).numpy() for j in range(len(res))]
    psnr_nn_1.append(np.mean(psnr))
    psnr_nn_s_1.append(np.std(psnr))
    ssim_nn_1.append(np.mean(ssim))
    ssim_nn_s_1.append(np.std(ssim))
    
    pm = np.array([anisodiff(im,niter = 1) for im in ims[0]['input']])
    pm = np.asarray(pm,dtype='float32')
    psnr = [tf.image.psnr(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
    ssim = [tf.image.ssim(pm[j],ims[1][j],1).numpy() for j in range(len(res))]
    psnr_pm_1.append(np.mean(psnr))
    psnr_pm_s_1.append(np.std(psnr))
    ssim_pm_1.append(np.mean(ssim))
    ssim_pm_s_1.append(np.std(ssim))
    
    psnr = tf.image.psnr(ims[0]['input'],ims[1],1).numpy()
    ssim = tf.image.ssim(ims[0]['input'],ims[1],1).numpy()
    psnr_or_1.append(np.mean(psnr))
    psnr_or_s_1.append(np.std(psnr))
    ssim_or_1.append(np.mean(ssim))
    ssim_or_s_1.append(np.std(ssim))
    
    

plt.figure(figsize=(15,7))
plt.subplot(121)
plt.errorbar(w,psnr_nn_1,psnr_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,psnr_pm_1,psnr_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,psnr_or_1,psnr_or_s_1,label='noisy',alpha=0.5)

#plt.errorbar(w,psnr_nn_2,psnr_nn_s_2,label='network\nfunction 2',alpha=0.5)
#plt.errorbar(w,psnr_pm_2,psnr_pm_s_2,label='pm\nfunction 2',alpha=0.5)
plt.xlabel('variance of noise')
plt.ylabel('psnr')
plt.title('PSNR as function of variance in noise')
plt.legend()

plt.subplot(122)
plt.errorbar(w,ssim_nn_1,ssim_nn_s_1,label='network',alpha=0.5)
plt.errorbar(w,ssim_pm_1,ssim_pm_s_1,label='pm\nfunction 1',alpha=0.5)
plt.errorbar(w,ssim_or_1,ssim_or_s_1,label='noisy',alpha=0.5)


plt.xlabel('variance of noise')
plt.ylabel('ssim')
plt.title('SSIM as function of variance in noise')
plt.legend()
plt.show()

# %%
order = 1
w = np.linspace(2,7,10)
w = np.asarray(100*w,dtype='int')/100
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/splines_{typ}_*.index")])


hist_psnr,hist_ssim = [],[]

for num_classes in ncl:

    psnr_nn_1,ssim_nn_1 = [],[]
    model = get_model("splines",it_lim=1,image_size=image_size,num_classes = num_classes,order=order)
    for i,m in enumerate(w):
        
        model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")
        gen_batch_train,gen_batch_val = get_generators(typ,0,w[i],CROP1=CROP,BATCH_SIZE=100)
        ims = np.array(next(gen_batch_val.as_numpy_iterator()))

        res = model(ims[0])
        res = res/np.expand_dims(np.expand_dims(np.amax(res,axis=(1,2)),axis=-2),axis=-2)
        psnr = [tf.image.psnr(res[j],ims[1][j],1).numpy() for j in range(len(res))]
        ssim = [tf.image.ssim(res[j],ims[1][j],1).numpy() for j in range(len(res))]
        psnr_nn_1.append(np.mean(psnr))
        ssim_nn_1.append(np.mean(ssim))


    hist_psnr.append(np.copy(psnr_nn_1))
    hist_ssim.append(np.copy(ssim_nn_1))
    

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.imshow(hist_psnr)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('PSNR')
plt.colorbar(label='PSNR')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.subplot(122)
plt.imshow(hist_ssim)
plt.xlabel('noise variance')
plt.ylabel('number of partitions')
plt.title('SSIM')
plt.colorbar(label='SSIM')
plt.xticks(np.arange(len(w)),w)
plt.yticks(np.arange(len(ncl)),ncl)
plt.show()

# %% [markdown]
# # Analizing functions for coefficients

# %%
order = 1
w = np.linspace(2,10,20)
ncl = np.sort([int(i.split('_')[-1].split('.')[0]) for i in glob(f"./checkpoints/splines_{typ}_*.index")])
xR,R = [],[]

for num_classes in ncl:
    model = get_model("splines",it_lim=10,image_size=image_size,num_classes = num_classes,order=order)
    model.load_weights(f"./checkpoints/splines_{typ}_{num_classes}")
    R.append([])
    xR.append([])
    for i,m in enumerate(w):


        gen_batch_train,gen_batch_val = get_generators(typ,var1_d=0,var1_u=w[i],CROP1=CROP,BATCH_SIZE=100)
        ims = next(gen_batch_val.as_numpy_iterator())
        p = model(ims[0])
        _ = np.random.choice(len(p))


        psnr_0 = tf.image.psnr(ims[0]['input'][_],ims[1][_],1).numpy()
        ssim_0 = tf.image.ssim(ims[0]['input'][_],ims[1][_],1).numpy()
        clean = p[_]
        psnr = tf.image.psnr(ims[1][_],clean,1).numpy()
        ssim = tf.image.ssim(ims[1][_],clean,1).numpy()
        clean = np.squeeze(clean)
        inputs = tf.keras.Input(shape=image_size + (1,))
        get_lambdas = tf.keras.models.Model(model.input,model.get_layer('coeff_spline_0').output)
        spline = np.squeeze(get_lambdas(ims[0]))
        spline = np.mean(spline,axis=0)

        partition = np.linspace(0,1,num_classes+1)
        x,s = [],[]


        for p in range(1,len(partition)):
            xp = np.linspace(partition[p-1],partition[p],100)
            linear = spline[p-1][0]*xp + spline[p-1][1]
            s.append(np.copy(linear))
            x.append(np.copy(xp))

        s = np.concatenate(s)
        x = np.concatenate(x)
    
    
        R[-1].append(np.copy(s))
        xR[-1].append(np.copy(x))

# %%
norm = mpl.colors.Normalize(vmin=np.amin(w), vmax=np.amax(w))

fig,axs = plt.subplots(ncols = 2,nrows = 3,figsize=(15,10))

for col in range(len(R)):
        
    if len(R[col]) == 0:
        continue

    viridis = cm.get_cmap('viridis', 256)
    colors = viridis(np.linspace(0, 1, len(R[col])))
    newcmp = ListedColormap(colors)

    for i in range(len(R[col])):

        #m,s = R[col][i].T

        #axs[col].errorbar(np.arange(len(m))/ncl[col],m,s,color=colors[i])
        axs[col//2,col%2].plot(xR[col][i],R[col][i],color=colors[i])

    axs[col//2,col%2].set_title(f"Mean function\nOrder: {1}\nNum of intervals: {ncl[col]}")
    axs[col//2,col%2].set_xlabel("fraction of maximum gradient norm")
    axs[col//2,col%2].set_ylabel("function value")
    plt.colorbar(cm.ScalarMappable(norm=norm, cmap=newcmp),ax=axs[col//2,col%2],label='noise variance')

plt.tight_layout()        
plt.show()
